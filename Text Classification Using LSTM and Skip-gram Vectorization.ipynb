# %% [markdown]
# Pada pertemuan sebelumnya kita sudah mempelajari text classification dengan menggunakan LSTM dan text vectorization skipgram dengan menggunakan data emotion classification.
#
#
# Pada forum kali ini anda diberikan data dengan 20 label, lakukan klasifikasi menggunakan LSTM dan text vectorization skipgram.
# Anda bebas melakukan tuning hyperparameter termasuk arsitektur LSTM.

# %%
import pandas as pd
import numpy as np

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import dataset
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Text Mining/GSLC 2/train_data.csv')

# %%
df.head()
# Out:
#                                                 text  label
# 0  Here are Thursday's biggest analyst calls: App...      0
# 1  Buy Las Vegas Sands as travel to Singapore bui...      0
# 2  Piper Sandler downgrades DocuSign to sell, cit...      0
# 3  Analysts react to Tesla's latest earnings, bre...      0
# 4  Netflix and its peers are set for a ‘return to...      0

# %%
print(df.iloc[0][0])
# Out:
# Here are Thursday's biggest analyst calls: Apple, Amazon, Tesla, Palantir, DocuSign, Exxon &amp; more  https://t.co/QPN8Gwl7Uh

# %%
df.shape
# Out:
# (16990, 2)

# %%
# check apakah semua kolom terisi
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16990 entries, 0 to 16989
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    16990 non-null  object
#  1   label   16990 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 265.6+ KB

# %%
# check jumlah data tiap label
df['label'].value_counts()
# Out:
# label
# 2     3545
# 18    2118
# 14    1822
# 9     1557
# 5      987
# 16     985
# 1      837
# 19     823
# 7      624
# 6      524
# 15     501
# 17     495
# 12     487
# 13     471
# 4      359
# 3      321
# 0      255
# 8      166
# 10      69
# 11      44
# Name: count, dtype: int64

# %%
# check apakah ada text yang duplicate
df = df.drop_duplicates(subset=['text'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16990 entries, 0 to 16989
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    16990 non-null  object
#  1   label   16990 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 265.6+ KB

# %%
def cleansing(df):
  df_clean = df.copy()
  df_clean = df_clean.str.lower()  #lowercase
  df_clean = [re.sub(r"\d+","", i) for i in df_clean]  #numbers
  df_clean = [re.sub(r'[^\w]', ' ', i) for i in df_clean]  #punctuation
  df_clean = [re.sub(r'\s+',' ', i) for i in df_clean]  #whitespace
  df_clean = [re.sub(r'https\s+','',i) for i in df_clean]  #URL
  return df_clean

# %%
# clean text
df['clean_text']=cleansing(df['text'])

# %%
print(df.iloc[0][2])
# Out:
# here are thursday s biggest analyst calls apple amazon tesla palantir docusign exxon amp more t co qpngwluh

# %%
df.head()
# Out:
#                                                 text  label  \
# 0  Here are Thursday's biggest analyst calls: App...      0
# 1  Buy Las Vegas Sands as travel to Singapore bui...      0
# 2  Piper Sandler downgrades DocuSign to sell, cit...      0
# 3  Analysts react to Tesla's latest earnings, bre...      0
# 4  Netflix and its peers are set for a ‘return to...      0
#
#                                           clean_text
# 0  here are thursday s biggest analyst calls appl...
# 1  buy las vegas sands as travel to singapore bui...
# 2  piper sandler downgrades docusign to sell citi...
# 3  analysts react to tesla s latest earnings brea...
# 4  netflix and its peers are set for a return to ...

# %%
#check maximum length of word in sentence
max_sen = df['clean_text'].str.split().str.len().max()

# %%
max_sen
# Out:
# 57

# %% [markdown]
# **Split the Data**

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, log_loss
from sklearn.metrics import classification_report, confusion_matrix

# %%
x_train, x_test, y_train, y_test = train_test_split(df['clean_text'], df['label'], test_size = 0.2, random_state = 42,stratify=df['label'])

# %%
len(x_train)
# Out:
# 13592

# %%
len(x_test)
# Out:
# 3398

# %%
 #check maximum length of word in train data
 x_train.str.split().str.len().max()
# Out:
# 57

# %% [markdown]
# **Remove Stopword and Tokenization**

# %%
#Define Stopwords
from nltk.corpus import stopwords
nltk.download('stopwords')
# Get a list of stop words in the English language
stop_words = set(stopwords.words('english'))

# Display the top 20 stop words
list(stop_words)[:20]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['all',
#  'ours',
#  'myself',
#  'very',
#  'mightn',
#  'off',
#  'up',
#  'too',
#  'our',
#  'being',
#  'themselves',
#  "mightn't",
#  'in',
#  "doesn't",
#  'until',
#  'are',
#  'be',
#  'through',
#  'needn',
#  'were']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#tokenization
word_token=[word_tokenize(i) for i in x_train]

# %%
word_token
# Out:
# [['it',
#   's',
#   'ecb',
#   'rate',
#   'decision',
#   'day',
#   'here',
#   's',
#   'what',
#   'to',
#   'expect',
#   'via',
#   'weberalexander',
#   'amp',
#   'carolynnlook',
#   't',
#   'co',
#   'isqgdue'],
#  ['twitter',
#   'users',
#   'were',
#   'quick',
#   'to',
#   'spot',
#   'liz',
#   'truss',
#   'seemingly',
#   'recreating',
#   'an',
#   'outfit',
#   'of',
#   'margaret',
#   'thatcher',
#   's',
#   'for',
#   'her',
#   'appearance',
#   'at',
#   'channel',
#   's',
#   'tory',
#   'leadership',
#   'debate',
#   't',
#   'co',
#   'vsiioegrz'],
#  ['jetblue',
#   'announces',
#   'webcast',
#   'of',
#   'second',
#   'quarter',
#   'earnings',
#   'conference',
#   'call',
#   't',
#   'co',
#   'kzrfsrwcpk',
#   't',
#   'co',
#   'xjbczmry'],
#  ['calm',
#   'cal',
#   'maine',
#   'foods',
#   'stock',
#   'ticks',
#   'higher',
#   'on',
#   'record',
#   'net',
#   'income',
#   'pricing',
#   'power',
#   't',
#   'co',
#   'nczmzphcx'],
#  ['tower',
#   'semiconductor',
#   'and',
#   'cadence',
#   'expand',
#   'collaboration',
#   'to',
#   'accelerate',
#   'automotive',
#   'ic',
#   'development',
#   't',
#   'co',
#   'vssriai',
#   't',
#   'co',
#   'kkjrddoxa'],
#  ['u',
#   's',
#   'stocks',
#   'fell',
#   'as',
#   'earnings',
#   'season',
#   'is',
#   'set',
#   'to',
#   'kick',
#   'off',
#   'this',
#   'week',
#   'and',
#   'investors',
#   'worried',
#   'about',
#   'the',
#   'impact',
#   'of',
#   'inflation',
#   'on',
#   'corporate',
#   'profits',
#   't',
#   'co',
#   'ffquuxyfhw'],
#  ['elon',
#   'musk',
#   'says',
#   'tesla',
#   'could',
#   'lower',
#   'prices',
#   'but',
#   'only',
#   'if',
#   'inflation',
#   'calms',
#   'down',
#   't',
#   'co',
#   'dbwjbknv'],
#  ['rolls',
#   'royce',
#   'and',
#   'easyjet',
#   'to',
#   'test',
#   'hydrogen',
#   'combustion',
#   'engine',
#   'tech',
#   'for',
#   'airplanes',
#   't',
#   'co',
#   'alilnplg'],
#  ['yuja',
#   'inc',
#   'introduces',
#   'accessible',
#   'media',
#   'technology',
#   'integration',
#   'with',
#   'cielo',
#   't',
#   'co',
#   'kdsob',
#   't',
#   'co',
#   'hunoecglhf'],
#  ['from',
#   'breakingviews',
#   'climate',
#   'fight',
#   'can',
#   'take',
#   'heart',
#   'from',
#   'an',
#   'old',
#   'oil',
#   'maxim',
#   't',
#   'co',
#   'mnznztvui'],
#  ['watch',
#   'germany',
#   'is',
#   'nearing',
#   'a',
#   'bailout',
#   'deal',
#   'for',
#   'troubled',
#   'gas',
#   'supplier',
#   'uniper',
#   'and',
#   'it',
#   'could',
#   'mean',
#   'higher',
#   'prices',
#   'for',
#   'consumers',
#   'reuters',
#   'sources',
#   'say',
#   'the',
#   'german',
#   'government',
#   'will',
#   'take',
#   'a',
#   'stake',
#   'in',
#   'the',
#   'firm',
#   't',
#   'co',
#   'byqteoz',
#   't',
#   'co',
#   'zhqzhgtza'],
#  ['oatt',
#   'us',
#   'wasde',
#   'corn',
#   'end',
#   'stocks',
#   'new',
#   'jul',
#   'm',
#   'est',
#   'm',
#   'prev',
#   'm',
#   'soybean',
#   'end',
#   'stocks',
#   'new',
#   'm',
#   'est',
#   'm',
#   'prev',
#   'm',
#   'wheat',
#   'end',
#   'stocks',
#   'new',
#   'm',
#   'est',
#   'm',
#   'prev',
#   'm',
#   'cotton',
#   'end',
#   'stocks',
#   'new',
#   'm',
#   'est',
#   'm',
#   'prev',
#   'm',
#   't',
#   'co',
#   'twsyiqnh'],
#  ['canadian',
#   'cpi',
#   'boc',
#   'core',
#   'm',
#   'm',
#   'jun',
#   'prev',
#   'canadian',
#   'cpi',
#   'boc',
#   'core',
#   'y',
#   'y',
#   'jun',
#   'est',
#   'prev',
#   'canadian',
#   'cpi',
#   'core',
#   'common',
#   'y',
#   'y',
#   'jun',
#   'est',
#   'prev',
#   'canadian',
#   'cpi',
#   'core',
#   'median',
#   'y',
#   'y',
#   'jun',
#   't',
#   'co',
#   'cyymoxhlh'],
#  ['r',
#   'ryder',
#   'system',
#   'raises',
#   'dividend',
#   'by',
#   'to',
#   't',
#   'co',
#   'cvutwzqe'],
#  ['kkr',
#   's',
#   'first',
#   'asset',
#   'based',
#   'finance',
#   'fund',
#   'raises',
#   'bln',
#   't',
#   'co',
#   'onzacnqvb',
#   't',
#   'co',
#   'lhtywhqgd'],
#  ['japan',
#   'shouldn',
#   't',
#   'step',
#   'into',
#   'the',
#   'foreign',
#   'exchange',
#   'market',
#   'to',
#   'prop',
#   'up',
#   'the',
#   'yen',
#   'at',
#   'this',
#   'stage',
#   'according',
#   'to',
#   'the',
#   'country',
#   's',
#   'former',
#   'chief',
#   'currency',
#   'official',
#   't',
#   'co',
#   'ijiyvqhugw'],
#  ['rtx',
#   'raytheon',
#   'technologies',
#   'chosen',
#   'by',
#   'doe',
#   'for',
#   'two',
#   'r',
#   'amp',
#   'd',
#   'projects',
#   't',
#   'co',
#   'bfhlakgqe'],
#  ['tan',
#   'icln',
#   'qcln',
#   'solar',
#   'stocks',
#   'plunge',
#   'as',
#   'manchin',
#   'nixes',
#   'new',
#   'climate',
#   'spending',
#   'in',
#   'economic',
#   'plan',
#   't',
#   'co',
#   'nyewdzc'],
#  ['fed',
#   'beige',
#   'book',
#   'economic',
#   'activity',
#   'expanded',
#   'at',
#   'a',
#   'modest',
#   'pace',
#   'on',
#   'balance',
#   'since',
#   'mid',
#   'may',
#   't',
#   'co',
#   'ihozflgnmb'],
#  ['south',
#   'africa',
#   's',
#   'rooibos',
#   'tea',
#   'industry',
#   'paid',
#   'to',
#   'indigenous',
#   'groups',
#   'as',
#   'a',
#   'way',
#   'to',
#   'recognize',
#   'the',
#   'plant',
#   's',
#   'original',
#   'cultivators',
#   't',
#   'co',
#   'rhquaxzdn'],
#  ['tph',
#   'tri',
#   'pointe',
#   'homes',
#   'q',
#   'earnings',
#   'preview',
#   't',
#   'co',
#   'bzmcjsc'],
#  ['stranger',
#   'things',
#   'viewing',
#   'data',
#   'continues',
#   'to',
#   'be',
#   'a',
#   'bright',
#   'spot',
#   'for',
#   'nflx',
#   'netflix',
#   'said',
#   'it',
#   'anticipates',
#   'that',
#   'in',
#   'q',
#   'million',
#   'paying',
#   'users',
#   'will',
#   'leave',
#   'the',
#   'platform',
#   'alliecanal',
#   'says',
#   'we',
#   're',
#   'seeing',
#   'increased',
#   'levels',
#   'of',
#   'cancellation',
#   'churn',
#   'a',
#   'slowdown',
#   'in',
#   'app',
#   'downloads',
#   't',
#   'co',
#   'bxovoirq'],
#  ['triton',
#   'digital',
#   'releases',
#   'the',
#   'australian',
#   'podcast',
#   'ranker',
#   'for',
#   'june',
#   't',
#   'co',
#   'slktmgdp'],
#  ['the',
#   'philippines',
#   'plans',
#   'to',
#   'revise',
#   'mobility',
#   'restrictions',
#   'next',
#   'month',
#   'as',
#   'covid',
#   'cases',
#   'caused',
#   'by',
#   'milder',
#   'strains',
#   'increase',
#   'president',
#   'ferdinand',
#   'marcos',
#   'jr',
#   'said',
#   't',
#   'co',
#   'hozmkplj'],
#  ['groupe',
#   'touchette',
#   'strikes',
#   'a',
#   'deal',
#   'to',
#   'acquire',
#   'american',
#   'tire',
#   'distributors',
#   'assets',
#   'in',
#   'canada',
#   'a',
#   'move',
#   'that',
#   'may',
#   'roughly',
#   'double',
#   'its',
#   'annual',
#   'sales',
#   't',
#   'co',
#   'yupuoqpth'],
#  ['validus',
#   'capital',
#   'appoints',
#   'sean',
#   'chen',
#   'as',
#   'chief',
#   'operating',
#   'officer',
#   'chief',
#   'compliance',
#   'officer',
#   'and',
#   'managing',
#   'partner',
#   't',
#   'co',
#   'lgemaesczj',
#   't',
#   'co',
#   'hfqqugeq'],
#  ['qubt',
#   'quantum',
#   'computing',
#   'poised',
#   'for',
#   'greatness',
#   'in',
#   'the',
#   'next',
#   'big',
#   'wave',
#   'of',
#   'computing',
#   'disruption',
#   't',
#   'co',
#   'ijnvhjmic',
#   'stockmarket',
#   'investing',
#   'stocks'],
#  ['lmt',
#   'misses',
#   'by',
#   'misses',
#   'on',
#   'revs',
#   'lowers',
#   'outlook',
#   'guides',
#   'fy',
#   'eps',
#   'below',
#   'consensus',
#   'revs',
#   'below',
#   'consensus'],
#  ['tsla',
#   'pre',
#   'tesla',
#   'profit',
#   'tops',
#   'target',
#   'musk',
#   'says',
#   'high',
#   'prices',
#   'could',
#   'hurt',
#   'demand',
#   'reuters',
#   't',
#   'co',
#   'guckmgqoh'],
#  ['the',
#   'jan',
#   'committee',
#   'looked',
#   'at',
#   'ties',
#   'between',
#   'the',
#   'oath',
#   'keepers',
#   'and',
#   'proud',
#   'boys',
#   'to',
#   'roger',
#   'stone',
#   'a',
#   'close',
#   'associate',
#   'of',
#   'trump',
#   'latest',
#   'updates',
#   't',
#   'co',
#   'shktxy',
#   't',
#   'co',
#   'tgsydcsrz'],
#  ['you',
#   'can',
#   'test',
#   'apple',
#   's',
#   'big',
#   'new',
#   'iphone',
#   'update',
#   'now',
#   'here',
#   's',
#   'how',
#   't',
#   'co',
#   'thouzumqvy'],
#  ['eras',
#   'lly',
#   'erasca',
#   'eli',
#   'lilly',
#   'to',
#   'collaborate',
#   'on',
#   'trial',
#   'to',
#   'evaluate',
#   'combo',
#   'treatment',
#   'for',
#   'two',
#   'cancers',
#   't',
#   'co',
#   'ohvvzkvgw'],
#  ['citi',
#   'jpmorgan',
#   'and',
#   'wells',
#   'fargo',
#   'all',
#   'increased',
#   'their',
#   'provisions',
#   'for',
#   'credit',
#   'losses',
#   'for',
#   'the',
#   'first',
#   'time',
#   'since',
#   'the',
#   'height',
#   'of',
#   'the',
#   'pandemic',
#   'leaving',
#   'investors',
#   'to',
#   'debate',
#   'whether',
#   'those',
#   'reserves',
#   'were',
#   'prudent',
#   'acts',
#   'or',
#   'a',
#   'sign',
#   'of',
#   'danger',
#   'ahead',
#   't',
#   'co',
#   'rmzhnona'],
#  ['economists',
#   'forecast',
#   'that',
#   'inflation',
#   'will',
#   'hit',
#   'a',
#   'fresh',
#   'pandemic',
#   'peak',
#   'that',
#   's',
#   'set',
#   'to',
#   'keep',
#   'the',
#   'fed',
#   'geared',
#   'for',
#   'another',
#   'big',
#   'interest',
#   'rate',
#   'hike',
#   'later',
#   'this',
#   'month',
#   't',
#   'co',
#   'zftchwn'],
#  ['dow',
#   'ends',
#   'around',
#   'points',
#   'higher',
#   'as',
#   'equities',
#   'extend',
#   'bounce',
#   't',
#   'co',
#   'vlzmqckds'],
#  ['rio',
#   'tinto',
#   'second',
#   'quarter',
#   'iron',
#   'ore',
#   'shipments',
#   'rise',
#   'about',
#   'rtrs',
#   't',
#   'co',
#   'ywvmgkam'],
#  ['laserfiche',
#   'appoints',
#   'karl',
#   'chan',
#   'as',
#   'chief',
#   'executive',
#   'officer',
#   't',
#   'co',
#   'eetxkaj',
#   't',
#   'co',
#   'macatblvc'],
#  ['china',
#   'files',
#   'diplomatic',
#   'protest',
#   'with',
#   'japan',
#   'over',
#   'a',
#   'visit',
#   'by',
#   'a',
#   'top',
#   'taiwanese',
#   'official',
#   'to',
#   'mourn',
#   'the',
#   'death',
#   'of',
#   'the',
#   'country',
#   's',
#   'former',
#   'leader',
#   'shinzo',
#   'abe',
#   't',
#   'co',
#   'vzwckuys'],
#  ['netflix',
#   'may',
#   'have',
#   'calmed',
#   'investors',
#   'worst',
#   'fears',
#   'with',
#   'a',
#   'second',
#   'quarter',
#   'subscriber',
#   'loss',
#   'that',
#   'was',
#   'better',
#   'than',
#   'expected',
#   'but',
#   'a',
#   'closer',
#   'look',
#   'at',
#   'the',
#   'streaming',
#   'giant',
#   's',
#   'results',
#   'indicate',
#   'it',
#   'still',
#   'faces',
#   'significant',
#   'hurdles',
#   't',
#   'co',
#   'avzwjostag'],
#  ['randomly',
#   'bought',
#   'eth',
#   'yesterday',
#   'morning',
#   'first',
#   'crypto',
#   'trade',
#   'of',
#   'saw',
#   'similar',
#   'to',
#   'what',
#   'i',
#   'am',
#   'seeing',
#   'in',
#   'the',
#   'nasdaq',
#   'w',
#   'basing',
#   'key',
#   'level',
#   'lifetime',
#   'vwap',
#   'etc',
#   'nice',
#   'start',
#   'today'],
#  ['brqs',
#   'borqs',
#   's',
#   'subsidiary',
#   'holu',
#   'hou',
#   'energy',
#   'signed',
#   'an',
#   'agreement',
#   'for',
#   'million',
#   'to',
#   'bring',
#   'renewable',
#   'energy',
#   'to',
#   'key',
#   'hawaiian',
#   'cultural',
#   'and',
#   'sporting',
#   'facility'],
#  ['cibc',
#   'innovation',
#   'banking',
#   'provides',
#   'million',
#   'growth',
#   'financing',
#   'to',
#   'fintech',
#   'company',
#   'smart',
#   'to',
#   'accelerate',
#   'growth',
#   'and',
#   'acquisitions',
#   't',
#   'co',
#   'qrckkxmgm',
#   't',
#   'co',
#   'svbwvuzgxv'],
#  ['ual',
#   'united',
#   'airlines',
#   'misses',
#   'by',
#   'reports',
#   'revs',
#   'in',
#   'line',
#   'continues',
#   'to',
#   'expect',
#   'to',
#   'be',
#   'profitable',
#   'for',
#   'fy',
#   't',
#   'co',
#   'jyxvyedxt'],
#  ['dis',
#   'disney',
#   'inks',
#   'major',
#   'advertising',
#   'deal',
#   'with',
#   'the',
#   'trade',
#   'desk',
#   'axios',
#   't',
#   'co',
#   'pjzfmcxibp'],
#  ['ixhl',
#   'incannex',
#   'healthcare',
#   'has',
#   'received',
#   'approval',
#   'from',
#   'the',
#   'bellberry',
#   'human',
#   'research',
#   'ethics',
#   'committee',
#   'for',
#   'a',
#   'phase',
#   't',
#   'co',
#   'ydejdkw'],
#  ['evex',
#   'eve',
#   'shareholders',
#   'looking',
#   'at',
#   'dilution',
#   'state',
#   'of',
#   'vc',
#   'weighs',
#   'on',
#   'multiple',
#   't',
#   'co',
#   'xxwfkxnx',
#   'business',
#   'economy',
#   'investing'],
#  ['hymlf',
#   'kimtf',
#   'tsla',
#   'hyundai',
#   'looks',
#   'to',
#   'break',
#   'into',
#   'the',
#   'u',
#   's',
#   'electric',
#   'vehicle',
#   'market',
#   't',
#   'co',
#   'vgrbmvkk'],
#  ['rio',
#   'tinto',
#   'reported',
#   'inventories',
#   'continue',
#   'to',
#   'decline',
#   'and',
#   'high',
#   'power',
#   'prices',
#   'are',
#   'limiting',
#   'production',
#   'growth',
#   'outside',
#   'china'],
#  ['train',
#   'drivers',
#   'at',
#   'eight',
#   'uk',
#   'rail',
#   'companies',
#   'are',
#   'to',
#   'stage',
#   'a',
#   'hour',
#   'saturday',
#   'strike',
#   'later',
#   'this',
#   'month',
#   'in',
#   'pay',
#   'disputes',
#   't',
#   'co',
#   'rqizztlaz'],
#  ['twitter', 'is', 'down', 't', 'co', 'uaoimllse'],
#  ['baesy',
#   'bae',
#   'systems',
#   'secures',
#   'b',
#   'us',
#   'army',
#   'contract',
#   't',
#   'co',
#   'crzlcw'],
#  ['neti',
#   'eneti',
#   'scorpio',
#   'holdings',
#   'ltd',
#   'purchased',
#   'common',
#   'shares',
#   'at',
#   'average',
#   'price',
#   'of',
#   't',
#   'co',
#   'awqqqygnyb'],
#  ['drug',
#   'lord',
#   'rafael',
#   'caro',
#   'quintero',
#   'who',
#   'was',
#   'behind',
#   'the',
#   'killing',
#   'of',
#   'a',
#   'dea',
#   'agent',
#   'in',
#   'has',
#   'been',
#   'captured',
#   'by',
#   'mexican',
#   'forces',
#   'nearly',
#   'a',
#   'decade',
#   'after',
#   'walking',
#   'out',
#   'of',
#   'a',
#   'mexican',
#   'prison',
#   'and',
#   'returning',
#   'to',
#   'drug',
#   'trafficking',
#   'via',
#   'ap',
#   't',
#   'co',
#   'tprcgrgju'],
#  ['coinbase',
#   'is',
#   'selling',
#   'geo',
#   'location',
#   'data',
#   'to',
#   'u',
#   's',
#   'immigration',
#   'enforcement',
#   'agency',
#   'nasdaq',
#   'coin',
#   'seeking',
#   'alpha',
#   't',
#   'co',
#   'gdsliunjtr'],
#  ['the',
#   'actress',
#   'who',
#   'claimed',
#   'she',
#   'turned',
#   'down',
#   'work',
#   'due',
#   'to',
#   'an',
#   'injury',
#   'began',
#   'receiving',
#   'disability',
#   'payments',
#   'just',
#   'five',
#   'days',
#   'after',
#   'last',
#   'working',
#   'on',
#   'yellowstone',
#   't',
#   'co',
#   'nlmaggw'],
#  ['how',
#   'china',
#   's',
#   'wechat',
#   'became',
#   'so',
#   'powerful',
#   'it',
#   'could',
#   'have',
#   'posed',
#   'a',
#   'real',
#   'threat',
#   'to',
#   'beijing',
#   's',
#   'rule',
#   't',
#   'co',
#   'ounxeqyh'],
#  ['production',
#   'at',
#   'us',
#   'factories',
#   'declined',
#   'in',
#   'june',
#   'for',
#   'a',
#   'second',
#   'month',
#   'restrained',
#   'by',
#   'higher',
#   'inventories',
#   'and',
#   'a',
#   'softer',
#   'economic',
#   'outlook',
#   't',
#   'co',
#   'neqfvtt'],
#  ['moon',
#   'capital',
#   'management',
#   'q',
#   'letter',
#   't',
#   'co',
#   'madsudluiu',
#   'economy',
#   'finance',
#   'investing'],
#  ['oakbx',
#   'oakmark',
#   'equity',
#   'and',
#   'income',
#   'fund',
#   'q',
#   'commentary',
#   't',
#   'co',
#   'onkrwnzfg',
#   'finance',
#   'stockmarket',
#   'economy'],
#  ['chinese',
#   'premier',
#   'li',
#   'keqiang',
#   'signals',
#   'a',
#   'focus',
#   'on',
#   'jobs',
#   'flexibility',
#   'on',
#   'the',
#   'economic',
#   'growth',
#   'rate',
#   'and',
#   'a',
#   'shift',
#   'toward',
#   'making',
#   'its',
#   'covid',
#   'control',
#   'measures',
#   'more',
#   'targeted',
#   't',
#   'co',
#   'lelvkdlj'],
#  ['etcc',
#   'environmental',
#   'tectonics',
#   'gaap',
#   'eps',
#   'of',
#   'revenue',
#   'of',
#   'm',
#   't',
#   'co',
#   'kcaejlvh'],
#  ['bad', 'news', 'comes', 'out', 'at', 'lows'],
#  ['microsoft',
#   'is',
#   'making',
#   'several',
#   'changes',
#   'to',
#   'attract',
#   'and',
#   'retain',
#   'employees',
#   't',
#   'co',
#   'qqqhckubdz'],
#  ['stocks',
#   'in',
#   'asia',
#   'face',
#   'another',
#   'challenging',
#   'trading',
#   'session',
#   'on',
#   'friday',
#   'amid',
#   'a',
#   'surge',
#   'in',
#   'the',
#   'dollar',
#   'that',
#   'underscores',
#   'concerns',
#   'about',
#   'a',
#   'global',
#   'economic',
#   'slowdown',
#   't',
#   'co',
#   'nqyouwgg'],
#  ['inflation',
#   'is',
#   'the',
#   'most',
#   'urgent',
#   'concern',
#   'that',
#   'filipinos',
#   'want',
#   'philippine',
#   'president',
#   'marcos',
#   'jr',
#   'to',
#   'prioritize',
#   'according',
#   'to',
#   'a',
#   'survey',
#   'by',
#   'pulse',
#   'asia',
#   'research',
#   't',
#   'co',
#   'huhlofkrf'],
#  ['activist',
#   'hedge',
#   'fund',
#   'elliott',
#   'management',
#   'has',
#   'amassed',
#   'a',
#   'stake',
#   'of',
#   'more',
#   'than',
#   'in',
#   'pinterest',
#   't',
#   'co',
#   'rtuulife'],
#  ['bank',
#   'of',
#   'america',
#   'puts',
#   'aside',
#   'million',
#   'for',
#   'probe',
#   'into',
#   'bankers',
#   'use',
#   'of',
#   'personal',
#   'devices',
#   't',
#   'co',
#   'pfgaiuuc',
#   't',
#   'co',
#   'jzbelxyl'],
#  ['the',
#   'drive',
#   'to',
#   'turn',
#   'tourism',
#   'from',
#   'a',
#   'prime',
#   'threat',
#   'to',
#   'saviour',
#   'of',
#   'global',
#   'biodiversity',
#   't',
#   'co',
#   'trdtcioez',
#   't',
#   'co',
#   'tabdoit'],
#  ['u',
#   's',
#   'department',
#   'of',
#   'defense',
#   'awards',
#   'skywater',
#   'a',
#   'm',
#   'option',
#   'to',
#   'facilitate',
#   'american',
#   'made',
#   'semiconductors',
#   'critical',
#   'to',
#   'national',
#   'security',
#   'and',
#   'domestic',
#   'supply',
#   'chains',
#   't',
#   'co',
#   'fypnuphp',
#   't',
#   'co',
#   'nfcnwghwt'],
#  ['vale',
#   'vale',
#   's',
#   'a',
#   'starts',
#   'construction',
#   'for',
#   'the',
#   'zhongzhai',
#   'pre',
#   'blending',
#   'project',
#   'a',
#   'partnership',
#   'between',
#   'vale',
#   'jiangsu',
#   't',
#   'co',
#   'zknhayr'],
#  ['the',
#   'toyota',
#   'crown',
#   'a',
#   'car',
#   'known',
#   'for',
#   'ferrying',
#   'around',
#   'japan',
#   's',
#   'elite',
#   'is',
#   'set',
#   'for',
#   'the',
#   'global',
#   'stage',
#   't',
#   'co',
#   'wmwxvoiin'],
#  ['pageone',
#   'nothing',
#   'assured',
#   'about',
#   'an',
#   'encore',
#   'performance',
#   'spy',
#   'qqq',
#   'dia',
#   'nflx',
#   'tnx',
#   'rut',
#   't',
#   'co',
#   'ndqkrhzplg',
#   'technical',
#   'rally',
#   'dma',
#   'eu',
#   'gas',
#   'consumption',
#   'russia',
#   'ukraine',
#   'uk',
#   'inflation',
#   'boe',
#   'ratehike',
#   'earnings',
#   'mortgage',
#   'applications',
#   'economy',
#   'stockmarket',
#   'premarket',
#   'analysis'],
#  ['the',
#   'ecb',
#   's',
#   'anti',
#   'fragmentation',
#   'instrument',
#   'is',
#   'expected',
#   'to',
#   'have',
#   'soft',
#   'conditions',
#   't',
#   'co',
#   'qkhotq'],
#  ['searcher',
#   'seismic',
#   'is',
#   'planning',
#   'a',
#   'survey',
#   'looking',
#   'for',
#   'oil',
#   'offshore',
#   'south',
#   'africa',
#   'months',
#   'after',
#   'it',
#   'called',
#   'off',
#   'an',
#   'earlier',
#   'search',
#   'due',
#   'to',
#   'a',
#   'court',
#   'challenge',
#   't',
#   'co',
#   'qzigtfggp'],
#  ['the',
#   'imf',
#   'called',
#   'on',
#   'china',
#   'to',
#   'expand',
#   'fiscal',
#   'support',
#   'and',
#   'apply',
#   'a',
#   'more',
#   'flexible',
#   'covid',
#   'containment',
#   'strategy',
#   'to',
#   'address',
#   'a',
#   'slowdown',
#   'in',
#   'the',
#   'world',
#   's',
#   'second',
#   'biggest',
#   'economy',
#   't',
#   'co',
#   'dbeeinta'],
#  ['ko',
#   'pep',
#   'coca',
#   'cola',
#   'and',
#   'pepsico',
#   'likely',
#   'to',
#   'struggle',
#   'in',
#   'a',
#   'deglobalizing',
#   'world',
#   't',
#   'co',
#   'ypwucsdu',
#   'investing',
#   'stockmarket',
#   'economy'],
#  ['gs',
#   'and',
#   'aapl',
#   'plan',
#   'to',
#   'slow',
#   'hiring',
#   'and',
#   'spending',
#   'growth',
#   'in',
#   't',
#   'co',
#   'thvvufhod'],
#  ['attractive',
#   'high',
#   'dividend',
#   'yield',
#   'stocks',
#   'to',
#   'buy',
#   't',
#   'co',
#   'ubtsvdsos',
#   'business',
#   'stocks',
#   'markets'],
#  ['virtualhealth',
#   'modernizes',
#   'utilization',
#   'management',
#   'with',
#   'new',
#   'software',
#   'release',
#   't',
#   'co',
#   'idzkroa',
#   't',
#   'co',
#   'oyhpkcosfo'],
#  ['ways',
#   'the',
#   'elon',
#   'musk',
#   'twitter',
#   'saga',
#   'could',
#   'end',
#   't',
#   'co',
#   'tsmyskvl'],
#  ['voltacharging',
#   'chief',
#   'commercial',
#   'officer',
#   'brandt',
#   'hastings',
#   'on',
#   'partnering',
#   'with',
#   'kroger',
#   'for',
#   'ev',
#   'charging',
#   'stations',
#   'we',
#   're',
#   'building',
#   'our',
#   'network',
#   'in',
#   'locations',
#   'that',
#   'millions',
#   'of',
#   'americans',
#   'already',
#   'love',
#   'to',
#   'visit',
#   'every',
#   'day',
#   'full',
#   'interview',
#   't',
#   'co',
#   'mjnubek'],
#  ['a',
#   'third',
#   'of',
#   'burberry',
#   'shareholders',
#   'voted',
#   'against',
#   'the',
#   're',
#   'election',
#   'of',
#   'board',
#   'member',
#   'antoine',
#   'de',
#   'saint',
#   'affrique',
#   'amid',
#   'concerns',
#   'about',
#   'directors',
#   'who',
#   'also',
#   'hold',
#   'other',
#   'jobs',
#   'spreading',
#   'themselves',
#   'too',
#   'thin',
#   't',
#   'co',
#   'ietgddm'],
#  ['pgr',
#   'progressive',
#   'seeing',
#   'improvements',
#   'in',
#   'the',
#   'business',
#   'growth',
#   'opportunities',
#   'remain',
#   't',
#   'co',
#   'nkizthwng',
#   'finance',
#   'stocks',
#   'economy'],
#  ['todaysfreefeature',
#   'settling',
#   'up',
#   'spy',
#   'tlt',
#   'fxe',
#   'es_f',
#   'tnx',
#   'eurusd',
#   't',
#   'co',
#   'lqxffwjpp',
#   'cpi',
#   'federalreserve',
#   'supplychain',
#   'issues',
#   'inflation',
#   'china',
#   'lockdowns',
#   'retailsales',
#   'housing',
#   'nahb',
#   'fedfunds',
#   'ratehike',
#   'etf',
#   'dailynotes',
#   't',
#   'co',
#   'fhceqwwi'],
#  ['bondx', 'new', 'supply', 't', 'co', 'zlthfafaq'],
#  ['hasi',
#   'hannon',
#   'armstrong',
#   'sustainable',
#   'infrastructure',
#   'take',
#   'the',
#   'short',
#   'seller',
#   'allegations',
#   'seriously',
#   't',
#   'co',
#   'bnulplkt',
#   'business',
#   'stockmarket',
#   'investing'],
#  ['the',
#   'nyse',
#   'welcomes',
#   'yearup',
#   'to',
#   'ring',
#   'the',
#   'opening',
#   'bell',
#   't',
#   'co',
#   'ynsyzvjn'],
#  ['royal',
#   'mail',
#   'could',
#   'be',
#   'changing',
#   'its',
#   'name',
#   't',
#   'co',
#   'jlippix'],
#  ['watch',
#   'british',
#   'consumer',
#   'price',
#   'inflation',
#   'hit',
#   'an',
#   'annual',
#   'rate',
#   'of',
#   'in',
#   'june',
#   'compared',
#   'with',
#   'in',
#   'may',
#   'the',
#   'data',
#   'bolstered',
#   'bets',
#   'that',
#   'the',
#   'bank',
#   'of',
#   'england',
#   'will',
#   'opt',
#   'for',
#   'a',
#   'basis',
#   'point',
#   'rate',
#   'hike',
#   'next',
#   'month',
#   't',
#   'co',
#   'fhxhdl',
#   't',
#   'co',
#   'brjwodefj'],
#  ['sstrazza',
#   'late',
#   'thursday',
#   'berkshire',
#   'disclosed',
#   'buying',
#   'another',
#   'million',
#   'shares',
#   'worth',
#   'about',
#   'million',
#   'based',
#   'on',
#   'current',
#   'prices'],
#  ['redemptions',
#   'overwhelmed',
#   'new',
#   'investments',
#   'for',
#   'citco',
#   'group',
#   's',
#   'hedge',
#   'fund',
#   'clients',
#   'in',
#   'june',
#   'bringing',
#   'net',
#   'outflows',
#   'to',
#   'billion',
#   't',
#   'co',
#   'yretofokk'],
#  ['the',
#   'imf',
#   's',
#   'board',
#   'approves',
#   'a',
#   'billion',
#   'extended',
#   'credit',
#   'facility',
#   'for',
#   'tanzania',
#   'and',
#   'plans',
#   'to',
#   'disburse',
#   'million',
#   'immediately',
#   't',
#   'co',
#   'mirkjqofa'],
#  ['qqq',
#   'powershares',
#   'qqq',
#   'erases',
#   'morning',
#   'losses',
#   'now',
#   'modestly',
#   'higher',
#   'was',
#   'down',
#   'about',
#   'at',
#   'this',
#   'morning',
#   's',
#   'lows',
#   't',
#   'co',
#   'bsqthxrfvj'],
#  ['astepro',
#   'allergy',
#   'first',
#   'and',
#   'only',
#   'steroid',
#   'free',
#   'antihistamine',
#   'nasal',
#   'spray',
#   'now',
#   'available',
#   'over',
#   'the',
#   'counter',
#   't',
#   'co',
#   'sxqdyov',
#   't',
#   'co',
#   'yekgbfxxt'],
#  ['listen',
#   'now',
#   'jpmorgan',
#   'and',
#   'morgan',
#   'stanley',
#   'missed',
#   'wall',
#   'street',
#   's',
#   'earnings',
#   'estimates',
#   'the',
#   'team',
#   'discusses',
#   'what',
#   'this',
#   'means',
#   'for',
#   'the',
#   'big',
#   'banks',
#   'listen',
#   'and',
#   'follow',
#   'the',
#   'squawkstreet',
#   'podcast',
#   'here',
#   'or',
#   'on',
#   'your',
#   'favorite',
#   'podcast',
#   'platform',
#   't',
#   'co',
#   'boklbewjy',
#   't',
#   'co',
#   'ooloeyqen'],
#  ['u',
#   'k',
#   'june',
#   'brc',
#   'retail',
#   'sales',
#   'monitor',
#   'yoy',
#   'actual',
#   'vs',
#   'previous',
#   'est'],
#  ['increased',
#   'use',
#   'of',
#   'lignite',
#   'coal',
#   'and',
#   'hydro',
#   'powered',
#   'electricity',
#   'generation',
#   'feature',
#   'in',
#   'greece',
#   's',
#   'plan',
#   'to',
#   'ensure',
#   'demand',
#   'is',
#   'met',
#   'should',
#   'supplies',
#   'of',
#   'natural',
#   'gas',
#   'fall',
#   'short',
#   't',
#   'co',
#   'mlmlajuk'],
#  ['fnf',
#   'fidelity',
#   'national',
#   'coo',
#   'roger',
#   'jewkes',
#   'transitions',
#   'from',
#   'his',
#   'role',
#   'to',
#   'the',
#   'role',
#   'of',
#   'executive',
#   'vp',
#   't',
#   'co',
#   'emkwmgqbb'],
#  ['mario',
#   'draghi',
#   'has',
#   'signaled',
#   'that',
#   'he',
#   's',
#   'determined',
#   'to',
#   'resign',
#   'as',
#   'italy',
#   's',
#   'prime',
#   'minister',
#   'within',
#   'days',
#   't',
#   'co',
#   'xyokvjf'],
#  ['jpmorgan',
#   'profit',
#   'falls',
#   'dimon',
#   'cautious',
#   'on',
#   'global',
#   'economy',
#   't',
#   'co',
#   'vuovmxzh',
#   't',
#   'co',
#   'nnnevariv'],
#  ['spy',
#   'spx',
#   'es_f',
#   'and',
#   'hour',
#   'candles',
#   'watching',
#   'for',
#   'bull',
#   'move',
#   'aapl',
#   'amzn',
#   'googl',
#   'msft',
#   'all',
#   'ran',
#   'up',
#   'here',
#   'and',
#   'are',
#   'looking',
#   'to',
#   'break',
#   'over',
#   'emma',
#   's',
#   'to',
#   'fill',
#   'gap',
#   'and',
#   'go',
#   'green',
#   'watch',
#   'hour',
#   'closes',
#   'in',
#   'min',
#   'for',
#   'spy',
#   'and',
#   'c',
#   't',
#   'co',
#   'oefixsxe'],
#  ['the',
#   'coming',
#   'weeks',
#   'will',
#   'be',
#   'filled',
#   'with',
#   'news',
#   'and',
#   'noise',
#   'about',
#   'this',
#   'case',
#   'twitter',
#   'ceo',
#   'parag',
#   'agrawal',
#   'warned',
#   'employees',
#   'in',
#   'an',
#   'email',
#   'tuesday',
#   't',
#   'co',
#   'ldkjgunga'],
#  ['key',
#   'keycorp',
#   'q',
#   'earnings',
#   'beat',
#   'estimates',
#   'as',
#   'its',
#   'market',
#   'share',
#   'continues',
#   'to',
#   'increase',
#   't',
#   'co',
#   'kgpflgvv'],
#  ['the',
#   'asian',
#   'development',
#   'bank',
#   'cut',
#   'its',
#   'forecast',
#   'for',
#   'gross',
#   'domestic',
#   'product',
#   'growth',
#   'in',
#   'developing',
#   'asia',
#   'this',
#   'year',
#   'as',
#   'china',
#   's',
#   'covid',
#   'zero',
#   'approach',
#   'to',
#   'containing',
#   'the',
#   'virus',
#   'creates',
#   'ripple',
#   'effects',
#   'on',
#   'regional',
#   'supply',
#   'chains',
#   'and',
#   'economic',
#   'development',
#   't',
#   'co',
#   'ulvkodryz'],
#  ['apple',
#   'google',
#   'meta',
#   'all',
#   'of',
#   'the',
#   'tech',
#   'companies',
#   'hitting',
#   'the',
#   'brakes',
#   'on',
#   'hiring',
#   't',
#   'co',
#   'vwtrlbz',
#   'by',
#   'ines_ferre',
#   'and',
#   'danielhowley',
#   't',
#   'co',
#   'oeykdimde'],
#  ['former',
#   'house',
#   'speaker',
#   'paul',
#   'ryan',
#   'said',
#   'the',
#   'jan',
#   'attack',
#   'on',
#   'the',
#   'u',
#   's',
#   'capitol',
#   'reduced',
#   'him',
#   'to',
#   'tears',
#   'his',
#   'reaction',
#   'was',
#   'quoted',
#   'in',
#   'a',
#   'new',
#   'book',
#   'about',
#   'former',
#   'president',
#   'donald',
#   'trump',
#   'and',
#   'his',
#   'relationship',
#   'with',
#   'the',
#   'republican',
#   'party',
#   't',
#   'co',
#   'bvqwrzaazv'],
#  ['company',
#   'investigation',
#   'alert',
#   'reminder',
#   'scott',
#   'scott',
#   'attorneys',
#   'at',
#   'law',
#   'llp',
#   'investigates',
#   'elon',
#   'musk',
#   'deal',
#   'with',
#   'company',
#   'twtr',
#   't',
#   'co',
#   'szolrix',
#   't',
#   'co',
#   'fsjhupvgo'],
#  ['jpmorgan',
#   'analysts',
#   'have',
#   'put',
#   'out',
#   'their',
#   'monthly',
#   'list',
#   'of',
#   'top',
#   'idea',
#   'stocks',
#   't',
#   'co',
#   'ywcdscqb'],
#  ['salata',
#   'salad',
#   'kitchen',
#   'introduces',
#   'southwestern',
#   'inspired',
#   'menu',
#   'items',
#   'featuring',
#   'a',
#   'new',
#   'protein',
#   'option',
#   'certified',
#   'angus',
#   'beef',
#   'steak',
#   't',
#   'co',
#   'mynzcmiju',
#   't',
#   'co',
#   'gcdqwcwpu'],
#  ['wipro',
#   'limited',
#   'to',
#   'announce',
#   'results',
#   'for',
#   'the',
#   'first',
#   'quarter',
#   'ended',
#   'june',
#   'on',
#   'july',
#   't',
#   'co',
#   'sgiwtzjzef',
#   't',
#   'co',
#   'zmvtyc'],
#  ['putin',
#   's',
#   'trip',
#   'to',
#   'iran',
#   'shows',
#   'russia',
#   's',
#   'desperation',
#   'says',
#   'u',
#   's',
#   'institute',
#   'of',
#   'peace',
#   't',
#   'co',
#   'ttxzxjak'],
#  ['royal',
#   'mail',
#   'says',
#   'it',
#   'will',
#   'consider',
#   'a',
#   'number',
#   'of',
#   'options',
#   'to',
#   'improve',
#   'the',
#   'prospects',
#   'of',
#   'the',
#   'group',
#   'including',
#   'separation',
#   'of',
#   'the',
#   'main',
#   'uk',
#   'postal',
#   'business',
#   'from',
#   'its',
#   'international',
#   'logistics',
#   'unit',
#   't',
#   'co',
#   'xnzjlqumb'],
#  ['lscc',
#   'lattice',
#   'semi',
#   'collaborates',
#   'with',
#   'lg',
#   'to',
#   'bring',
#   'edge',
#   'ai',
#   'technology',
#   'to',
#   'lg',
#   's',
#   'premium',
#   'laptop',
#   'lineup',
#   't',
#   'co',
#   'wngqvygfnf'],
#  ['save',
#   'pre',
#   'frontier',
#   'group',
#   'ulcc',
#   'in',
#   'letter',
#   'to',
#   'spirit',
#   'says',
#   'remain',
#   'very',
#   'far',
#   'from',
#   'obtaining',
#   'approval',
#   'from',
#   'spirit',
#   'stockholders',
#   'based',
#   'on',
#   'proxy',
#   'data',
#   'reuters',
#   'si',
#   't',
#   'co',
#   'lxacine'],
#  ['eric',
#   'ericsson',
#   'misses',
#   'by',
#   'sek',
#   'beats',
#   'on',
#   'revs',
#   't',
#   'co',
#   'fpeysuki'],
#  ['euro',
#   'area',
#   'consumer',
#   'confidence',
#   'drops',
#   'to',
#   'its',
#   'lowest',
#   'level',
#   'on',
#   'record',
#   'as',
#   'households',
#   'brace',
#   'for',
#   'a',
#   'possible',
#   'recession',
#   't',
#   'co',
#   'fbvjgrdq'],
#  ['hungarians',
#   'are',
#   'holding',
#   'daily',
#   'protests',
#   'as',
#   'a',
#   'plunging',
#   'currency',
#   'and',
#   'the',
#   'threat',
#   'of',
#   'a',
#   'russian',
#   'cut',
#   'off',
#   'of',
#   'natural',
#   'gas',
#   'shipments',
#   'forces',
#   'prime',
#   'minister',
#   'viktor',
#   'orban',
#   'to',
#   'embrace',
#   'unpopular',
#   'austerity',
#   'measures',
#   't',
#   'co',
#   'ijolaluyg'],
#  ['phm',
#   'pultegroup',
#   'an',
#   'exciting',
#   'buy',
#   'with',
#   'potential',
#   'annual',
#   'returns',
#   'to',
#   't',
#   'co',
#   'djcncgd',
#   'finance',
#   'economy',
#   'investing'],
#  ['fidelity',
#   'payment',
#   'services',
#   'announces',
#   'strategic',
#   'growth',
#   'investment',
#   'from',
#   'psg',
#   't',
#   'co',
#   'rhfpkblhm',
#   't',
#   'co',
#   'pknhcceyb'],
#  ['xbi',
#   'xbi',
#   'are',
#   'biotech',
#   'stocks',
#   'a',
#   'good',
#   'investment',
#   'again',
#   't',
#   'co',
#   'phzuaffq',
#   'business',
#   'markets',
#   'finance'],
#  ['a',
#   'brutal',
#   'heatwave',
#   'is',
#   'sweeping',
#   'through',
#   'europe',
#   'and',
#   'impacting',
#   'everything',
#   'from',
#   'transport',
#   'to',
#   'food',
#   'and',
#   'energy',
#   'production',
#   't',
#   'co',
#   'wzjapjrqdv'],
#  ['the',
#   'federal',
#   'minimum',
#   'wage',
#   'hasn',
#   't',
#   'gone',
#   'up',
#   'in',
#   'years',
#   'and',
#   'is',
#   'at',
#   'its',
#   'lowest',
#   'value',
#   'since',
#   'via',
#   'cnbcmakeit',
#   't',
#   'co',
#   'inslxvvlg'],
#  ['s',
#   'amp',
#   'p',
#   'affirms',
#   'assured',
#   'guaranty',
#   's',
#   'aa',
#   'financial',
#   'strength',
#   'ratings',
#   'with',
#   'stable',
#   'outlook',
#   't',
#   'co',
#   'fznnutx'],
#  ['electric',
#   'vehicle',
#   'maker',
#   'rivian',
#   'confirmed',
#   'plans',
#   'to',
#   'rethink',
#   'some',
#   'operations',
#   'and',
#   'trim',
#   'jobs',
#   'as',
#   'necessary',
#   'with',
#   'ceo',
#   'rj',
#   'scaringe',
#   'telling',
#   'employees',
#   'the',
#   'company',
#   'will',
#   'be',
#   'thoughtful',
#   'with',
#   'any',
#   'staff',
#   'cut',
#   't',
#   'co',
#   'nbyjlgq'],
#  ['royal',
#   'mail',
#   'faces',
#   'a',
#   'possible',
#   'nationwide',
#   'strike',
#   'by',
#   'more',
#   'than',
#   'postal',
#   'staff',
#   'that',
#   'would',
#   'be',
#   'the',
#   'biggest',
#   'walkout',
#   'by',
#   'british',
#   'workers',
#   'this',
#   'summer',
#   't',
#   'co',
#   'wrdhsghy'],
#  ['safm',
#   'sanderson',
#   'farms',
#   'dips',
#   'on',
#   'report',
#   'of',
#   'concessions',
#   'in',
#   'cargill',
#   'takeover',
#   't',
#   'co',
#   'lyqkkoln'],
#  ['in',
#   'california',
#   'the',
#   'size',
#   'of',
#   'fields',
#   'intended',
#   'for',
#   'almonds',
#   'rice',
#   'wine',
#   'grapes',
#   'and',
#   'other',
#   'crops',
#   'left',
#   'unworked',
#   'could',
#   'be',
#   'around',
#   'acres',
#   't',
#   'co',
#   'acjbwjqtv'],
#  ['donald',
#   'trump',
#   'paid',
#   'respects',
#   'to',
#   'his',
#   'first',
#   'wife',
#   'ivana',
#   'trump',
#   'joining',
#   'their',
#   'children',
#   'ivanka',
#   'don',
#   'jr',
#   'and',
#   'eric',
#   'at',
#   'st',
#   'vincent',
#   'ferrer',
#   'roman',
#   'catholic',
#   'church',
#   'for',
#   'a',
#   'funeral',
#   'service',
#   't',
#   'co',
#   'omlhsxmwsz',
#   't',
#   'co',
#   'kdsfxgqr'],
#  ['llkkf',
#   'lake',
#   'resources',
#   'lithium',
#   'process',
#   'slammed',
#   'by',
#   'short',
#   'seller',
#   'report',
#   't',
#   'co',
#   'dpeovj'],
#  ['watch',
#   'on',
#   'breakingviews',
#   'australia',
#   's',
#   'new',
#   'government',
#   'is',
#   'more',
#   'committed',
#   'to',
#   'tackling',
#   'global',
#   'warming',
#   'than',
#   'its',
#   'predecessor',
#   'on',
#   'the',
#   'other',
#   'hand',
#   'it',
#   'wants',
#   'to',
#   'keep',
#   'exporting',
#   'coal',
#   'and',
#   'gas',
#   'that',
#   'drives',
#   'up',
#   'emissions',
#   'seeding',
#   'more',
#   'climate',
#   'disasters',
#   'says',
#   'antonymcurrie',
#   't',
#   'co',
#   'tovncgvl'],
#  ['tues',
#   'amzn',
#   'aws',
#   'summit',
#   'yr',
#   'note',
#   'auction',
#   'amzn',
#   'prime',
#   'days',
#   'wed',
#   'cpi',
#   'oil',
#   'inv',
#   'beige',
#   'book',
#   'th',
#   'ppi',
#   'jpm',
#   'ms',
#   'fri',
#   'china',
#   'gdp',
#   'us',
#   'retail',
#   'sales',
#   'consumer',
#   'confidence',
#   'goog',
#   'split',
#   'c',
#   'bac',
#   'gs',
#   'nflx',
#   'tsla',
#   'eps'],
#  ['genting',
#   'singapore',
#   'one',
#   'of',
#   'the',
#   'city',
#   'state',
#   's',
#   'two',
#   'casino',
#   'operators',
#   'is',
#   'attracting',
#   'takeover',
#   'interest',
#   'as',
#   'tourists',
#   'start',
#   'coming',
#   'back',
#   'to',
#   'the',
#   'asian',
#   'travel',
#   'hub',
#   'sources',
#   'said',
#   't',
#   'co',
#   'aiscarktby'],
#  ['zyme',
#   'zymeworks',
#   'plans',
#   'to',
#   'become',
#   'a',
#   'delaware',
#   'corporation',
#   't',
#   'co',
#   'eawbfwrsrq'],
#  ['fourkites',
#   'sees',
#   'recovery',
#   'at',
#   'chinese',
#   'ports',
#   'as',
#   'covid',
#   'lockdowns',
#   'ease',
#   't',
#   'co',
#   'tsftpbs',
#   't',
#   'co',
#   'abubuwngfr'],
#  ['s',
#   'korean',
#   'won',
#   'opens',
#   'onshore',
#   'trade',
#   'at',
#   'per',
#   'dollar',
#   'vs',
#   'at',
#   'previous',
#   'close'],
#  ['nord',
#   'stream',
#   'russian',
#   'gas',
#   'shipments',
#   'resumed',
#   'on',
#   'thursday',
#   'bbg',
#   't',
#   'co',
#   'juhfwbpmb'],
#  ['business',
#   'activity',
#   'in',
#   'the',
#   'region',
#   's',
#   'service',
#   'sector',
#   'declined',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'over',
#   'a',
#   'year',
#   'according',
#   'to',
#   'firms',
#   'responding',
#   'to',
#   'the',
#   'new',
#   'york',
#   'fed',
#   's',
#   'july',
#   'business',
#   'leaders',
#   'survey',
#   'the',
#   'survey',
#   's',
#   'headline',
#   'business',
#   'activity',
#   'index',
#   'fell',
#   'points',
#   'to',
#   'web',
#   't',
#   'co',
#   'stwoyyav',
#   't',
#   'co',
#   'fkcyzdr'],
#  ['taiwan',
#   's',
#   'foxconn',
#   'says',
#   'is',
#   'shareholder',
#   'of',
#   'troubled',
#   'chinese',
#   'chip',
#   'firm',
#   'reuters',
#   't',
#   'co',
#   'ydyvqpkvfd'],
#  ['now',
#   'that',
#   'the',
#   'james',
#   'webb',
#   'space',
#   'telescope',
#   'has',
#   'released',
#   'its',
#   'first',
#   'images',
#   'it',
#   's',
#   'time',
#   'for',
#   'the',
#   'science',
#   'to',
#   'begin',
#   'meet',
#   'five',
#   'scientists',
#   'who',
#   'll',
#   'analyze',
#   'the',
#   'earliest',
#   'galaxies',
#   'and',
#   'unexplored',
#   'regions',
#   'of',
#   'our',
#   'solar',
#   'system',
#   'watch',
#   'in',
#   'full',
#   't',
#   'co',
#   'vfnubkaf',
#   't',
#   'co',
#   'bontraghjt',
#   't',
#   'co',
#   'lgjgxhezfa'],
#  ['canadian',
#   'bond',
#   'and',
#   'index',
#   'update',
#   'mtlexchange',
#   't',
#   'co',
#   'popjw'],
#  ['facebook',
#   'owner',
#   'meta',
#   'releases',
#   'first',
#   'human',
#   'rights',
#   'report',
#   't',
#   'co',
#   'dzetwkfn'],
#  ['blk',
#   'blackrock',
#   'inc',
#   'blk',
#   'ceo',
#   'laurence',
#   'fink',
#   'on',
#   'q',
#   'results',
#   'earnings',
#   'call',
#   'transcript',
#   't',
#   'co',
#   'lellfebjd',
#   'stockmarket',
#   'markets',
#   'business'],
#  ['caredx',
#   'deadline',
#   'alert',
#   'bragar',
#   'eagel',
#   'amp',
#   'squire',
#   'p',
#   'c',
#   'reminds',
#   'investors',
#   'that',
#   'a',
#   'class',
#   'action',
#   'lawsuit',
#   'has',
#   'been',
#   'filed',
#   'against',
#   'caredx',
#   'inc',
#   'and',
#   'encourages',
#   'investors',
#   'to',
#   'contact',
#   'the',
#   'firm',
#   't',
#   'co',
#   'unyswrpo'],
#  ['nept',
#   'flagging',
#   'here',
#   'for',
#   'another',
#   'leg',
#   'up',
#   'look',
#   'at',
#   'the',
#   'volume',
#   'accumulation',
#   'over',
#   'the',
#   'past',
#   'sessions',
#   'once',
#   'it',
#   'breaks',
#   'next',
#   'pv',
#   'lies',
#   'at',
#   'then',
#   'gap',
#   'zone',
#   'chart',
#   'speaks',
#   'for',
#   'itself',
#   't',
#   'co',
#   'qidiizmsob'],
#  ['alzamend',
#   'neuro',
#   'receives',
#   'positive',
#   'pre',
#   'ind',
#   'response',
#   'from',
#   'fda',
#   'for',
#   'al',
#   'treatment',
#   'of',
#   'bipolar',
#   'disorder',
#   'major',
#   'depressive',
#   'disorder',
#   'and',
#   'post',
#   'traumatic',
#   'stress',
#   'disorder',
#   't',
#   'co',
#   'sloduluusx',
#   't',
#   'co',
#   'shblocblc'],
#  ['nemacolin',
#   'selects',
#   'optii',
#   'as',
#   'its',
#   'housekeeping',
#   'management',
#   'platform',
#   't',
#   'co',
#   'bauzidqnuj',
#   't',
#   'co',
#   'cgzdynloq'],
#  ['rhhby',
#   'roche',
#   'hldg',
#   'board',
#   'of',
#   'directors',
#   'has',
#   'appointed',
#   'thomas',
#   'schinecker',
#   'as',
#   'the',
#   'new',
#   'roche',
#   'ceo',
#   'effective',
#   'march',
#   't',
#   'co',
#   'olocwmxa'],
#  ['ranpak',
#   'expands',
#   'automated',
#   'packaging',
#   'portfolio',
#   'with',
#   'global',
#   'launch',
#   'of',
#   'the',
#   'flap',
#   'it',
#   'solution',
#   't',
#   'co',
#   'gkiounmn',
#   't',
#   'co',
#   'evoshcdup'],
#  ['breaking',
#   'judge',
#   'sets',
#   'october',
#   'trial',
#   'over',
#   'elon',
#   'musk',
#   's',
#   'bid',
#   'to',
#   'walk',
#   'away',
#   'from',
#   'his',
#   'billion',
#   'company',
#   'acquisition',
#   'twtr',
#   't',
#   'co',
#   'akqqrzvpsi'],
#  ['emx',
#   'emx',
#   'royalty',
#   'commences',
#   'commercial',
#   'production',
#   'for',
#   'oxide',
#   'gold',
#   'mineralization',
#   'at',
#   'its',
#   'flagship',
#   'gediktepe',
#   'royalty',
#   't',
#   'co',
#   'cqlgwcx'],
#  ['business',
#   'travelers',
#   'are',
#   'filling',
#   'eurostar',
#   'trains',
#   'as',
#   'airports',
#   'and',
#   'airlines',
#   'cancel',
#   'thousands',
#   'of',
#   'flights',
#   't',
#   'co',
#   'ayfxaowcd'],
#  ['vblt',
#   'adil',
#   'rvmd',
#   'baker',
#   'hughes',
#   'bath',
#   'amp',
#   'body',
#   'works',
#   'revolution',
#   'medicines',
#   'among',
#   'premarket',
#   'losers',
#   'pack',
#   't',
#   'co',
#   'jqwsnajgx'],
#  ['i',
#   'am',
#   'very',
#   'saddened',
#   'to',
#   'inform',
#   'all',
#   'of',
#   'those',
#   'that',
#   'loved',
#   'her',
#   'of',
#   'which',
#   'there',
#   'are',
#   'many',
#   'that',
#   'ivana',
#   'trump',
#   'has',
#   'passed',
#   'away',
#   'at',
#   'her',
#   'home',
#   'in',
#   'new',
#   'york',
#   'city',
#   'former',
#   'president',
#   'donald',
#   'trump',
#   'posted',
#   'on',
#   'truth',
#   'social',
#   't',
#   'co',
#   'bkwzip'],
#  ['turkey',
#   's',
#   'president',
#   'erdogan',
#   'will',
#   'discuss',
#   'paying',
#   'for',
#   'russian',
#   'energy',
#   'imports',
#   'with',
#   'currencies',
#   'other',
#   'than',
#   'the',
#   'us',
#   'dollar',
#   'when',
#   'he',
#   'meets',
#   'vladimir',
#   'putin',
#   'sources',
#   'say',
#   't',
#   'co',
#   'vlhtvrbm'],
#  ['t', 'co', 'atixwyfal', 'shares', 'hit', 'session', 'low', 'last', 'up'],
#  ['norway',
#   's',
#   'inflation',
#   'hits',
#   'a',
#   'year',
#   'high',
#   'feeding',
#   'speculation',
#   'that',
#   'the',
#   'central',
#   'bank',
#   'will',
#   'keep',
#   'up',
#   'the',
#   'accelerated',
#   'pace',
#   'of',
#   'interest',
#   'rate',
#   'hikes',
#   't',
#   'co',
#   'xpqidteenf'],
#  ['watch',
#   'from',
#   'breakingviews',
#   'ge',
#   'revealed',
#   'the',
#   'names',
#   'of',
#   'the',
#   'companies',
#   'it',
#   'will',
#   'split',
#   'into',
#   'ge',
#   'aerospace',
#   'ge',
#   'vernova',
#   'and',
#   'ge',
#   'healthcare',
#   'the',
#   'names',
#   'are',
#   'as',
#   'pedestrian',
#   'as',
#   'ge',
#   's',
#   'stock',
#   'performance',
#   'lauren',
#   'silva',
#   'laughlin',
#   'says',
#   't',
#   'co',
#   'kuhhgzckg'],
#  ['blue',
#   'apron',
#   'to',
#   'release',
#   'second',
#   'quarter',
#   'results',
#   'on',
#   'august',
#   't',
#   'co',
#   'qkygadtnz',
#   't',
#   'co',
#   'nonhhcfzb'],
#  ['elv',
#   'elevance',
#   'health',
#   'beats',
#   'q',
#   'estimates',
#   'thanks',
#   'to',
#   'rising',
#   'premium',
#   'revenue',
#   't',
#   'co',
#   'cbvvjpka'],
#  ['cost',
#   'costco',
#   'at',
#   'session',
#   'highs',
#   'after',
#   'deutsche',
#   'bank',
#   'upgrade',
#   'shares',
#   'now',
#   'higher',
#   'off',
#   'yesterday',
#   's',
#   'lows',
#   't',
#   'co',
#   'vrnkkfkbhr'],
#  ['fisker',
#   'hired',
#   'a',
#   'longtime',
#   'bmw',
#   'executive',
#   'to',
#   'lead',
#   'global',
#   'manufacturing',
#   'efforts',
#   'ahead',
#   'of',
#   'the',
#   'startup',
#   's',
#   'plan',
#   'to',
#   'begin',
#   'building',
#   'electric',
#   'vehicles',
#   'later',
#   'this',
#   'year',
#   't',
#   'co',
#   'bfrpjlzs'],
#  ['tsla',
#   'tesla',
#   'q',
#   'don',
#   't',
#   'bet',
#   'on',
#   'elon',
#   'musk',
#   'overdelivering',
#   't',
#   'co',
#   'rgfhcumn',
#   'investing',
#   'stocks',
#   'finance'],
#  ['s',
#   'korean',
#   'president',
#   'yoon',
#   'urges',
#   'shipyard',
#   'strike',
#   'to',
#   'end',
#   'negotiations',
#   'stalled',
#   't',
#   'co',
#   'eqbozcx',
#   't',
#   'co',
#   'ozeohejm'],
#  ['jcyte',
#   'announces',
#   'appointment',
#   'of',
#   'dr',
#   'stewart',
#   'craig',
#   'as',
#   'chief',
#   'technology',
#   'officer',
#   't',
#   'co',
#   'fenbakpy',
#   't',
#   'co',
#   'tgzttodg'],
#  ['a',
#   'halt',
#   'of',
#   'russian',
#   'gas',
#   'supplies',
#   'to',
#   'the',
#   'european',
#   'union',
#   'could',
#   'potentially',
#   'reduce',
#   'its',
#   'gross',
#   'domestic',
#   'product',
#   'by',
#   'as',
#   'much',
#   'as',
#   'according',
#   'to',
#   'new',
#   'estimates',
#   'from',
#   'the',
#   'bloc',
#   't',
#   'co',
#   'yfpwrwo'],
#  ['ibm',
#   'cautioned',
#   'that',
#   'the',
#   'impact',
#   'of',
#   'the',
#   'strongest',
#   'dollar',
#   'in',
#   'more',
#   'than',
#   'two',
#   'decades',
#   'would',
#   'erode',
#   'full',
#   'year',
#   'sales',
#   'by',
#   'around',
#   'billion',
#   't',
#   'co',
#   'ndpvozmzl'],
#  ['from',
#   'breakingviews',
#   'saudi',
#   'can',
#   'win',
#   'two',
#   'ways',
#   'in',
#   'global',
#   'energy',
#   'reshuffle',
#   't',
#   'co',
#   'asbafcgsn'],
#  ['lzb',
#   'la',
#   'z',
#   'boy',
#   'finalizes',
#   'plans',
#   'for',
#   'previously',
#   'announced',
#   'closure',
#   'of',
#   'its',
#   'newton',
#   'ms',
#   'facility',
#   't',
#   'co',
#   'kmupvvo'],
#  ['italian',
#   'premier',
#   'mario',
#   'draghi',
#   'says',
#   'he',
#   'will',
#   'resign',
#   't',
#   'co',
#   'ivwawkar'],
#  ['president',
#   'jair',
#   'bolsonaro',
#   'gets',
#   'the',
#   'green',
#   'light',
#   'to',
#   'spend',
#   'billion',
#   'to',
#   'help',
#   'brazilians',
#   'suffering',
#   'with',
#   'inflation',
#   't',
#   'co',
#   'atnfocisy'],
#  ['aci',
#   'fraud',
#   'management',
#   'wins',
#   'at',
#   'merchant',
#   'payments',
#   'ecosystem',
#   'awards',
#   't',
#   'co',
#   'pwwisrhvpm',
#   't',
#   'co',
#   'lnvqewsq'],
#  ['new',
#   'zealand',
#   'jun',
#   'exports',
#   'actual',
#   'b',
#   'vs',
#   'b',
#   'previous',
#   'new',
#   'zealand',
#   'jun',
#   'imports',
#   'actual',
#   'b',
#   'vs',
#   'b',
#   'previous'],
#  ['spy',
#   'july',
#   'p',
#   'entry',
#   'contracts',
#   'min',
#   'inverted',
#   'hammer',
#   'min',
#   'very',
#   'bearish'],
#  ['candidates',
#   'for',
#   'conservative',
#   'party',
#   'leader',
#   'are',
#   'left',
#   'to',
#   'battle',
#   'for',
#   'the',
#   'spots',
#   'in',
#   'a',
#   'run',
#   'off',
#   'vote',
#   'to',
#   'replace',
#   'boris',
#   'johnson',
#   'as',
#   'the',
#   'uk',
#   's',
#   'next',
#   'prime',
#   'minister',
#   't',
#   'co',
#   'hqtmdyjr'],
#  ['taoglas',
#   'and',
#   'novotech',
#   'announce',
#   'partnership',
#   'to',
#   'deliver',
#   'iot',
#   'excellence',
#   'in',
#   'canada',
#   't',
#   'co',
#   'ojtjygssw',
#   't',
#   'co',
#   'bfkcnytmf'],
#  ['ecu',
#   'health',
#   'partners',
#   'with',
#   'acadia',
#   'healthcare',
#   'to',
#   'build',
#   'a',
#   'new',
#   'behavioral',
#   'health',
#   'hospital',
#   'expanding',
#   'access',
#   'to',
#   'behavioral',
#   'health',
#   'services',
#   't',
#   'co',
#   'zmzcdyjnqv',
#   't',
#   'co',
#   'muficw'],
#  ['pioneer',
#   'landscape',
#   'centers',
#   'launches',
#   'service',
#   'to',
#   'help',
#   'customers',
#   'increase',
#   'productivity',
#   'and',
#   'cost',
#   'savings',
#   't',
#   'co',
#   'npukckv',
#   't',
#   'co',
#   'gtconakks'],
#  ['sisvel',
#   'launches',
#   'a',
#   'patent',
#   'pool',
#   'on',
#   'wi',
#   'fi',
#   't',
#   'co',
#   'ipojriiw',
#   't',
#   'co',
#   'zyjgsvtnr'],
#  ['bloomberg',
#   'economics',
#   'new',
#   'nowcast',
#   'model',
#   'flags',
#   'that',
#   'us',
#   'gdp',
#   'may',
#   'have',
#   'contracted',
#   'in',
#   'the',
#   'second',
#   'quarter',
#   't',
#   'co',
#   'axuqvaal'],
#  ['pjt',
#   'partners',
#   'inc',
#   'to',
#   'report',
#   'second',
#   'quarter',
#   'financial',
#   'results',
#   'and',
#   'host',
#   'a',
#   'conference',
#   'call',
#   'on',
#   'july',
#   't',
#   'co',
#   'fcdwxgpwe'],
#  ['qd',
#   'qudian',
#   'chief',
#   'turns',
#   'to',
#   'star',
#   'power',
#   'in',
#   'company',
#   'transformation',
#   't',
#   'co',
#   'majhxmef',
#   'stocks',
#   'finance',
#   'economy'],
#  ['watch',
#   'from',
#   'elon',
#   'musk',
#   's',
#   'bid',
#   'to',
#   'avoid',
#   'buying',
#   'twitter',
#   'to',
#   'hedge',
#   'fund',
#   'titan',
#   'bill',
#   'ackman',
#   'giving',
#   'back',
#   'billion',
#   'to',
#   'investors',
#   'we',
#   'round',
#   'up',
#   'the',
#   'big',
#   'stories',
#   'in',
#   'business',
#   'and',
#   'finance',
#   'over',
#   'the',
#   'week',
#   't',
#   'co',
#   'dulwafjle'],
#  ['qh',
#   'quhuo',
#   'cfo',
#   'wenting',
#   'ji',
#   'to',
#   'resign',
#   't',
#   'co',
#   'zenppugwq'],
#  ['heard',
#   'on',
#   'the',
#   'street',
#   'apple',
#   'microsoft',
#   'and',
#   'google',
#   'pare',
#   'back',
#   'hiring',
#   'plans',
#   'as',
#   'slowing',
#   'growth',
#   'puts',
#   'focus',
#   'on',
#   'maintaining',
#   'margins',
#   't',
#   'co',
#   'trwxeeoywt'],
#  ['oil',
#   'prices',
#   'have',
#   'fallen',
#   'below',
#   'a',
#   'barrel',
#   'for',
#   'the',
#   'first',
#   'time',
#   'since',
#   'russia',
#   'invaded',
#   'ukraine',
#   'as',
#   'fears',
#   'of',
#   'an',
#   'impending',
#   'global',
#   'recession',
#   'grip',
#   'commodity',
#   'markets',
#   'and',
#   'batter',
#   'forecasts',
#   'for',
#   'demand',
#   't',
#   'co',
#   'optiagcr',
#   't',
#   'co',
#   'cmqdhgygh'],
#  ['india',
#   's',
#   'central',
#   'bank',
#   'governor',
#   'says',
#   'monetary',
#   'policy',
#   'is',
#   'mindful',
#   'of',
#   'the',
#   'economy',
#   's',
#   'growth',
#   'needs',
#   'signaling',
#   'that',
#   'tightening',
#   'will',
#   'be',
#   'geared',
#   'to',
#   'ensure',
#   'there',
#   'isn',
#   't',
#   'a',
#   'massive',
#   'slowdown',
#   't',
#   'co',
#   'zxdxoktu'],
#  ['nasdaq',
#   'profits',
#   'top',
#   'wall',
#   'street',
#   'views',
#   'as',
#   'software',
#   'services',
#   'rise',
#   't',
#   'co',
#   'syaycqvtqc',
#   't',
#   'co',
#   'kwvuglinq'],
#  ['singapore',
#   'central',
#   'bank',
#   'tightens',
#   'monetary',
#   'policy',
#   'in',
#   'unexpected',
#   'move',
#   't',
#   'co',
#   'peogwelc'],
#  ['the',
#   'single',
#   'biggest',
#   'problem',
#   'of',
#   'the',
#   'last',
#   'years',
#   'has',
#   'been',
#   'low',
#   'growth',
#   'it',
#   's',
#   'why',
#   'we',
#   've',
#   'got',
#   'such',
#   'an',
#   'acute',
#   'cost',
#   'of',
#   'living',
#   'crisis',
#   'why',
#   'we',
#   'have',
#   'got',
#   'inflation',
#   'that',
#   'is',
#   'so',
#   'high',
#   'keir',
#   'starmer',
#   'tells',
#   'bloomberg',
#   't',
#   'co',
#   'dpgdxjls'],
#  ['the',
#   'worldwide',
#   'copper',
#   'pyrithione',
#   'industry',
#   'is',
#   'expected',
#   'to',
#   'reach',
#   'million',
#   'by',
#   't',
#   'co',
#   'guyibzphc',
#   't',
#   'co',
#   'gcoawsri',
#   't',
#   'co',
#   'fqxxylit'],
#  ['comdx', 'energy', 'settlement', 'prices', 't', 'co', 'voawng'],
#  ['ctm',
#   'surpasses',
#   'expectations',
#   'at',
#   'the',
#   'global',
#   'cybersecurity',
#   'conference',
#   'firstcon',
#   't',
#   'co',
#   'tduewkeoss',
#   't',
#   'co',
#   'zmdvjguri'],
#  ['curo',
#   'closes',
#   'million',
#   'facility',
#   't',
#   'co',
#   'ootxvrk',
#   't',
#   'co',
#   'mnvnlkikh'],
#  ['soaring',
#   'us',
#   'inflation',
#   'is',
#   'squeezing',
#   'the',
#   'living',
#   'standards',
#   'of',
#   'manufacturing',
#   'workers',
#   'especially',
#   'hard',
#   'adding',
#   'to',
#   'the',
#   'danger',
#   'democrats',
#   'face',
#   'in',
#   'key',
#   'battleground',
#   'states',
#   'in',
#   'the',
#   'midterm',
#   'elections',
#   't',
#   'co',
#   'iiezusmri'],
#  ['belarus',
#   'russia',
#   's',
#   'most',
#   'loyal',
#   'ally',
#   'was',
#   'declared',
#   'in',
#   'default',
#   'by',
#   'fitch',
#   'ratings',
#   'joining',
#   'moody',
#   's',
#   'investors',
#   'service',
#   't',
#   'co',
#   'gneulqmz'],
#  ['boe',
#   's',
#   'bailey',
#   'expecting',
#   'inflation',
#   'to',
#   'come',
#   'down',
#   'rapidly',
#   'next',
#   'year'],
#  ['kkr',
#   'anzby',
#   'kkr',
#   'is',
#   'said',
#   'to',
#   'seek',
#   'over',
#   'b',
#   'for',
#   'myob',
#   'group',
#   'in',
#   'talks',
#   'with',
#   'anz',
#   't',
#   'co',
#   'uvtuajdvx'],
#  ['bondx', 'new', 'supply', 't', 'co', 'lryjvmgnp'],
#  ['wabtec',
#   'announces',
#   'second',
#   'quarter',
#   'earnings',
#   'release',
#   'date',
#   't',
#   'co',
#   'priupvon',
#   't',
#   'co',
#   'zhvztojfov'],
#  ['citibank',
#   'uk',
#   'regulatory',
#   'announcement',
#   'frn',
#   'variable',
#   'rate',
#   'fix',
#   't',
#   'co',
#   'mivaumlos',
#   't',
#   'co',
#   'cwzryhwew'],
#  ['breaking',
#   'company',
#   'can',
#   'fast',
#   'track',
#   'its',
#   'lawsuit',
#   'against',
#   'elon',
#   'musk',
#   'over',
#   'his',
#   'canceled',
#   'buyout',
#   'according',
#   'to',
#   'a',
#   'delaware',
#   'judge',
#   'the',
#   'trial',
#   'will',
#   'take',
#   'place',
#   'in',
#   'october',
#   't',
#   'co',
#   'iouioeya',
#   't',
#   'co',
#   'jenkhdchl'],
#  ['bank',
#   'data',
#   'shows',
#   'u',
#   's',
#   'consumer',
#   'financial',
#   'health',
#   'holds',
#   'up',
#   'amid',
#   'rising',
#   'inflation',
#   'reuters',
#   't',
#   'co',
#   'ygksglfjc'],
#  ['meridianlink',
#   'appoints',
#   'duston',
#   'williams',
#   'to',
#   'its',
#   'board',
#   'of',
#   'directors',
#   't',
#   'co',
#   'plyvjtecf',
#   't',
#   'co',
#   'dtpvdtva'],
#  ['u', 's', 'stocks', 'extend', 'fall', 's', 'amp', 'p', 'down'],
#  ['inflation',
#   'so',
#   'high',
#   'americans',
#   'are',
#   'cutting',
#   'back',
#   'on',
#   'food',
#   'spending',
#   't',
#   'co',
#   'uhovct'],
#  ['interest',
#   'policy',
#   'will',
#   'help',
#   'nubank',
#   'lower',
#   'funding',
#   'costs',
#   'say',
#   'analysts',
#   't',
#   'co',
#   'dycztrjege',
#   't',
#   'co',
#   'ibhqxbdcuz'],
#  ['equitiesfirst',
#   'is',
#   'unnamed',
#   'debtor',
#   'to',
#   'troubled',
#   'crypto',
#   'firm',
#   'celsius',
#   't',
#   'co',
#   'dduicfuh'],
#  ['siemens',
#   'energy',
#   'to',
#   'power',
#   'the',
#   'world',
#   's',
#   'lowest',
#   'emission',
#   'lng',
#   'facility',
#   't',
# ...
#   'unsolicited',
#   'mini',
#   'tender',
#   'offer',
#   't',
#   'co',
#   'gbjxfctnk'],
#  ['fed',
#   's',
#   'mester',
#   'expect',
#   'fed',
#   'will',
#   'need',
#   'to',
#   'go',
#   'well',
#   'beyond',
#   'neutral',
#   'rate',
#   'bbg',
#   'tv'],
#  ['ivz',
#   'invesco',
#   'reports',
#   'preliminary',
#   'month',
#   'end',
#   'assets',
#   'under',
#   'management',
#   'of',
#   'bln',
#   'as',
#   'of',
#   'june',
#   'a',
#   'decrease',
#   'of',
#   't',
#   'co',
#   'vlpglh'],
#  ['air', 'aar', 'q', 'earnings', 'preview', 't', 'co', 'soylsngv'],
#  ['olb', 'intraday', 'break', 'on', 'heavy', 'volume'],
#  ['ukraine',
#   'is',
#   'seeking',
#   'to',
#   'delay',
#   'payments',
#   'on',
#   'foreign',
#   'debt',
#   'and',
#   'change',
#   'terms',
#   'of',
#   'gdp',
#   'warrants',
#   'as',
#   'russia',
#   's',
#   'invasion',
#   'undermines',
#   'the',
#   'economy',
#   't',
#   'co',
#   'vxhefzn'],
#  ['accenture',
#   'to',
#   'acquire',
#   'the',
#   'stable',
#   'to',
#   'bolster',
#   'its',
#   'commerce',
#   'transformation',
#   'expertise',
#   'in',
#   'north',
#   'america',
#   't',
#   'co',
#   'zqdvfgfg',
#   't',
#   'co',
#   'ghsbbonvhy'],
#  ['cbu',
#   'community',
#   'bank',
#   'system',
#   'raises',
#   'quarterly',
#   'dividend',
#   'by',
#   't',
#   'co',
#   'mefxgtajk'],
#  ['japan',
#   'reported',
#   'a',
#   'trade',
#   'deficit',
#   'for',
#   'a',
#   'th',
#   'consecutive',
#   'month',
#   'in',
#   'june',
#   'as',
#   'higher',
#   'energy',
#   'prices',
#   'and',
#   'a',
#   'weaker',
#   'yen',
#   'continued',
#   'to',
#   'inflate',
#   'the',
#   'nation',
#   's',
#   'import',
#   'bill',
#   't',
#   'co',
#   'spkatwdrwv'],
#  ['nord',
#   'stream',
#   'gas',
#   'pipeline',
#   'nominations',
#   'at',
#   'kwh',
#   'h',
#   'for',
#   'cet',
#   'rtrs'],
#  ['joe',
#   'biden',
#   'i',
#   'will',
#   'use',
#   'force',
#   'to',
#   'stop',
#   'iran',
#   'getting',
#   'a',
#   'nuclear',
#   'weapon',
#   'the',
#   'telegraph',
#   't',
#   'co',
#   'yhbhypuorr'],
#  ['redwood',
#   'trust',
#   'announces',
#   'date',
#   'of',
#   'second',
#   'quarter',
#   'financial',
#   'results',
#   'webcast',
#   'and',
#   'conference',
#   'call',
#   't',
#   'co',
#   'mjbmysvksr',
#   't',
#   'co',
#   'ergdpjzn'],
#  ['epd',
#   'enterprise',
#   'products',
#   'partners',
#   'cheap',
#   'yield',
#   'and',
#   'the',
#   'distribution',
#   'just',
#   'grew',
#   't',
#   'co',
#   'leydby',
#   'economy',
#   'business',
#   'stocks'],
#  ['the',
#   'global',
#   'boss',
#   'of',
#   'pwc',
#   'said',
#   'the',
#   'firm',
#   'would',
#   'report',
#   'record',
#   'revenues',
#   'of',
#   'about',
#   'bn',
#   'this',
#   'year',
#   'as',
#   'he',
#   'defended',
#   'the',
#   'model',
#   'of',
#   'combining',
#   'audit',
#   'and',
#   'consulting',
#   'services',
#   't',
#   'co',
#   'ehoywbyd'],
#  ['britain',
#   's',
#   'wealth',
#   'gap',
#   'increased',
#   'by',
#   'since',
#   'according',
#   'to',
#   'a',
#   'think',
#   'tank',
#   't',
#   'co',
#   'sojjkuxa'],
#  ['investor',
#   'alert',
#   'law',
#   'offices',
#   'of',
#   'howard',
#   'g',
#   'smith',
#   'announces',
#   'investigation',
#   'of',
#   't',
#   'co',
#   'fzwqukvei',
#   'inc',
#   'amzn',
#   'on',
#   'behalf',
#   'of',
#   'investors',
#   't',
#   'co',
#   'olgugxqc',
#   't',
#   'co',
#   'yiwlhjc'],
#  ['nvta',
#   'pre',
#   'invitae',
#   'announces',
#   'strategic',
#   'business',
#   'realignment',
#   'to',
#   'accelerate',
#   'its',
#   'path',
#   'to',
#   'positive',
#   'cash',
#   'flow',
#   'and',
#   'realize',
#   'full',
#   'potential',
#   'of',
#   'industry',
#   'leading',
#   'genetics',
#   'testing',
#   'platform',
#   'prn',
#   't',
#   'co',
#   'dgdemtxzqv'],
#  ['in',
#   'china',
#   'the',
#   'government',
#   'usually',
#   'gets',
#   'what',
#   'it',
#   'wants',
#   'that',
#   's',
#   'what',
#   'made',
#   'beijing',
#   's',
#   'vaccine',
#   'mandate',
#   'reversal',
#   'so',
#   'interesting',
#   't',
#   'co',
#   'hqewxvjk'],
#  ['president',
#   'xi',
#   'jinping',
#   'hasn',
#   't',
#   'made',
#   'a',
#   'reported',
#   'public',
#   'appearance',
#   'for',
#   'days',
#   'since',
#   'returning',
#   'from',
#   'a',
#   'landmark',
#   'trip',
#   'to',
#   'hong',
#   'kong',
#   'that',
#   'was',
#   'his',
#   'first',
#   'outside',
#   'mainland',
#   'china',
#   'since',
#   'the',
#   'pandemic',
#   's',
#   'outset',
#   't',
#   'co',
#   'tgpyopyz'],
#  ['total',
#   'corporate',
#   'funding',
#   'for',
#   'solar',
#   'sector',
#   'totaled',
#   'billion',
#   'in',
#   'h',
#   't',
#   'co',
#   'rasfcbp',
#   't',
#   'co',
#   'eftvbof'],
#  ['gm',
#   'reveals',
#   'its',
#   'new',
#   'electric',
#   'chevrolet',
#   'blazer',
#   'priced',
#   'starting',
#   'at',
#   't',
#   'co',
#   'jmbxbslomp'],
#  ['discover',
#   'partners',
#   'with',
#   'artist',
#   'and',
#   'influencer',
#   'to',
#   'create',
#   'next',
#   'design',
#   'for',
#   'discover',
#   'student',
#   'cards',
#   't',
#   'co',
#   'xmhiggr',
#   't',
#   'co',
#   'yrkijsutg'],
#  ['dov',
#   'dover',
#   'non',
#   'gaap',
#   'eps',
#   'of',
#   'beats',
#   'by',
#   'revenue',
#   'of',
#   'm',
#   'misses',
#   'by',
#   'b',
#   'provides',
#   'fy',
#   'adj',
#   'eps',
#   'guidance',
#   't',
#   'co',
#   'xicfngyjxk'],
#  ['ee',
#   'excelerate',
#   'energy',
#   'signs',
#   'mou',
#   'with',
#   'bulgaria',
#   's',
#   'overgas',
#   'relating',
#   'to',
#   'regasified',
#   'lng',
#   'downstream',
#   'sales',
#   't',
#   'co',
#   'arwsnble'],
#  ['aal',
#   'and',
#   'ual',
#   'both',
#   'report',
#   'q',
#   'earnings',
#   'misses',
#   't',
#   'co',
#   'arwczykvu'],
#  ['plrx',
#   'pliant',
#   'therapeutics',
#   'prices',
#   'offering',
#   'of',
#   'shares',
#   'of',
#   'its',
#   'common',
#   'stock',
#   'at',
#   'per',
#   'share',
#   't',
#   'co',
#   'xtxbkbsg'],
#  ['in',
#   'bitcoin',
#   'everyone',
#   's',
#   'equal',
#   'or',
#   'so',
#   'the',
#   'theory',
#   'goes',
#   'but',
#   'does',
#   'the',
#   'theory',
#   'match',
#   'the',
#   'reality',
#   'alyssa',
#   'blackburn',
#   'and',
#   'dr',
#   'erez',
#   'lieberman',
#   'aiden',
#   'discuss',
#   'their',
#   'research',
#   'into',
#   'who',
#   'controlled',
#   'bitcoin',
#   'from',
#   'the',
#   'early',
#   'days',
#   'apple',
#   't',
#   'co',
#   'brpjope',
#   'spotify',
#   't',
#   'co',
#   'dkfnzpsll',
#   't',
#   'co',
#   'itnocxr'],
#  ['uber',
#   'pre',
#   'uber',
#   'broke',
#   'laws',
#   'duped',
#   'police',
#   'and',
#   'secretly',
#   'lobbied',
#   'governments',
#   'leak',
#   'reveals',
#   'the',
#   'guardian',
#   't',
#   'co',
#   'cjvtjtyvxl'],
#  ['japan', 'machine', 'tool', 'orders', 'y', 'y', 'jun', 'f', 'prev'],
#  ['clearhaven',
#   'partners',
#   'invests',
#   'm',
#   'for',
#   'a',
#   'controlling',
#   'interest',
#   'in',
#   'sundaysky',
#   't',
#   'co',
#   'yhhyhhxxfx',
#   't',
#   'co',
#   'eykrxnbn'],
#  ['white',
#   'house',
#   'says',
#   'president',
#   'biden',
#   'has',
#   'tested',
#   'positive',
#   'for',
#   'covid'],
#  ['j',
#   'amp',
#   'j',
#   'trims',
#   'outlook',
#   'but',
#   'tops',
#   'earnings',
#   'expectations',
#   't',
#   'co',
#   'uryezzf'],
#  ['unp',
#   'union',
#   'pacific',
#   'beats',
#   'by',
#   'beats',
#   'on',
#   'revs',
#   't',
#   'co',
#   'eizveqvzw'],
#  ['srne',
#   'sorrento',
#   'gains',
#   'as',
#   'fda',
#   'clears',
#   'phase',
#   'trial',
#   'for',
#   'covid',
#   'therapeutic',
#   't',
#   'co',
#   'zlcnevuwe'],
#  ['usd',
#   'partners',
#   'announces',
#   'quarterly',
#   'distribution',
#   'and',
#   'its',
#   'second',
#   'quarter',
#   'earnings',
#   'release',
#   'date',
#   't',
#   'co',
#   'wxqjovjm',
#   't',
#   'co',
#   'nsugowihvb'],
#  ['forever',
#   'collaborates',
#   'with',
#   'airwalk',
#   'for',
#   'nostalgic',
#   'back',
#   'to',
#   'school',
#   'collection',
#   't',
#   'co',
#   'quqoipmula',
#   't',
#   'co',
#   'szetudtt'],
#  ['viemed',
#   'healthcare',
#   'for',
#   'the',
#   'home',
#   'technical',
#   'analysis',
#   't',
#   'co',
#   'vexxpmnbsh',
#   'finance',
#   'markets',
#   'investing'],
#  ['markforged',
#   'sets',
#   'reporting',
#   'date',
#   'for',
#   'second',
#   'quarter',
#   'financial',
#   'results',
#   't',
#   'co',
#   'zyltpmrh',
#   't',
#   'co',
#   'tgwllll'],
#  ['high',
#   'yield',
#   'blue',
#   'chip',
#   'bargains',
#   'to',
#   'retire',
#   'in',
#   'safety',
#   'and',
#   'splendor',
#   't',
#   'co',
#   'lmjhhcep',
#   'economy',
#   'trading',
#   'stocks'],
#  ['biden',
#   'urges',
#   'senate',
#   'to',
#   'pass',
#   'build',
#   'back',
#   'better',
#   'bill',
#   'without',
#   'climate',
#   'measures',
#   't',
#   'co',
#   'bmvufftara'],
#  ['comdx', 'energy', 'settlement', 'prices', 't', 'co', 'yeckxt'],
#  ['nvs',
#   'all',
#   'eyes',
#   'on',
#   'novartis',
#   'q',
#   'show',
#   'amid',
#   'likely',
#   'impact',
#   'from',
#   'strong',
#   'dollar',
#   't',
#   'co',
#   'pjqvkmrfcm'],
#  ['dov',
#   'dover',
#   'corporation',
#   'q',
#   'results',
#   'earnings',
#   'call',
#   'presentation',
#   't',
#   'co',
#   'rebijbx',
#   'stocks',
#   'stockmarket',
#   'trading'],
#  ['chinese',
#   'firms',
#   'grappling',
#   'with',
#   'a',
#   'delisting',
#   'wave',
#   'in',
#   'new',
#   'york',
#   'are',
#   'heading',
#   'for',
#   'zurich',
#   'drawn',
#   'by',
#   'its',
#   'greater',
#   'geopolitical',
#   'certainty',
#   'and',
#   'wealthy',
#   'investors',
#   't',
#   'co',
#   'ykuxjvwrc'],
#  ['now',
#   'servicenow',
#   'slumps',
#   'in',
#   'wake',
#   'of',
#   'ceo',
#   's',
#   'economic',
#   'comments',
#   't',
#   'co',
#   'usyfgqqitp'],
#  ['dubai',
#   's',
#   'metaverse',
#   'strategy',
#   'envisions',
#   'the',
#   'sector',
#   'supporting',
#   'as',
#   'many',
#   'as',
#   'additional',
#   'virtual',
#   'jobs',
#   'and',
#   'adding',
#   'billion',
#   'to',
#   'the',
#   'city',
#   's',
#   'gdp',
#   'in',
#   'five',
#   'years',
#   't',
#   'co',
#   'lircsfif'],
#  ['breaking',
#   'russia',
#   'reportedly',
#   'starts',
#   'sending',
#   'gas',
#   'to',
#   'europe',
#   'through',
#   'its',
#   'biggest',
#   'pipeline',
#   'nord',
#   'stream',
#   'offering',
#   'some',
#   'relief',
#   'after',
#   'skyrocketing',
#   'fuel',
#   'costs',
#   't',
#   'co',
#   'hxmikjgqk'],
#  ['elon',
#   'musk',
#   'has',
#   'accused',
#   'twitter',
#   'of',
#   'an',
#   'unjustifiable',
#   'request',
#   'to',
#   'rush',
#   'the',
#   'trial',
#   'to',
#   'determine',
#   'whether',
#   'he',
#   'should',
#   'be',
#   'forced',
#   'to',
#   'complete',
#   'a',
#   'bn',
#   'deal',
#   'to',
#   'buy',
#   'the',
#   'company',
#   't',
#   'co',
#   'mjmpuomw'],
#  ['xela', 'breaks', 'abv', 'c'],
#  ['roku',
#   'roku',
#   'netflix',
#   's',
#   'pivot',
#   'validates',
#   'advertising',
#   'business',
#   'model',
#   't',
#   'co',
#   'noomryq',
#   'stockmarket',
#   'markets',
#   'trading'],
#  ['trp',
#   'tc',
#   'energy',
#   'declares',
#   'force',
#   'majeure',
#   'on',
#   'keystone',
#   'pipeline',
#   't',
#   'co',
#   'dzfyeqknm'],
#  ['the',
#   'european',
#   'union',
#   'proposes',
#   'to',
#   'cut',
#   'its',
#   'natural',
#   'gas',
#   'consumption',
#   'by',
#   'over',
#   'the',
#   'next',
#   'eight',
#   'months',
#   'in',
#   'a',
#   'plan',
#   'that',
#   'would',
#   'affect',
#   'all',
#   'households',
#   'power',
#   'producers',
#   'and',
#   'industry',
#   't',
#   'co',
#   'xdlahvmg'],
#  ['ams',
#   'launches',
#   'full',
#   'service',
#   'high',
#   'volume',
#   'recruitment',
#   'solution',
#   'to',
#   'meet',
#   'hiring',
#   'challenges',
#   't',
#   'co',
#   'nbvytbsv',
#   't',
#   'co',
#   'yxfijgf'],
#  ['hmtv',
#   'stock',
#   'alert',
#   'halper',
#   'sadeh',
#   'llp',
#   'is',
#   'investigating',
#   'whether',
#   'the',
#   'sale',
#   'of',
#   'hemisphere',
#   'media',
#   'group',
#   'inc',
#   'is',
#   'fair',
#   'to',
#   'shareholders',
#   't',
#   'co',
#   'tmifbnbxc',
#   't',
#   'co',
#   'tzmghkqx'],
#  ['energy',
#   'prices',
#   'up',
#   'over',
#   'past',
#   'months',
#   't',
#   'co',
#   'njfrnuj',
#   'by',
#   'ines_ferre',
#   't',
#   'co',
#   'tnjbvtzl'],
#  ['european',
#   'stocks',
#   'extend',
#   'decline',
#   'after',
#   'us',
#   'inflation',
#   'data',
#   't',
#   'co',
#   'jatkvnzku',
#   't',
#   'co',
#   'pavfsrgse'],
#  ['wfc',
#   'wfc',
#   'pl',
#   'wfcnp',
#   'wells',
#   'fargo',
#   'amp',
#   'company',
#   'q',
#   'results',
#   'earnings',
#   'call',
#   'presentation',
#   't',
#   'co',
#   'qxnhghtkk',
#   'economy',
#   'business',
#   'investing'],
#  ['scandinavian',
#   'carrier',
#   'sas',
#   'warns',
#   'that',
#   'emergency',
#   'funding',
#   'related',
#   'to',
#   'a',
#   'bankruptcy',
#   'process',
#   'in',
#   'the',
#   'us',
#   'is',
#   'at',
#   'risk',
#   'from',
#   'a',
#   'pilots',
#   'strike',
#   'that',
#   'entered',
#   'its',
#   'th',
#   'day',
#   'on',
#   'thursday',
#   't',
#   'co',
#   'tfxaqzxla'],
#  ['iipr',
#   'iipr',
#   'pa',
#   'innovative',
#   'industrial',
#   'properties',
#   'now',
#   'yields',
#   'over',
#   'buy',
#   'hand',
#   'over',
#   'fist',
#   't',
#   'co',
#   'tbdhivp',
#   'trading',
#   'stockmarket',
#   'investing'],
#  ['frc',
#   'first',
#   'republic',
#   'bank',
#   'stock',
#   'jumps',
#   'after',
#   'q',
#   'earnings',
#   'beat',
#   'on',
#   'robust',
#   'loan',
#   'growth',
#   't',
#   'co',
#   'ataidlnq'],
#  ['goldman',
#   'sachs',
#   'plans',
#   'to',
#   'slow',
#   'hiring',
#   'and',
#   'reinstate',
#   'annual',
#   'performance',
#   'reviews',
#   'as',
#   'the',
#   'wall',
#   'street',
#   'bank',
#   'looks',
#   'to',
#   'rein',
#   'in',
#   'expenses',
#   't',
#   'co',
#   'xztuqyl'],
#  ['sasr',
#   'sandy',
#   'spring',
#   'bancorp',
#   'non',
#   'gaap',
#   'eps',
#   'of',
#   'beats',
#   'by',
#   'revenue',
#   'of',
#   'm',
#   'beats',
#   'by',
#   'm',
#   't',
#   'co',
#   'sdmoxz'],
#  ['nigeria',
#   's',
#   'central',
#   'bank',
#   'raises',
#   'its',
#   'key',
#   'interest',
#   'rate',
#   'by',
#   'basis',
#   'points',
#   'to',
#   'to',
#   'curb',
#   'accelerating',
#   'inflation',
#   't',
#   'co',
#   'tlwcbvpav'],
#  ['calling',
#   'it',
#   'a',
#   'a',
#   'defining',
#   'moment',
#   'embattled',
#   'crypto',
#   'lender',
#   'celsius',
#   'networks',
#   'has',
#   'filed',
#   'for',
#   'chapter',
#   'bankruptcy',
#   'protection',
#   't',
#   'co',
#   'bonlqyb'],
#  ['ctmx',
#   'cytomx',
#   'therapeutics',
#   'to',
#   'cut',
#   'workforce',
#   'by',
#   'about',
#   't',
#   'co',
#   'rsdhdvagn'],
#  ['euro',
#   'edges',
#   'closer',
#   'to',
#   'dollar',
#   'parity',
#   'latest',
#   'markets',
#   'updates',
#   't',
#   'co',
#   'upltrhdi',
#   't',
#   'co',
#   'exeklee'],
#  ['velod',
#   'partners',
#   'with',
#   'hartech',
#   'group',
#   'to',
#   'distribute',
#   'its',
#   'end',
#   'to',
#   'end',
#   'solution',
#   'and',
#   'deliver',
#   'a',
#   'turn',
#   'key',
#   'process',
#   'for',
#   'federal',
#   'government',
#   'customers',
#   't',
#   'co',
#   'vbzjybibl'],
#  ['south',
#   'korean',
#   'prosecutors',
#   'are',
#   'investigating',
#   'members',
#   'of',
#   'former',
#   'president',
#   'moon',
#   'jae',
#   'in',
#   's',
#   'government',
#   'over',
#   'the',
#   'forced',
#   'repatriation',
#   'of',
#   'two',
#   'north',
#   'korean',
#   't',
#   'co',
#   'cofcureba'],
#  ['dorm',
#   'dorman',
#   'releases',
#   'more',
#   'than',
#   'new',
#   'steering',
#   'amp',
#   'suspension',
#   'products',
#   't',
#   'co',
#   'bgpspftmb'],
#  ['pratt',
#   'amp',
#   'whitney',
#   'evaluating',
#   'an',
#   'end',
#   'to',
#   'end',
#   'solution',
#   'from',
#   'velod',
#   'to',
#   'manufacture',
#   'production',
#   'jet',
#   'engine',
#   'components',
#   't',
#   'co',
#   'mzyenwmulm',
#   't',
#   'co',
#   'lqyopmrt'],
#  ['spain',
#   'hits',
#   'banks',
#   'and',
#   'utilities',
#   'with',
#   'windfall',
#   'tax',
#   't',
#   'co',
#   'vadofg'],
#  ['asia',
#   'pacific',
#   'markets',
#   'set',
#   'to',
#   'trade',
#   'mixed',
#   'after',
#   'positive',
#   'u',
#   's',
#   'jobs',
#   'report',
#   't',
#   'co',
#   'lseosfoym'],
#  ['the',
#   'supercharged',
#   'us',
#   'dollar',
#   'breached',
#   'parity',
#   'with',
#   'the',
#   'euro',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'decades',
#   'nicolesylive',
#   'explains',
#   'what',
#   'that',
#   'means',
#   't',
#   'co',
#   'samapet',
#   't',
#   'co',
#   'kpeiguuzw'],
#  ['here',
#   'top',
#   'vacation',
#   'rental',
#   'investment',
#   'marketplace',
#   'raises',
#   'm',
#   'to',
#   'expand',
#   'into',
#   'new',
#   'destinations',
#   't',
#   'co',
#   'xujyhejbsv',
#   't',
#   'co',
#   'zompngkke'],
#  ['kyocera',
#   'and',
#   'shiseido',
#   'develop',
#   'the',
#   'world',
#   's',
#   'first',
#   'ever',
#   'cosmetic',
#   'face',
#   'powder',
#   'using',
#   'kyocera',
#   's',
#   'kyoto',
#   'opal',
#   't',
#   'co',
#   'zvladmw',
#   't',
#   'co',
#   'xuezsshec'],
#  ['watch',
#   'from',
#   'another',
#   'lender',
#   'going',
#   'under',
#   'to',
#   'why',
#   'there',
#   's',
#   'no',
#   'crypto',
#   'winter',
#   'in',
#   'one',
#   'corner',
#   'of',
#   'africa',
#   'these',
#   'are',
#   'the',
#   'week',
#   's',
#   'big',
#   'stories',
#   'in',
#   'alternative',
#   'currencies',
#   't',
#   'co',
#   'mfwpepsvz'],
#  ['market',
#   'moves',
#   'into',
#   'higher',
#   'gear',
#   'spy',
#   'qqq',
#   'dia',
#   'spx',
#   'compq',
#   'djia',
#   'nflx',
#   'tsla',
#   'xlv',
#   'xlu',
#   'xlp',
#   't',
#   'co',
#   'lzemmlqjhi',
#   'economy',
#   'stockmarket'],
#  ['bond',
#   'yields',
#   'rise',
#   'after',
#   'russia',
#   'resumes',
#   'gas',
#   'flows',
#   't',
#   'co',
#   'dlfhiydo'],
#  ['the',
#   'first',
#   'round',
#   'of',
#   'voting',
#   'in',
#   'the',
#   'tory',
#   'leadership',
#   'contest',
#   'is',
#   'over',
#   'get',
#   'the',
#   'readout',
#   'with',
#   'allegra',
#   'stratton',
#   't',
#   'co',
#   'sztfcahaa'],
#  ...]

# %%
len(word_token)
# Out:
# 13592

# %%
# Remove stopwords from each sublist in word_token
filtered_tokens_train = [[word for word in sublist if word not in stop_words] for sublist in word_token]

# Display the first sublist of filtered tokens after removing stopwords
print(filtered_tokens_train[0])
# Out:
# ['ecb', 'rate', 'decision', 'day', 'expect', 'via', 'weberalexander', 'amp', 'carolynnlook', 'co', 'isqgdue']

# %%
print(filtered_tokens_train[1])
# Out:
# ['twitter', 'users', 'quick', 'spot', 'liz', 'truss', 'seemingly', 'recreating', 'outfit', 'margaret', 'thatcher', 'appearance', 'channel', 'tory', 'leadership', 'debate', 'co', 'vsiioegrz']

# %% [markdown]
# **Lemmatization**

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatized_tokens_train = [[lemmatizer.lemmatize(word) for word in sublist] for sublist in filtered_tokens_train]

# %%
lemmatized_tokens_train
# Out:
# [['ecb',
#   'rate',
#   'decision',
#   'day',
#   'expect',
#   'via',
#   'weberalexander',
#   'amp',
#   'carolynnlook',
#   'co',
#   'isqgdue'],
#  ['twitter',
#   'user',
#   'quick',
#   'spot',
#   'liz',
#   'truss',
#   'seemingly',
#   'recreating',
#   'outfit',
#   'margaret',
#   'thatcher',
#   'appearance',
#   'channel',
#   'tory',
#   'leadership',
#   'debate',
#   'co',
#   'vsiioegrz'],
#  ['jetblue',
#   'announces',
#   'webcast',
#   'second',
#   'quarter',
#   'earnings',
#   'conference',
#   'call',
#   'co',
#   'kzrfsrwcpk',
#   'co',
#   'xjbczmry'],
#  ['calm',
#   'cal',
#   'maine',
#   'food',
#   'stock',
#   'tick',
#   'higher',
#   'record',
#   'net',
#   'income',
#   'pricing',
#   'power',
#   'co',
#   'nczmzphcx'],
#  ['tower',
#   'semiconductor',
#   'cadence',
#   'expand',
#   'collaboration',
#   'accelerate',
#   'automotive',
#   'ic',
#   'development',
#   'co',
#   'vssriai',
#   'co',
#   'kkjrddoxa'],
#  ['u',
#   'stock',
#   'fell',
#   'earnings',
#   'season',
#   'set',
#   'kick',
#   'week',
#   'investor',
#   'worried',
#   'impact',
#   'inflation',
#   'corporate',
#   'profit',
#   'co',
#   'ffquuxyfhw'],
#  ['elon',
#   'musk',
#   'say',
#   'tesla',
#   'could',
#   'lower',
#   'price',
#   'inflation',
#   'calm',
#   'co',
#   'dbwjbknv'],
#  ['roll',
#   'royce',
#   'easyjet',
#   'test',
#   'hydrogen',
#   'combustion',
#   'engine',
#   'tech',
#   'airplane',
#   'co',
#   'alilnplg'],
#  ['yuja',
#   'inc',
#   'introduces',
#   'accessible',
#   'medium',
#   'technology',
#   'integration',
#   'cielo',
#   'co',
#   'kdsob',
#   'co',
#   'hunoecglhf'],
#  ['breakingviews',
#   'climate',
#   'fight',
#   'take',
#   'heart',
#   'old',
#   'oil',
#   'maxim',
#   'co',
#   'mnznztvui'],
#  ['watch',
#   'germany',
#   'nearing',
#   'bailout',
#   'deal',
#   'troubled',
#   'gas',
#   'supplier',
#   'uniper',
#   'could',
#   'mean',
#   'higher',
#   'price',
#   'consumer',
#   'reuters',
#   'source',
#   'say',
#   'german',
#   'government',
#   'take',
#   'stake',
#   'firm',
#   'co',
#   'byqteoz',
#   'co',
#   'zhqzhgtza'],
#  ['oatt',
#   'u',
#   'wasde',
#   'corn',
#   'end',
#   'stock',
#   'new',
#   'jul',
#   'est',
#   'prev',
#   'soybean',
#   'end',
#   'stock',
#   'new',
#   'est',
#   'prev',
#   'wheat',
#   'end',
#   'stock',
#   'new',
#   'est',
#   'prev',
#   'cotton',
#   'end',
#   'stock',
#   'new',
#   'est',
#   'prev',
#   'co',
#   'twsyiqnh'],
#  ['canadian',
#   'cpi',
#   'boc',
#   'core',
#   'jun',
#   'prev',
#   'canadian',
#   'cpi',
#   'boc',
#   'core',
#   'jun',
#   'est',
#   'prev',
#   'canadian',
#   'cpi',
#   'core',
#   'common',
#   'jun',
#   'est',
#   'prev',
#   'canadian',
#   'cpi',
#   'core',
#   'median',
#   'jun',
#   'co',
#   'cyymoxhlh'],
#  ['r', 'ryder', 'system', 'raise', 'dividend', 'co', 'cvutwzqe'],
#  ['kkr',
#   'first',
#   'asset',
#   'based',
#   'finance',
#   'fund',
#   'raise',
#   'bln',
#   'co',
#   'onzacnqvb',
#   'co',
#   'lhtywhqgd'],
#  ['japan',
#   'step',
#   'foreign',
#   'exchange',
#   'market',
#   'prop',
#   'yen',
#   'stage',
#   'according',
#   'country',
#   'former',
#   'chief',
#   'currency',
#   'official',
#   'co',
#   'ijiyvqhugw'],
#  ['rtx',
#   'raytheon',
#   'technology',
#   'chosen',
#   'doe',
#   'two',
#   'r',
#   'amp',
#   'project',
#   'co',
#   'bfhlakgqe'],
#  ['tan',
#   'icln',
#   'qcln',
#   'solar',
#   'stock',
#   'plunge',
#   'manchin',
#   'nix',
#   'new',
#   'climate',
#   'spending',
#   'economic',
#   'plan',
#   'co',
#   'nyewdzc'],
#  ['fed',
#   'beige',
#   'book',
#   'economic',
#   'activity',
#   'expanded',
#   'modest',
#   'pace',
#   'balance',
#   'since',
#   'mid',
#   'may',
#   'co',
#   'ihozflgnmb'],
#  ['south',
#   'africa',
#   'rooibos',
#   'tea',
#   'industry',
#   'paid',
#   'indigenous',
#   'group',
#   'way',
#   'recognize',
#   'plant',
#   'original',
#   'cultivator',
#   'co',
#   'rhquaxzdn'],
#  ['tph', 'tri', 'pointe', 'home', 'q', 'earnings', 'preview', 'co', 'bzmcjsc'],
#  ['stranger',
#   'thing',
#   'viewing',
#   'data',
#   'continues',
#   'bright',
#   'spot',
#   'nflx',
#   'netflix',
#   'said',
#   'anticipates',
#   'q',
#   'million',
#   'paying',
#   'user',
#   'leave',
#   'platform',
#   'alliecanal',
#   'say',
#   'seeing',
#   'increased',
#   'level',
#   'cancellation',
#   'churn',
#   'slowdown',
#   'app',
#   'downloads',
#   'co',
#   'bxovoirq'],
#  ['triton',
#   'digital',
#   'release',
#   'australian',
#   'podcast',
#   'ranker',
#   'june',
#   'co',
#   'slktmgdp'],
#  ['philippine',
#   'plan',
#   'revise',
#   'mobility',
#   'restriction',
#   'next',
#   'month',
#   'covid',
#   'case',
#   'caused',
#   'milder',
#   'strain',
#   'increase',
#   'president',
#   'ferdinand',
#   'marcos',
#   'jr',
#   'said',
#   'co',
#   'hozmkplj'],
#  ['groupe',
#   'touchette',
#   'strike',
#   'deal',
#   'acquire',
#   'american',
#   'tire',
#   'distributor',
#   'asset',
#   'canada',
#   'move',
#   'may',
#   'roughly',
#   'double',
#   'annual',
#   'sale',
#   'co',
#   'yupuoqpth'],
#  ['validus',
#   'capital',
#   'appoints',
#   'sean',
#   'chen',
#   'chief',
#   'operating',
#   'officer',
#   'chief',
#   'compliance',
#   'officer',
#   'managing',
#   'partner',
#   'co',
#   'lgemaesczj',
#   'co',
#   'hfqqugeq'],
#  ['qubt',
#   'quantum',
#   'computing',
#   'poised',
#   'greatness',
#   'next',
#   'big',
#   'wave',
#   'computing',
#   'disruption',
#   'co',
#   'ijnvhjmic',
#   'stockmarket',
#   'investing',
#   'stock'],
#  ['lmt',
#   'miss',
#   'miss',
#   'rev',
#   'lower',
#   'outlook',
#   'guide',
#   'fy',
#   'eps',
#   'consensus',
#   'rev',
#   'consensus'],
#  ['tsla',
#   'pre',
#   'tesla',
#   'profit',
#   'top',
#   'target',
#   'musk',
#   'say',
#   'high',
#   'price',
#   'could',
#   'hurt',
#   'demand',
#   'reuters',
#   'co',
#   'guckmgqoh'],
#  ['jan',
#   'committee',
#   'looked',
#   'tie',
#   'oath',
#   'keeper',
#   'proud',
#   'boy',
#   'roger',
#   'stone',
#   'close',
#   'associate',
#   'trump',
#   'latest',
#   'update',
#   'co',
#   'shktxy',
#   'co',
#   'tgsydcsrz'],
#  ['test', 'apple', 'big', 'new', 'iphone', 'update', 'co', 'thouzumqvy'],
#  ['era',
#   'lly',
#   'erasca',
#   'eli',
#   'lilly',
#   'collaborate',
#   'trial',
#   'evaluate',
#   'combo',
#   'treatment',
#   'two',
#   'cancer',
#   'co',
#   'ohvvzkvgw'],
#  ['citi',
#   'jpmorgan',
#   'well',
#   'fargo',
#   'increased',
#   'provision',
#   'credit',
#   'loss',
#   'first',
#   'time',
#   'since',
#   'height',
#   'pandemic',
#   'leaving',
#   'investor',
#   'debate',
#   'whether',
#   'reserve',
#   'prudent',
#   'act',
#   'sign',
#   'danger',
#   'ahead',
#   'co',
#   'rmzhnona'],
#  ['economist',
#   'forecast',
#   'inflation',
#   'hit',
#   'fresh',
#   'pandemic',
#   'peak',
#   'set',
#   'keep',
#   'fed',
#   'geared',
#   'another',
#   'big',
#   'interest',
#   'rate',
#   'hike',
#   'later',
#   'month',
#   'co',
#   'zftchwn'],
#  ['dow',
#   'end',
#   'around',
#   'point',
#   'higher',
#   'equity',
#   'extend',
#   'bounce',
#   'co',
#   'vlzmqckds'],
#  ['rio',
#   'tinto',
#   'second',
#   'quarter',
#   'iron',
#   'ore',
#   'shipment',
#   'rise',
#   'rtrs',
#   'co',
#   'ywvmgkam'],
#  ['laserfiche',
#   'appoints',
#   'karl',
#   'chan',
#   'chief',
#   'executive',
#   'officer',
#   'co',
#   'eetxkaj',
#   'co',
#   'macatblvc'],
#  ['china',
#   'file',
#   'diplomatic',
#   'protest',
#   'japan',
#   'visit',
#   'top',
#   'taiwanese',
#   'official',
#   'mourn',
#   'death',
#   'country',
#   'former',
#   'leader',
#   'shinzo',
#   'abe',
#   'co',
#   'vzwckuys'],
#  ['netflix',
#   'may',
#   'calmed',
#   'investor',
#   'worst',
#   'fear',
#   'second',
#   'quarter',
#   'subscriber',
#   'loss',
#   'better',
#   'expected',
#   'closer',
#   'look',
#   'streaming',
#   'giant',
#   'result',
#   'indicate',
#   'still',
#   'face',
#   'significant',
#   'hurdle',
#   'co',
#   'avzwjostag'],
#  ['randomly',
#   'bought',
#   'eth',
#   'yesterday',
#   'morning',
#   'first',
#   'crypto',
#   'trade',
#   'saw',
#   'similar',
#   'seeing',
#   'nasdaq',
#   'w',
#   'basing',
#   'key',
#   'level',
#   'lifetime',
#   'vwap',
#   'etc',
#   'nice',
#   'start',
#   'today'],
#  ['brqs',
#   'borqs',
#   'subsidiary',
#   'holu',
#   'hou',
#   'energy',
#   'signed',
#   'agreement',
#   'million',
#   'bring',
#   'renewable',
#   'energy',
#   'key',
#   'hawaiian',
#   'cultural',
#   'sporting',
#   'facility'],
#  ['cibc',
#   'innovation',
#   'banking',
#   'provides',
#   'million',
#   'growth',
#   'financing',
#   'fintech',
#   'company',
#   'smart',
#   'accelerate',
#   'growth',
#   'acquisition',
#   'co',
#   'qrckkxmgm',
#   'co',
#   'svbwvuzgxv'],
#  ['ual',
#   'united',
#   'airline',
#   'miss',
#   'report',
#   'rev',
#   'line',
#   'continues',
#   'expect',
#   'profitable',
#   'fy',
#   'co',
#   'jyxvyedxt'],
#  ['dis',
#   'disney',
#   'ink',
#   'major',
#   'advertising',
#   'deal',
#   'trade',
#   'desk',
#   'axios',
#   'co',
#   'pjzfmcxibp'],
#  ['ixhl',
#   'incannex',
#   'healthcare',
#   'received',
#   'approval',
#   'bellberry',
#   'human',
#   'research',
#   'ethic',
#   'committee',
#   'phase',
#   'co',
#   'ydejdkw'],
#  ['evex',
#   'eve',
#   'shareholder',
#   'looking',
#   'dilution',
#   'state',
#   'vc',
#   'weighs',
#   'multiple',
#   'co',
#   'xxwfkxnx',
#   'business',
#   'economy',
#   'investing'],
#  ['hymlf',
#   'kimtf',
#   'tsla',
#   'hyundai',
#   'look',
#   'break',
#   'u',
#   'electric',
#   'vehicle',
#   'market',
#   'co',
#   'vgrbmvkk'],
#  ['rio',
#   'tinto',
#   'reported',
#   'inventory',
#   'continue',
#   'decline',
#   'high',
#   'power',
#   'price',
#   'limiting',
#   'production',
#   'growth',
#   'outside',
#   'china'],
#  ['train',
#   'driver',
#   'eight',
#   'uk',
#   'rail',
#   'company',
#   'stage',
#   'hour',
#   'saturday',
#   'strike',
#   'later',
#   'month',
#   'pay',
#   'dispute',
#   'co',
#   'rqizztlaz'],
#  ['twitter', 'co', 'uaoimllse'],
#  ['baesy',
#   'bae',
#   'system',
#   'secures',
#   'b',
#   'u',
#   'army',
#   'contract',
#   'co',
#   'crzlcw'],
#  ['neti',
#   'eneti',
#   'scorpio',
#   'holding',
#   'ltd',
#   'purchased',
#   'common',
#   'share',
#   'average',
#   'price',
#   'co',
#   'awqqqygnyb'],
#  ['drug',
#   'lord',
#   'rafael',
#   'caro',
#   'quintero',
#   'behind',
#   'killing',
#   'dea',
#   'agent',
#   'captured',
#   'mexican',
#   'force',
#   'nearly',
#   'decade',
#   'walking',
#   'mexican',
#   'prison',
#   'returning',
#   'drug',
#   'trafficking',
#   'via',
#   'ap',
#   'co',
#   'tprcgrgju'],
#  ['coinbase',
#   'selling',
#   'geo',
#   'location',
#   'data',
#   'u',
#   'immigration',
#   'enforcement',
#   'agency',
#   'nasdaq',
#   'coin',
#   'seeking',
#   'alpha',
#   'co',
#   'gdsliunjtr'],
#  ['actress',
#   'claimed',
#   'turned',
#   'work',
#   'due',
#   'injury',
#   'began',
#   'receiving',
#   'disability',
#   'payment',
#   'five',
#   'day',
#   'last',
#   'working',
#   'yellowstone',
#   'co',
#   'nlmaggw'],
#  ['china',
#   'wechat',
#   'became',
#   'powerful',
#   'could',
#   'posed',
#   'real',
#   'threat',
#   'beijing',
#   'rule',
#   'co',
#   'ounxeqyh'],
#  ['production',
#   'u',
#   'factory',
#   'declined',
#   'june',
#   'second',
#   'month',
#   'restrained',
#   'higher',
#   'inventory',
#   'softer',
#   'economic',
#   'outlook',
#   'co',
#   'neqfvtt'],
#  ['moon',
#   'capital',
#   'management',
#   'q',
#   'letter',
#   'co',
#   'madsudluiu',
#   'economy',
#   'finance',
#   'investing'],
#  ['oakbx',
#   'oakmark',
#   'equity',
#   'income',
#   'fund',
#   'q',
#   'commentary',
#   'co',
#   'onkrwnzfg',
#   'finance',
#   'stockmarket',
#   'economy'],
#  ['chinese',
#   'premier',
#   'li',
#   'keqiang',
#   'signal',
#   'focus',
#   'job',
#   'flexibility',
#   'economic',
#   'growth',
#   'rate',
#   'shift',
#   'toward',
#   'making',
#   'covid',
#   'control',
#   'measure',
#   'targeted',
#   'co',
#   'lelvkdlj'],
#  ['etcc',
#   'environmental',
#   'tectonics',
#   'gaap',
#   'eps',
#   'revenue',
#   'co',
#   'kcaejlvh'],
#  ['bad', 'news', 'come', 'low'],
#  ['microsoft',
#   'making',
#   'several',
#   'change',
#   'attract',
#   'retain',
#   'employee',
#   'co',
#   'qqqhckubdz'],
#  ['stock',
#   'asia',
#   'face',
#   'another',
#   'challenging',
#   'trading',
#   'session',
#   'friday',
#   'amid',
#   'surge',
#   'dollar',
#   'underscore',
#   'concern',
#   'global',
#   'economic',
#   'slowdown',
#   'co',
#   'nqyouwgg'],
#  ['inflation',
#   'urgent',
#   'concern',
#   'filipino',
#   'want',
#   'philippine',
#   'president',
#   'marcos',
#   'jr',
#   'prioritize',
#   'according',
#   'survey',
#   'pulse',
#   'asia',
#   'research',
#   'co',
#   'huhlofkrf'],
#  ['activist',
#   'hedge',
#   'fund',
#   'elliott',
#   'management',
#   'amassed',
#   'stake',
#   'pinterest',
#   'co',
#   'rtuulife'],
#  ['bank',
#   'america',
#   'put',
#   'aside',
#   'million',
#   'probe',
#   'banker',
#   'use',
#   'personal',
#   'device',
#   'co',
#   'pfgaiuuc',
#   'co',
#   'jzbelxyl'],
#  ['drive',
#   'turn',
#   'tourism',
#   'prime',
#   'threat',
#   'saviour',
#   'global',
#   'biodiversity',
#   'co',
#   'trdtcioez',
#   'co',
#   'tabdoit'],
#  ['u',
#   'department',
#   'defense',
#   'award',
#   'skywater',
#   'option',
#   'facilitate',
#   'american',
#   'made',
#   'semiconductor',
#   'critical',
#   'national',
#   'security',
#   'domestic',
#   'supply',
#   'chain',
#   'co',
#   'fypnuphp',
#   'co',
#   'nfcnwghwt'],
#  ['vale',
#   'vale',
#   'start',
#   'construction',
#   'zhongzhai',
#   'pre',
#   'blending',
#   'project',
#   'partnership',
#   'vale',
#   'jiangsu',
#   'co',
#   'zknhayr'],
#  ['toyota',
#   'crown',
#   'car',
#   'known',
#   'ferrying',
#   'around',
#   'japan',
#   'elite',
#   'set',
#   'global',
#   'stage',
#   'co',
#   'wmwxvoiin'],
#  ['pageone',
#   'nothing',
#   'assured',
#   'encore',
#   'performance',
#   'spy',
#   'qqq',
#   'dia',
#   'nflx',
#   'tnx',
#   'rut',
#   'co',
#   'ndqkrhzplg',
#   'technical',
#   'rally',
#   'dma',
#   'eu',
#   'gas',
#   'consumption',
#   'russia',
#   'ukraine',
#   'uk',
#   'inflation',
#   'boe',
#   'ratehike',
#   'earnings',
#   'mortgage',
#   'application',
#   'economy',
#   'stockmarket',
#   'premarket',
#   'analysis'],
#  ['ecb',
#   'anti',
#   'fragmentation',
#   'instrument',
#   'expected',
#   'soft',
#   'condition',
#   'co',
#   'qkhotq'],
#  ['searcher',
#   'seismic',
#   'planning',
#   'survey',
#   'looking',
#   'oil',
#   'offshore',
#   'south',
#   'africa',
#   'month',
#   'called',
#   'earlier',
#   'search',
#   'due',
#   'court',
#   'challenge',
#   'co',
#   'qzigtfggp'],
#  ['imf',
#   'called',
#   'china',
#   'expand',
#   'fiscal',
#   'support',
#   'apply',
#   'flexible',
#   'covid',
#   'containment',
#   'strategy',
#   'address',
#   'slowdown',
#   'world',
#   'second',
#   'biggest',
#   'economy',
#   'co',
#   'dbeeinta'],
#  ['ko',
#   'pep',
#   'coca',
#   'cola',
#   'pepsico',
#   'likely',
#   'struggle',
#   'deglobalizing',
#   'world',
#   'co',
#   'ypwucsdu',
#   'investing',
#   'stockmarket',
#   'economy'],
#  ['g',
#   'aapl',
#   'plan',
#   'slow',
#   'hiring',
#   'spending',
#   'growth',
#   'co',
#   'thvvufhod'],
#  ['attractive',
#   'high',
#   'dividend',
#   'yield',
#   'stock',
#   'buy',
#   'co',
#   'ubtsvdsos',
#   'business',
#   'stock',
#   'market'],
#  ['virtualhealth',
#   'modernizes',
#   'utilization',
#   'management',
#   'new',
#   'software',
#   'release',
#   'co',
#   'idzkroa',
#   'co',
#   'oyhpkcosfo'],
#  ['way', 'elon', 'musk', 'twitter', 'saga', 'could', 'end', 'co', 'tsmyskvl'],
#  ['voltacharging',
#   'chief',
#   'commercial',
#   'officer',
#   'brandt',
#   'hastings',
#   'partnering',
#   'kroger',
#   'ev',
#   'charging',
#   'station',
#   'building',
#   'network',
#   'location',
#   'million',
#   'american',
#   'already',
#   'love',
#   'visit',
#   'every',
#   'day',
#   'full',
#   'interview',
#   'co',
#   'mjnubek'],
#  ['third',
#   'burberry',
#   'shareholder',
#   'voted',
#   'election',
#   'board',
#   'member',
#   'antoine',
#   'de',
#   'saint',
#   'affrique',
#   'amid',
#   'concern',
#   'director',
#   'also',
#   'hold',
#   'job',
#   'spreading',
#   'thin',
#   'co',
#   'ietgddm'],
#  ['pgr',
#   'progressive',
#   'seeing',
#   'improvement',
#   'business',
#   'growth',
#   'opportunity',
#   'remain',
#   'co',
#   'nkizthwng',
#   'finance',
#   'stock',
#   'economy'],
#  ['todaysfreefeature',
#   'settling',
#   'spy',
#   'tlt',
#   'fxe',
#   'es_f',
#   'tnx',
#   'eurusd',
#   'co',
#   'lqxffwjpp',
#   'cpi',
#   'federalreserve',
#   'supplychain',
#   'issue',
#   'inflation',
#   'china',
#   'lockdown',
#   'retailsales',
#   'housing',
#   'nahb',
#   'fedfunds',
#   'ratehike',
#   'etf',
#   'dailynotes',
#   'co',
#   'fhceqwwi'],
#  ['bondx', 'new', 'supply', 'co', 'zlthfafaq'],
#  ['hasi',
#   'hannon',
#   'armstrong',
#   'sustainable',
#   'infrastructure',
#   'take',
#   'short',
#   'seller',
#   'allegation',
#   'seriously',
#   'co',
#   'bnulplkt',
#   'business',
#   'stockmarket',
#   'investing'],
#  ['nyse', 'welcome', 'yearup', 'ring', 'opening', 'bell', 'co', 'ynsyzvjn'],
#  ['royal', 'mail', 'could', 'changing', 'name', 'co', 'jlippix'],
#  ['watch',
#   'british',
#   'consumer',
#   'price',
#   'inflation',
#   'hit',
#   'annual',
#   'rate',
#   'june',
#   'compared',
#   'may',
#   'data',
#   'bolstered',
#   'bet',
#   'bank',
#   'england',
#   'opt',
#   'basis',
#   'point',
#   'rate',
#   'hike',
#   'next',
#   'month',
#   'co',
#   'fhxhdl',
#   'co',
#   'brjwodefj'],
#  ['sstrazza',
#   'late',
#   'thursday',
#   'berkshire',
#   'disclosed',
#   'buying',
#   'another',
#   'million',
#   'share',
#   'worth',
#   'million',
#   'based',
#   'current',
#   'price'],
#  ['redemption',
#   'overwhelmed',
#   'new',
#   'investment',
#   'citco',
#   'group',
#   'hedge',
#   'fund',
#   'client',
#   'june',
#   'bringing',
#   'net',
#   'outflow',
#   'billion',
#   'co',
#   'yretofokk'],
#  ['imf',
#   'board',
#   'approves',
#   'billion',
#   'extended',
#   'credit',
#   'facility',
#   'tanzania',
#   'plan',
#   'disburse',
#   'million',
#   'immediately',
#   'co',
#   'mirkjqofa'],
#  ['qqq',
#   'powershares',
#   'qqq',
#   'era',
#   'morning',
#   'loss',
#   'modestly',
#   'higher',
#   'morning',
#   'low',
#   'co',
#   'bsqthxrfvj'],
#  ['astepro',
#   'allergy',
#   'first',
#   'steroid',
#   'free',
#   'antihistamine',
#   'nasal',
#   'spray',
#   'available',
#   'counter',
#   'co',
#   'sxqdyov',
#   'co',
#   'yekgbfxxt'],
#  ['listen',
#   'jpmorgan',
#   'morgan',
#   'stanley',
#   'missed',
#   'wall',
#   'street',
#   'earnings',
#   'estimate',
#   'team',
#   'discus',
#   'mean',
#   'big',
#   'bank',
#   'listen',
#   'follow',
#   'squawkstreet',
#   'podcast',
#   'favorite',
#   'podcast',
#   'platform',
#   'co',
#   'boklbewjy',
#   'co',
#   'ooloeyqen'],
#  ['u',
#   'k',
#   'june',
#   'brc',
#   'retail',
#   'sale',
#   'monitor',
#   'yoy',
#   'actual',
#   'v',
#   'previous',
#   'est'],
#  ['increased',
#   'use',
#   'lignite',
#   'coal',
#   'hydro',
#   'powered',
#   'electricity',
#   'generation',
#   'feature',
#   'greece',
#   'plan',
#   'ensure',
#   'demand',
#   'met',
#   'supply',
#   'natural',
#   'gas',
#   'fall',
#   'short',
#   'co',
#   'mlmlajuk'],
#  ['fnf',
#   'fidelity',
#   'national',
#   'coo',
#   'roger',
#   'jewkes',
#   'transition',
#   'role',
#   'role',
#   'executive',
#   'vp',
#   'co',
#   'emkwmgqbb'],
#  ['mario',
#   'draghi',
#   'signaled',
#   'determined',
#   'resign',
#   'italy',
#   'prime',
#   'minister',
#   'within',
#   'day',
#   'co',
#   'xyokvjf'],
#  ['jpmorgan',
#   'profit',
#   'fall',
#   'dimon',
#   'cautious',
#   'global',
#   'economy',
#   'co',
#   'vuovmxzh',
#   'co',
#   'nnnevariv'],
#  ['spy',
#   'spx',
#   'es_f',
#   'hour',
#   'candle',
#   'watching',
#   'bull',
#   'move',
#   'aapl',
#   'amzn',
#   'googl',
#   'msft',
#   'ran',
#   'looking',
#   'break',
#   'emma',
#   'fill',
#   'gap',
#   'go',
#   'green',
#   'watch',
#   'hour',
#   'close',
#   'min',
#   'spy',
#   'c',
#   'co',
#   'oefixsxe'],
#  ['coming',
#   'week',
#   'filled',
#   'news',
#   'noise',
#   'case',
#   'twitter',
#   'ceo',
#   'parag',
#   'agrawal',
#   'warned',
#   'employee',
#   'email',
#   'tuesday',
#   'co',
#   'ldkjgunga'],
#  ['key',
#   'keycorp',
#   'q',
#   'earnings',
#   'beat',
#   'estimate',
#   'market',
#   'share',
#   'continues',
#   'increase',
#   'co',
#   'kgpflgvv'],
#  ['asian',
#   'development',
#   'bank',
#   'cut',
#   'forecast',
#   'gross',
#   'domestic',
#   'product',
#   'growth',
#   'developing',
#   'asia',
#   'year',
#   'china',
#   'covid',
#   'zero',
#   'approach',
#   'containing',
#   'virus',
#   'creates',
#   'ripple',
#   'effect',
#   'regional',
#   'supply',
#   'chain',
#   'economic',
#   'development',
#   'co',
#   'ulvkodryz'],
#  ['apple',
#   'google',
#   'meta',
#   'tech',
#   'company',
#   'hitting',
#   'brake',
#   'hiring',
#   'co',
#   'vwtrlbz',
#   'ines_ferre',
#   'danielhowley',
#   'co',
#   'oeykdimde'],
#  ['former',
#   'house',
#   'speaker',
#   'paul',
#   'ryan',
#   'said',
#   'jan',
#   'attack',
#   'u',
#   'capitol',
#   'reduced',
#   'tear',
#   'reaction',
#   'quoted',
#   'new',
#   'book',
#   'former',
#   'president',
#   'donald',
#   'trump',
#   'relationship',
#   'republican',
#   'party',
#   'co',
#   'bvqwrzaazv'],
#  ['company',
#   'investigation',
#   'alert',
#   'reminder',
#   'scott',
#   'scott',
#   'attorney',
#   'law',
#   'llp',
#   'investigates',
#   'elon',
#   'musk',
#   'deal',
#   'company',
#   'twtr',
#   'co',
#   'szolrix',
#   'co',
#   'fsjhupvgo'],
#  ['jpmorgan',
#   'analyst',
#   'put',
#   'monthly',
#   'list',
#   'top',
#   'idea',
#   'stock',
#   'co',
#   'ywcdscqb'],
#  ['salata',
#   'salad',
#   'kitchen',
#   'introduces',
#   'southwestern',
#   'inspired',
#   'menu',
#   'item',
#   'featuring',
#   'new',
#   'protein',
#   'option',
#   'certified',
#   'angus',
#   'beef',
#   'steak',
#   'co',
#   'mynzcmiju',
#   'co',
#   'gcdqwcwpu'],
#  ['wipro',
#   'limited',
#   'announce',
#   'result',
#   'first',
#   'quarter',
#   'ended',
#   'june',
#   'july',
#   'co',
#   'sgiwtzjzef',
#   'co',
#   'zmvtyc'],
#  ['putin',
#   'trip',
#   'iran',
#   'show',
#   'russia',
#   'desperation',
#   'say',
#   'u',
#   'institute',
#   'peace',
#   'co',
#   'ttxzxjak'],
#  ['royal',
#   'mail',
#   'say',
#   'consider',
#   'number',
#   'option',
#   'improve',
#   'prospect',
#   'group',
#   'including',
#   'separation',
#   'main',
#   'uk',
#   'postal',
#   'business',
#   'international',
#   'logistics',
#   'unit',
#   'co',
#   'xnzjlqumb'],
#  ['lscc',
#   'lattice',
#   'semi',
#   'collaborates',
#   'lg',
#   'bring',
#   'edge',
#   'ai',
#   'technology',
#   'lg',
#   'premium',
#   'laptop',
#   'lineup',
#   'co',
#   'wngqvygfnf'],
#  ['save',
#   'pre',
#   'frontier',
#   'group',
#   'ulcc',
#   'letter',
#   'spirit',
#   'say',
#   'remain',
#   'far',
#   'obtaining',
#   'approval',
#   'spirit',
#   'stockholder',
#   'based',
#   'proxy',
#   'data',
#   'reuters',
#   'si',
#   'co',
#   'lxacine'],
#  ['eric', 'ericsson', 'miss', 'sek', 'beat', 'rev', 'co', 'fpeysuki'],
#  ['euro',
#   'area',
#   'consumer',
#   'confidence',
#   'drop',
#   'lowest',
#   'level',
#   'record',
#   'household',
#   'brace',
#   'possible',
#   'recession',
#   'co',
#   'fbvjgrdq'],
#  ['hungarian',
#   'holding',
#   'daily',
#   'protest',
#   'plunging',
#   'currency',
#   'threat',
#   'russian',
#   'cut',
#   'natural',
#   'gas',
#   'shipment',
#   'force',
#   'prime',
#   'minister',
#   'viktor',
#   'orban',
#   'embrace',
#   'unpopular',
#   'austerity',
#   'measure',
#   'co',
#   'ijolaluyg'],
#  ['phm',
#   'pultegroup',
#   'exciting',
#   'buy',
#   'potential',
#   'annual',
#   'return',
#   'co',
#   'djcncgd',
#   'finance',
#   'economy',
#   'investing'],
#  ['fidelity',
#   'payment',
#   'service',
#   'announces',
#   'strategic',
#   'growth',
#   'investment',
#   'psg',
#   'co',
#   'rhfpkblhm',
#   'co',
#   'pknhcceyb'],
#  ['xbi',
#   'xbi',
#   'biotech',
#   'stock',
#   'good',
#   'investment',
#   'co',
#   'phzuaffq',
#   'business',
#   'market',
#   'finance'],
#  ['brutal',
#   'heatwave',
#   'sweeping',
#   'europe',
#   'impacting',
#   'everything',
#   'transport',
#   'food',
#   'energy',
#   'production',
#   'co',
#   'wzjapjrqdv'],
#  ['federal',
#   'minimum',
#   'wage',
#   'gone',
#   'year',
#   'lowest',
#   'value',
#   'since',
#   'via',
#   'cnbcmakeit',
#   'co',
#   'inslxvvlg'],
#  ['amp',
#   'p',
#   'affirms',
#   'assured',
#   'guaranty',
#   'aa',
#   'financial',
#   'strength',
#   'rating',
#   'stable',
#   'outlook',
#   'co',
#   'fznnutx'],
#  ['electric',
#   'vehicle',
#   'maker',
#   'rivian',
#   'confirmed',
#   'plan',
#   'rethink',
#   'operation',
#   'trim',
#   'job',
#   'necessary',
#   'ceo',
#   'rj',
#   'scaringe',
#   'telling',
#   'employee',
#   'company',
#   'thoughtful',
#   'staff',
#   'cut',
#   'co',
#   'nbyjlgq'],
#  ['royal',
#   'mail',
#   'face',
#   'possible',
#   'nationwide',
#   'strike',
#   'postal',
#   'staff',
#   'would',
#   'biggest',
#   'walkout',
#   'british',
#   'worker',
#   'summer',
#   'co',
#   'wrdhsghy'],
#  ['safm',
#   'sanderson',
#   'farm',
#   'dip',
#   'report',
#   'concession',
#   'cargill',
#   'takeover',
#   'co',
#   'lyqkkoln'],
#  ['california',
#   'size',
#   'field',
#   'intended',
#   'almond',
#   'rice',
#   'wine',
#   'grape',
#   'crop',
#   'left',
#   'unworked',
#   'could',
#   'around',
#   'acre',
#   'co',
#   'acjbwjqtv'],
#  ['donald',
#   'trump',
#   'paid',
#   'respect',
#   'first',
#   'wife',
#   'ivana',
#   'trump',
#   'joining',
#   'child',
#   'ivanka',
#   'jr',
#   'eric',
#   'st',
#   'vincent',
#   'ferrer',
#   'roman',
#   'catholic',
#   'church',
#   'funeral',
#   'service',
#   'co',
#   'omlhsxmwsz',
#   'co',
#   'kdsfxgqr'],
#  ['llkkf',
#   'lake',
#   'resource',
#   'lithium',
#   'process',
#   'slammed',
#   'short',
#   'seller',
#   'report',
#   'co',
#   'dpeovj'],
#  ['watch',
#   'breakingviews',
#   'australia',
#   'new',
#   'government',
#   'committed',
#   'tackling',
#   'global',
#   'warming',
#   'predecessor',
#   'hand',
#   'want',
#   'keep',
#   'exporting',
#   'coal',
#   'gas',
#   'drive',
#   'emission',
#   'seeding',
#   'climate',
#   'disaster',
#   'say',
#   'antonymcurrie',
#   'co',
#   'tovncgvl'],
#  ['tues',
#   'amzn',
#   'aws',
#   'summit',
#   'yr',
#   'note',
#   'auction',
#   'amzn',
#   'prime',
#   'day',
#   'wed',
#   'cpi',
#   'oil',
#   'inv',
#   'beige',
#   'book',
#   'th',
#   'ppi',
#   'jpm',
#   'm',
#   'fri',
#   'china',
#   'gdp',
#   'u',
#   'retail',
#   'sale',
#   'consumer',
#   'confidence',
#   'goog',
#   'split',
#   'c',
#   'bac',
#   'g',
#   'nflx',
#   'tsla',
#   'eps'],
#  ['genting',
#   'singapore',
#   'one',
#   'city',
#   'state',
#   'two',
#   'casino',
#   'operator',
#   'attracting',
#   'takeover',
#   'interest',
#   'tourist',
#   'start',
#   'coming',
#   'back',
#   'asian',
#   'travel',
#   'hub',
#   'source',
#   'said',
#   'co',
#   'aiscarktby'],
#  ['zyme',
#   'zymeworks',
#   'plan',
#   'become',
#   'delaware',
#   'corporation',
#   'co',
#   'eawbfwrsrq'],
#  ['fourkites',
#   'see',
#   'recovery',
#   'chinese',
#   'port',
#   'covid',
#   'lockdown',
#   'ease',
#   'co',
#   'tsftpbs',
#   'co',
#   'abubuwngfr'],
#  ['korean',
#   'open',
#   'onshore',
#   'trade',
#   'per',
#   'dollar',
#   'v',
#   'previous',
#   'close'],
#  ['nord',
#   'stream',
#   'russian',
#   'gas',
#   'shipment',
#   'resumed',
#   'thursday',
#   'bbg',
#   'co',
#   'juhfwbpmb'],
#  ['business',
#   'activity',
#   'region',
#   'service',
#   'sector',
#   'declined',
#   'first',
#   'time',
#   'year',
#   'according',
#   'firm',
#   'responding',
#   'new',
#   'york',
#   'fed',
#   'july',
#   'business',
#   'leader',
#   'survey',
#   'survey',
#   'headline',
#   'business',
#   'activity',
#   'index',
#   'fell',
#   'point',
#   'web',
#   'co',
#   'stwoyyav',
#   'co',
#   'fkcyzdr'],
#  ['taiwan',
#   'foxconn',
#   'say',
#   'shareholder',
#   'troubled',
#   'chinese',
#   'chip',
#   'firm',
#   'reuters',
#   'co',
#   'ydyvqpkvfd'],
#  ['james',
#   'webb',
#   'space',
#   'telescope',
#   'released',
#   'first',
#   'image',
#   'time',
#   'science',
#   'begin',
#   'meet',
#   'five',
#   'scientist',
#   'analyze',
#   'earliest',
#   'galaxy',
#   'unexplored',
#   'region',
#   'solar',
#   'system',
#   'watch',
#   'full',
#   'co',
#   'vfnubkaf',
#   'co',
#   'bontraghjt',
#   'co',
#   'lgjgxhezfa'],
#  ['canadian', 'bond', 'index', 'update', 'mtlexchange', 'co', 'popjw'],
#  ['facebook',
#   'owner',
#   'meta',
#   'release',
#   'first',
#   'human',
#   'right',
#   'report',
#   'co',
#   'dzetwkfn'],
#  ['blk',
#   'blackrock',
#   'inc',
#   'blk',
#   'ceo',
#   'laurence',
#   'fink',
#   'q',
#   'result',
#   'earnings',
#   'call',
#   'transcript',
#   'co',
#   'lellfebjd',
#   'stockmarket',
#   'market',
#   'business'],
#  ['caredx',
#   'deadline',
#   'alert',
#   'bragar',
#   'eagel',
#   'amp',
#   'squire',
#   'p',
#   'c',
#   'reminds',
#   'investor',
#   'class',
#   'action',
#   'lawsuit',
#   'filed',
#   'caredx',
#   'inc',
#   'encourages',
#   'investor',
#   'contact',
#   'firm',
#   'co',
#   'unyswrpo'],
#  ['nept',
#   'flagging',
#   'another',
#   'leg',
#   'look',
#   'volume',
#   'accumulation',
#   'past',
#   'session',
#   'break',
#   'next',
#   'pv',
#   'lie',
#   'gap',
#   'zone',
#   'chart',
#   'speaks',
#   'co',
#   'qidiizmsob'],
#  ['alzamend',
#   'neuro',
#   'receives',
#   'positive',
#   'pre',
#   'ind',
#   'response',
#   'fda',
#   'al',
#   'treatment',
#   'bipolar',
#   'disorder',
#   'major',
#   'depressive',
#   'disorder',
#   'post',
#   'traumatic',
#   'stress',
#   'disorder',
#   'co',
#   'sloduluusx',
#   'co',
#   'shblocblc'],
#  ['nemacolin',
#   'selects',
#   'optii',
#   'housekeeping',
#   'management',
#   'platform',
#   'co',
#   'bauzidqnuj',
#   'co',
#   'cgzdynloq'],
#  ['rhhby',
#   'roche',
#   'hldg',
#   'board',
#   'director',
#   'appointed',
#   'thomas',
#   'schinecker',
#   'new',
#   'roche',
#   'ceo',
#   'effective',
#   'march',
#   'co',
#   'olocwmxa'],
#  ['ranpak',
#   'expands',
#   'automated',
#   'packaging',
#   'portfolio',
#   'global',
#   'launch',
#   'flap',
#   'solution',
#   'co',
#   'gkiounmn',
#   'co',
#   'evoshcdup'],
#  ['breaking',
#   'judge',
#   'set',
#   'october',
#   'trial',
#   'elon',
#   'musk',
#   'bid',
#   'walk',
#   'away',
#   'billion',
#   'company',
#   'acquisition',
#   'twtr',
#   'co',
#   'akqqrzvpsi'],
#  ['emx',
#   'emx',
#   'royalty',
#   'commences',
#   'commercial',
#   'production',
#   'oxide',
#   'gold',
#   'mineralization',
#   'flagship',
#   'gediktepe',
#   'royalty',
#   'co',
#   'cqlgwcx'],
#  ['business',
#   'traveler',
#   'filling',
#   'eurostar',
#   'train',
#   'airport',
#   'airline',
#   'cancel',
#   'thousand',
#   'flight',
#   'co',
#   'ayfxaowcd'],
#  ['vblt',
#   'adil',
#   'rvmd',
#   'baker',
#   'hughes',
#   'bath',
#   'amp',
#   'body',
#   'work',
#   'revolution',
#   'medicine',
#   'among',
#   'premarket',
#   'loser',
#   'pack',
#   'co',
#   'jqwsnajgx'],
#  ['saddened',
#   'inform',
#   'loved',
#   'many',
#   'ivana',
#   'trump',
#   'passed',
#   'away',
#   'home',
#   'new',
#   'york',
#   'city',
#   'former',
#   'president',
#   'donald',
#   'trump',
#   'posted',
#   'truth',
#   'social',
#   'co',
#   'bkwzip'],
#  ['turkey',
#   'president',
#   'erdogan',
#   'discus',
#   'paying',
#   'russian',
#   'energy',
#   'import',
#   'currency',
#   'u',
#   'dollar',
#   'meet',
#   'vladimir',
#   'putin',
#   'source',
#   'say',
#   'co',
#   'vlhtvrbm'],
#  ['co', 'atixwyfal', 'share', 'hit', 'session', 'low', 'last'],
#  ['norway',
#   'inflation',
#   'hit',
#   'year',
#   'high',
#   'feeding',
#   'speculation',
#   'central',
#   'bank',
#   'keep',
#   'accelerated',
#   'pace',
#   'interest',
#   'rate',
#   'hike',
#   'co',
#   'xpqidteenf'],
#  ['watch',
#   'breakingviews',
#   'ge',
#   'revealed',
#   'name',
#   'company',
#   'split',
#   'ge',
#   'aerospace',
#   'ge',
#   'vernova',
#   'ge',
#   'healthcare',
#   'name',
#   'pedestrian',
#   'ge',
#   'stock',
#   'performance',
#   'lauren',
#   'silva',
#   'laughlin',
#   'say',
#   'co',
#   'kuhhgzckg'],
#  ['blue',
#   'apron',
#   'release',
#   'second',
#   'quarter',
#   'result',
#   'august',
#   'co',
#   'qkygadtnz',
#   'co',
#   'nonhhcfzb'],
#  ['elv',
#   'elevance',
#   'health',
#   'beat',
#   'q',
#   'estimate',
#   'thanks',
#   'rising',
#   'premium',
#   'revenue',
#   'co',
#   'cbvvjpka'],
#  ['cost',
#   'costco',
#   'session',
#   'high',
#   'deutsche',
#   'bank',
#   'upgrade',
#   'share',
#   'higher',
#   'yesterday',
#   'low',
#   'co',
#   'vrnkkfkbhr'],
#  ['fisker',
#   'hired',
#   'longtime',
#   'bmw',
#   'executive',
#   'lead',
#   'global',
#   'manufacturing',
#   'effort',
#   'ahead',
#   'startup',
#   'plan',
#   'begin',
#   'building',
#   'electric',
#   'vehicle',
#   'later',
#   'year',
#   'co',
#   'bfrpjlzs'],
#  ['tsla',
#   'tesla',
#   'q',
#   'bet',
#   'elon',
#   'musk',
#   'overdelivering',
#   'co',
#   'rgfhcumn',
#   'investing',
#   'stock',
#   'finance'],
#  ['korean',
#   'president',
#   'yoon',
#   'urge',
#   'shipyard',
#   'strike',
#   'end',
#   'negotiation',
#   'stalled',
#   'co',
#   'eqbozcx',
#   'co',
#   'ozeohejm'],
#  ['jcyte',
#   'announces',
#   'appointment',
#   'dr',
#   'stewart',
#   'craig',
#   'chief',
#   'technology',
#   'officer',
#   'co',
#   'fenbakpy',
#   'co',
#   'tgzttodg'],
#  ['halt',
#   'russian',
#   'gas',
#   'supply',
#   'european',
#   'union',
#   'could',
#   'potentially',
#   'reduce',
#   'gross',
#   'domestic',
#   'product',
#   'much',
#   'according',
#   'new',
#   'estimate',
#   'bloc',
#   'co',
#   'yfpwrwo'],
#  ['ibm',
#   'cautioned',
#   'impact',
#   'strongest',
#   'dollar',
#   'two',
#   'decade',
#   'would',
#   'erode',
#   'full',
#   'year',
#   'sale',
#   'around',
#   'billion',
#   'co',
#   'ndpvozmzl'],
#  ['breakingviews',
#   'saudi',
#   'win',
#   'two',
#   'way',
#   'global',
#   'energy',
#   'reshuffle',
#   'co',
#   'asbafcgsn'],
#  ['lzb',
#   'la',
#   'z',
#   'boy',
#   'finalizes',
#   'plan',
#   'previously',
#   'announced',
#   'closure',
#   'newton',
#   'm',
#   'facility',
#   'co',
#   'kmupvvo'],
#  ['italian', 'premier', 'mario', 'draghi', 'say', 'resign', 'co', 'ivwawkar'],
#  ['president',
#   'jair',
#   'bolsonaro',
#   'get',
#   'green',
#   'light',
#   'spend',
#   'billion',
#   'help',
#   'brazilian',
#   'suffering',
#   'inflation',
#   'co',
#   'atnfocisy'],
#  ['aci',
#   'fraud',
#   'management',
#   'win',
#   'merchant',
#   'payment',
#   'ecosystem',
#   'award',
#   'co',
#   'pwwisrhvpm',
#   'co',
#   'lnvqewsq'],
#  ['new',
#   'zealand',
#   'jun',
#   'export',
#   'actual',
#   'b',
#   'v',
#   'b',
#   'previous',
#   'new',
#   'zealand',
#   'jun',
#   'import',
#   'actual',
#   'b',
#   'v',
#   'b',
#   'previous'],
#  ['spy',
#   'july',
#   'p',
#   'entry',
#   'contract',
#   'min',
#   'inverted',
#   'hammer',
#   'min',
#   'bearish'],
#  ['candidate',
#   'conservative',
#   'party',
#   'leader',
#   'left',
#   'battle',
#   'spot',
#   'run',
#   'vote',
#   'replace',
#   'boris',
#   'johnson',
#   'uk',
#   'next',
#   'prime',
#   'minister',
#   'co',
#   'hqtmdyjr'],
#  ['taoglas',
#   'novotech',
#   'announce',
#   'partnership',
#   'deliver',
#   'iot',
#   'excellence',
#   'canada',
#   'co',
#   'ojtjygssw',
#   'co',
#   'bfkcnytmf'],
#  ['ecu',
#   'health',
#   'partner',
#   'acadia',
#   'healthcare',
#   'build',
#   'new',
#   'behavioral',
#   'health',
#   'hospital',
#   'expanding',
#   'access',
#   'behavioral',
#   'health',
#   'service',
#   'co',
#   'zmzcdyjnqv',
#   'co',
#   'muficw'],
#  ['pioneer',
#   'landscape',
#   'center',
#   'launch',
#   'service',
#   'help',
#   'customer',
#   'increase',
#   'productivity',
#   'cost',
#   'saving',
#   'co',
#   'npukckv',
#   'co',
#   'gtconakks'],
#  ['sisvel',
#   'launch',
#   'patent',
#   'pool',
#   'wi',
#   'fi',
#   'co',
#   'ipojriiw',
#   'co',
#   'zyjgsvtnr'],
#  ['bloomberg',
#   'economics',
#   'new',
#   'nowcast',
#   'model',
#   'flag',
#   'u',
#   'gdp',
#   'may',
#   'contracted',
#   'second',
#   'quarter',
#   'co',
#   'axuqvaal'],
#  ['pjt',
#   'partner',
#   'inc',
#   'report',
#   'second',
#   'quarter',
#   'financial',
#   'result',
#   'host',
#   'conference',
#   'call',
#   'july',
#   'co',
#   'fcdwxgpwe'],
#  ['qd',
#   'qudian',
#   'chief',
#   'turn',
#   'star',
#   'power',
#   'company',
#   'transformation',
#   'co',
#   'majhxmef',
#   'stock',
#   'finance',
#   'economy'],
#  ['watch',
#   'elon',
#   'musk',
#   'bid',
#   'avoid',
#   'buying',
#   'twitter',
#   'hedge',
#   'fund',
#   'titan',
#   'bill',
#   'ackman',
#   'giving',
#   'back',
#   'billion',
#   'investor',
#   'round',
#   'big',
#   'story',
#   'business',
#   'finance',
#   'week',
#   'co',
#   'dulwafjle'],
#  ['qh', 'quhuo', 'cfo', 'wenting', 'ji', 'resign', 'co', 'zenppugwq'],
#  ['heard',
#   'street',
#   'apple',
#   'microsoft',
#   'google',
#   'pare',
#   'back',
#   'hiring',
#   'plan',
#   'slowing',
#   'growth',
#   'put',
#   'focus',
#   'maintaining',
#   'margin',
#   'co',
#   'trwxeeoywt'],
#  ['oil',
#   'price',
#   'fallen',
#   'barrel',
#   'first',
#   'time',
#   'since',
#   'russia',
#   'invaded',
#   'ukraine',
#   'fear',
#   'impending',
#   'global',
#   'recession',
#   'grip',
#   'commodity',
#   'market',
#   'batter',
#   'forecast',
#   'demand',
#   'co',
#   'optiagcr',
#   'co',
#   'cmqdhgygh'],
#  ['india',
#   'central',
#   'bank',
#   'governor',
#   'say',
#   'monetary',
#   'policy',
#   'mindful',
#   'economy',
#   'growth',
#   'need',
#   'signaling',
#   'tightening',
#   'geared',
#   'ensure',
#   'massive',
#   'slowdown',
#   'co',
#   'zxdxoktu'],
#  ['nasdaq',
#   'profit',
#   'top',
#   'wall',
#   'street',
#   'view',
#   'software',
#   'service',
#   'rise',
#   'co',
#   'syaycqvtqc',
#   'co',
#   'kwvuglinq'],
#  ['singapore',
#   'central',
#   'bank',
#   'tightens',
#   'monetary',
#   'policy',
#   'unexpected',
#   'move',
#   'co',
#   'peogwelc'],
#  ['single',
#   'biggest',
#   'problem',
#   'last',
#   'year',
#   'low',
#   'growth',
#   'got',
#   'acute',
#   'cost',
#   'living',
#   'crisis',
#   'got',
#   'inflation',
#   'high',
#   'keir',
#   'starmer',
#   'tell',
#   'bloomberg',
#   'co',
#   'dpgdxjls'],
#  ['worldwide',
#   'copper',
#   'pyrithione',
#   'industry',
#   'expected',
#   'reach',
#   'million',
#   'co',
#   'guyibzphc',
#   'co',
#   'gcoawsri',
#   'co',
#   'fqxxylit'],
#  ['comdx', 'energy', 'settlement', 'price', 'co', 'voawng'],
#  ['ctm',
#   'surpasses',
#   'expectation',
#   'global',
#   'cybersecurity',
#   'conference',
#   'firstcon',
#   'co',
#   'tduewkeoss',
#   'co',
#   'zmdvjguri'],
#  ['curo', 'close', 'million', 'facility', 'co', 'ootxvrk', 'co', 'mnvnlkikh'],
#  ['soaring',
#   'u',
#   'inflation',
#   'squeezing',
#   'living',
#   'standard',
#   'manufacturing',
#   'worker',
#   'especially',
#   'hard',
#   'adding',
#   'danger',
#   'democrat',
#   'face',
#   'key',
#   'battleground',
#   'state',
#   'midterm',
#   'election',
#   'co',
#   'iiezusmri'],
#  ['belarus',
#   'russia',
#   'loyal',
#   'ally',
#   'declared',
#   'default',
#   'fitch',
#   'rating',
#   'joining',
#   'moody',
#   'investor',
#   'service',
#   'co',
#   'gneulqmz'],
#  ['boe',
#   'bailey',
#   'expecting',
#   'inflation',
#   'come',
#   'rapidly',
#   'next',
#   'year'],
#  ['kkr',
#   'anzby',
#   'kkr',
#   'said',
#   'seek',
#   'b',
#   'myob',
#   'group',
#   'talk',
#   'anz',
#   'co',
#   'uvtuajdvx'],
#  ['bondx', 'new', 'supply', 'co', 'lryjvmgnp'],
#  ['wabtec',
#   'announces',
#   'second',
#   'quarter',
#   'earnings',
#   'release',
#   'date',
#   'co',
#   'priupvon',
#   'co',
#   'zhvztojfov'],
#  ['citibank',
#   'uk',
#   'regulatory',
#   'announcement',
#   'frn',
#   'variable',
#   'rate',
#   'fix',
#   'co',
#   'mivaumlos',
#   'co',
#   'cwzryhwew'],
#  ['breaking',
#   'company',
#   'fast',
#   'track',
#   'lawsuit',
#   'elon',
#   'musk',
#   'canceled',
#   'buyout',
#   'according',
#   'delaware',
#   'judge',
#   'trial',
#   'take',
#   'place',
#   'october',
#   'co',
#   'iouioeya',
#   'co',
#   'jenkhdchl'],
#  ['bank',
#   'data',
#   'show',
#   'u',
#   'consumer',
#   'financial',
#   'health',
#   'hold',
#   'amid',
#   'rising',
#   'inflation',
#   'reuters',
#   'co',
#   'ygksglfjc'],
#  ['meridianlink',
#   'appoints',
#   'duston',
#   'williams',
#   'board',
#   'director',
#   'co',
#   'plyvjtecf',
#   'co',
#   'dtpvdtva'],
#  ['u', 'stock', 'extend', 'fall', 'amp', 'p'],
#  ['inflation',
#   'high',
#   'american',
#   'cutting',
#   'back',
#   'food',
#   'spending',
#   'co',
#   'uhovct'],
#  ['interest',
#   'policy',
#   'help',
#   'nubank',
#   'lower',
#   'funding',
#   'cost',
#   'say',
#   'analyst',
#   'co',
#   'dycztrjege',
#   'co',
#   'ibhqxbdcuz'],
#  ['equitiesfirst',
#   'unnamed',
#   'debtor',
#   'troubled',
#   'crypto',
#   'firm',
#   'celsius',
#   'co',
#   'dduicfuh'],
#  ['siemens',
#   'energy',
#   'power',
#   'world',
#   'lowest',
#   'emission',
#   'lng',
#   'facility',
#   'co',
#   'ckodvzqlhc',
#   'co',
#   'rjktwrlrw'],
#  ['f',
#   'always',
#   'hard',
#   'time',
#   'finding',
#   'large',
#   'u',
#   'fan',
#   'base',
#   'finally',
#   'found',
#   'secret',
#   'americanize',
#   'co',
#   'zpuspif',
#   'via',
#   'bw'],
#  ['amp',
#   'earnings',
#   'call',
#   'cash',
#   'flow',
#   'cut',
#   'price',
#   'hike',
#   'race',
#   'inflation',
#   'co',
#   'fxytet'],
#  ['roqaf',
#   'uk',
#   'biotech',
#   'roquefort',
#   'begin',
#   'trading',
#   'otcqb',
#   'venture',
#   'market',
#   'co',
#   'vycbcnjhvk'],
#  ['e',
#   'equilibrium',
#   'long',
#   'either',
#   'open',
#   'go',
#   'bid',
#   'open',
#   'minor',
#   'resistance',
#   'bid',
#   'run',
#   'resistance'],
#  ['g',
#   'report',
#   'strong',
#   'q',
#   'earnings',
#   'beat',
#   'bac',
#   'post',
#   'miss',
#   'take',
#   'look',
#   'investment',
#   'banking',
#   'story',
#   'revenue',
#   'asset',
#   'management',
#   'well',
#   'thematic',
#   'seen',
#   'big',
#   'money',
#   'center',
#   'bank',
#   'bcheungz',
#   'say',
#   'goldman',
#   'sachs',
#   'co',
#   'lnhsdhpq'],
#  ['bigc',
#   'bigcommerce',
#   'report',
#   'uk',
#   'ev',
#   'charging',
#   'firm',
#   'joining',
#   'platform',
#   'co',
#   'asqotcdgfo'],
#  ['mortgage',
#   'rate',
#   'edge',
#   'higher',
#   'week',
#   'co',
#   'stujeoaymf',
#   '__gabriellacruz',
#   'co',
#   'gpaztrmfom'],
#  ['earnings',
#   'tesla',
#   'q',
#   'eps',
#   'adj',
#   'v',
#   'est',
#   'q',
#   'rev',
#   'b',
#   'v',
#   'b',
#   'est',
#   'lebeaucarnews',
#   'report',
#   'co',
#   'crubekpuj',
#   'co',
#   'rwjcim'],
#  ['stt',
#   'pre',
#   'state',
#   'street',
#   'non',
#   'gaap',
#   'eps',
#   'beat',
#   'revenue',
#   'b',
#   'miss',
#   'sa',
#   'co',
#   'ahirsy'],
#  ['marinus',
#   'pharmaceutical',
#   'provide',
#   'business',
#   'update',
#   'report',
#   'second',
#   'quarter',
#   'financial',
#   'result',
#   'august',
#   'co',
#   'avajvyyrsr',
#   'co',
#   'emnpupgdnw'],
#  ['uk',
#   'accounting',
#   'watchdog',
#   'blast',
#   'mazars',
#   'bdo',
#   'accountant',
#   'unacceptable',
#   'quality',
#   'audit',
#   'co',
#   'ibdjihhcp'],
#  ['coin',
#   'coinbase',
#   'remains',
#   'uncharted',
#   'water',
#   'amidst',
#   'crypto',
#   'selloff',
#   'co',
#   'zokhotid',
#   'stock',
#   'finance',
#   'stockmarket'],
#  ['u', 'seen', 'narrowly', 'skirting', 'recession', 'co', 'hnrfrnso'],
#  ['transcript',
#   'josh',
#   'younger',
#   'explains',
#   'bond',
#   'market',
#   'volatile',
#   'co',
#   'wgagwcj'],
#  ['producer',
#   'price',
#   'index',
#   'final',
#   'demand',
#   'representing',
#   'wholesale',
#   'cost',
#   'u',
#   'good',
#   'service',
#   'rose',
#   'seasonally',
#   'adjusted',
#   'june',
#   'year',
#   'earlier',
#   'price',
#   'seasonally',
#   'adjusted',
#   'increasing',
#   'may',
#   'co',
#   'hpulylwen',
#   'co',
#   'hpwacjzhr'],
#  ['see',
#   'hold',
#   'amp',
#   'consolidates',
#   'next',
#   'continues',
#   'spx',
#   'es_f',
#   'spy'],
#  ['well',
#   'fargo',
#   'mostly',
#   'defeat',
#   'two',
#   'lawsuit',
#   'mortgage',
#   'loss',
#   'co',
#   'fnfnstypx',
#   'co',
#   'xycdxonwdf'],
#  ['ithx',
#   'pre',
#   'ithax',
#   'acquisition',
#   'corp',
#   'shareholder',
#   'approve',
#   'business',
#   'combination',
#   'mondee',
#   'bw',
#   'co',
#   'dsqlchbm'],
#  ['european',
#   'stock',
#   'decline',
#   'second',
#   'day',
#   'ahead',
#   'key',
#   'earnings',
#   'season',
#   'amid',
#   'concern',
#   'new',
#   'lockdown',
#   'china',
#   'co',
#   'pvfvwetwo'],
#  ['ba',
#   'boeing',
#   'ana',
#   'holding',
#   'alnpy',
#   'formalized',
#   'order',
#   'airplane',
#   'co',
#   'durngxqki'],
#  ['first',
#   'trust',
#   'global',
#   'fund',
#   'plc',
#   'uk',
#   'regulatory',
#   'announcement',
#   'net',
#   'asset',
#   'value',
#   'co',
#   'iryeblfyg',
#   'co',
#   'avbdcc'],
#  ['m',
#   'sentiment',
#   'negative',
#   'side',
#   'morgan',
#   'stanley',
#   'q',
#   'eps',
#   'co',
#   'tjfqfgl'],
#  ['view',
#   'early',
#   'refinancing',
#   'infra',
#   'debt',
#   'market',
#   'rubis',
#   'terminal',
#   'issue',
#   'redemption',
#   'notice',
#   'bond',
#   'co',
#   'iawosual',
#   'co',
#   'bkphawnr'],
#  ['c',
#   'jpm',
#   'bac',
#   'citigroup',
#   'strong',
#   'earnings',
#   'give',
#   'investor',
#   'greenlight',
#   'buy',
#   'stock',
#   'co',
#   'dxnxbgeql'],
#  ['breaking',
#   'china',
#   'fine',
#   'didi',
#   'billion',
#   'wrapping',
#   'cybersecurity',
#   'probe',
#   'co',
#   'bokompdg',
#   'co',
#   'iwbbuwwdj'],
#  ['gpro',
#   'gopro',
#   'fear',
#   'dip',
#   'co',
#   'ixijtrhjj',
#   'business',
#   'market',
#   'trading'],
#  ['virgin',
#   'medium',
#   'discussion',
#   'acquire',
#   'talktalk',
#   'telecom',
#   'marking',
#   'another',
#   'round',
#   'telecom',
#   'consolidation',
#   'source',
#   'say',
#   'co',
#   'ujlsltoei'],
#  ['dollar',
#   'climb',
#   'pinning',
#   'euro',
#   'yen',
#   'multi',
#   'decade',
#   'low',
#   'reuters',
#   'co',
#   'omojvdp'],
#  ['note',
#   'g',
#   'u',
#   'treasury',
#   'secretary',
#   'russia',
#   'still',
#   'raking',
#   'oil',
#   'even',
#   'export',
#   'showing',
#   'sign',
#   'ebbing',
#   'co',
#   'ghwwmrbpl'],
#  ['james',
#   'webb',
#   'space',
#   'telescope',
#   'released',
#   'first',
#   'image',
#   'time',
#   'science',
#   'begin',
#   'meet',
#   'five',
#   'scientist',
#   'analyze',
#   'earliest',
#   'galaxy',
#   'unexplored',
#   'region',
#   'solar',
#   'system',
#   'watch',
#   'full',
#   'co',
#   'vfnuapilf',
#   'co',
#   'bontrzzlj',
#   'co',
#   'biohvyim'],
#  ['grpty', 'grptf', 'getlink', 'report', 'h', 'result', 'co', 'mcaalaxczs'],
#  ['industry',
#   'veteran',
#   'joe',
#   'strickland',
#   'join',
#   'futureproof',
#   'head',
#   'underwriting',
#   'co',
#   'xlxxovf',
#   'co',
#   'laefinv'],
#  ['uk',
#   'extend',
#   'loan',
#   'support',
#   'small',
#   'business',
#   'two',
#   'year',
#   'reuters',
#   'co',
#   'reajpzmifr'],
#  ['rapidly',
#   'increasing',
#   'number',
#   'disgruntled',
#   'chinese',
#   'homebuyers',
#   'refusing',
#   'pay',
#   'mortgage',
#   'unfinished',
#   'construction',
#   'project',
#   'co',
#   'ipazbgus'],
#  ['cbsh', 'commerce', 'bancshares', 'beat', 'beat', 'rev', 'co', 'lfzvfjioww'],
#  ['azerbaijan',
#   'oil',
#   'output',
#   'mln',
#   'jan',
#   'june',
#   'statistic',
#   'committee'],
#  ['cgc',
#   'weed',
#   'ca',
#   'canopy',
#   'growth',
#   'constellation',
#   'investment',
#   'go',
#   'smoke',
#   'co',
#   'kdpuuyqpc',
#   'finance',
#   'investing',
#   'stock'],
#  ['iphone',
#   'pro',
#   'ipad',
#   'pro',
#   'macbook',
#   'pro',
#   'airpods',
#   'pro',
#   'soon',
#   'apple',
#   'watch',
#   'pro',
#   'co',
#   'vilbnnmd'],
#  ['xm',
#   'pre',
#   'qualtrics',
#   'announces',
#   'second',
#   'quarter',
#   'financial',
#   'result',
#   'co',
#   'lvfvpuzu'],
#  ['game',
#   'game',
#   'ca',
#   'engine',
#   'gaming',
#   'medium',
#   'inc',
#   'game',
#   'ceo',
#   'lou',
#   'schwartz',
#   'q',
#   'result',
#   'earnings',
#   'call',
#   'transcript',
#   'co',
#   'foaau',
#   'business',
#   'trading',
#   'stock'],
#  ['u',
#   'unity',
#   'software',
#   'underpaid',
#   'ironsource',
#   'co',
#   'lroroehvo',
#   'stock',
#   'market',
#   'business'],
#  ['sbux',
#   'starbucks',
#   'set',
#   'sell',
#   'russian',
#   'business',
#   'restaurateur',
#   'rapper',
#   'co',
#   'soyplrell'],
#  ['trump',
#   'accused',
#   'possible',
#   'witness',
#   'tampering',
#   'highlight',
#   'jan',
#   'hearing',
#   'co',
#   'xqrdcwiy'],
#  ['watch',
#   'record',
#   'high',
#   'price',
#   'fast',
#   'rising',
#   'interest',
#   'rate',
#   'made',
#   'buying',
#   'home',
#   'expensive',
#   'growing',
#   'share',
#   'american',
#   'household',
#   'sending',
#   'sale',
#   'previously',
#   'owned',
#   'home',
#   'u',
#   'june',
#   'lowest',
#   'level',
#   'two',
#   'year',
#   'co',
#   'bpmxjgqv',
#   'co',
#   'cndxqjjq'],
#  ['ccj',
#   'cameco',
#   'conservative',
#   'choice',
#   'uranium',
#   'market',
#   'improving',
#   'fundamental',
#   'co',
#   'catutkaxaf',
#   'finance',
#   'economy',
#   'business'],
#  ['albertsons',
#   'company',
#   'announces',
#   'common',
#   'stock',
#   'dividend',
#   'co',
#   'rwxdqyuwzr',
#   'co',
#   'fhcuzxxw'],
#  ['wire', 'wire', 'co', 'pnyldte'],
#  ['riot',
#   'game',
#   'put',
#   'owner',
#   'prestigious',
#   'esports',
#   'team',
#   'tsm',
#   'two',
#   'year',
#   'probation',
#   'internal',
#   'investigation',
#   'accused',
#   'harassment',
#   'bullying',
#   'co',
#   'bmhzgebp'],
#  ['boeing',
#   'unitedhealth',
#   'underperform',
#   'djia',
#   'wednesday',
#   'ba',
#   'unh',
#   'dow',
#   'pg',
#   'spy',
#   'qqq',
#   'dia',
#   'spx',
#   'compq',
#   'co',
#   'lzemmlqjhi',
#   'economy',
#   'stockmarket'],
#  ['fortune',
#   'international',
#   'acquires',
#   'new',
#   'orleans',
#   'fish',
#   'house',
#   'leading',
#   'supplier',
#   'fresh',
#   'seafood',
#   'top',
#   'restaurant',
#   'new',
#   'orleans',
#   'gulf',
#   'region',
#   'co',
#   'sqfxlpj',
#   'co',
#   'ciwtdbh'],
#  ['acmr',
#   'acm',
#   'research',
#   'introduces',
#   'new',
#   'post',
#   'cmp',
#   'cleaning',
#   'tool',
#   'serving',
#   'cleaning',
#   'step',
#   'following',
#   'chemical',
#   'co',
#   'paxthk'],
#  ['lithium',
#   'refining',
#   'license',
#   'print',
#   'money',
#   'elon',
#   'musk',
#   'say',
#   'urge',
#   'investment',
#   'battery',
#   'material',
#   'co',
#   'bzupkizq'],
#  ['broad',
#   'buying',
#   'interest',
#   'megacaps',
#   'leading',
#   'tsla',
#   'meta',
#   'nvda',
#   'rsp',
#   'mgk',
#   'spy',
#   'qqq',
#   'dia',
#   'spx',
#   'compq',
#   'djia',
#   'co',
#   'lzemmmkg',
#   'economy',
#   'stockmarket'],
#  ['tcda', 'vtnr', 'epix', 'goev'],
#  ['metc', 'ramaco', 'dip', 'dividend', 'share', 'co', 'bpzjrxo'],
#  ['india',
#   'consider',
#   'giving',
#   'assistance',
#   'sri',
#   'lanka',
#   'help',
#   'rescue',
#   'island',
#   'nation',
#   'worst',
#   'economic',
#   'crisis',
#   'since',
#   'independence',
#   'co',
#   'tjlwr'],
#  ['rep',
#   'jamie',
#   'raskin',
#   'md',
#   'suggested',
#   'bannon',
#   'change',
#   'heart',
#   'watching',
#   'presumably',
#   'people',
#   'come',
#   'forward',
#   'including',
#   'cassidy',
#   'hutchinson',
#   'decided',
#   'want',
#   'come',
#   'co',
#   'fqmdhlo'],
#  ['universal',
#   'electronics',
#   'launch',
#   'new',
#   'voice',
#   'remote',
#   'rdk',
#   'platform',
#   'rdk',
#   'tech',
#   'summit',
#   'co',
#   'vxkpvivth',
#   'co',
#   'qbscmunkdy'],
#  ['kkonthedash',
#   'middleeast',
#   'lower',
#   'high',
#   'lower',
#   'low',
#   'declining',
#   'ma',
#   'volatile',
#   'market',
#   'near',
#   'term',
#   'downtrend'],
#  ['vino',
#   'vault',
#   'announces',
#   'seventh',
#   'u',
#   'location',
#   'second',
#   'site',
#   'texas',
#   'purchase',
#   'houston',
#   'wine',
#   'cellar',
#   'co',
#   'znnclxlpp',
#   'co',
#   'ghawongpm'],
#  ['iron',
#   'mountain',
#   'schedule',
#   'second',
#   'quarter',
#   'earnings',
#   'release',
#   'conference',
#   'call',
#   'co',
#   'pusieiebx',
#   'co',
#   'mucjviwp'],
#  ['twtr',
#   'elon',
#   'musk',
#   'twitter',
#   'option',
#   'co',
#   'jpohorirt',
#   'trading',
#   'stock',
#   'business'],
#  ['world',
#   'bank',
#   'president',
#   'david',
#   'malpass',
#   'say',
#   'lack',
#   'progress',
#   'largest',
#   'economy',
#   'reduce',
#   'debt',
#   'burden',
#   'poorest',
#   'nation',
#   'borrowing',
#   'cost',
#   'rise',
#   'cause',
#   'worsening',
#   'poverty',
#   'rate',
#   'instability',
#   'co',
#   'mbjcttlqk'],
#  ['national',
#   'stock',
#   'exchange',
#   'india',
#   'set',
#   'hire',
#   'ashish',
#   'kumar',
#   'chauhan',
#   'chief',
#   'executive',
#   'smaller',
#   'rival',
#   'bse',
#   'top',
#   'official',
#   'beef',
#   'effort',
#   'overcome',
#   'spate',
#   'past',
#   'scandal',
#   'co',
#   'gftfsuqel'],
#  ['small',
#   'business',
#   'outlook',
#   'future',
#   'condition',
#   'reach',
#   'year',
#   'low',
#   'co',
#   'eclwzkrg'],
#  ['never',
#   'expensive',
#   'get',
#   'hotel',
#   'room',
#   'london',
#   'tourist',
#   'number',
#   'rise',
#   'spite',
#   'continuing',
#   'travel',
#   'chaos',
#   'co',
#   'komsvtjs'],
#  ['cummins',
#   'elect',
#   'gary',
#   'belske',
#   'board',
#   'director',
#   'co',
#   'xhkkbwdnv',
#   'co',
#   'gnxwmrdnny'],
#  ['ceqp',
#   'crestwood',
#   'equity',
#   'partner',
#   'cheap',
#   'ignore',
#   'co',
#   'mdzhptb',
#   'investing',
#   'market',
#   'economy'],
#  ['china',
#   'holding',
#   'u',
#   'debt',
#   'fall',
#   'trillion',
#   'first',
# ...
#   'small',
#   'step',
#   'de',
#   'dollarization',
#   'andymukherjee',
#   'explains',
#   'co',
#   'ovvypdw',
#   'via',
#   'opinion'],
#  ['latest',
#   'italy',
#   'prime',
#   'minister',
#   'mario',
#   'draghi',
#   'tell',
#   'lawmaker',
#   'meet',
#   'president',
#   'thursday',
#   'morning',
#   'expected',
#   'offer',
#   'resignation',
#   'co',
#   'upprgky',
#   'co',
#   'opvxxbgpwa'],
#  ['cannabis',
#   'leader',
#   'nabis',
#   'parent',
#   'company',
#   'forge',
#   'exclusive',
#   'distribution',
#   'partnership',
#   'co',
#   'hzlvdzlxev',
#   'co',
#   'surrtfxvte'],
#  ['twen',
#   'holding',
#   'begin',
#   'u',
#   'ipo',
#   'effort',
#   'co',
#   'gbpmrd',
#   'stockmarket',
#   'trading',
#   'business'],
#  ['netflix',
#   'cautioned',
#   'may',
#   'lost',
#   'another',
#   'million',
#   'subscriber',
#   'second',
#   'quarter',
#   'planned',
#   'launch',
#   'cheaper',
#   'ad',
#   'supported',
#   'service',
#   'could',
#   'bring',
#   'back',
#   'need',
#   'know',
#   'ahead',
#   'nflx',
#   'earnings',
#   'report',
#   'co',
#   'hyozapkxc'],
#  ['earnings', 'season', 'go', 'list', 'name', 'good', 'time', 'start', 'one'],
#  ['nvax',
#   'go',
#   'bmra',
#   'biomerica',
#   'clene',
#   'top',
#   'healthcare',
#   'gainer',
#   'contrafect',
#   'novavax',
#   'lead',
#   'loser',
#   'pack',
#   'co',
#   'wynaghag'],
#  ['u',
#   'energy',
#   'secretary',
#   'granholm',
#   'say',
#   'miner',
#   'help',
#   'diversify',
#   'clean',
#   'energy',
#   'supply',
#   'chain'],
#  ['rancher',
#   'top',
#   'cattle',
#   'state',
#   'texas',
#   'sell',
#   'herd',
#   'fast',
#   'enough',
#   'degree',
#   'fahrenheit',
#   'temperature',
#   'making',
#   'expensive',
#   'sustain',
#   'animal',
#   'co',
#   'hdgkvdbspm'],
#  ['singapore',
#   'home',
#   'sale',
#   'slump',
#   'june',
#   'lowest',
#   'two',
#   'year',
#   'concern',
#   'interest',
#   'rate',
#   'hike',
#   'kept',
#   'buyer',
#   'bay',
#   'co',
#   'obfrzhyi'],
#  ['list',
#   'accumulation',
#   'volume',
#   'candidate',
#   'mara',
#   'turn',
#   'take',
#   'note',
#   'mini',
#   'bullish',
#   'flag',
#   'formed',
#   'last',
#   'week',
#   'co',
#   'ohauatvtp'],
#  ['south',
#   'africa',
#   'state',
#   'owned',
#   'power',
#   'utility',
#   'eskom',
#   'may',
#   'limit',
#   'electricity',
#   'rationing',
#   'megawatt',
#   'time',
#   'saturday',
#   'end',
#   'next',
#   'week',
#   'co',
#   'zhsefeozeb'],
#  ['prime',
#   'day',
#   'fix',
#   'amazon',
#   'near',
#   'term',
#   'challenge',
#   'finding',
#   'new',
#   'u',
#   'member',
#   'getting',
#   'harder',
#   'co',
#   'lkkhmdknp'],
#  ['euro',
#   'descent',
#   'year',
#   'one',
#   'part',
#   'global',
#   'story',
#   'dollar',
#   'dominance',
#   'greenback',
#   'favor',
#   'year',
#   'investment',
#   'helped',
#   'higher',
#   'u',
#   'interest',
#   'rate',
#   'co',
#   'wqouhukri',
#   'co',
#   'qvrazolkv'],
#  ['law',
#   'firm',
#   'sidley',
#   'austin',
#   'joining',
#   'rush',
#   'company',
#   'heading',
#   'miami',
#   'opening',
#   'new',
#   'office',
#   'south',
#   'florida',
#   'city',
#   'co',
#   'rgeapnio'],
#  ['ever',
#   'pharma',
#   'launch',
#   'digital',
#   'training',
#   'app',
#   'mine',
#   'pump',
#   'co',
#   'olxztnv',
#   'co',
#   'wuvnndjia'],
#  ['moody',
#   'chief',
#   'economist',
#   'say',
#   'never',
#   'seen',
#   'many',
#   'people',
#   'convinced',
#   'u',
#   'recession',
#   'imminent',
#   'co',
#   'mmfxwnwvm'],
#  ['new',
#   'zealand',
#   'inflation',
#   'accelerated',
#   'economist',
#   'expected',
#   'second',
#   'quarter',
#   'fresh',
#   'year',
#   'high',
#   'co',
#   'wgpzpvwkt'],
#  ['qcaaf',
#   'quinsam',
#   'capital',
#   'declares',
#   'cad',
#   'dividend',
#   'co',
#   'aomdpoepr'],
#  ['stalicla',
#   'awarded',
#   'eur',
#   'million',
#   'lead',
#   'computational',
#   'drug',
#   'repositioning',
#   'activity',
#   'eu',
#   'funded',
#   'repoeu',
#   'project',
#   'co',
#   'uxkbphxr',
#   'co',
#   'bbfgixqug'],
#  ['ntb',
#   'bank',
#   'n',
#   'butterfield',
#   'amp',
#   'son',
#   'announces',
#   'unsolicited',
#   'mini',
#   'tender',
#   'offer',
#   'co',
#   'gbjxfctnk'],
#  ['fed',
#   'mester',
#   'expect',
#   'fed',
#   'need',
#   'go',
#   'well',
#   'beyond',
#   'neutral',
#   'rate',
#   'bbg',
#   'tv'],
#  ['ivz',
#   'invesco',
#   'report',
#   'preliminary',
#   'month',
#   'end',
#   'asset',
#   'management',
#   'bln',
#   'june',
#   'decrease',
#   'co',
#   'vlpglh'],
#  ['air', 'aar', 'q', 'earnings', 'preview', 'co', 'soylsngv'],
#  ['olb', 'intraday', 'break', 'heavy', 'volume'],
#  ['ukraine',
#   'seeking',
#   'delay',
#   'payment',
#   'foreign',
#   'debt',
#   'change',
#   'term',
#   'gdp',
#   'warrant',
#   'russia',
#   'invasion',
#   'undermines',
#   'economy',
#   'co',
#   'vxhefzn'],
#  ['accenture',
#   'acquire',
#   'stable',
#   'bolster',
#   'commerce',
#   'transformation',
#   'expertise',
#   'north',
#   'america',
#   'co',
#   'zqdvfgfg',
#   'co',
#   'ghsbbonvhy'],
#  ['cbu',
#   'community',
#   'bank',
#   'system',
#   'raise',
#   'quarterly',
#   'dividend',
#   'co',
#   'mefxgtajk'],
#  ['japan',
#   'reported',
#   'trade',
#   'deficit',
#   'th',
#   'consecutive',
#   'month',
#   'june',
#   'higher',
#   'energy',
#   'price',
#   'weaker',
#   'yen',
#   'continued',
#   'inflate',
#   'nation',
#   'import',
#   'bill',
#   'co',
#   'spkatwdrwv'],
#  ['nord',
#   'stream',
#   'gas',
#   'pipeline',
#   'nomination',
#   'kwh',
#   'h',
#   'cet',
#   'rtrs'],
#  ['joe',
#   'biden',
#   'use',
#   'force',
#   'stop',
#   'iran',
#   'getting',
#   'nuclear',
#   'weapon',
#   'telegraph',
#   'co',
#   'yhbhypuorr'],
#  ['redwood',
#   'trust',
#   'announces',
#   'date',
#   'second',
#   'quarter',
#   'financial',
#   'result',
#   'webcast',
#   'conference',
#   'call',
#   'co',
#   'mjbmysvksr',
#   'co',
#   'ergdpjzn'],
#  ['epd',
#   'enterprise',
#   'product',
#   'partner',
#   'cheap',
#   'yield',
#   'distribution',
#   'grew',
#   'co',
#   'leydby',
#   'economy',
#   'business',
#   'stock'],
#  ['global',
#   'bos',
#   'pwc',
#   'said',
#   'firm',
#   'would',
#   'report',
#   'record',
#   'revenue',
#   'bn',
#   'year',
#   'defended',
#   'model',
#   'combining',
#   'audit',
#   'consulting',
#   'service',
#   'co',
#   'ehoywbyd'],
#  ['britain',
#   'wealth',
#   'gap',
#   'increased',
#   'since',
#   'according',
#   'think',
#   'tank',
#   'co',
#   'sojjkuxa'],
#  ['investor',
#   'alert',
#   'law',
#   'office',
#   'howard',
#   'g',
#   'smith',
#   'announces',
#   'investigation',
#   'co',
#   'fzwqukvei',
#   'inc',
#   'amzn',
#   'behalf',
#   'investor',
#   'co',
#   'olgugxqc',
#   'co',
#   'yiwlhjc'],
#  ['nvta',
#   'pre',
#   'invitae',
#   'announces',
#   'strategic',
#   'business',
#   'realignment',
#   'accelerate',
#   'path',
#   'positive',
#   'cash',
#   'flow',
#   'realize',
#   'full',
#   'potential',
#   'industry',
#   'leading',
#   'genetics',
#   'testing',
#   'platform',
#   'prn',
#   'co',
#   'dgdemtxzqv'],
#  ['china',
#   'government',
#   'usually',
#   'get',
#   'want',
#   'made',
#   'beijing',
#   'vaccine',
#   'mandate',
#   'reversal',
#   'interesting',
#   'co',
#   'hqewxvjk'],
#  ['president',
#   'xi',
#   'jinping',
#   'made',
#   'reported',
#   'public',
#   'appearance',
#   'day',
#   'since',
#   'returning',
#   'landmark',
#   'trip',
#   'hong',
#   'kong',
#   'first',
#   'outside',
#   'mainland',
#   'china',
#   'since',
#   'pandemic',
#   'outset',
#   'co',
#   'tgpyopyz'],
#  ['total',
#   'corporate',
#   'funding',
#   'solar',
#   'sector',
#   'totaled',
#   'billion',
#   'h',
#   'co',
#   'rasfcbp',
#   'co',
#   'eftvbof'],
#  ['gm',
#   'reveals',
#   'new',
#   'electric',
#   'chevrolet',
#   'blazer',
#   'priced',
#   'starting',
#   'co',
#   'jmbxbslomp'],
#  ['discover',
#   'partner',
#   'artist',
#   'influencer',
#   'create',
#   'next',
#   'design',
#   'discover',
#   'student',
#   'card',
#   'co',
#   'xmhiggr',
#   'co',
#   'yrkijsutg'],
#  ['dov',
#   'dover',
#   'non',
#   'gaap',
#   'eps',
#   'beat',
#   'revenue',
#   'miss',
#   'b',
#   'provides',
#   'fy',
#   'adj',
#   'eps',
#   'guidance',
#   'co',
#   'xicfngyjxk'],
#  ['ee',
#   'excelerate',
#   'energy',
#   'sign',
#   'mou',
#   'bulgaria',
#   'overgas',
#   'relating',
#   'regasified',
#   'lng',
#   'downstream',
#   'sale',
#   'co',
#   'arwsnble'],
#  ['aal', 'ual', 'report', 'q', 'earnings', 'miss', 'co', 'arwczykvu'],
#  ['plrx',
#   'pliant',
#   'therapeutic',
#   'price',
#   'offering',
#   'share',
#   'common',
#   'stock',
#   'per',
#   'share',
#   'co',
#   'xtxbkbsg'],
#  ['bitcoin',
#   'everyone',
#   'equal',
#   'theory',
#   'go',
#   'theory',
#   'match',
#   'reality',
#   'alyssa',
#   'blackburn',
#   'dr',
#   'erez',
#   'lieberman',
#   'aiden',
#   'discus',
#   'research',
#   'controlled',
#   'bitcoin',
#   'early',
#   'day',
#   'apple',
#   'co',
#   'brpjope',
#   'spotify',
#   'co',
#   'dkfnzpsll',
#   'co',
#   'itnocxr'],
#  ['uber',
#   'pre',
#   'uber',
#   'broke',
#   'law',
#   'duped',
#   'police',
#   'secretly',
#   'lobbied',
#   'government',
#   'leak',
#   'reveals',
#   'guardian',
#   'co',
#   'cjvtjtyvxl'],
#  ['japan', 'machine', 'tool', 'order', 'jun', 'f', 'prev'],
#  ['clearhaven',
#   'partner',
#   'invests',
#   'controlling',
#   'interest',
#   'sundaysky',
#   'co',
#   'yhhyhhxxfx',
#   'co',
#   'eykrxnbn'],
#  ['white',
#   'house',
#   'say',
#   'president',
#   'biden',
#   'tested',
#   'positive',
#   'covid'],
#  ['j',
#   'amp',
#   'j',
#   'trim',
#   'outlook',
#   'top',
#   'earnings',
#   'expectation',
#   'co',
#   'uryezzf'],
#  ['unp', 'union', 'pacific', 'beat', 'beat', 'rev', 'co', 'eizveqvzw'],
#  ['srne',
#   'sorrento',
#   'gain',
#   'fda',
#   'clear',
#   'phase',
#   'trial',
#   'covid',
#   'therapeutic',
#   'co',
#   'zlcnevuwe'],
#  ['usd',
#   'partner',
#   'announces',
#   'quarterly',
#   'distribution',
#   'second',
#   'quarter',
#   'earnings',
#   'release',
#   'date',
#   'co',
#   'wxqjovjm',
#   'co',
#   'nsugowihvb'],
#  ['forever',
#   'collaborates',
#   'airwalk',
#   'nostalgic',
#   'back',
#   'school',
#   'collection',
#   'co',
#   'quqoipmula',
#   'co',
#   'szetudtt'],
#  ['viemed',
#   'healthcare',
#   'home',
#   'technical',
#   'analysis',
#   'co',
#   'vexxpmnbsh',
#   'finance',
#   'market',
#   'investing'],
#  ['markforged',
#   'set',
#   'reporting',
#   'date',
#   'second',
#   'quarter',
#   'financial',
#   'result',
#   'co',
#   'zyltpmrh',
#   'co',
#   'tgwllll'],
#  ['high',
#   'yield',
#   'blue',
#   'chip',
#   'bargain',
#   'retire',
#   'safety',
#   'splendor',
#   'co',
#   'lmjhhcep',
#   'economy',
#   'trading',
#   'stock'],
#  ['biden',
#   'urge',
#   'senate',
#   'pas',
#   'build',
#   'back',
#   'better',
#   'bill',
#   'without',
#   'climate',
#   'measure',
#   'co',
#   'bmvufftara'],
#  ['comdx', 'energy', 'settlement', 'price', 'co', 'yeckxt'],
#  ['nv',
#   'eye',
#   'novartis',
#   'q',
#   'show',
#   'amid',
#   'likely',
#   'impact',
#   'strong',
#   'dollar',
#   'co',
#   'pjqvkmrfcm'],
#  ['dov',
#   'dover',
#   'corporation',
#   'q',
#   'result',
#   'earnings',
#   'call',
#   'presentation',
#   'co',
#   'rebijbx',
#   'stock',
#   'stockmarket',
#   'trading'],
#  ['chinese',
#   'firm',
#   'grappling',
#   'delisting',
#   'wave',
#   'new',
#   'york',
#   'heading',
#   'zurich',
#   'drawn',
#   'greater',
#   'geopolitical',
#   'certainty',
#   'wealthy',
#   'investor',
#   'co',
#   'ykuxjvwrc'],
#  ['servicenow',
#   'slump',
#   'wake',
#   'ceo',
#   'economic',
#   'comment',
#   'co',
#   'usyfgqqitp'],
#  ['dubai',
#   'metaverse',
#   'strategy',
#   'envisions',
#   'sector',
#   'supporting',
#   'many',
#   'additional',
#   'virtual',
#   'job',
#   'adding',
#   'billion',
#   'city',
#   'gdp',
#   'five',
#   'year',
#   'co',
#   'lircsfif'],
#  ['breaking',
#   'russia',
#   'reportedly',
#   'start',
#   'sending',
#   'gas',
#   'europe',
#   'biggest',
#   'pipeline',
#   'nord',
#   'stream',
#   'offering',
#   'relief',
#   'skyrocketing',
#   'fuel',
#   'cost',
#   'co',
#   'hxmikjgqk'],
#  ['elon',
#   'musk',
#   'accused',
#   'twitter',
#   'unjustifiable',
#   'request',
#   'rush',
#   'trial',
#   'determine',
#   'whether',
#   'forced',
#   'complete',
#   'bn',
#   'deal',
#   'buy',
#   'company',
#   'co',
#   'mjmpuomw'],
#  ['xela', 'break', 'abv', 'c'],
#  ['roku',
#   'roku',
#   'netflix',
#   'pivot',
#   'validates',
#   'advertising',
#   'business',
#   'model',
#   'co',
#   'noomryq',
#   'stockmarket',
#   'market',
#   'trading'],
#  ['trp',
#   'tc',
#   'energy',
#   'declares',
#   'force',
#   'majeure',
#   'keystone',
#   'pipeline',
#   'co',
#   'dzfyeqknm'],
#  ['european',
#   'union',
#   'proposes',
#   'cut',
#   'natural',
#   'gas',
#   'consumption',
#   'next',
#   'eight',
#   'month',
#   'plan',
#   'would',
#   'affect',
#   'household',
#   'power',
#   'producer',
#   'industry',
#   'co',
#   'xdlahvmg'],
#  ['am',
#   'launch',
#   'full',
#   'service',
#   'high',
#   'volume',
#   'recruitment',
#   'solution',
#   'meet',
#   'hiring',
#   'challenge',
#   'co',
#   'nbvytbsv',
#   'co',
#   'yxfijgf'],
#  ['hmtv',
#   'stock',
#   'alert',
#   'halper',
#   'sadeh',
#   'llp',
#   'investigating',
#   'whether',
#   'sale',
#   'hemisphere',
#   'medium',
#   'group',
#   'inc',
#   'fair',
#   'shareholder',
#   'co',
#   'tmifbnbxc',
#   'co',
#   'tzmghkqx'],
#  ['energy',
#   'price',
#   'past',
#   'month',
#   'co',
#   'njfrnuj',
#   'ines_ferre',
#   'co',
#   'tnjbvtzl'],
#  ['european',
#   'stock',
#   'extend',
#   'decline',
#   'u',
#   'inflation',
#   'data',
#   'co',
#   'jatkvnzku',
#   'co',
#   'pavfsrgse'],
#  ['wfc',
#   'wfc',
#   'pl',
#   'wfcnp',
#   'well',
#   'fargo',
#   'amp',
#   'company',
#   'q',
#   'result',
#   'earnings',
#   'call',
#   'presentation',
#   'co',
#   'qxnhghtkk',
#   'economy',
#   'business',
#   'investing'],
#  ['scandinavian',
#   'carrier',
#   'sa',
#   'warns',
#   'emergency',
#   'funding',
#   'related',
#   'bankruptcy',
#   'process',
#   'u',
#   'risk',
#   'pilot',
#   'strike',
#   'entered',
#   'th',
#   'day',
#   'thursday',
#   'co',
#   'tfxaqzxla'],
#  ['iipr',
#   'iipr',
#   'pa',
#   'innovative',
#   'industrial',
#   'property',
#   'yield',
#   'buy',
#   'hand',
#   'fist',
#   'co',
#   'tbdhivp',
#   'trading',
#   'stockmarket',
#   'investing'],
#  ['frc',
#   'first',
#   'republic',
#   'bank',
#   'stock',
#   'jump',
#   'q',
#   'earnings',
#   'beat',
#   'robust',
#   'loan',
#   'growth',
#   'co',
#   'ataidlnq'],
#  ['goldman',
#   'sachs',
#   'plan',
#   'slow',
#   'hiring',
#   'reinstate',
#   'annual',
#   'performance',
#   'review',
#   'wall',
#   'street',
#   'bank',
#   'look',
#   'rein',
#   'expense',
#   'co',
#   'xztuqyl'],
#  ['sasr',
#   'sandy',
#   'spring',
#   'bancorp',
#   'non',
#   'gaap',
#   'eps',
#   'beat',
#   'revenue',
#   'beat',
#   'co',
#   'sdmoxz'],
#  ['nigeria',
#   'central',
#   'bank',
#   'raise',
#   'key',
#   'interest',
#   'rate',
#   'basis',
#   'point',
#   'curb',
#   'accelerating',
#   'inflation',
#   'co',
#   'tlwcbvpav'],
#  ['calling',
#   'defining',
#   'moment',
#   'embattled',
#   'crypto',
#   'lender',
#   'celsius',
#   'network',
#   'filed',
#   'chapter',
#   'bankruptcy',
#   'protection',
#   'co',
#   'bonlqyb'],
#  ['ctmx', 'cytomx', 'therapeutic', 'cut', 'workforce', 'co', 'rsdhdvagn'],
#  ['euro',
#   'edge',
#   'closer',
#   'dollar',
#   'parity',
#   'latest',
#   'market',
#   'update',
#   'co',
#   'upltrhdi',
#   'co',
#   'exeklee'],
#  ['velod',
#   'partner',
#   'hartech',
#   'group',
#   'distribute',
#   'end',
#   'end',
#   'solution',
#   'deliver',
#   'turn',
#   'key',
#   'process',
#   'federal',
#   'government',
#   'customer',
#   'co',
#   'vbzjybibl'],
#  ['south',
#   'korean',
#   'prosecutor',
#   'investigating',
#   'member',
#   'former',
#   'president',
#   'moon',
#   'jae',
#   'government',
#   'forced',
#   'repatriation',
#   'two',
#   'north',
#   'korean',
#   'co',
#   'cofcureba'],
#  ['dorm',
#   'dorman',
#   'release',
#   'new',
#   'steering',
#   'amp',
#   'suspension',
#   'product',
#   'co',
#   'bgpspftmb'],
#  ['pratt',
#   'amp',
#   'whitney',
#   'evaluating',
#   'end',
#   'end',
#   'solution',
#   'velod',
#   'manufacture',
#   'production',
#   'jet',
#   'engine',
#   'component',
#   'co',
#   'mzyenwmulm',
#   'co',
#   'lqyopmrt'],
#  ['spain', 'hit', 'bank', 'utility', 'windfall', 'tax', 'co', 'vadofg'],
#  ['asia',
#   'pacific',
#   'market',
#   'set',
#   'trade',
#   'mixed',
#   'positive',
#   'u',
#   'job',
#   'report',
#   'co',
#   'lseosfoym'],
#  ['supercharged',
#   'u',
#   'dollar',
#   'breached',
#   'parity',
#   'euro',
#   'first',
#   'time',
#   'decade',
#   'nicolesylive',
#   'explains',
#   'mean',
#   'co',
#   'samapet',
#   'co',
#   'kpeiguuzw'],
#  ['top',
#   'vacation',
#   'rental',
#   'investment',
#   'marketplace',
#   'raise',
#   'expand',
#   'new',
#   'destination',
#   'co',
#   'xujyhejbsv',
#   'co',
#   'zompngkke'],
#  ['kyocera',
#   'shiseido',
#   'develop',
#   'world',
#   'first',
#   'ever',
#   'cosmetic',
#   'face',
#   'powder',
#   'using',
#   'kyocera',
#   'kyoto',
#   'opal',
#   'co',
#   'zvladmw',
#   'co',
#   'xuezsshec'],
#  ['watch',
#   'another',
#   'lender',
#   'going',
#   'crypto',
#   'winter',
#   'one',
#   'corner',
#   'africa',
#   'week',
#   'big',
#   'story',
#   'alternative',
#   'currency',
#   'co',
#   'mfwpepsvz'],
#  ['market',
#   'move',
#   'higher',
#   'gear',
#   'spy',
#   'qqq',
#   'dia',
#   'spx',
#   'compq',
#   'djia',
#   'nflx',
#   'tsla',
#   'xlv',
#   'xlu',
#   'xlp',
#   'co',
#   'lzemmlqjhi',
#   'economy',
#   'stockmarket'],
#  ['bond',
#   'yield',
#   'rise',
#   'russia',
#   'resume',
#   'gas',
#   'flow',
#   'co',
#   'dlfhiydo'],
#  ['first',
#   'round',
#   'voting',
#   'tory',
#   'leadership',
#   'contest',
#   'get',
#   'readout',
#   'allegra',
#   'stratton',
#   'co',
#   'sztfcahaa'],
#  ...]

# %% [markdown]
# **Vectorization Word2Vec - Skipgram**

# %%
import gensim
from gensim.models import Word2Vec
model_skipgram = gensim.models.Word2Vec(lemmatized_tokens_train, min_count = 2,vector_size = 100, sg=1)

# %%
vocabulary_skipgram = model_skipgram.wv.index_to_key
word_vec_dict={}

for word in vocabulary_skipgram:
    word_vec_dict[word]=model_skipgram.wv.get_vector(word)
print("The no of key-value pairs : ",len(word_vec_dict)) # should come equal to vocab size
# Out:
# The no of key-value pairs :  9865

# %%
word_vec_dict
# Out:
# {'co': array([ 0.04944844, -0.19914235,  0.3364713 ,  0.12279912, -0.41393432,
#         -0.52009106,  0.5553665 ,  0.4353354 , -0.3946706 , -0.03693954,
#         -0.15181535, -0.32468238, -0.16752617, -0.07201686, -0.06053897,
#         -0.0801933 ,  0.14561123,  0.055388  , -0.3384287 , -0.5023502 ,
#          0.06110964,  0.3375496 ,  0.2389425 ,  0.12013111,  0.05166225,
#          0.01275238, -0.10810937, -0.31905845, -0.3874342 ,  0.12249593,
#         -0.03629033, -0.38851312,  0.26802772, -0.31107968,  0.05597866,
#          0.4101505 ,  0.4262082 ,  0.07180206, -0.27372456, -0.31661138,
#         -0.09810401, -0.21975182, -0.55745196,  0.09015995,  0.327454  ,
#         -0.16610835, -0.36411408,  0.34496367,  0.1836047 ,  0.3386533 ,
#         -0.02744745, -0.21516791,  0.41073635, -0.03007238,  0.13282804,
#          0.08214888, -0.06219637, -0.26565292, -0.03453907,  0.13757613,
#          0.13707286, -0.17200856,  0.1315011 , -0.07553819, -0.35424396,
#          0.58695334,  0.2811549 ,  0.63059765, -0.18320894,  0.01305134,
#          0.18192586,  0.4756818 ,  0.35472375, -0.33891597, -0.05759578,
#          0.12397514,  0.23879   ,  0.40282822,  0.00141112,  0.04048133,
#         -0.00393245,  0.31833684, -0.1815038 ,  0.38540116,  0.05128803,
#         -0.03544105,  0.11967201,  0.00885785,  0.01743871,  0.54258156,
#          0.4990488 , -0.09712758,  0.04354823, -0.0507219 ,  0.27068728,
#         -0.0306373 , -0.03087093, -0.2773379 ,  0.20462967,  0.15945852],
#        dtype=float32),
#  'u': array([-2.71457851e-01,  1.88888073e-01,  1.27768844e-01,  1.58887237e-01,
#         -2.18632445e-01, -5.47344148e-01,  1.66778386e-01,  3.16925824e-01,
#          1.10727377e-01, -3.33447993e-01, -1.98714882e-02, -1.24035597e-01,
#         -3.02778155e-01,  4.82472703e-02, -5.79842590e-02, -1.40617624e-01,
#          1.00357883e-01, -1.26671419e-01,  3.06902435e-02, -3.39191496e-01,
#          1.75872222e-01, -4.89101596e-02,  3.59479606e-01,  5.58434799e-02,
#          1.57914385e-01, -5.92297912e-02, -5.49508333e-01, -3.02003443e-01,
#         -4.41533059e-01,  3.97919506e-01,  2.42618337e-01, -1.93107635e-01,
#          3.72965246e-01, -1.75053731e-01,  3.33911508e-01,  3.34451377e-01,
#         -1.77118719e-01, -2.71933347e-01,  4.87164520e-02, -8.51864740e-02,
#          4.83868495e-02, -2.09892884e-01, -3.62913430e-01, -9.46482047e-02,
#          1.12478249e-01,  2.55002767e-01, -4.45005409e-02,  8.31319839e-02,
#         -3.10534593e-02,  1.17220797e-01,  5.31661630e-01, -1.66470781e-01,
#         -2.35817581e-01, -4.00492311e-01, -4.51259315e-01,  1.87547095e-02,
#          5.15137196e-01, -2.94174165e-01, -1.13594092e-01,  2.71659166e-01,
#         -2.97145516e-01, -5.84079651e-03, -5.28558940e-02,  2.93102354e-01,
#         -8.98790956e-02,  3.09271574e-01,  7.91221932e-02,  2.41372466e-01,
#         -5.25985777e-01,  9.27447602e-02, -6.31091148e-02, -8.36569741e-02,
#          1.52441412e-01, -9.76999700e-02,  3.88459951e-01,  1.23763666e-01,
#         -3.86263102e-01, -1.50208339e-01,  2.83371285e-02,  6.97785765e-02,
#         -3.40229720e-01,  1.33527610e-02, -1.30598396e-01,  2.38405958e-01,
#         -2.66613811e-02,  1.38428152e-01,  3.27655047e-01,  1.27275407e-01,
#          9.05230418e-02, -1.23397492e-01,  3.40918191e-02, -6.81694746e-02,
#          2.72631019e-01, -4.52963263e-02, -1.12597086e-01,  4.79033362e-04,
#          2.37013653e-01, -3.28287706e-02, -6.65850490e-02, -3.17090958e-01],
#        dtype=float32),
#  'stock': array([-0.41697255,  0.29474232,  0.12177947,  0.02363851, -0.0768817 ,
#         -0.61924803,  0.0219485 ,  0.6456221 , -0.5540826 , -0.4020213 ,
#         -0.0052725 , -0.4608767 ,  0.22227782, -0.06801219,  0.31080678,
#         -0.22075115,  0.23131336, -0.17675665, -0.30767757, -0.6431819 ,
#          0.07101804,  0.05538785,  0.25967544, -0.38929856, -0.1567054 ,
#         -0.12356625, -0.06437454, -0.24699032, -0.12006859,  0.09947506,
#          0.5073169 , -0.34520817,  0.02890714, -0.03488465, -0.07618142,
#          0.43414152,  0.24293448, -0.30641657, -0.29082745, -0.03952555,
#          0.04583332, -0.28737548, -0.21189192,  0.03524846,  0.2834376 ,
#          0.00660102, -0.01872258, -0.03942276,  0.01270888,  0.07900147,
#          0.37088266, -0.06463039,  0.12639175,  0.10575102, -0.31242895,
#          0.24088003,  0.29891333, -0.00652573,  0.07500844,  0.00751125,
#          0.14285666, -0.13123727,  0.40074593,  0.50393176, -0.29871532,
#          0.6093836 ,  0.13090912,  0.5398284 , -0.54859555,  0.04747983,
#         -0.19541927,  0.00223266,  0.5221857 , -0.13608995,  0.04035056,
#          0.3291928 , -0.1311049 ,  0.24198219, -0.18365344,  0.2205333 ,
#         -0.09525301, -0.19519818, -0.22997816,  0.5424274 ,  0.19351406,
#          0.08964919,  0.0070463 ,  0.33993885,  0.43648264,  0.19182849,
#          0.32665703,  0.17448586,  0.12554225, -0.20792541,  0.45140085,
#          0.10859895,  0.4188563 , -0.21477848,  0.39868605, -0.35283783],
#        dtype=float32),
#  'market': array([-0.24124737,  0.11900862,  0.30218127,  0.27061763, -0.18369451,
#         -0.7070123 ,  0.18769954,  0.6567683 , -0.34762245, -0.5085258 ,
#          0.07188997, -0.40919054,  0.07150617,  0.06641904,  0.24316905,
#         -0.08293665,  0.30132937, -0.2283874 ,  0.00154331, -0.5247847 ,
#          0.34261104,  0.4708098 ,  0.3993475 , -0.10107689, -0.31652188,
#          0.18993852, -0.09977852, -0.17642044, -0.16793932,  0.03083296,
#          0.45855385, -0.22429344,  0.05347891, -0.00973083, -0.0399284 ,
#          0.4890514 ,  0.33751175, -0.3486021 , -0.3153659 , -0.0989099 ,
#          0.17825101, -0.38171095, -0.30891487,  0.00186953,  0.42033026,
#         -0.19845179,  0.01000442, -0.10398621, -0.16886854,  0.14323525,
#          0.15398598, -0.07088051,  0.08522771, -0.0738252 , -0.08529349,
#          0.3115073 ,  0.06730523,  0.04917619,  0.05935505,  0.16452318,
#         -0.21155642, -0.15769757,  0.28905985,  0.2028433 , -0.33645272,
#          0.57107216,  0.13801725,  0.5636122 , -0.41454732,  0.1283003 ,
#         -0.23260154, -0.04671033,  0.2874144 , -0.12416902, -0.00534747,
#          0.14769553, -0.20242281,  0.22682169, -0.25288546,  0.13437772,
#         -0.22679605, -0.08975527, -0.11659763,  0.5657832 ,  0.00529439,
#         -0.0371818 ,  0.28097376,  0.27629474,  0.4042705 ,  0.2939992 ,
#          0.1642192 , -0.1727097 ,  0.04435908, -0.3722489 ,  0.51155573,
#         -0.02672365,  0.5745537 , -0.02856325,  0.31276336, -0.1591497 ],
#        dtype=float32),
#  'new': array([-0.21365419, -0.3780572 ,  0.07916491,  0.09706649,  0.12916654,
#         -0.08686519, -0.02241633,  0.43546626, -0.09147366, -0.21219037,
#         -0.35850376, -0.00946533, -0.6494693 ,  0.5175785 , -0.08092958,
#          0.02195733,  0.2628275 ,  0.35266975, -0.0396808 , -0.7722492 ,
#          0.15765738, -0.22161457,  0.20865402,  0.12706569,  0.30474004,
#         -0.05409556, -0.70100063,  0.16009896, -0.78283477, -0.07667401,
#          0.18723892,  0.25299314,  0.43948826, -0.3945133 ,  0.17042129,
#          0.17433968, -0.02257858, -0.2773832 , -0.10637224, -0.28330365,
#         -0.19141053, -0.49450046, -0.31300473,  0.19921507,  0.23913525,
#          0.06825437, -0.23803373,  0.20397618,  0.26246366, -0.01154672,
#         -0.01154952, -0.03116026,  0.28682825, -0.28060773, -0.38356033,
#         -0.1031976 ,  0.04861207, -0.24475096, -0.29715237,  0.25310352,
#         -0.10028407, -0.2456813 , -0.28692392, -0.03864038, -0.08841477,
#          0.19200929,  0.20563214,  0.3474227 , -0.2919287 , -0.04404331,
#         -0.19801696,  0.3849645 ,  0.02339664,  0.16439849,  0.32358202,
#          0.20490171, -0.16716042,  0.13565597,  0.13449019, -0.18771073,
#         -0.16909333, -0.14361376,  0.1845615 ,  0.09795515, -0.2803919 ,
#          0.06945616,  0.39352366,  0.02942736, -0.1140677 , -0.16601664,
#          0.08854757, -0.05030689,  0.2215192 , -0.19697165,  0.399693  ,
#         -0.1638999 ,  0.00992606,  0.05209085, -0.03953261, -0.09543014],
#        dtype=float32),
#  'earnings': array([-0.19757715,  0.20828977, -0.18314144,  0.05374854, -0.10193485,
#         -0.56386614,  0.34380528,  0.5441507 , -0.5127052 , -0.4042855 ,
#         -0.31709552, -0.54322094, -0.19466624, -0.17416443, -0.12382795,
#         -0.16100441, -0.21663031, -0.10125092,  0.01310835, -0.42809215,
#          0.06833128, -0.01517779,  0.56920695, -0.36968875, -0.33714834,
#         -0.6952016 ,  0.01624434, -0.40328172,  0.12311792,  0.408071  ,
#          0.5440338 , -0.65665305, -0.01928928, -0.35932037, -0.07903032,
#          0.5806782 ,  0.03118134, -0.00482617, -0.26046   , -0.35164648,
#          0.45668945, -0.41761386, -0.24509576,  0.33399653,  0.3626178 ,
#         -0.04928942,  0.1904281 ,  0.03542764,  0.33803508,  0.06048289,
#          0.49314287, -0.43170583,  0.8277569 ,  0.0883307 , -0.42546654,
#          0.5366324 ,  0.35643816, -0.03735003, -0.35014984, -0.29678354,
#          0.32435685,  0.15198039,  0.53470045,  0.22195664, -0.25862384,
#          0.5037653 ,  0.1145547 ,  1.003607  , -0.49162796, -0.1927039 ,
#          0.3046976 ,  0.01987537,  1.0833517 ,  0.00393203,  0.23593535,
#          0.45975867, -0.21375671,  0.23706917, -0.10723972,  0.26006466,
#         -0.31638238, -0.19082212, -0.2253476 ,  0.13442543,  0.41345415,
#         -0.39789078, -0.22215357,  0.5406278 , -0.0204661 ,  0.10354082,
#          1.0182295 ,  0.4161694 ,  0.08836422, -0.04040138,  0.74988973,
#          0.18713474,  0.23032753, -0.38299105,  0.35294926, -0.21135154],
#        dtype=float32),
#  'year': array([ 3.5727128e-02, -2.0191681e-01,  6.9413707e-02,  2.2709806e-01,
#         -1.9727586e-01, -5.8051747e-01,  6.8447948e-02,  5.0056660e-01,
#         -5.3863730e-03,  2.8001568e-01, -1.5421624e-01, -3.1196767e-01,
#         -9.6124671e-02,  4.8362729e-01, -1.1971014e-01, -2.4167740e-01,
#          1.5582399e-01,  2.4992095e-02,  1.6954009e-01, -7.1989882e-01,
#          7.1783644e-01,  1.6712765e-01,  3.5719916e-01, -5.3921785e-02,
#          2.1867581e-02,  2.5766322e-01, -2.9035231e-01, -5.3365219e-01,
#         -2.5523972e-02,  2.2906533e-01,  4.0674290e-01,  6.5422580e-02,
#          4.9397543e-01, -2.9208004e-01, -8.5129716e-02,  8.5429126e-01,
#         -1.5702209e-01, -1.2770806e-01, -5.2127129e-01, -3.0004016e-01,
#          7.4639678e-02, -4.2003894e-01, -1.5553905e-01, -7.3425677e-03,
#          2.1581961e-01,  2.8250086e-01, -3.8683778e-01, -3.1690294e-01,
#          7.0341438e-02,  9.0452150e-02,  2.6699679e-02, -2.1800358e-02,
#          4.1510133e-04, -1.2653399e-01,  5.7895355e-02, -1.6238010e-01,
#          1.1533376e-01, -4.9048495e-01, -4.1134042e-01, -5.6659594e-02,
#         -1.0242141e-01, -4.0900341e-01,  2.6708326e-01,  1.1116022e-01,
#         -3.4914055e-01,  3.6622310e-01,  3.6593787e-02,  3.1842712e-01,
#         -4.4284278e-01,  4.2128339e-01,  2.9299536e-01,  5.3700011e-02,
#          2.2581884e-01,  4.2332408e-01,  5.0623846e-01,  6.8657428e-02,
#          3.6642641e-01,  5.2298602e-02, -1.2723209e-01,  3.9589339e-01,
#         -3.9908737e-02, -2.4692966e-01, -2.8903329e-01,  8.5642055e-02,
#         -1.5632594e-01, -1.0697452e-01,  6.1950558e-01,  1.0832723e-02,
#          2.4167435e-01,  9.6321352e-02,  2.1326585e-01, -2.3118824e-01,
#          2.4096504e-01,  1.9413403e-01,  2.5076914e-01, -8.5969523e-02,
#          3.1284022e-01, -1.6081138e-01, -3.8971099e-01,  1.3335286e-01],
#        dtype=float32),
#  'say': array([ 0.0792052 , -0.151811  ,  0.08353459,  0.21669517, -0.5026521 ,
#         -0.29104874,  0.4816626 ,  0.06669682, -0.20490548, -0.3678857 ,
#         -0.13388836, -0.03184944, -0.41921207,  0.02980109, -0.07486247,
#         -0.09781061,  0.3648726 , -0.12309986,  0.31634095, -0.5574754 ,
#          0.24033114,  0.22740844,  0.26857033, -0.08792681, -0.35875434,
#          0.25141135, -0.30519068,  0.31096396, -0.43127555,  0.438674  ,
#         -0.03029778,  0.02605459,  0.30313554, -0.24004598,  0.08669005,
#          0.19525431, -0.35398507, -0.19468156, -0.25333044,  0.08357322,
#         -0.04252386, -0.21147512, -0.24263625, -0.28147087,  0.12327214,
#         -0.16495381, -0.07721898,  0.13874578,  0.2201217 , -0.06337988,
#         -0.20020315, -0.22345014, -0.16612004, -0.37793308, -0.11207275,
#         -0.07670573,  0.05741385,  0.01877036, -0.23395705,  0.4510417 ,
#         -0.23603912,  0.28304562, -0.18936212,  0.01082695, -0.2806637 ,
#          0.3142345 , -0.06565786,  0.48948783, -0.6203554 ,  0.08222751,
#          0.06165091,  0.11359415,  0.20764916, -0.12965323,  0.1641563 ,
#         -0.01833259,  0.02924398, -0.38074797, -0.06811527,  0.15364677,
#         -0.26179087, -0.07967915, -0.7279029 ,  0.4751696 ,  0.2985621 ,
#         -0.44847608,  0.03396607,  0.38772368,  0.0993139 , -0.05937923,
#         -0.05088665,  0.0172226 , -0.10896669,  0.01551023,  0.16446598,
#          0.06431321, -0.09131987, -0.10716277,  0.3762824 , -0.17456794],
#        dtype=float32),
#  'economy': array([-0.1674303 ,  0.05868417,  0.44501886,  0.22697373, -0.1485526 ,
#         -0.72422177,  0.41085413,  0.56790507, -0.6010657 , -0.3810307 ,
#         -0.05219929, -0.47237858, -0.04723674, -0.10666513,  0.15312758,
#         -0.00266863,  0.08927713, -0.15704362, -0.00421391, -0.37915558,
#          0.23055504,  0.48847738,  0.59567016, -0.33939224, -0.18648839,
#          0.0089434 , -0.19514471,  0.05116318, -0.21002841, -0.1339207 ,
#          0.4849518 , -0.3641267 ,  0.06519623,  0.01333113, -0.12588292,
#          0.6285247 ,  0.19332518, -0.505492  , -0.52403706,  0.13129553,
#          0.4237177 , -0.2231336 , -0.38613117, -0.05280956,  0.4708205 ,
#         -0.38377896,  0.11559099, -0.29497802, -0.09428102, -0.00757343,
#          0.29034832, -0.08879539,  0.05892556, -0.05134174, -0.19135635,
#          0.42590502,  0.0221046 ,  0.01602154,  0.00810186,  0.12176667,
#         -0.3078516 ,  0.00365132,  0.3217701 ,  0.19785655, -0.4943271 ,
#          0.44550014,  0.04006761,  0.48919958, -0.3713957 ,  0.27439618,
#         -0.42022234,  0.24157415,  0.56012064,  0.0687699 , -0.10424661,
#          0.4478497 ,  0.06541546, -0.10686004, -0.20412223,  0.45946705,
#         -0.29679978, -0.36130303, -0.10452851,  0.6293995 , -0.26981422,
#          0.11250804, -0.04992501,  0.2290233 ,  0.1695887 ,  0.4675037 ,
#          0.41601732, -0.02712763, -0.05831952, -0.45337844,  0.71180385,
#         -0.011099  ,  0.6563891 , -0.2450776 ,  0.6060456 , -0.00370739],
#        dtype=float32),
#  'inflation': array([-0.20982975, -0.00769283, -0.29963747,  0.26121223, -0.24304919,
#         -0.6584512 , -0.00578442,  0.6156014 ,  0.12197161, -0.29516065,
#         -0.02128163, -0.23893002, -0.7060261 ,  0.22632146,  0.11318716,
#          0.02903097,  0.21887784, -0.34864676,  0.3925637 , -0.47196844,
#          0.49352136,  0.4705958 ,  0.6222483 , -0.08771659,  0.09470885,
#          0.05345671, -0.53986   , -0.1332904 , -0.25417903,  0.17927976,
#          0.5709839 , -0.04957694,  0.6304467 , -0.09198247, -0.09301811,
#          0.49965113,  0.24154066,  0.19409508, -0.5184658 ,  0.21294875,
#          0.0967536 , -0.28301314, -0.29833347, -0.11574814,  0.26410535,
#          0.24224916, -0.16188498,  0.21251304,  0.19684313,  0.26507303,
#          0.34505716,  0.17260575, -0.16117643, -0.11358061,  0.05118226,
#         -0.28096297,  0.37285984, -0.31756526, -0.3237423 ,  0.1403126 ,
#         -0.5317959 ,  0.04788672,  0.31886518,  0.32404155, -0.41524187,
#          0.1381706 ,  0.04148906,  0.49887168, -0.37741584,  0.28569314,
#          0.18051934,  0.15897201,  0.20426682,  0.10751779,  0.2450235 ,
#         -0.00644246,  0.31650168, -0.11938921, -0.12718467,  0.33105385,
#         -0.2562183 , -0.6304451 , -0.5811335 ,  0.17398159,  0.08764248,
#         -0.10760955,  0.38271838,  0.30355492,  0.18636616,  0.08351515,
#          0.12356889,  0.09134114,  0.08699618,  0.12992138,  0.54896474,
#         -0.36622697,  0.36144558,  0.16549791,  0.20996243, -0.20150554],
#        dtype=float32),
#  'business': array([-0.21671279, -0.13245657,  0.46377045,  0.24065326, -0.2079168 ,
#         -0.7601271 ,  0.24957548,  0.7194195 , -0.64190996, -0.52265745,
#          0.02424712, -0.45636314,  0.07925637,  0.04363377,  0.04578627,
#         -0.00441799,  0.32521734, -0.08420677, -0.00209555, -0.486038  ,
#          0.07376772,  0.01237104,  0.4614034 , -0.358166  , -0.08301453,
#         -0.09203779, -0.21167915,  0.00923431, -0.25381872,  0.00693391,
#          0.22026558, -0.2357746 ,  0.16932844,  0.01034205,  0.07237167,
#          0.6047533 ,  0.28181133, -0.35553885, -0.4441857 , -0.16783336,
#          0.10763282, -0.40546045, -0.23061486,  0.04708781,  0.43175718,
#         -0.35062584,  0.00214141, -0.14055553, -0.12245604,  0.07322718,
#          0.07848039, -0.14284295,  0.17780556,  0.22407126, -0.21088244,
#          0.3797043 ,  0.08464999,  0.08741719,  0.06516474,  0.1798577 ,
#         -0.09219633, -0.05481642,  0.19959141,  0.10541379, -0.4404475 ,
#          0.5828474 ,  0.13251252,  0.47377267, -0.25312787,  0.195873  ,
#         -0.17349188,  0.2690529 ,  0.5697008 ,  0.06394864,  0.12644327,
#          0.3829437 , -0.10295978, -0.00721815, -0.19569756,  0.253818  ,
#         -0.02208898,  0.01379866, -0.05632713,  0.56303227, -0.10317012,
#          0.11639028, -0.29403424,  0.2563417 ,  0.35596555,  0.51433223,
#          0.42830056, -0.12495825, -0.01604171, -0.23752698,  0.48393345,
#          0.02523365,  0.32571602, -0.30926028,  0.4249909 , -0.2351411 ],
#        dtype=float32),
#  'q': array([ 0.23672089,  0.34745455, -0.09705507,  0.37293762,  0.20406431,
#         -0.6278817 ,  0.14835864,  0.73009664, -0.72673726, -0.24915491,
#          0.17389846, -0.1781697 , -0.16025776,  0.06949719,  0.13901006,
#         -0.20094551,  0.06000178, -0.24031492,  0.03142397, -0.61994034,
#         -0.08650447, -0.12931444,  0.45916298, -0.5814047 , -0.46493867,
#         -0.6787935 , -0.47234493,  0.00758589, -0.20318684,  0.31069022,
#          0.35351214, -0.67407817,  0.06710111, -0.35790876,  0.04421676,
#          0.548974  , -0.06025504, -0.07491338, -0.3605726 , -0.37207037,
#          0.09620473, -0.38957527, -0.3555916 ,  0.34164652,  0.36015043,
#         -0.06025272,  0.47326726, -0.19622731,  0.25323984,  0.25578773,
#          0.5255013 , -0.43650898,  0.75653136,  0.35702136, -0.18668468,
#          0.5559343 , -0.00382296,  0.15594783, -0.34412602, -0.04746898,
#          0.08850346, -0.01498146,  0.23426403,  0.3137664 , -0.05897631,
#          0.5534149 ,  0.3616966 ,  0.926167  , -0.27697003, -0.09009316,
#         -0.05645598,  0.2852661 ,  0.9651945 ,  0.2065204 , -0.15309167,
#          0.5730864 , -0.3887347 ,  0.03019125,  0.07958741, -0.05550053,
#         -0.16642739, -0.07815465, -0.34209797,  0.10812663,  0.18263716,
#         -0.03860353, -0.19919562,  0.2206883 ,  0.43549484,  0.5102985 ,
#          0.8607248 ,  0.05312534, -0.14575996, -0.02352344,  0.62981653,
#         -0.22876136, -0.13403106, -0.2652861 , -0.00581822, -0.5147029 ],
#        dtype=float32),
#  'bank': array([ 0.15602268, -0.22557329,  0.20774648, -0.5272617 ,  0.35412145,
#         -0.11109053,  0.09757846,  0.63701594,  0.55693567, -0.1947525 ,
#         -0.34465212, -0.7688918 , -0.81127065, -0.01461244, -0.40864295,
#         -0.36887702,  0.05705027,  0.08280627,  0.42925093, -0.791197  ,
#         -0.0195954 ,  0.19986501,  0.19427057,  0.23459487, -0.33572423,
#          0.40883896, -0.5086307 ,  0.29865557, -0.20312333,  0.3166429 ,
#         -0.0229526 , -0.12303517,  0.370566  , -0.19767861, -0.28986165,
#         -0.35918048, -0.5124126 , -0.49308816, -0.01316213, -0.12921742,
#          0.2850482 , -0.02823881, -0.580872  ,  0.05570901,  0.07179809,
#         -0.5673637 ,  0.63381726, -0.13327415, -0.34704307,  0.557893  ,
#          0.2415203 , -0.3946205 ,  0.46150514, -0.13385297,  0.0907917 ,
#         -0.22873722,  0.1151814 , -0.30647463,  0.20195864,  0.39084855,
#         -0.3528801 , -0.20578973,  0.07421438, -0.16924103, -0.20798622,
#          0.4645769 ,  0.56434333,  0.50111616, -0.7454595 ,  0.17410046,
#          0.22398077,  0.24512936,  0.7844492 , -0.21540074, -0.2269115 ,
#         -0.08612689,  0.28637356, -0.43439707, -0.323085  ,  0.1030409 ,
#         -0.80844885,  0.04387018, -0.5927852 ,  0.26294222, -0.11567116,
#         -0.17191468,  0.96702564, -0.12437177, -0.22430861, -0.10832499,
#          0.27405632, -0.09379866,  0.31680733, -0.09978635,  0.62355447,
#         -0.22120094,  0.16378173,  0.3604032 ,  0.4046548 ,  0.38037094],
#        dtype=float32),
#  'price': array([-4.90400225e-01,  3.91854554e-01, -2.86345512e-01,  1.60204798e-01,
#         -3.43504578e-01, -8.17071676e-01, -1.32208630e-01,  1.62605092e-01,
#         -2.19779462e-01, -3.34700316e-01,  3.68646920e-01, -1.50958970e-01,
#         -4.84630108e-01, -2.38079369e-01,  5.21878123e-01, -1.26189217e-01,
#          5.38473904e-01, -4.73265678e-01, -5.37841208e-03, -5.95463455e-01,
#          3.54372472e-01,  4.18344140e-01,  5.89538932e-01,  3.77515622e-04,
#          8.74650553e-02,  4.66553956e-01, -3.34459484e-01, -3.32598478e-01,
#         -1.87897861e-01,  2.80937642e-01,  4.61789936e-01,  3.50552022e-01,
#          5.72799921e-01, -1.16306253e-01,  2.99160808e-01,  4.12142575e-01,
#         -3.16709466e-02,  1.65007785e-01, -1.74569696e-01,  4.80615161e-02,
#          1.35405406e-01, -4.14726496e-01, -7.68239871e-02, -1.45765856e-01,
#          1.57327592e-01,  1.24504507e-01, -3.44950259e-01,  3.21466327e-01,
#          3.63537997e-01,  1.11807724e-02,  6.45617068e-01, -1.72689959e-01,
#         -2.63043046e-01,  1.46611631e-01, -2.83184886e-01,  1.58268213e-01,
#          2.91178703e-01, -3.77566904e-01, -1.09450191e-01,  2.08409548e-01,
#          4.40741666e-02,  1.96526259e-01,  3.88448417e-01,  3.91523480e-01,
#          5.22575937e-02,  1.60294890e-01,  1.86018348e-02,  7.48980939e-01,
#         -4.84584719e-01,  1.34651259e-01, -3.34370546e-02,  4.62382399e-02,
#          7.71788135e-02, -1.20134875e-02,  2.56647050e-01,  2.07841724e-01,
#         -1.21184804e-01,  2.59920396e-02, -7.50834495e-02,  2.02666044e-01,
#         -9.34234858e-02, -6.49621844e-01, -7.12993219e-02,  3.44968021e-01,
#          2.11617291e-01,  1.05964199e-01,  1.99562997e-01,  3.63706648e-01,
#          4.41376895e-01,  5.55195846e-02,  3.65525186e-01,  3.23716402e-01,
#          2.55569369e-01,  1.45742863e-01,  1.53352126e-01, -1.88231587e-01,
#          3.89163941e-01, -5.85136786e-02, -9.76177454e-02, -9.40918326e-02],
#        dtype=float32),
#  'rate': array([ 1.99284300e-01,  1.71168283e-01,  6.20677019e-04, -1.00693487e-01,
#         -3.52460444e-02, -7.80188918e-01, -1.51551468e-02,  4.94309843e-01,
#          7.57289529e-01, -4.54661220e-01,  1.11842774e-01, -7.94565380e-01,
#         -7.31554568e-01, -1.35931268e-01, -2.48943150e-01,  1.56806648e-01,
#          2.64988899e-01, -5.29017866e-01,  3.24725568e-01, -5.99706531e-01,
#          6.00131035e-01,  9.93423581e-01,  4.84826773e-01, -2.90768921e-01,
#         -3.68834347e-01,  5.82537472e-01, -1.63778484e-01, -3.04361820e-01,
#         -1.90059781e-01,  6.51785731e-02,  4.14442420e-01, -2.10457388e-02,
#          4.92308140e-01, -2.30060309e-01, -2.58487701e-01, -8.00301880e-02,
#          1.96993545e-01, -6.01312481e-02, -3.54743361e-01,  1.03279486e-01,
#          2.70795673e-01, -4.34227765e-01, -3.14596772e-01, -3.25757191e-02,
#          5.85900903e-01,  3.42074484e-01, -3.53804380e-01,  1.27757221e-01,
#          1.98074818e-01,  2.88275301e-01,  4.01276141e-01,  2.52779543e-01,
#          4.72634017e-01, -5.06227672e-01, -1.79331839e-01, -9.63728949e-02,
#          5.89180231e-01, -5.82570016e-01, -7.21965358e-02,  2.53817320e-01,
#         -3.93196374e-01, -2.33836249e-01,  9.56749693e-02,  3.61391157e-01,
#         -1.17255300e-01,  1.81002200e-01,  2.38375254e-02,  3.19017202e-01,
#         -6.55452967e-01,  2.36081854e-01, -1.94458917e-01, -2.43074462e-01,
#          8.17091346e-01, -2.29124218e-01,  2.03549489e-03, -1.31465778e-01,
#          3.49114895e-01, -1.38670802e-01, -1.87997565e-01,  5.92752159e-01,
#         -3.75569403e-01, -7.66133964e-01, -6.88315988e-01, -1.66036725e-01,
#          3.33043277e-01, -1.37402818e-01,  7.40383446e-01,  2.73199379e-01,
#          1.40596241e-01, -5.66983931e-02,  4.88457441e-01,  1.83653370e-01,
#          3.70274305e-01,  2.42816433e-01,  3.53890985e-01, -4.70499098e-01,
#          1.94718331e-01,  6.06349945e-01,  2.26423994e-01,  2.18765795e-01],
#        dtype=float32),
#  'trading': array([-0.32264444,  0.14826411,  0.2957614 ,  0.14774951, -0.24512915,
#         -0.8618488 ,  0.17662965,  0.6895216 , -0.59804386, -0.3715857 ,
#         -0.07711382, -0.5866283 ,  0.11466197,  0.01751233,  0.1499289 ,
#         -0.0443949 ,  0.0950496 , -0.1438284 , -0.29352832, -0.5632075 ,
#          0.11512648,  0.19497193,  0.3654591 , -0.5486793 , -0.27233425,
#         -0.06202181, -0.12288776, -0.12052441, -0.1391121 , -0.04399079,
#          0.46520817, -0.33035278,  0.11950329, -0.04158165, -0.10517775,
#          0.7233837 ,  0.34390828, -0.5275409 , -0.63647866, -0.13055009,
#          0.07342998, -0.35580328, -0.30941448,  0.10391825,  0.4924615 ,
#         -0.13797337, -0.11611984, -0.25243756,  0.09234532, -0.00864982,
#          0.0959627 , -0.00582099,  0.25494802,  0.20571768, -0.27100578,
#          0.46012273,  0.27476615,  0.1723743 ,  0.179776  ,  0.15236618,
#          0.17884049, -0.08531397,  0.31634888,  0.27229953, -0.5293974 ,
#          0.57074744, -0.06728937,  0.44532222, -0.4568718 ,  0.35043147,
#         -0.2853059 ,  0.14598544,  0.59112495,  0.08971614,  0.09453234,
#          0.3152459 , -0.04625811,  0.09162593, -0.28762087,  0.19698437,
#         -0.12217684, -0.05263875, -0.19477999,  0.5385315 ,  0.07117224,
#          0.08491281, -0.21293427,  0.23353118,  0.557063  ,  0.50627977,
#          0.5242924 ,  0.01646231,  0.01109361, -0.27473754,  0.4598102 ,
#          0.15637833,  0.53840095, -0.2257009 ,  0.604733  , -0.14153033],
#        dtype=float32),
#  'second': array([ 0.08134888, -0.10171308,  0.15996626,  0.17628922,  0.24310985,
#         -0.45945895,  0.12514141,  0.65652055, -0.18669707,  0.07055651,
#         -0.42364195, -0.59264433, -0.14334384, -0.08639619, -0.3571435 ,
#          0.18853766, -0.1856209 , -0.14925803,  0.15573518, -0.713388  ,
#          0.62140286,  0.2732388 ,  0.49323952,  0.20649375,  0.08873328,
#          0.07696775,  0.05378468, -0.3531009 , -0.04076254,  0.38674372,
#          0.58489484, -0.43479052,  0.16406089, -0.47589603, -0.07271571,
#          0.71705115, -0.02809995, -0.14886756, -0.4514803 , -0.75516135,
#          0.24552162, -0.5629056 , -0.11620439,  0.69840264,  0.36812195,
#         -0.08838098,  0.0595124 , -0.49443054,  0.34479758,  0.27420276,
#          0.17664151, -0.52267945,  0.32316282, -0.04691749,  0.21660733,
#          0.24453264, -0.4086243 , -0.46124172, -0.46507195, -0.09171492,
#          0.3525506 ,  0.24982303,  0.30537817,  0.38423297, -0.3732391 ,
#          0.6137455 ,  0.19003676,  0.95139444, -0.24368918,  0.31635293,
#          0.246735  ,  0.31992748,  0.5817434 ,  0.03600446,  0.33374843,
#          0.19120543,  0.31235826, -0.08455652,  0.27642268,  0.32900438,
#         -0.2562158 , -0.16212964, -0.23108102,  0.07200769, -0.18855162,
#         -0.181943  , -0.0767615 ,  0.18460426, -0.28123772, -0.25171083,
#          0.863087  ,  0.09483081,  0.6980793 ,  0.24575   ,  0.23915166,
#         -0.1876626 , -0.08775925, -0.41081044, -0.21635927,  0.36259648],
#        dtype=float32),
#  'quarter': array([ 0.08583697,  0.09391239,  0.10605492, -0.09196922,  0.2798385 ,
#         -0.7474699 ,  0.32109714,  0.7766997 , -0.35236433,  0.09000522,
#         -0.4279785 , -0.64793605,  0.07924295, -0.10314716, -0.01889353,
#         -0.18087998, -0.08474133, -0.24148521,  0.38323286, -0.87501085,
#          0.69953907,  0.22209115,  0.25375873, -0.14601335, -0.01944069,
#         -0.09615576, -0.12797533, -0.4047177 ,  0.17834032,  0.5023274 ,
#          0.4393894 , -0.37664565,  0.12282949, -0.5995115 , -0.07175973,
#          0.88478273, -0.3614848 ,  0.08044446, -0.13178557, -0.7259829 ,
#          0.41308522, -0.8677369 , -0.10397241,  0.72158957,  0.38235372,
#         -0.17052908, -0.06793536, -0.32755744,  0.2583202 ,  0.3113426 ,
#          0.416893  , -0.1876465 ,  0.6093165 , -0.18907765,  0.37009344,
#          0.10301062, -0.06166389, -0.3530821 , -0.34719244,  0.08524347,
#          0.09456751, -0.00422167,  0.06251954,  0.31127515, -0.27143428,
#          0.7477466 ,  0.3932567 ,  1.0647886 , -0.35030657,  0.19847797,
#          0.34720972,  0.1169874 ,  0.6743389 ,  0.36604777,  0.51059735,
#          0.35972226,  0.46556172,  0.12742037,  0.1583678 ,  0.5204007 ,
#         -0.45197573,  0.16910978, -0.15111218,  0.09885202,  0.23651129,
#         -0.02732249,  0.40957353,  0.2937745 ,  0.12262065, -0.12178238,
#          1.0677556 ,  0.13810389,  0.7112219 ,  0.12340798,  0.56612545,
#          0.06706892,  0.11899756, -0.5364285 , -0.08159886,  0.01334809],
#        dtype=float32),
#  'result': array([ 0.23649074, -0.07570522, -0.20227617,  0.19723015,  0.18070306,
#         -0.649075  ,  0.42664954,  0.7645982 , -0.42898998, -0.5044816 ,
#         -0.2556453 , -0.3362689 , -0.06284796, -0.00279622, -0.0213467 ,
#          0.01502972,  0.07662454,  0.06650624,  0.4150162 , -0.276621  ,
#          0.46961588, -0.2212889 ,  0.5326915 , -0.7136019 , -0.0469869 ,
#         -0.5035653 , -0.14529544, -0.19819883,  0.03613416,  0.30801734,
#          0.5652782 , -0.6039713 , -0.13423802, -0.6118196 , -0.0208076 ,
#          0.44310656, -0.0933311 ,  0.01307125, -0.16583718, -0.7109525 ,
#          0.40964204, -0.6576508 , -0.14216077,  0.37870494,  0.5533721 ,
#         -0.2063318 , -0.12009579, -0.0764764 ,  0.62498796, -0.00390852,
#          0.37186167, -0.38033116,  0.6713288 , -0.03872485, -0.1157449 ,
#          0.8341575 , -0.06799659, -0.03989475, -0.15013534, -0.03945016,
#          0.20454732,  0.48450544,  0.38077217,  0.39292318, -0.516227  ,
#          0.9027112 ,  0.23295435,  1.163614  , -0.38909373, -0.0961807 ,
#          0.2336545 ,  0.17031735,  0.9653964 ,  0.02416326,  0.35719463,
#          0.4446023 , -0.04810365,  0.12185417, -0.23594509,  0.3714509 ,
#         -0.4324903 , -0.18026409, -0.23070697,  0.44232917,  0.57258403,
#         -0.30746147, -0.21832223,  0.64103955, -0.03374668, -0.02324008,
#          1.1749222 ,  0.02011159,  0.34557968, -0.02069373,  0.8170864 ,
#          0.2238639 ,  0.15349253, -0.46565735,  0.25439182, -0.19695638],
#        dtype=float32),
#  'company': array([-8.14245939e-02, -2.14528903e-01,  1.92699477e-01,  3.29333246e-02,
#         -1.17058970e-01, -4.51801032e-01,  1.87399909e-01,  5.73579311e-01,
#         -5.28153062e-01, -1.38130099e-01, -1.86045635e-02, -2.00374335e-01,
#         -3.07656301e-04, -1.65353268e-01, -1.09790690e-01,  4.23283912e-02,
#          4.54088062e-01, -2.21952692e-01, -1.12880260e-01, -9.17283475e-01,
#          1.21039309e-01, -3.63182098e-01,  5.37487417e-02,  5.80385793e-03,
#          1.46286726e-01,  7.27461800e-02, -1.79935649e-01, -2.54212786e-02,
#         -6.51532412e-02,  2.94088662e-01,  4.70589809e-02,  9.77699533e-02,
#          2.46731445e-01, -2.71267831e-01,  4.97433953e-02,  6.43686771e-01,
#         -2.49194130e-01, -2.12893188e-01, -2.22569197e-01, -5.48607528e-01,
#         -1.68765977e-01, -2.40600407e-01,  2.40951598e-01,  2.06689805e-01,
#          2.06496015e-01, -2.29160801e-01, -2.20542520e-01,  6.38538077e-02,
#         -1.31375536e-01,  3.14690620e-01, -1.80068061e-01, -4.56837893e-01,
#         -1.95661217e-01,  1.00677185e-01, -1.98529795e-01,  1.53731272e-01,
#         -3.45527893e-03,  2.50865594e-02, -2.21216500e-01,  1.98389634e-01,
#          2.15865552e-01,  2.06294373e-01, -7.47406706e-02, -1.49562374e-01,
#         -3.16513062e-01,  3.57166231e-01,  2.54581660e-01,  5.50749779e-01,
#         -3.64132255e-01,  2.29383722e-01,  1.53900132e-01,  3.58420432e-01,
#          2.89987653e-01, -4.13994901e-02,  1.37063175e-01, -5.41883074e-02,
#          1.39738396e-02, -1.45888217e-02, -7.02804029e-02,  1.47458419e-01,
#          3.46270502e-02,  1.92739382e-01, -1.86495304e-01,  2.26231590e-01,
#          6.29951209e-02,  4.32348028e-02, -2.52678514e-01,  1.15307890e-01,
#         -4.86935750e-02, -1.38754016e-02,  3.77569497e-02,  2.13819668e-01,
#         -6.67793974e-02,  1.66658163e-01,  2.05647960e-01, -4.21441980e-02,
#         -3.77140343e-01, -4.98179287e-01,  1.89017713e-01,  7.79908821e-02],
#        dtype=float32),
#  'announces': array([ 0.0953804 , -0.22713062,  0.12704346, -0.00605462,  0.49158427,
#         -0.24649541,  0.21366148,  0.4213029 , -0.0776305 , -0.1562274 ,
#         -0.12465916, -0.3579051 ,  0.22630854,  0.13836925, -0.12968789,
#         -0.30039504,  0.0135383 , -0.15751569, -0.10364596, -0.54245794,
#          0.21205345, -0.24937323, -0.11811601, -0.029976  ,  0.2587202 ,
#         -0.32800364, -0.08857793, -0.30171764, -0.31431723, -0.04536664,
#          0.15468371, -0.37367228,  0.14020023, -0.49358475, -0.05253556,
#          0.16220003, -0.45786253, -0.13232227,  0.4249657 , -0.9602671 ,
#          0.12891798, -0.57099384, -0.25880557,  0.6844861 ,  0.2583889 ,
#         -0.50493824, -0.1898811 , -0.14563821,  0.0210911 ,  0.48344266,
#          0.13879408, -0.3092818 ,  0.4472518 , -0.15462881, -0.01017527,
#          0.45706958, -0.0428776 , -0.30178148, -0.33906245,  0.03161857,
#          0.2320943 ,  0.16190001, -0.47022563,  0.04860632, -0.45225278,
#          0.7554839 ,  0.2818456 ,  0.3398651 , -0.1404388 , -0.27658206,
#          0.14123994,  0.09111252,  0.4011198 , -0.10529877,  0.34815815,
#          0.38030574, -0.03065307,  0.27318197, -0.17893012,  0.32679114,
#         -0.34264785,  0.2032392 ,  0.01382951,  0.16148439, -0.01852604,
#          0.3007791 ,  0.02758047, -0.01054858, -0.15281932, -0.14942433,
#          0.36463508,  0.12257992,  0.64338464,  0.15160055,  0.4944404 ,
#          0.08613543, -0.13643277, -0.6375179 , -0.25613505, -0.07373202],
#        dtype=float32),
#  'report': array([ 0.12444679,  0.08089864, -0.01953851,  0.24261425,  0.14860578,
#         -0.34930015,  0.20972963,  0.4629257 , -0.1018537 ,  0.02231776,
#          0.01780371, -0.33911422,  0.06328782,  0.07950675, -0.06443971,
#         -0.21233982,  0.0799441 , -0.18181203,  0.12012033, -0.28165692,
#          0.2684992 , -0.14977719,  0.1760911 , -0.11824811, -0.10186146,
#         -0.3232267 , -0.26707083, -0.46003976,  0.14244802,  0.3851918 ,
#          0.45447385, -0.389456  ,  0.20044678, -0.48835582,  0.03499517,
#          0.4264492 , -0.20438443,  0.00528921, -0.1988442 , -0.3737752 ,
#          0.30263528, -0.40437   , -0.22703888,  0.36621296,  0.12469841,
#         -0.13141714,  0.00146795, -0.1497136 ,  0.20483188,  0.17928877,
#          0.43089887, -0.09608408,  0.29680768,  0.09436046,  0.01286159,
#          0.1607675 ,  0.17987394, -0.39322722, -0.54175293, -0.10976551,
#          0.03968509,  0.07171437,  0.04148956,  0.06576718, -0.21649767,
#          0.24705611,  0.36415178,  0.57094693, -0.19537115,  0.04444093,
#          0.40633315,  0.16150108,  0.659555  , -0.06931062,  0.3207204 ,
#          0.15744096,  0.06506196,  0.01482622, -0.10225263,  0.35546476,
#         -0.31394997, -0.25449216, -0.2295071 ,  0.05946988,  0.00843132,
#          0.0904948 ,  0.3098891 ,  0.23321737,  0.06270309,  0.0770326 ,
#          0.6909696 ,  0.07124986,  0.12992   ,  0.09528193,  0.4526753 ,
#          0.02645869, -0.07029764, -0.17372774, -0.03269096, -0.2006765 ],
#        dtype=float32),
#  'finance': array([ 0.01557784,  0.02492434,  0.46980077,  0.29242778, -0.2540848 ,
#         -0.79611796,  0.2321361 ,  0.78194904, -0.66435033, -0.5953806 ,
#          0.04187765, -0.5124859 ,  0.07812966,  0.08987733,  0.16255963,
#          0.02565828,  0.4059282 ,  0.03002206, -0.03103059, -0.4577236 ,
#          0.12926842,  0.20861201,  0.29086006, -0.4947121 , -0.08029699,
#         -0.06688497, -0.32443705,  0.16739208, -0.34809235, -0.04278895,
#          0.28602162, -0.37917748, -0.03037911, -0.13754156, -0.00269805,
#          0.6555268 ,  0.39572942, -0.62028575, -0.5201045 , -0.05362631,
#          0.29418984, -0.4850003 , -0.25638813, -0.08899634,  0.44387344,
#         -0.41755292,  0.02839514, -0.24665567,  0.00682214,  0.1073129 ,
#          0.07632725, -0.06982751,  0.11933177,  0.08272404, -0.20864971,
#          0.49954933,  0.08792712, -0.00424616,  0.1759553 ,  0.2593829 ,
#         -0.17633009,  0.00977989,  0.18739851,  0.26848885, -0.5252319 ,
#          0.7826799 ,  0.10930498,  0.5011311 , -0.483755  ,  0.3873844 ,
#         -0.5120965 ,  0.33171672,  0.71446145, -0.03427175,  0.00223416,
#          0.39606264, -0.12119687, -0.03001262, -0.18187888,  0.3951065 ,
#         -0.13510124, -0.05428471, -0.20824593,  0.70673615, -0.08137989,
#          0.1455394 , -0.16016585,  0.24091054,  0.38343066,  0.6305073 ,
#          0.31054994, -0.15108529, -0.21153885, -0.41820058,  0.40053934,
#         -0.13260773,  0.19297782, -0.20497747,  0.5787786 , -0.10877397],
#        dtype=float32),
#  'stockmarket': array([-0.25117737,  0.06525589,  0.3729944 ,  0.20392543, -0.18763988,
#         -1.0117278 ,  0.33963063,  0.8025438 , -0.89863366, -0.630294  ,
#         -0.05810231, -0.44520324,  0.22818786,  0.06069582,  0.33620983,
#          0.01929892,  0.21579301, -0.2865264 , -0.25490996, -0.6781126 ,
#          0.06667278,  0.27129295,  0.4962222 , -0.60200363, -0.29880133,
#         -0.0292299 , -0.26142797, -0.01527344, -0.14189084, -0.01504308,
#          0.62968147, -0.43069473, -0.05053073, -0.09990844, -0.02661505,
#          0.65926576,  0.2788211 , -0.484281  , -0.6930222 , -0.1625141 ,
#          0.25180858, -0.35578114, -0.28111458,  0.03906294,  0.57917225,
#         -0.42899525,  0.0270905 , -0.34104243, -0.01086444, -0.02755592,
#          0.19418982, -0.17942005,  0.11100042,  0.26760304, -0.26336843,
#          0.6080906 ,  0.21524978,  0.15931949,  0.10307436,  0.17498703,
#          0.05260168, -0.01380155,  0.31890336,  0.29261896, -0.4633221 ,
#          0.6225102 ,  0.04721823,  0.47453383, -0.40739018,  0.32600912,
#         -0.25280103,  0.23869894,  0.7621954 ,  0.09969081, -0.01079353,
#          0.3563344 ,  0.02044313,  0.06694827, -0.25881153,  0.26014674,
#         -0.11063144, -0.23941751, -0.16578113,  0.698545  , -0.18015482,
#          0.07182831, -0.33862916,  0.30440515,  0.44256586,  0.5603373 ,
#          0.54799396,  0.07096462, -0.02585702, -0.254331  ,  0.73003864,
#          0.01374177,  0.6913862 , -0.48450768,  0.5347255 , -0.1926048 ],
#        dtype=float32),
#  'investing': array([-0.3157991 , -0.0457649 ,  0.40619457,  0.18600142, -0.27447912,
#         -0.9951746 ,  0.35122523,  0.913297  , -0.829687  , -0.55619854,
#          0.01742951, -0.47885284,  0.14143762,  0.04128474,  0.2645772 ,
#          0.02207674,  0.33631057, -0.1861319 , -0.23564054, -0.6741168 ,
#          0.09574696,  0.20072688,  0.40741658, -0.53222454, -0.28824592,
#         -0.00528069, -0.23469993, -0.08686424, -0.10993949,  0.06128826,
#          0.55805165, -0.34002858,  0.11882574, -0.04143029, -0.02924454,
#          0.74421495,  0.36373428, -0.45509326, -0.5340181 , -0.16920567,
#          0.19254391, -0.5307883 , -0.20629911, -0.00901809,  0.5154417 ,
#         -0.40507266,  0.01781257, -0.21943252,  0.02369923,  0.04731366,
#          0.11359061, -0.1133595 ,  0.15075772,  0.25970677, -0.12303046,
#          0.4478086 ,  0.26908436,  0.10556251,  0.13351642,  0.24163981,
#          0.07942372, -0.08061133,  0.31209263,  0.22382617, -0.51074165,
#          0.75014806,  0.08712574,  0.5718864 , -0.49514154,  0.4124423 ,
#         -0.23850374,  0.22811095,  0.6768212 ,  0.06586846,  0.08545559,
#          0.30881414,  0.05792714,  0.03764082, -0.27686343,  0.26161972,
#         -0.01387398, -0.12176709, -0.19475567,  0.7793686 , -0.06365804,
#          0.03182513, -0.29115513,  0.35968825,  0.47485772,  0.5676699 ,
#          0.50910366, -0.03242622, -0.06372161, -0.2118014 ,  0.6230846 ,
#          0.01965243,  0.585958  , -0.37932414,  0.59935665, -0.24233747],
#        dtype=float32),
#  'first': array([ 0.319719  ,  0.33532175,  0.07105729,  0.19301865, -0.08307578,
#         -0.3858999 , -0.10529741,  0.34921893,  0.2928108 ,  0.07639252,
#         -0.40438807,  0.03017712,  0.10499009, -0.09196258, -0.44232956,
#          0.21606982,  0.15355402,  0.00975302, -0.03830635, -0.6878598 ,
#          0.075825  ,  0.387247  ,  0.01696453, -0.25115493,  0.20899896,
#          0.43045577, -0.3186183 , -0.62890595, -0.5148967 ,  0.28571334,
#          0.59984833, -0.47965854,  0.04477251, -0.64684856, -0.05257183,
#          0.6885868 , -0.04699181, -0.331811  , -0.2882291 , -1.0141453 ,
#         -0.09915846, -0.51655704, -0.1338923 ,  0.31395733,  0.30392548,
#         -0.29273787, -0.40104616, -0.62301594,  0.31179377,  0.268035  ,
#         -0.03982413, -0.24103265, -0.15587915, -0.06521526, -0.02851609,
#         -0.10011028, -0.38306183, -0.57144374, -0.39500192,  0.01460047,
#          0.3514501 , -0.1835006 ,  0.05067081,  0.57212895, -0.16998948,
#          0.5634665 ,  0.35128522, -0.00313659, -0.7812755 ,  0.0713421 ,
#         -0.18673863,  0.06881225,  0.11411436, -0.2831024 ,  0.24686651,
#         -0.22820967, -0.32449865,  0.30485687,  0.25287467,  0.28169578,
#          0.1703663 , -0.01135785, -0.30056968,  0.08407435, -0.104898  ,
#         -0.3177735 ,  0.5146816 ,  0.14731364, -0.10064446,  0.06769946,
#         -0.07270671, -0.1672348 ,  0.66862744,  0.21860108, -0.14611045,
#         -0.45888728, -0.3911857 ,  0.20866105, -0.43440652,  0.22539344],
#        dtype=float32),
#  'call': array([-0.15876736,  0.03328904, -0.05679736,  0.11755063,  0.14668752,
#         -0.45925835,  0.5849335 ,  0.39836356, -0.6091387 , -0.34275472,
#         -0.25902957, -0.40904337, -0.15180588, -0.33110467, -0.21350777,
#         -0.30426118,  0.06589749, -0.20298105, -0.21932031, -0.5729146 ,
#          0.5314971 , -0.30490023,  0.8371002 , -0.6378028 , -0.28773612,
#         -0.43672192,  0.01391734,  0.06913856, -0.01454419,  0.13352361,
#          0.27457473, -0.21888793,  0.11356101, -0.17193669, -0.10891332,
#          0.53753144, -0.3358433 , -0.38281235, -0.31725332, -0.5282855 ,
#          0.5989825 , -0.46712178, -0.2724044 ,  0.37030038,  0.39143547,
#         -0.5971626 ,  0.22043307, -0.55130404,  0.49366406,  0.09115332,
#          0.36202067, -0.34140447,  0.5858113 ,  0.05228897, -0.42391622,
#          0.82216996, -0.04318288,  0.01603612, -0.32776615, -0.10402676,
#          0.42695186,  0.32896206,  0.19870721, -0.02670931, -0.818474  ,
#          0.7743922 , -0.01114068,  0.94528913, -0.6178835 ,  0.16875646,
#         -0.21131396,  0.04082745,  0.6792691 , -0.01059006,  0.2675351 ,
#          0.4697468 ,  0.00175383,  0.2985899 , -0.40419108,  0.6664954 ,
#         -0.4248718 ,  0.03967188, -0.20857021,  0.5922349 ,  0.17571624,
#         -0.32868108, -0.53912765,  0.5886062 ,  0.2164007 , -0.02338998,
#          1.2867635 , -0.01815639,  0.4289175 , -0.34604865,  0.56136346,
#          0.15229881,  0.4401491 , -0.29752707,  0.48122215,  0.12744214],
#        dtype=float32),
#  'amp': array([ 0.15810828,  0.06306896, -0.16738103,  0.21048683,  0.16374575,
#         -0.46427262,  0.5553321 , -0.11031957,  0.18490565, -0.13014808,
#         -0.03763955, -0.54409456, -0.13296638,  0.31722432,  0.01097474,
#         -0.32727754,  0.09647531, -0.19978976, -0.30530092, -0.24461393,
#          0.07837008,  0.33133057, -0.09008396, -0.18766929, -0.30019483,
#         -0.32868707, -0.10793448, -0.34974304, -0.33527547, -0.31277612,
#          0.6815258 , -0.17837206,  0.02325758, -0.51581657, -0.19960874,
#          0.16936868, -0.05572271,  0.20831512,  0.23172717, -0.7520588 ,
#         -0.39084166, -0.4960282 , -0.56258476,  0.1972197 , -0.11201169,
#         -0.27732036, -0.4693143 , -0.13684541,  0.34360462,  0.26532868,
#          0.01311045, -0.5391474 ,  0.39780527,  0.0374615 ,  0.10047635,
#          0.5224973 ,  0.44963792,  0.25890994, -0.24292724,  0.30204472,
#          0.06236985, -0.20610748,  0.21542488, -0.393141  , -0.37952733,
#          0.26981843, -0.54032844,  0.30411023, -0.31769574, -0.25219488,
#         -0.05988452,  0.26222223,  0.6094864 , -0.01682275,  0.34654143,
#         -0.1450961 , -0.34855193,  0.29348025, -0.2970092 , -0.46741244,
#         -0.27054754, -0.2294548 , -0.04181161,  0.30652788,  0.17090148,
#         -0.32748505,  0.20555723, -0.2630916 ,  0.8806222 ,  0.08042227,
#          0.2313691 ,  0.2775539 ,  0.29415438, -0.18330252,  0.34926233,
#          0.31948817,  0.38837337,  0.12732363, -0.35444105, -0.28686625],
#        dtype=float32),
#  'china': array([-0.3327214 , -0.19010082,  0.0006615 ,  0.198165  , -0.0460089 ,
#         -0.41497588,  0.14229527,  0.41826242, -0.09157044, -0.10333799,
#         -0.15769458, -0.3206641 , -0.30556548,  0.25344253, -0.23420106,
#          0.0489729 ,  0.10315026, -0.16531046,  0.5551838 , -0.34000096,
#          0.3509242 ,  0.16263978,  0.6037075 ,  0.25092444,  0.16755727,
#          0.06243075, -0.2923521 , -0.09905144, -0.2757128 ,  0.24612474,
#          0.43187988,  0.00301423,  0.3680957 , -0.2035563 , -0.03516264,
#          0.43432102, -0.13601837, -0.36803594, -0.28085628,  0.10022216,
#          0.20592825, -0.11726584, -0.31301722, -0.20441355,  0.32831624,
#         -0.02490752,  0.00896905, -0.06041694, -0.5230219 ,  0.01637252,
#          0.428235  , -0.11574613, -0.20006189, -0.05293179, -0.3346309 ,
#         -0.12959456, -0.0375759 , -0.30796793, -0.4496185 ,  0.21559626,
#         -0.44066325, -0.01337197,  0.03840508,  0.19082408, -0.27179363,
#          0.0690606 ,  0.03895931,  0.24662296, -0.1616843 ,  0.17659518,
#          0.3244958 , -0.0318154 ,  0.24975115,  0.06987385,  0.09839315,
#          0.16911896, -0.08674295, -0.19882178, -0.12519045,  0.37332085,
#         -0.30825788, -0.526839  , -0.07158477,  0.12402188, -0.31731305,
#          0.22012174,  0.37889028,  0.26044095, -0.17746216, -0.15087411,
#          0.1457347 , -0.14869837,  0.09325407, -0.27864155,  0.4534272 ,
#          0.05470363,  0.2765675 , -0.37847516,  0.3782291 ,  0.00274534],
#        dtype=float32),
#  'share': array([-3.75939488e-01, -5.34358397e-02, -1.05603665e-01, -2.60090083e-01,
#          2.51155525e-01, -3.93244475e-01, -2.25177675e-01,  5.71990371e-01,
#         -2.61783719e-01, -1.50169045e-01, -1.67066813e-01, -5.65654457e-01,
#          3.33146930e-01,  1.94015414e-01,  2.52331614e-01, -1.08411603e-01,
#          1.34867609e-01, -2.52699524e-01, -5.08709669e-01, -9.20533836e-01,
#         -2.13905260e-01, -4.18846831e-02, -1.96608361e-02, -1.67883694e-01,
#          1.40455425e-01,  1.23309977e-01, -3.16088945e-01, -1.96203247e-01,
#          1.11966223e-01,  2.77593672e-01,  2.40802959e-01,  1.17646079e-04,
#          1.05527014e-01, -1.92731068e-01, -2.70098541e-02,  2.70907164e-01,
#         -3.78303509e-03, -3.92266482e-01,  5.98983467e-02, -3.96975219e-01,
#         -1.07341662e-01, -4.66827214e-01,  5.11670895e-02,  3.64085555e-01,
#          5.30722663e-02,  6.97581321e-02, -4.09574479e-01,  2.60644346e-01,
#          2.89361358e-01,  7.14997500e-02,  6.73506856e-02, -1.53331280e-01,
#         -9.12334025e-03,  3.04028422e-01,  6.91287220e-02,  8.85154903e-02,
#          3.62335265e-01, -3.22542220e-01, -2.18716543e-02,  1.02812208e-01,
#          5.49918592e-01, -3.74999270e-02,  2.16125235e-01,  5.45082271e-01,
#         -3.89047623e-01,  6.49526596e-01,  5.99474050e-02,  5.36004722e-01,
#         -7.90770411e-01, -6.46482920e-03,  3.78709644e-01,  3.60463113e-01,
#          3.22077394e-01, -5.11927158e-02,  4.97882627e-02, -3.71287912e-02,
#          2.23437712e-01, -2.15774365e-02, -3.41706514e-01,  1.12083003e-01,
#         -1.77320123e-01, -8.85829777e-02, -2.41503179e-01,  3.39470834e-01,
#          3.75462770e-01,  3.39637518e-01,  1.31245762e-01,  4.28964168e-01,
#          1.09194472e-01, -3.44473720e-02,  3.05128306e-01,  5.03888726e-01,
#          4.07139927e-01,  4.83337015e-01,  3.35002571e-01,  2.19859749e-01,
#          1.12383952e-02, -5.82594454e-01,  2.14872763e-01, -1.56501070e-01],
#        dtype=float32),
#  'investor': array([-0.13824819, -0.07395346,  0.17606667,  0.16248453, -0.29114747,
#         -0.8693691 ,  0.7366514 ,  0.3595844 , -0.00981308, -0.5016654 ,
#         -0.16393712, -0.56801057, -0.04478083, -0.2290882 , -0.21963206,
#         -0.4896853 , -0.12423698, -0.45752838,  0.37799707, -0.4216188 ,
#          0.73972416, -0.1955938 ,  0.13035578,  0.07907055, -0.2653153 ,
#         -0.38197306,  0.04978129,  0.10142373, -0.02804715, -0.43938386,
#          0.6916161 , -0.04903742,  0.32633755,  0.09552568,  0.14989194,
#         -0.09401443,  0.2156412 ,  0.11031   , -0.20809513,  0.13215356,
# ...
#         -0.17083852, -0.10731996, -0.41381016, -0.32129782, -0.71639717,
#          0.38965678,  0.6615086 ,  0.2017252 , -0.32251906, -0.1827582 ,
#          0.07864051, -0.01985641, -0.43916655, -0.15690048,  0.07023489,
#          0.6743415 , -0.05651282,  0.15468784, -0.16612054, -0.2164782 ,
#          0.3226185 ,  0.10352959, -0.1892895 , -0.20416833, -0.47198206,
#         -0.01541192, -0.3025231 , -0.43134925,  0.17402692,  0.15217553,
#         -0.03570965, -0.30818847, -0.15040472,  0.1590726 ,  0.17561166,
#          0.24854827, -0.02191379,  0.18124826, -0.32126346, -0.03983296,
#          0.23803659,  0.41810533, -0.08484525,  0.01209522,  0.16734976,
#         -0.00803238, -0.20209959,  0.23158269,  0.11987039, -0.4587504 ,
#          0.31924498, -0.18733141,  0.39609733, -0.7356399 ,  0.2737769 ,
#         -0.25301364, -0.03498312,  0.4029354 , -0.11688432,  0.15170673,
#          0.03823813, -0.02962813,  0.37963676, -0.30665895,  0.00514591,
#         -0.31265238, -0.3879064 , -0.24922815,  0.3238092 ,  0.18572535,
#         -0.18125775,  0.49409476,  0.11161897,  0.65226334,  0.02764121,
#          0.46308243,  0.11629722,  0.3000341 ,  0.0075349 ,  0.19168489,
#         -0.06754464,  0.83654654,  0.2817981 ,  0.04453099,  0.05369287],
#        dtype=float32),
#  'mining': array([-0.15644325, -0.04607276,  0.10791523,  0.09957677, -0.06301511,
#         -0.4922695 ,  0.13772312,  0.34164804, -0.25353912, -0.18738782,
#         -0.05022067, -0.25122026,  0.0293038 ,  0.04719885,  0.03680674,
#         -0.0511396 ,  0.08569761, -0.21643738,  0.02154503, -0.45667875,
#          0.09056289,  0.02319944,  0.19351022, -0.07217617,  0.08564031,
#          0.04778287, -0.12772456, -0.08939891, -0.23664239, -0.00329092,
#          0.29313514,  0.00795872,  0.19819883, -0.13396879,  0.11730739,
#          0.26126742, -0.07046894, -0.2430445 , -0.14469601, -0.2860618 ,
#          0.03812132, -0.2637604 , -0.14098352,  0.03752811,  0.22342591,
#         -0.15559815, -0.1163285 ,  0.01523525, -0.02626527,  0.13138077,
#          0.00882985, -0.16803269, -0.05559623,  0.0204632 , -0.16769475,
#          0.1225424 ,  0.04412541, -0.14734866, -0.1507409 ,  0.1716461 ,
#          0.05674494,  0.09448203, -0.04955291,  0.04850894, -0.16982035,
#          0.21586098,  0.05422189,  0.31590804, -0.2998089 ,  0.13939981,
#         -0.01285462,  0.12176208,  0.31066802, -0.02951773,  0.16252242,
#          0.1287042 , -0.07103294,  0.02265638, -0.10249279,  0.1617019 ,
#          0.00514661, -0.1648855 , -0.09062902,  0.23700239, -0.04353708,
#          0.04133058,  0.01250464,  0.12439717,  0.16474651,  0.05055312,
#          0.08037981,  0.07434024,  0.11694797,  0.00373784,  0.28777853,
#          0.06195227,  0.08365345, -0.32038432,  0.06872725, -0.08307496],
#        dtype=float32),
#  'grain': array([-0.16698138, -0.03762964,  0.13851722,  0.10983588, -0.2513476 ,
#         -0.42613986,  0.14265229,  0.12379298,  0.04646102, -0.03064191,
#         -0.07822406, -0.1864017 , -0.23867466, -0.04588949,  0.01150092,
#         -0.0380872 ,  0.1183202 , -0.38641757,  0.23018515, -0.4713568 ,
#          0.16611335,  0.27859312,  0.22775488,  0.11058452,  0.00966457,
#          0.29373434, -0.14687766, -0.00723167, -0.43187317,  0.04037469,
#          0.2531161 ,  0.17399952,  0.40091544, -0.08927675,  0.17719875,
#          0.18719359, -0.11144957, -0.30357474, -0.2493871 , -0.06136223,
#         -0.034887  , -0.05341866, -0.32665703, -0.21640208,  0.2500546 ,
#         -0.0103131 , -0.1628255 ,  0.28184474, -0.08180007,  0.1118046 ,
#          0.06087438, -0.07698046, -0.17753132, -0.26064366, -0.2653473 ,
#         -0.03683618, -0.00295143, -0.33446687, -0.2977083 ,  0.3424527 ,
#         -0.23002334,  0.25814638, -0.2744046 ,  0.00864324, -0.01090707,
#         -0.03803283, -0.02346514,  0.31911656, -0.41634196,  0.26576275,
#         -0.00656841,  0.18346956,  0.23123851, -0.16717343,  0.10016651,
#          0.08139055, -0.05922648, -0.23178269, -0.02494098,  0.27714312,
#         -0.04305431, -0.3640703 , -0.16375852,  0.24181318, -0.08363267,
#         -0.00860759,  0.11980233,  0.23445454,  0.23691452, -0.00532144,
#         -0.03778845,  0.11645811,  0.12434399, -0.09245981,  0.27281317,
#          0.02612837,  0.09323242, -0.17414926,  0.083549  , -0.04120131],
#        dtype=float32),
#  'penny': array([ 0.12159077, -0.0224209 ,  0.21241197,  0.16246903, -0.02271939,
#         -0.48073202,  0.06691783, -0.05686922,  0.33867007, -0.13092053,
#         -0.18349168, -0.3542388 , -0.15952812,  0.10825568, -0.16354151,
#         -0.22174186,  0.10335147, -0.19217014,  0.14610991, -0.28893515,
#          0.27417588,  0.09635229,  0.22595699, -0.12267812,  0.39623332,
#          0.12873322, -0.100671  , -0.00429618, -0.64814764, -0.17392756,
#          0.16018553,  0.18445815,  0.2555669 , -0.30919686,  0.14992325,
#          0.0720027 , -0.24403878, -0.50874424, -0.32384452, -0.3205781 ,
#         -0.10245729, -0.07623367, -0.19513135, -0.3002978 ,  0.29043132,
#         -0.1311328 , -0.30868047,  0.08636604,  0.05213252,  0.3755025 ,
#         -0.25910255, -0.03272206, -0.12090904, -0.1823721 , -0.3749912 ,
#          0.15025672, -0.07778595, -0.23240142, -0.3601687 ,  0.34004918,
#          0.00521179,  0.18440998, -0.41984925, -0.04107002, -0.15650585,
#         -0.06068417, -0.05565352,  0.08229838, -0.24945667,  0.32512853,
#         -0.33092874,  0.25214207,  0.4530903 , -0.03543501,  0.32902148,
#          0.09470557, -0.10163786, -0.05182308,  0.00745617,  0.310779  ,
#          0.02186497, -0.23826095, -0.28540725, -0.03228565, -0.01882912,
#         -0.08140653,  0.04041067, -0.06171422,  0.3776947 , -0.07280685,
#         -0.01356606,  0.04635287,  0.04632784, -0.24534869,  0.16868706,
#         -0.02735319, -0.28926373, -0.10623656, -0.07905071,  0.01386169],
#        dtype=float32),
#  'manchin': array([-4.77909409e-02, -5.32070100e-02,  1.21317282e-01,  1.32611230e-01,
#         -1.99840620e-01, -3.93391073e-01,  2.46645749e-01,  6.05405271e-02,
#          2.37933457e-01, -8.43787938e-02, -1.74933344e-01, -1.00162663e-01,
#         -2.83944041e-01,  9.23397094e-02, -4.22000624e-02, -1.60715908e-01,
#          4.13854867e-02, -2.78245866e-01,  2.83754826e-01, -4.08703089e-01,
#          2.87469447e-01,  1.43120557e-01,  2.66164899e-01,  1.33338332e-01,
#          2.16319799e-01,  2.09780797e-01, -1.59263790e-01, -4.92738262e-02,
#         -6.90802813e-01,  5.81842810e-02,  1.04795814e-01,  1.27611786e-01,
#          4.47508305e-01, -2.68673450e-01,  2.31264055e-01,  8.42419863e-02,
#         -3.35570395e-01, -2.53969043e-01, -1.56298205e-01, -2.37743169e-01,
#         -1.28212348e-01,  5.70837269e-03, -3.74999642e-01, -2.47443512e-01,
#          2.47670606e-01,  4.82132956e-02, -2.57332116e-01,  2.98165828e-01,
#         -7.57856071e-02,  1.95513740e-01, -1.21838212e-01, -3.09142340e-02,
#         -3.91997755e-01, -4.25992817e-01, -2.57010907e-01, -1.12168729e-01,
#          4.76516485e-02, -3.02344024e-01, -4.07061964e-01,  4.21330005e-01,
#         -2.40547106e-01,  3.29397172e-01, -4.43927258e-01,  6.42087543e-03,
#         -1.13648437e-01,  6.69491201e-05, -8.83418024e-02,  1.63587138e-01,
#         -3.14935535e-01,  1.88792020e-01, -8.34550336e-02,  1.97983295e-01,
#          2.43294656e-01, -3.63287926e-02,  2.87972331e-01,  8.13874975e-02,
#         -2.39599142e-02, -1.20136254e-01, -1.43855046e-02,  2.55156964e-01,
#         -1.31059801e-02, -2.19947115e-01, -3.63089681e-01,  1.40153930e-01,
#         -5.38936630e-02, -7.46409222e-02,  1.27054259e-01,  1.18503816e-01,
#          2.01938316e-01, -2.08591923e-01, -1.22152396e-01,  9.14899558e-02,
#          1.26436472e-01, -9.08902884e-02,  1.81725845e-01,  9.39972252e-02,
#         -4.22393829e-02, -1.73766777e-01, -4.69160341e-02, -1.00568809e-01],
#        dtype=float32),
#  'within': array([-4.4676233e-02,  2.7033478e-02,  7.5431623e-02,  1.8688664e-01,
#         -2.0907836e-01, -4.3403766e-01,  7.9883762e-02,  1.8532757e-01,
#          1.7304242e-01,  3.8845565e-02, -2.1146151e-01, -2.6274598e-01,
#         -1.8163675e-01,  1.8350076e-02, -3.2838795e-02, -3.0795388e-02,
#          6.8437532e-02, -2.1674754e-01,  1.7425399e-01, -3.9933842e-01,
#          3.3247814e-01,  2.3139185e-01,  2.5606412e-01, -9.5308409e-05,
#          1.6827232e-01,  2.3238052e-01, -1.7132691e-01, -1.9958472e-01,
#         -3.9253661e-01,  8.5427172e-02,  3.0080259e-01,  9.7963072e-02,
#          3.4300140e-01, -2.1941422e-01,  1.2849252e-01,  3.2593086e-01,
#         -7.5540535e-02, -2.4038857e-01, -3.7162638e-01, -2.4465108e-01,
#          9.9734804e-03, -9.8288424e-02, -2.6401421e-01, -1.3961555e-01,
#          2.0081213e-01, -2.0678623e-02, -2.7154222e-01,  8.6266771e-02,
#          4.3995332e-02,  1.4595687e-01,  2.7977475e-03,  4.6966681e-03,
#         -2.3593129e-01, -2.6000416e-01, -1.9018246e-01, -1.3177184e-02,
#          3.3587005e-02, -3.2880875e-01, -3.2445699e-01,  2.4973913e-01,
#         -1.0513762e-01,  1.5822347e-01, -1.5486982e-01,  5.4324999e-02,
#         -1.9243558e-01,  8.3270036e-02, -2.7674556e-02,  3.1206563e-01,
#         -3.9694807e-01,  3.3217824e-01, -5.9272930e-02,  2.0813727e-01,
#          2.4668415e-01, -4.4379397e-03,  2.6445228e-01,  3.4151211e-02,
#          7.0675951e-03, -8.6426958e-02,  8.7720603e-03,  3.3410475e-01,
#         -4.3666501e-02, -2.5505364e-01, -2.0262282e-01,  1.3130230e-01,
#          3.4651118e-03, -8.3517298e-02,  2.1293330e-01,  1.8164314e-01,
#          2.5963569e-01, -8.3329052e-02, -2.1756232e-02,  3.7600875e-02,
#          1.7906918e-01, -1.2926856e-01,  1.9084100e-01,  7.0230840e-03,
#          4.9312308e-02, -1.0026814e-01, -5.1443927e-02,  8.0053834e-03],
#        dtype=float32),
#  'budget': array([-9.50278416e-02,  6.17629550e-02, -3.82688944e-04, -3.96155901e-02,
#         -6.64985254e-02, -3.93265456e-01,  9.44953412e-03,  3.07455212e-01,
#          1.64294660e-01, -7.64339119e-02, -1.04158387e-01, -2.84376264e-01,
#         -2.13634253e-01,  4.95347865e-02, -1.79617330e-01, -1.02097124e-01,
#          1.24395043e-01, -3.04511011e-01,  1.13179602e-01, -5.71421981e-01,
#          2.91916970e-02,  1.08694717e-01,  1.82301864e-01,  5.26858233e-02,
#          6.38133958e-02,  1.84144139e-01, -3.14153492e-01, -2.10133195e-01,
#         -2.41197765e-01,  2.41791099e-01,  2.05160007e-01,  9.01730731e-02,
#          3.22036117e-01, -2.00497672e-01,  1.40758678e-01,  1.77348956e-01,
#         -2.27573663e-01, -2.65269607e-01, -1.83885455e-01, -1.74674422e-01,
#         -8.55484530e-02, -1.05403028e-01, -2.81413406e-01, -1.08538873e-01,
#          1.53541416e-01,  1.36224970e-01, -1.70727685e-01,  2.39598781e-01,
#         -7.45997205e-02,  1.86955661e-01,  1.45529106e-01, -5.32918572e-02,
#         -1.11421041e-01, -1.87718540e-01, -1.85578138e-01, -6.98044077e-02,
#          1.79454133e-01, -3.20687085e-01, -2.60725349e-01,  2.58742809e-01,
#         -1.23435356e-01,  9.84743610e-02, -1.49795175e-01,  1.40319556e-01,
#         -6.97381794e-02,  2.58831829e-02,  7.57203996e-02,  1.93189621e-01,
#         -4.85550672e-01,  1.68332756e-01,  1.46975145e-01,  1.06515683e-01,
#          2.38242820e-01, -6.29735440e-02,  6.89212829e-02, -3.31389457e-02,
#         -3.15139219e-02, -2.76489586e-01, -8.78358334e-02,  2.19276026e-01,
#         -1.66104719e-01, -1.99159428e-01, -3.66180688e-01, -1.35484291e-03,
#          1.59601152e-01,  4.86557968e-02,  3.63463402e-01,  2.14561939e-01,
#          1.22324638e-01, -4.48727049e-02,  5.81686273e-02,  1.19580477e-01,
#          1.31120786e-01,  9.83569697e-02,  1.63611084e-01, -6.63175508e-02,
#         -2.46579070e-02, -1.20166607e-01,  1.45531014e-01, -1.01174161e-01],
#        dtype=float32),
#  'behalf': array([ 0.0230817 , -0.19234675,  0.10184924, -0.04557543,  0.04535505,
#         -0.6809578 ,  0.622147  ,  0.21573983, -0.33556023, -0.44999894,
#         -0.20167874, -0.36988002,  0.03668268,  0.01977781, -0.17412059,
#         -0.32160923, -0.05570464, -0.28159592,  0.00614936, -0.72455215,
#          0.29744697, -0.35415605,  0.08894847, -0.09313898, -0.04667738,
#         -0.35709772,  0.1023065 ,  0.05860055, -0.25111917, -0.23787811,
#          0.36295503, -0.03628653,  0.20895475, -0.30981696,  0.09550757,
#          0.01414534, -0.38101986, -0.13767384,  0.12015717, -0.71469927,
#         -0.19706409, -0.43489125, -0.0784952 ,  0.29827774,  0.14942332,
#         -0.7023368 , -0.03246289, -0.01940929,  0.10180327,  0.4805692 ,
#         -0.23512773, -0.54478025,  0.19277577,  0.04441533, -0.09490819,
#          0.29294407,  0.11802047,  0.21358578, -0.21266575,  0.16750465,
#          0.29175547,  0.21961793, -0.19639695, -0.19131969, -0.24169633,
#          0.47984195,  0.04800078,  0.35656476, -0.1734045 , -0.10819319,
#         -0.04304511,  0.02746518,  0.7733361 , -0.15009081,  0.47268298,
#          0.10079803, -0.07846062,  0.32192466, -0.2159442 , -0.13658312,
#         -0.06596418,  0.11021917, -0.4420047 ,  0.3550372 , -0.01304288,
#         -0.18380259, -0.11113053, -0.11128568,  0.19631363, -0.13930035,
#          0.21125239,  0.36279163,  0.21921562,  0.29382253,  0.43593183,
#          0.23705217, -0.13276163, -0.41896734,  0.04791098, -0.23308007],
#        dtype=float32),
#  'halt': array([-0.28017274, -0.01082906,  0.13208283,  0.1678158 , -0.2951244 ,
#         -0.41930148,  0.14758258,  0.13744396, -0.01788241,  0.01445116,
#          0.0369921 , -0.13794623, -0.16049632, -0.06345762,  0.03218293,
#         -0.02903716,  0.17177472, -0.4665741 ,  0.22269015, -0.4829893 ,
#          0.05785784,  0.26725358,  0.2810907 ,  0.14381114,  0.06316631,
#          0.32228714, -0.14776193, -0.05327933, -0.4390701 , -0.01541106,
#          0.25599474,  0.19608475,  0.4134681 , -0.0926768 ,  0.28139755,
#          0.2294017 , -0.09347105, -0.38783878, -0.25789717, -0.06130645,
#         -0.03497282, -0.02427608, -0.36570367, -0.23351479,  0.24946018,
#         -0.00449646, -0.1975341 ,  0.2764865 , -0.07936665,  0.05695785,
#          0.13713773, -0.07868908, -0.23382881, -0.1571467 , -0.29624522,
#          0.00446692, -0.07562982, -0.32735205, -0.3166909 ,  0.32235172,
#         -0.22200204,  0.2732195 , -0.2616306 ,  0.0312252 ,  0.04877081,
#         -0.10500428, -0.05420518,  0.32813856, -0.3937301 ,  0.24642102,
#         -0.03562369,  0.2119168 ,  0.23377788, -0.16727518,  0.05637631,
#          0.11804632, -0.15149835, -0.27894527, -0.00773453,  0.2536167 ,
#         -0.01333796, -0.42303538,  0.00105222,  0.26577666, -0.13034585,
#          0.07386969,  0.06664372,  0.25144365,  0.30806828,  0.08309063,
#         -0.07107101,  0.09747927,  0.10959073, -0.10588435,  0.3172287 ,
#          0.08506362,  0.09750551, -0.26929992,  0.03182914, -0.09568217],
#        dtype=float32),
#  'llc': array([ 0.12909818, -0.14532357,  0.12171342, -0.02280516,  0.20441508,
#         -0.5677038 ,  0.2718119 ,  0.14566593, -0.05402391, -0.4015073 ,
#         -0.06688326, -0.394091  , -0.01445046,  0.15228252, -0.10971299,
#         -0.25544348,  0.0512265 , -0.18882601, -0.15025891, -0.5081779 ,
#          0.1427352 , -0.09563563,  0.07580237, -0.2300316 ,  0.19303459,
#         -0.2125227 , -0.00238898, -0.0572524 , -0.4122068 , -0.28925222,
#          0.28440118, -0.0397068 ,  0.03494814, -0.41504744,  0.05657883,
#          0.10643303, -0.33141986, -0.26393047,  0.09444996, -0.6869071 ,
#         -0.03817363, -0.43938294, -0.14212227,  0.15091243,  0.27348346,
#         -0.4547546 , -0.19084257, -0.1008032 ,  0.17535806,  0.42282325,
#         -0.1264726 , -0.36451995,  0.27785608,  0.14666893, -0.16421643,
#          0.4490286 ,  0.01488649,  0.00324031, -0.1978257 ,  0.15340264,
#          0.26396886,  0.06265382, -0.15850313, -0.23244426, -0.18272944,
#          0.28421378,  0.00992331,  0.26887798, -0.15796924, -0.06842776,
#         -0.16082935,  0.10073124,  0.5769793 , -0.04965299,  0.34234348,
#          0.1348072 , -0.17844301,  0.27967262, -0.17609105, -0.03172611,
#         -0.04187505, -0.0692049 , -0.27134433,  0.06493976, -0.12630625,
#         -0.04107315,  0.04108694, -0.30832887,  0.3350595 , -0.01041258,
#          0.29750174,  0.18435729,  0.08470311,  0.07654557,  0.26164922,
#          0.0677983 , -0.23324673, -0.20243795, -0.12242062, -0.14848672],
#        dtype=float32),
#  ...}

# %%
from keras.preprocessing.text import one_hot,Tokenizer
tok = Tokenizer()
tok.fit_on_texts(lemmatized_tokens_train)
encd_rev = tok.texts_to_sequences(lemmatized_tokens_train)

# %%
max_sen_len= max_sen # max lenght of word in a sentence
vocab_size = len(tok.word_index) * 2  #ideally it should be len(tok.word_index) + 1  or total no of words in data, but to handle number of data which not appear in train, for example in test, make the size higher
embed_dim=100 # embedding dimension as choosen in word2vec constructor, same with vector size

# %%
# now creating the embedding matrix
embed_matrix=np.zeros(shape=(vocab_size,embed_dim))

for word,i in tok.word_index.items():
    embed_vector=word_vec_dict.get(word) #mapping the vector to word in our skipgram dictionary
    if embed_vector is not None:  # word is in the vocabulary learned by the w2v model
        embed_matrix[i]=embed_vector
  # if word is not found then embed_vector corressponding to that vector will stay zero.

# %% [markdown]
# **Preparing the Data for Embedding Layer**

# %%
encd_rev
# Out:
# [[173, 15, 505, 49, 546, 57, 4585, 28, 4586, 1, 9866],
#  [157,
#   817,
#   1892,
#   860,
#   758,
#   659,
#   6905,
#   9867,
#   5500,
#   4587,
#   3514,
#   5501,
#   1182,
#   739,
#   238,
#   1429,
#   1,
#   9868],
#  [3515, 21, 740, 17, 18, 6, 128, 27, 1, 9869, 1, 9870],
#  [1893, 3516, 2628, 227, 3, 2133, 83, 121, 279, 326, 797, 146, 1, 9871],
#  [1369, 628, 4588, 482, 1225, 1279, 1370, 4589, 571, 1, 9872, 1, 9873],
#  [2, 3, 412, 6, 572, 110, 2033, 35, 31, 1894, 554, 10, 384, 137, 1, 9874],
#  [144, 89, 8, 155, 60, 193, 14, 10, 1893, 1, 9875],
#  [1714, 5502, 5503, 483, 2629, 9876, 1634, 313, 3517, 1, 9877],
#  [5504, 58, 966, 6906, 358, 96, 2034, 9878, 1, 9879, 1, 9880],
#  [345, 191, 547, 99, 1895, 723, 45, 6907, 1, 9881],
#  [78,
#   591,
#   2035,
#   2134,
#   70,
#   2858,
#   55,
#   1280,
#   1896,
#   60,
#   833,
#   83,
#   14,
#   122,
#   362,
#   232,
#   8,
#   724,
#   104,
#   99,
#   555,
#   85,
#   1,
#   9882,
#   1,
#   9883],
#  [6908,
#   2,
#   9884,
#   3972,
#   123,
#   3,
#   5,
#   518,
#   95,
#   184,
#   3135,
#   123,
#   3,
#   5,
#   95,
#   184,
#   1635,
#   123,
#   3,
#   5,
#   95,
#   184,
#   4590,
#   123,
#   3,
#   5,
#   95,
#   184,
#   1,
#   9885],
#  [614,
#   181,
#   3136,
#   673,
#   186,
#   184,
#   614,
#   181,
#   3136,
#   673,
#   186,
#   95,
#   184,
#   614,
#   181,
#   673,
#   467,
#   186,
#   95,
#   184,
#   614,
#   181,
#   673,
#   1715,
#   186,
#   1,
#   9886],
#  [525, 5505, 172, 101, 54, 1, 9887],
#  [1716, 26, 165, 506, 23, 64, 101, 426, 1, 9888, 1, 9889],
#  [349,
#   413,
#   385,
#   350,
#   4,
#   4591,
#   1487,
#   1033,
#   82,
#   113,
#   153,
#   136,
#   463,
#   273,
#   1,
#   9890],
#  [3518, 4592, 96, 3973, 6909, 142, 525, 28, 359, 1, 9891],
#  [4593, 9892, 5506, 629, 3, 798, 967, 9893, 5, 191, 327, 74, 76, 1, 9894],
#  [51, 2273, 1371, 74, 771, 2630, 3974, 539, 818, 100, 903, 40, 1, 9895],
#  [322,
#   468,
#   5507,
#   5508,
#   92,
#   1372,
#   3519,
#   52,
#   288,
#   3520,
#   741,
#   2859,
#   5509,
#   1,
#   9896],
#  [3975, 4594, 4595, 162, 12, 6, 457, 1, 9897],
#  [5510,
#   556,
#   9898,
#   75,
#   469,
#   3976,
#   860,
#   526,
#   220,
#   73,
#   5511,
#   12,
#   72,
#   1226,
#   817,
#   1097,
#   202,
#   1636,
#   8,
#   819,
#   557,
#   166,
#   4596,
#   9899,
#   834,
#   1637,
#   9900,
#   1,
#   9901],
#  [5512, 270, 158, 1373, 707, 9902, 46, 1, 9903],
#  [1638,
#   76,
#   3977,
#   2274,
#   1321,
#   41,
#   39,
#   129,
#   393,
#   2275,
#   6910,
#   1897,
#   116,
#   36,
#   6911,
#   3978,
#   2631,
#   73,
#   1,
#   9904],
#  [3521,
#   6912,
#   615,
#   70,
#   725,
#   176,
#   5513,
#   2632,
#   165,
#   339,
#   159,
#   40,
#   1639,
#   799,
#   437,
#   50,
#   1,
#   9905],
#  [9906,
#   90,
#   340,
#   5514,
#   9907,
#   136,
#   1034,
#   300,
#   136,
#   1098,
#   300,
#   1640,
#   111,
#   1,
#   9908,
#   1,
#   9909],
#  [9910, 3137, 2440, 1641, 9911, 41, 103, 438, 2440, 1061, 1, 9912, 24, 25, 3],
#  [1898, 205, 205, 233, 193, 167, 904, 363, 79, 439, 233, 439],
#  [216, 65, 155, 137, 63, 209, 89, 8, 37, 14, 60, 2441, 143, 362, 1, 9913],
#  [440,
#   507,
#   3522,
#   1374,
#   5515,
#   5516,
#   3523,
#   2860,
#   2861,
#   3524,
#   171,
#   2862,
#   245,
#   132,
#   135,
#   1,
#   1899,
#   1,
#   9914],
#  [483, 221, 103, 5, 2863, 135, 1, 9915],
#  [1062, 3525, 6913, 4597, 4598, 2276, 217, 4599, 4600, 708, 142, 573, 1, 9916],
#  [1227,
#   592,
#   231,
#   861,
#   557,
#   2277,
#   188,
#   177,
#   26,
#   42,
#   100,
#   3979,
#   252,
#   1322,
#   31,
#   1429,
#   581,
#   406,
#   3980,
#   1063,
#   168,
#   1563,
#   140,
#   1,
#   9917],
#  [548,
#   289,
#   10,
#   147,
#   582,
#   252,
#   1149,
#   110,
#   242,
#   51,
#   3138,
#   213,
#   103,
#   62,
#   15,
#   77,
#   496,
#   39,
#   1,
#   9918],
#  [341, 123, 399, 61, 83, 257, 820, 800, 1, 9919],
#  [1228, 1564, 17, 18, 1804, 2278, 948, 124, 603, 1, 9920],
#  [9921, 340, 5517, 5518, 136, 301, 300, 1, 9922, 1, 9923],
#  [29,
#   630,
#   3139,
#   1229,
#   349,
#   835,
#   63,
#   6914,
#   273,
#   6915,
#   1805,
#   113,
#   153,
#   274,
#   2279,
#   1806,
#   1,
#   9924],
#  [220,
#   40,
#   9925,
#   31,
#   660,
#   342,
#   17,
#   18,
#   821,
#   177,
#   351,
#   126,
#   1323,
#   161,
#   926,
#   497,
#   19,
#   6916,
#   150,
#   258,
#   927,
#   2442,
#   1,
#   9926],
#  [9927,
#   928,
#   2036,
#   1488,
#   674,
#   26,
#   154,
#   133,
#   1324,
#   1900,
#   819,
#   352,
#   1035,
#   3981,
#   170,
#   166,
#   5519,
#   2037,
#   4601,
#   822,
#   239,
#   163],
#  [5520,
#   6917,
#   968,
#   9928,
#   9929,
#   33,
#   2280,
#   169,
#   72,
#   675,
#   1642,
#   33,
#   170,
#   9930,
#   6918,
#   6919,
#   470],
#  [9931,
#   1003,
#   726,
#   583,
#   72,
#   48,
#   836,
#   2135,
#   20,
#   1064,
#   1279,
#   48,
#   234,
#   1,
#   9932,
#   1,
#   9933],
#  [2136, 464, 364, 205, 22, 233, 222, 469, 546, 3140, 363, 1, 9934],
#  [2038, 1150, 2443, 394, 2137, 70, 133, 2864, 3526, 1, 9935],
#  [6920, 6921, 458, 1183, 540, 9936, 1430, 441, 9937, 507, 527, 1, 9938],
#  [3982, 3983, 386, 484, 9939, 134, 4602, 2633, 1099, 1, 9940, 11, 9, 25],
#  [6922, 9941, 216, 2444, 161, 323, 2, 261, 314, 4, 1, 9942],
#  [1228, 1564, 687, 1230, 449, 353, 37, 146, 14, 3527, 156, 48, 1281, 29],
#  [2445,
#   1375,
#   1717,
#   32,
#   1643,
#   20,
#   1033,
#   727,
#   2138,
#   615,
#   496,
#   39,
#   246,
#   1807,
#   1,
#   9943],
#  [157, 1, 9944],
#  [3528, 2634, 172, 1184, 59, 2, 2039, 249, 1, 9945],
#  [6923, 6924, 9946, 118, 837, 3141, 467, 30, 508, 14, 1, 9947],
#  [509,
#   3529,
#   5521,
#   5522,
#   5523,
#   742,
#   1489,
#   3530,
#   1644,
#   4603,
#   1231,
#   427,
#   584,
#   247,
#   2635,
#   1231,
#   2636,
#   2637,
#   509,
#   5524,
#   57,
#   676,
#   1,
#   9948],
#  [1901,
#   728,
#   3531,
#   1902,
#   75,
#   2,
#   4604,
#   2865,
#   759,
#   352,
#   1490,
#   1004,
#   4605,
#   1,
#   9949],
#  [6925,
#   5525,
#   2281,
#   400,
#   428,
#   4606,
#   3142,
#   4607,
#   1565,
#   354,
#   421,
#   49,
#   130,
#   969,
#   6926,
#   1,
#   9950],
#  [29, 2282, 970, 1151, 60, 2446, 290, 574, 1100, 688, 1, 9951],
#  [156, 2, 1152, 1718, 46, 17, 39, 9952, 83, 1230, 3143, 74, 167, 1, 9953],
#  [5526, 90, 192, 12, 949, 1, 9954, 9, 23, 25],
#  [9955, 4608, 257, 326, 64, 12, 1719, 1, 9956, 23, 24, 9],
#  [268,
#   1065,
#   2447,
#   5527,
#   801,
#   772,
#   253,
#   3144,
#   74,
#   48,
#   15,
#   1645,
#   1101,
#   328,
#   129,
#   549,
#   880,
#   3984,
#   1,
#   9957],
#  [9958, 1903, 9959, 148, 79, 44, 1, 9960],
#  [789, 265, 355, 125],
#  [661, 328, 1566, 307, 2040, 3985, 631, 1, 9961],
#  [3,
#   528,
#   258,
#   213,
#   2139,
#   16,
#   881,
#   760,
#   179,
#   414,
#   105,
#   3532,
#   330,
#   34,
#   74,
#   834,
#   1,
#   9962],
#  [10,
#   2283,
#   330,
#   6927,
#   429,
#   1638,
#   36,
#   3978,
#   2631,
#   5528,
#   82,
#   558,
#   4609,
#   528,
#   441,
#   1,
#   9963],
#  [1376, 802, 64, 1567, 192, 6928, 555, 1720, 1, 9964],
#  [13, 228, 262, 2448, 72, 1102, 1185, 324, 2140, 929, 1, 9965, 1, 9966],
#  [616, 575, 4610, 117, 574, 6929, 34, 5529, 1, 9967, 1, 9968],
#  [2,
#   838,
#   1325,
#   529,
#   4611,
#   485,
#   5530,
#   176,
#   576,
#   628,
#   2041,
#   387,
#   206,
#   1568,
#   66,
#   430,
#   1,
#   9969,
#   1,
#   9970],
#  [2866, 2866, 239, 905, 9971, 65, 9972, 359, 442, 2866, 9973, 1, 9974],
#  [3533, 1326, 443, 2284, 9975, 399, 349, 9976, 110, 34, 1033, 1, 9977],
#  [9978,
#   2042,
#   4612,
#   6930,
#   709,
#   115,
#   243,
#   585,
#   526,
#   3145,
#   9979,
#   1,
#   9980,
#   839,
#   395,
#   3534,
#   203,
#   55,
#   1431,
#   69,
#   139,
#   32,
#   10,
#   1282,
#   4613,
#   6,
#   224,
#   906,
#   9,
#   24,
#   1327,
#   710],
#  [173, 1153, 3535, 1904, 126, 2043, 773, 1, 9981],
#  [9982,
#   5531,
#   882,
#   558,
#   484,
#   45,
#   1905,
#   322,
#   468,
#   39,
#   729,
#   388,
#   2867,
#   428,
#   282,
#   617,
#   1,
#   9983],
#  [803,
#   729,
#   29,
#   482,
#   331,
#   149,
#   4614,
#   2638,
#   129,
#   6931,
#   510,
#   1232,
#   834,
#   102,
#   17,
#   141,
#   9,
#   1,
#   9984],
#  [2639, 1233, 2141, 2142, 1328, 310, 1103, 9985, 102, 1, 9986, 25, 24, 9],
#  [471, 593, 76, 677, 519, 327, 48, 1, 9987],
#  [1377, 37, 54, 194, 3, 67, 1, 9988, 11, 3, 4],
#  [9989, 9990, 5532, 192, 5, 476, 158, 1, 9991, 1, 9992],
#  [288, 144, 89, 157, 5533, 60, 123, 1, 9993],
#  [9994,
#   136,
#   862,
#   300,
#   9995,
#   6932,
#   2640,
#   9996,
#   346,
#   1569,
#   1491,
#   594,
#   332,
#   1902,
#   72,
#   176,
#   498,
#   2044,
#   835,
#   1283,
#   49,
#   315,
#   1570,
#   1,
#   9997],
#  [292,
#   4615,
#   386,
#   2045,
#   365,
#   259,
#   378,
#   5534,
#   1234,
#   5535,
#   6933,
#   179,
#   330,
#   308,
#   577,
#   379,
#   253,
#   2868,
#   4616,
#   1,
#   9998],
#  [3986, 3146, 819, 2285, 11, 48, 511, 559, 1, 9999, 23, 3, 9],
#  [6934,
#   6935,
#   115,
#   4617,
#   6936,
#   883,
#   3145,
#   4618,
#   1,
#   6937,
#   181,
#   3147,
#   3536,
#   422,
#   10,
#   29,
#   711,
#   6938,
#   560,
#   3987,
#   10000,
#   4613,
#   240,
#   10001,
#   1,
#   10002],
#  [1646, 5, 66, 1, 10003],
#  [2046, 1571, 1572, 632, 712, 99, 199, 1036, 3988, 4619, 1, 10004, 11, 24, 25],
#  [1104, 930, 10005, 3989, 1378, 1906, 1, 10006],
#  [1647, 2869, 60, 2870, 200, 1, 10007],
#  [78,
#   678,
#   122,
#   14,
#   10,
#   147,
#   437,
#   15,
#   46,
#   1432,
#   40,
#   75,
#   5536,
#   662,
#   13,
#   1105,
#   6939,
#   396,
#   61,
#   15,
#   77,
#   41,
#   39,
#   1,
#   6940,
#   1,
#   10008],
#  [10009, 907, 450, 1907, 2641, 465, 213, 72, 30, 646, 72, 506, 486, 14],
#  [4620,
#   10010,
#   5,
#   112,
#   10011,
#   52,
#   802,
#   64,
#   1186,
#   46,
#   1492,
#   279,
#   1235,
#   43,
#   1,
#   10012],
#  [803, 259, 1573, 43, 1721, 188, 470, 6941, 76, 6942, 72, 2047, 1, 10013],
#  [243, 10014, 243, 1062, 674, 177, 2449, 83, 674, 125, 1, 10015],
#  [10016,
#   6943,
#   26,
#   6944,
#   774,
#   10017,
#   6945,
#   6946,
#   1154,
#   2450,
#   1,
#   10018,
#   1,
#   10019],
#  [931,
#   592,
#   415,
#   512,
#   2451,
#   275,
#   174,
#   6,
#   366,
#   401,
#   513,
#   833,
#   103,
#   13,
#   931,
#   884,
#   6947,
#   707,
#   1329,
#   707,
#   202,
#   1,
#   10020,
#   1,
#   10021],
#  [2, 214, 46, 5537, 276, 50, 3148, 1037, 302, 106, 225, 95],
#  [557,
#   324,
#   10022,
#   761,
#   10023,
#   2143,
#   863,
#   689,
#   1722,
#   5538,
#   76,
#   1330,
#   143,
#   1433,
#   66,
#   343,
#   55,
#   160,
#   199,
#   1,
#   10024],
#  [10025, 4621, 387, 1493, 2861, 10026, 1106, 690, 690, 301, 2642, 1, 10027],
#  [520, 293, 2871, 2872, 1434, 297, 117, 109, 971, 49, 1, 10028],
#  [592, 137, 160, 3537, 2286, 34, 9, 1, 10029, 1, 10030],
#  [115,
#   303,
#   883,
#   727,
#   1574,
#   1038,
#   885,
#   159,
#   593,
#   371,
#   1107,
#   972,
#   6948,
#   484,
#   323,
#   6949,
#   1908,
#   477,
#   180,
#   407,
#   78,
#   727,
#   171,
#   1494,
#   115,
#   93,
#   1,
#   10031],
#  [372,
#   35,
#   3538,
#   265,
#   5539,
#   393,
#   157,
#   53,
#   4622,
#   3990,
#   2287,
#   631,
#   5540,
#   423,
#   1,
#   10032],
#  [170, 4623, 12, 6, 47, 366, 4, 30, 469, 116, 1, 10033],
#  [886,
#   571,
#   13,
#   91,
#   289,
#   2144,
#   1568,
#   207,
#   48,
#   1808,
#   528,
#   7,
#   29,
#   129,
#   1039,
#   1187,
#   6950,
#   1575,
#   2288,
#   6951,
#   1576,
#   1284,
#   66,
#   430,
#   74,
#   571,
#   1,
#   10034],
#  [221, 633, 472, 313, 20, 1188, 2289, 519, 1, 10035, 2048, 1809, 1, 10036],
#  [153,
#   218,
#   3149,
#   3150,
#   2643,
#   73,
#   440,
#   1648,
#   2,
#   1236,
#   2049,
#   10037,
#   2050,
#   10038,
#   5,
#   1371,
#   153,
#   36,
#   1155,
#   245,
#   1909,
#   1495,
#   291,
#   1,
#   10039],
#  [20,
#   487,
#   397,
#   1910,
#   1911,
#   1911,
#   1066,
#   304,
#   932,
#   2873,
#   144,
#   89,
#   70,
#   20,
#   530,
#   1,
#   10040,
#   1,
#   10041],
#  [592, 305, 262, 389, 663, 63, 1496, 3, 1, 10042],
#  [10043,
#   10044,
#   3991,
#   966,
#   6952,
#   4624,
#   3992,
#   1237,
#   2644,
#   5,
#   6953,
#   485,
#   4625,
#   10045,
#   3151,
#   4626,
#   1,
#   10046,
#   1,
#   10047],
#  [3539, 933, 210, 19, 26, 18, 1067, 46, 86, 1, 10048, 1, 10049],
#  [743, 1285, 1108, 215, 69, 10050, 8, 2, 2290, 5541, 1, 10051],
#  [1647,
#   2869,
#   8,
#   1109,
#   380,
#   485,
#   887,
#   762,
#   52,
#   531,
#   10052,
#   1110,
#   32,
#   6954,
#   11,
#   237,
#   1577,
#   499,
#   1,
#   10053],
#  [10054,
#   6955,
#   3993,
#   2452,
#   4627,
#   675,
#   934,
#   864,
#   96,
#   4627,
#   865,
#   3994,
#   3540,
#   1,
#   10055],
#  [1723,
#   65,
#   2874,
#   52,
#   4628,
#   949,
#   1724,
#   8,
#   559,
#   561,
#   10056,
#   540,
#   1724,
#   1578,
#   506,
#   3995,
#   75,
#   362,
#   550,
#   1,
#   6956],
#  [2145, 5542, 205, 1040, 47, 233, 1, 10057],
#  [175, 521, 122, 679, 271, 680, 166, 121, 888, 1579, 664, 98, 1, 10058],
#  [5543,
#   118,
#   562,
#   1229,
#   2875,
#   463,
#   574,
#   189,
#   91,
#   343,
#   55,
#   948,
#   427,
#   117,
#   109,
#   3996,
#   3997,
#   3998,
#   3999,
#   6957,
#   880,
#   1,
#   10059],
#  [5544, 6958, 10060, 67, 235, 437, 451, 1, 10061, 23, 9, 25],
#  [4621, 354, 87, 21, 618, 48, 112, 10062, 1, 10063, 1, 10064],
#  [3152, 3152, 1497, 3, 190, 112, 1, 10065, 11, 4, 23],
#  [3541, 1331, 1810, 107, 6959, 973, 1498, 227, 33, 156, 1, 10066],
#  [280, 1499, 1111, 2146, 7, 680, 250, 100, 57, 1649, 1, 10067],
#  [28, 84, 4000, 4612, 5545, 2291, 38, 1005, 514, 1650, 167, 1, 10068],
#  [261,
#   314,
#   541,
#   1912,
#   1725,
#   76,
#   4001,
#   763,
#   1913,
#   253,
#   4629,
#   53,
#   10069,
#   10070,
#   2453,
#   631,
#   20,
#   10071,
#   935,
#   91,
#   1,
#   10072],
#  [1647,
#   2869,
#   258,
#   664,
#   2051,
#   615,
#   6954,
#   935,
#   204,
#   141,
#   4630,
#   678,
#   522,
#   665,
#   1,
#   10073],
#  [5546, 10074, 4631, 889, 22, 2645, 10075, 908, 1, 10076],
#  [974,
#   2147,
#   1379,
#   2646,
#   10077,
#   2876,
#   3153,
#   10078,
#   2454,
#   1068,
#   10079,
#   60,
#   399,
#   5547,
#   1,
#   10080],
#  [1155,
#   245,
#   1372,
#   3154,
#   26,
#   1914,
#   1811,
#   245,
#   1580,
#   950,
#   6960,
#   2631,
#   2145,
#   713,
#   4002,
#   6961,
#   4003,
#   3155,
#   3156,
#   4004,
#   87,
#   1,
#   10081,
#   1,
#   10082],
#  [6962, 4005, 804, 1500, 1189, 4006, 199, 1036, 22, 1, 10083],
#  [78,
#   345,
#   666,
#   5,
#   104,
#   3157,
#   3158,
#   34,
#   2292,
#   10084,
#   1286,
#   429,
#   242,
#   2455,
#   761,
#   55,
#   616,
#   1156,
#   10085,
#   191,
#   3159,
#   8,
#   10086,
#   1,
#   10087],
#  [5548,
#   371,
#   2052,
#   1651,
#   1157,
#   691,
#   1652,
#   371,
#   117,
#   49,
#   1812,
#   181,
#   45,
#   2877,
#   2273,
#   1371,
#   390,
#   1581,
#   1435,
#   1380,
#   1582,
#   29,
#   840,
#   2,
#   276,
#   50,
#   122,
#   679,
#   1287,
#   764,
#   93,
#   1190,
#   471,
#   526,
#   216,
#   79],
#  [6963,
#   563,
#   56,
#   283,
#   134,
#   142,
#   2293,
#   1381,
#   4007,
#   908,
#   62,
#   2148,
#   239,
#   372,
#   68,
#   886,
#   564,
#   1382,
#   232,
#   73,
#   1,
#   10088],
#  [6964, 6965, 76, 488, 1006, 284, 1, 10089],
#  [10090, 71, 909, 268, 1332, 129, 711, 1501, 1, 10091, 1, 10092],
#  [2053, 114, 3160, 133, 402, 105, 106, 225, 171],
#  [692, 604, 189, 55, 948, 2294, 450, 403, 1, 10093],
#  [11,
#   771,
#   489,
#   87,
#   195,
#   1718,
#   26,
#   42,
#   7,
#   82,
#   85,
#   3161,
#   5,
#   316,
#   51,
#   86,
#   11,
#   274,
#   558,
#   558,
#   2295,
#   11,
#   771,
#   183,
#   412,
#   61,
#   2456,
#   1,
#   10094,
#   1,
#   10095],
#  [1813, 4008, 8, 386, 2858, 268, 551, 85, 362, 1, 10096],
#  [823,
#   1726,
#   595,
#   1814,
#   1288,
#   26,
#   1653,
#   42,
#   714,
#   619,
#   408,
#   421,
#   2149,
#   2296,
#   2457,
#   1815,
#   3162,
#   489,
#   629,
#   172,
#   78,
#   315,
#   1,
#   6966,
#   1,
#   6967,
#   1,
#   10097],
#  [614, 151, 183, 135, 1112, 1, 10098],
#  [1007, 1158, 472, 158, 26, 1430, 223, 22, 1, 10099],
#  [2647,
#   951,
#   58,
#   2647,
#   53,
#   10100,
#   10101,
#   12,
#   19,
#   6,
#   27,
#   254,
#   1,
#   10102,
#   24,
#   4,
#   11],
#  [4632,
#   1191,
#   397,
#   1915,
#   1916,
#   28,
#   1917,
#   84,
#   93,
#   1816,
#   31,
#   459,
#   226,
#   347,
#   1069,
#   4632,
#   58,
#   744,
#   31,
#   634,
#   85,
#   1,
#   10103],
#  [866,
#   5549,
#   213,
#   3163,
#   161,
#   431,
#   2648,
#   542,
#   881,
#   323,
#   41,
#   2297,
#   2054,
#   477,
#   1817,
#   381,
#   2298,
#   1,
#   10104],
#  [10105,
#   10106,
#   367,
#   605,
#   65,
#   3542,
#   1159,
#   409,
#   2299,
#   708,
#   10107,
#   2649,
#   394,
#   10108,
#   2649,
#   373,
#   6968,
#   1583,
#   2649,
#   1,
#   10109,
#   1,
#   10110],
#  [10111, 1383, 6969, 6970, 192, 202, 1, 10112, 1, 10113],
#  [2650,
#   2150,
#   10114,
#   259,
#   308,
#   1584,
#   2878,
#   10115,
#   5,
#   2150,
#   53,
#   1289,
#   1436,
#   1,
#   10116],
#  [10117, 348, 3164, 2300, 578, 34, 120, 10118, 196, 1, 10119, 1, 10120],
#  [255,
#   890,
#   110,
#   891,
#   217,
#   144,
#   89,
#   368,
#   1818,
#   805,
#   43,
#   20,
#   234,
#   530,
#   1,
#   10121],
#  [6971,
#   6971,
#   1192,
#   2458,
#   862,
#   156,
#   4633,
#   374,
#   10122,
#   3165,
#   10123,
#   1192,
#   1,
#   10124],
#  [11, 1437, 10125, 10126, 2445, 841, 364, 3166, 1918, 842, 1, 10127],
#  [3543,
#   4009,
#   5550,
#   2055,
#   2879,
#   3544,
#   28,
#   1585,
#   400,
#   4010,
#   2056,
#   317,
#   1327,
#   1160,
#   2301,
#   1,
#   10128],
#  [10129,
#   10130,
#   6972,
#   432,
#   1811,
#   245,
#   1919,
#   805,
#   162,
#   5,
#   316,
#   283,
#   153,
#   36,
#   1155,
#   245,
#   1438,
#   4634,
#   523,
#   1,
#   10131],
#  [1113,
#   36,
#   3167,
#   513,
#   1226,
#   189,
#   33,
#   532,
#   463,
#   2,
#   105,
#   408,
#   1502,
#   743,
#   232,
#   8,
#   1,
#   10132],
#  [1, 6973, 30, 147, 881, 125, 130],
#  [2880,
#   10,
#   147,
#   7,
#   37,
#   3545,
#   1439,
#   80,
#   13,
#   242,
#   1503,
#   539,
#   62,
#   15,
#   77,
#   1,
#   10133],
#  [78,
#   345,
#   975,
#   2459,
#   200,
#   20,
#   764,
#   975,
#   1727,
#   975,
#   6974,
#   975,
#   458,
#   200,
#   6975,
#   975,
#   3,
#   709,
#   4635,
#   5551,
#   5552,
#   8,
#   1,
#   10134],
#  [1440, 4636, 158, 17, 18, 19, 138, 1, 10135, 1, 10136],
#  [2651, 2881, 127, 47, 12, 366, 1070, 285, 865, 44, 1, 10137],
#  [88, 1920, 881, 37, 806, 13, 1193, 30, 83, 1488, 125, 1, 10138],
#  [4637,
#   2151,
#   4011,
#   2460,
#   301,
#   416,
#   34,
#   460,
#   375,
#   140,
#   775,
#   76,
#   619,
#   594,
#   261,
#   314,
#   496,
#   7,
#   1,
#   10139],
#  [216, 155, 12, 662, 144, 89, 6976, 1, 10140, 25, 3, 23],
#  [2053, 36, 6977, 1654, 4638, 615, 123, 5553, 2152, 1, 10141, 1, 10142],
#  [10143, 21, 936, 1921, 3546, 3168, 136, 96, 300, 1, 10144, 1, 10145],
#  [976,
#   189,
#   55,
#   66,
#   108,
#   466,
#   60,
#   1041,
#   977,
#   2144,
#   1568,
#   207,
#   309,
#   82,
#   5,
#   366,
#   2302,
#   1,
#   10146],
#  [892,
#   3547,
#   554,
#   4639,
#   105,
#   142,
#   247,
#   204,
#   10147,
#   315,
#   7,
#   50,
#   399,
#   43,
#   1,
#   10148],
#  [345, 311, 444, 142, 288, 34, 33, 6978, 1, 10149],
#  [6979,
#   1071,
#   2652,
#   2860,
#   10150,
#   76,
#   1114,
#   776,
#   6980,
#   6981,
#   1380,
#   470,
#   1,
#   10151],
#  [478, 1065, 520, 293, 8, 1434, 1, 10152],
#  [36, 4640, 2882, 131, 407, 1384, 1819, 43, 197, 1820, 4012, 10, 1, 10153],
#  [4013, 1072, 192, 444, 2883, 354, 3169, 529, 1, 10154, 1, 10155],
#  [5,
#   843,
#   186,
#   244,
#   302,
#   59,
#   106,
#   59,
#   225,
#   5,
#   843,
#   186,
#   532,
#   302,
#   59,
#   106,
#   59,
#   225],
#  [115, 86, 84, 1385, 249, 1494, 2461, 4014, 1494, 1441],
#  [844,
#   565,
#   291,
#   274,
#   1068,
#   952,
#   860,
#   473,
#   333,
#   1194,
#   635,
#   325,
#   32,
#   41,
#   117,
#   109,
#   1,
#   10156],
#  [10157, 10158, 210, 442, 893, 6982, 2884, 339, 1, 10159, 1, 10160],
#  [5554,
#   127,
#   111,
#   4015,
#   458,
#   667,
#   5,
#   3170,
#   127,
#   2057,
#   1442,
#   647,
#   3170,
#   127,
#   87,
#   1,
#   10161,
#   1,
#   10162],
#  [3171, 6983, 533, 120, 87, 197, 382, 116, 2653, 88, 1115, 1, 10163, 1, 10164],
#  [10165, 120, 1728, 1922, 4641, 10166, 1, 10167, 1, 10168],
#  [404, 2058, 5, 6984, 745, 1161, 2, 840, 40, 4642, 17, 18, 1, 10169],
#  [10170, 111, 58, 22, 17, 18, 38, 19, 648, 128, 27, 86, 1, 10171],
#  [3172, 4016, 136, 575, 953, 146, 20, 2153, 1, 10172, 3, 23, 9],
#  [78,
#   144,
#   89,
#   368,
#   777,
#   465,
#   157,
#   802,
#   64,
#   4643,
#   281,
#   3548,
#   1238,
#   68,
#   43,
#   31,
#   479,
#   103,
#   1195,
#   11,
#   23,
#   35,
#   1,
#   10173],
#  [10174, 10175, 845, 10176, 10177, 1434, 1, 10178],
#  [1290,
#   174,
#   221,
#   661,
#   633,
#   3549,
#   68,
#   519,
#   76,
#   715,
#   48,
#   262,
#   772,
#   5555,
#   1008,
#   1,
#   10179],
#  [45,
#   14,
#   2885,
#   910,
#   26,
#   42,
#   100,
#   69,
#   4017,
#   139,
#   342,
#   5556,
#   34,
#   98,
#   2303,
#   681,
#   4,
#   6985,
#   289,
#   143,
#   1,
#   10180,
#   1,
#   10181],
#  [312,
#   80,
#   13,
#   636,
#   8,
#   586,
#   145,
#   4644,
#   9,
#   48,
#   152,
#   1821,
#   778,
#   3138,
#   1330,
#   1504,
#   834,
#   1,
#   10182],
#  [352, 137, 63, 275, 174, 1196, 476, 87, 124, 1, 10183, 1, 10184],
#  [563, 80, 13, 4018, 586, 145, 4019, 159, 1, 10185],
#  [978,
#   141,
#   911,
#   130,
#   7,
#   125,
#   48,
#   1239,
#   3173,
#   88,
#   637,
#   211,
#   1239,
#   10,
#   37,
#   4645,
#   4646,
#   937,
#   404,
#   1,
#   10186],
#  [938, 954, 10187, 92, 126, 566, 72, 1, 955, 1, 10188, 1, 10189],
#  [1923, 33, 1116, 14, 1, 10190],
#  [10191, 6986, 266, 34, 2059, 128, 10192, 1, 10193, 1, 10194],
#  [10195, 171, 72, 470, 1, 10196, 1, 10197],
#  [606,
#   2,
#   10,
#   5557,
#   637,
#   1586,
#   460,
#   522,
#   2886,
#   596,
#   807,
#   1563,
#   1042,
#   258,
#   170,
#   5558,
#   134,
#   2304,
#   365,
#   1,
#   10198],
#  [6987, 69, 6988, 730, 2305, 1291, 2887, 514, 1580, 1924, 31, 87, 1, 10199],
#  [1282, 2060, 3550, 10, 355, 1925, 41, 7],
#  [1716, 10200, 1716, 73, 638, 59, 6989, 52, 356, 3551, 1, 10201],
#  [1646, 5, 66, 1, 10202],
#  [6990, 21, 17, 18, 6, 158, 334, 1, 10203, 1, 10204],
#  [5559, 32, 260, 269, 1729, 1587, 15, 894, 1, 10205, 1, 10206],
#  [255,
#   20,
#   376,
#   543,
#   347,
#   144,
#   89,
#   2306,
#   1073,
#   82,
#   1006,
#   890,
#   217,
#   99,
#   693,
#   891,
#   1,
#   10207,
#   1,
#   10208],
#  [13, 75, 215, 2, 122, 38, 127, 379, 179, 285, 10, 362, 1, 10209],
#  [10210, 340, 10211, 1822, 259, 308, 1, 10212, 1, 10213],
#  [2, 3, 820, 160, 28, 84],
#  [10, 37, 176, 979, 68, 227, 327, 1, 10214],
#  [62, 145, 197, 6991, 193, 639, 88, 8, 305, 1, 10215, 1, 10216],
#  [10217, 10218, 10219, 2858, 154, 85, 694, 1, 10220],
#  [5560, 33, 146, 102, 680, 1156, 1505, 470, 1, 10221, 1, 10222],
#  [377,
#   2061,
#   596,
#   42,
#   1823,
#   716,
#   2,
#   1443,
#   682,
#   1444,
#   1043,
#   2462,
#   5561,
#   1,
#   10223,
#   57,
#   587],
#  [28, 6, 27, 417, 452, 91, 14, 77, 620, 10, 1, 10224],
#  [10225, 32, 1497, 10226, 619, 16, 10227, 980, 4, 1, 10228],
#  [607, 1926, 178, 2654, 114, 180, 368, 114, 1927, 731, 368, 473, 731],
#  [471,
#   22,
#   164,
#   12,
#   6,
#   47,
#   1190,
#   373,
#   205,
#   99,
#   161,
#   112,
#   726,
#   1195,
#   44,
#   165,
#   192,
#   231,
#   10229,
#   534,
#   103,
#   433,
#   533,
#   13,
#   4020,
#   8,
#   306,
#   490,
#   1,
#   10230],
#  [6992, 6993, 22, 32, 346, 1569, 85, 1580, 202, 1, 10231],
#  [224, 15, 934, 83, 35, 1, 10232, 6994, 1, 10233],
#  [6,
#   155,
#   12,
#   79,
#   1445,
#   106,
#   95,
#   12,
#   233,
#   59,
#   106,
#   59,
#   95,
#   10234,
#   22,
#   1,
#   10235,
#   1,
#   10236],
#  [5562, 65, 134, 174, 360, 148, 79, 47, 44, 59, 205, 491, 1, 10237],
#  [4647, 867, 597, 11, 135, 22, 17, 18, 38, 19, 138, 1, 10238, 1, 10239],
#  [32, 2307, 1730, 5563, 6995, 5564, 10240, 5565, 1928, 2463, 1, 10241],
#  [1490, 1901, 746, 10242, 598, 4648, 154, 1929, 1, 10243, 3, 23, 24],
#  [2, 534, 4649, 10244, 98, 1, 10245],
#  [254, 4650, 3174, 1074, 151, 4, 1197, 1, 10246],
#  [695,
#   14,
#   183,
#   790,
#   143,
#   2464,
#   1930,
#   88,
#   2,
#   190,
#   87,
#   434,
#   1931,
#   1198,
#   46,
#   7,
#   388,
#   14,
#   1931,
#   1198,
#   683,
#   40,
#   1,
#   10247,
#   1,
#   10248],
#  [71, 379, 28, 3175, 41, 469, 303, 883, 115],
#  [231, 861, 2062, 2465, 142, 347, 224, 177, 1, 10249, 1, 10250],
#  [4651, 65, 4652, 234, 535, 386, 2308, 11, 1240, 4653, 587, 1, 10251],
#  [108, 3, 353, 17, 49, 140, 170, 6, 572, 179, 330, 5, 711, 29, 1, 10252],
#  [684, 536, 10253, 118, 10254, 10255, 251, 3517, 1, 10256],
#  [26, 329, 34, 64, 492, 32, 260, 269, 279, 165, 250, 1, 10257, 1, 10258],
#  [1380, 1044, 1009, 1932, 415, 512, 12, 79, 1, 10259],
#  [1196,
#   241,
#   3552,
#   10260,
#   248,
#   4,
#   10261,
#   3553,
#   422,
#   4620,
#   1117,
#   151,
#   1,
#   10262,
#   1,
#   10263],
#  [93, 1435, 1190, 895, 164, 6, 599, 31, 10264, 67, 3, 1, 10265],
#  [255, 29, 1292, 2063, 43, 4021, 2059, 1102, 1, 10266, 1, 10267],
#  [10268, 10269, 342, 889, 1, 10270, 11, 4, 16],
#  [4022,
#   358,
#   1506,
#   725,
#   10271,
#   2466,
#   2154,
#   213,
#   479,
#   2466,
#   1507,
#   232,
#   8,
#   1,
#   10272],
#  [105, 1588, 10273, 175, 1487, 1446, 247, 125, 362, 1, 10274],
#  [691,
#   471,
#   2,
#   391,
#   649,
#   69,
#   150,
#   10275,
#   45,
#   198,
#   244,
#   1293,
#   168,
#   5566,
#   1,
#   10276],
#  [823,
#   1726,
#   595,
#   1814,
#   1288,
#   26,
#   1653,
#   42,
#   714,
#   619,
#   408,
#   421,
#   2149,
#   2296,
#   2457,
#   1815,
#   3162,
#   489,
#   629,
#   172,
#   78,
#   315,
#   1,
#   4023,
#   1,
#   4024,
#   1,
#   10277],
#  [10278, 10279, 10280, 22, 461, 19, 1, 10281],
#  [92, 2888, 435, 10282, 453, 10283, 294, 2655, 1, 10284, 1, 10285],
#  [32, 820, 454, 149, 500, 11, 142, 7, 362, 1, 10286],
#  [1925, 683, 380, 6996, 268, 1824, 1508, 246, 224, 2889, 905, 359, 1, 10287],
#  [10288, 747, 2155, 47, 47, 233, 1, 10289],
#  [4025, 45, 868, 383, 440, 46, 4026, 507],
#  [5567, 6997, 981, 4654, 48, 4027, 112, 180, 10290, 1, 10291, 23, 25, 3],
#  [2863,
#   1241,
#   5568,
#   1241,
#   3554,
#   1241,
#   6998,
#   1241,
#   717,
#   221,
#   78,
#   1241,
#   1,
#   10292],
#  [2656, 65, 3176, 21, 17, 18, 38, 19, 1, 10293],
#  [1010,
#   1010,
#   981,
#   1634,
#   1825,
#   358,
#   58,
#   1010,
#   53,
#   10294,
#   10295,
#   12,
#   19,
#   6,
#   27,
#   254,
#   1,
#   10296,
#   11,
#   16,
#   3],
#  [2, 1162, 476, 10297, 2064, 1, 10298, 3, 4, 11],
#  [3177, 2890, 110, 335, 189, 11, 10299, 6999, 1, 10300],
#  [245, 1731, 664, 3555, 10301, 1933, 440, 869, 1, 10302],
#  [78,
#   121,
#   37,
#   14,
#   376,
#   285,
#   62,
#   15,
#   576,
#   465,
#   162,
#   1589,
#   418,
#   30,
#   176,
#   888,
#   1386,
#   50,
#   1114,
#   808,
#   162,
#   2,
#   46,
#   680,
#   166,
#   142,
#   7,
#   1,
#   5569,
#   1,
#   10303],
#  [7000, 10304, 565, 1447, 7001, 4, 4655, 1590, 1, 10305, 23, 9, 11],
#  [4656, 20, 21, 467, 3, 54, 1, 10306, 1, 10307],
#  [201, 201, 1, 10308],
#  [2065,
#   1010,
#   262,
#   1158,
#   4028,
#   7002,
#   401,
#   1448,
#   142,
#   7,
#   10309,
#   2066,
#   487,
#   1731,
#   10310,
#   10311,
#   1,
#   10312],
#  [536,
#   2156,
#   3178,
#   824,
#   600,
#   684,
#   1591,
#   341,
#   2891,
#   115,
#   243,
#   585,
#   303,
#   809,
#   1,
#   982,
#   9,
#   24],
#  [3179,
#   237,
#   588,
#   5,
#   4657,
#   5570,
#   218,
#   480,
#   1280,
#   582,
#   4658,
#   63,
#   1509,
#   5,
#   4657,
#   1826,
#   489,
#   1,
#   10313,
#   1,
#   10314],
#  [10315,
#   7003,
#   441,
#   966,
#   5,
#   373,
#   4659,
#   4029,
#   791,
#   3180,
#   4029,
#   413,
#   419,
#   2657,
#   1,
#   10316],
#  [1500, 2658, 1592, 1934, 433, 144, 89, 8, 1654, 112, 608, 983, 1, 10317],
#  [1593,
#   465,
#   62,
#   5571,
#   480,
#   216,
#   472,
#   1075,
#   4660,
#   5572,
#   115,
#   243,
#   585,
#   303,
#   809,
#   824,
#   1,
#   1732,
#   9,
#   24],
#  [7004, 10318, 4661, 2309],
#  [7005, 7006, 889, 54, 30, 1, 10319],
#  [312,
#   1109,
#   1238,
#   4662,
#   567,
#   696,
#   197,
#   2892,
#   1935,
#   286,
#   660,
#   74,
#   211,
#   100,
#   3556,
#   1,
#   10320],
#  [1733,
#   3557,
#   3558,
#   3181,
#   4663,
#   2157,
#   307,
#   1895,
#   1038,
#   10321,
#   187,
#   355,
#   1294,
#   531,
#   7007,
#   3559,
#   2659,
#   429,
#   355,
#   1,
#   10322],
#  [1734,
#   1333,
#   120,
#   5,
#   2660,
#   2661,
#   7008,
#   202,
#   7008,
#   313,
#   1651,
#   1,
#   10323,
#   1,
#   10324],
#  [10325, 10326, 193, 37, 193, 125, 1655, 4030, 1197, 4, 445, 185, 2467],
#  [1387,
#   3560,
#   21,
#   3182,
#   2,
#   1902,
#   17,
#   1827,
#   621,
#   446,
#   2310,
#   3153,
#   10327,
#   1,
#   10328,
#   1,
#   10329],
#  [1804, 3183, 870, 17, 18, 6, 158, 128, 27, 1, 10330, 1, 10331],
#  [530, 144, 89, 157, 485, 1, 10332, 16, 3, 11],
#  [102,
#   13,
#   36,
#   1656,
#   7009,
#   8,
#   1657,
#   1163,
#   336,
#   9,
#   977,
#   248,
#   4664,
#   5573,
#   286,
#   1295,
#   88,
#   124,
#   2311,
#   1735,
#   4031,
#   15,
#   5574,
#   1,
#   10333],
#  [387,
#   3,
#   350,
#   312,
#   110,
#   1011,
#   5575,
#   10334,
#   10335,
#   136,
#   301,
#   1658,
#   912,
#   10336,
#   63,
#   273,
#   3151,
#   375,
#   3184,
#   10337,
#   542,
#   1936,
#   1,
#   10338],
#  [500, 11, 167, 119, 773, 566, 7, 125, 1, 10339],
#  [1334,
#   1589,
#   131,
#   1937,
#   1938,
#   552,
#   2148,
#   380,
#   124,
#   7010,
#   1939,
#   564,
#   1594,
#   1,
#   10340],
#  [3185, 2312, 2893, 10341, 259, 308, 1, 10342, 1, 10343],
#  [10344, 7011, 257, 111, 1296, 2894, 1, 10345, 25, 4, 9],
#  [29, 118, 2, 248, 160, 1012, 26, 42, 100, 1, 10346],
#  [391, 10347, 7012, 194, 568, 173, 1439, 1, 10348],
#  [10349, 10350, 71, 12, 44, 366, 83, 439, 1, 10351],
#  [2067, 283, 882, 3186, 5576, 2868, 10352, 10353, 5, 689, 57, 732, 1, 10354],
#  [105, 1510, 432, 10355, 2158, 3, 1, 10356],
#  [108, 913, 289, 10, 10, 1149, 12, 271, 12, 1, 10357, 1, 10358],
#  [7013,
#   4665,
#   158,
#   134,
#   75,
#   533,
#   22,
#   1823,
#   7014,
#   5577,
#   10359,
#   1382,
#   1447,
#   3187,
#   10360,
#   6983,
#   1,
#   10361,
#   1,
#   10362],
#  [45, 14, 800, 22, 10363, 266, 311, 868, 124, 94, 835, 1, 10364],
#  [3188, 4666, 111, 358, 149, 5578, 2468, 48],
#  [846, 433, 4, 14, 1164, 650, 173, 15, 77, 825, 14, 650, 77, 825, 650, 826],
#  [10365,
#   1184,
#   72,
#   462,
#   639,
#   1388,
#   564,
#   10366,
#   10367,
#   564,
#   1827,
#   531,
#   10368,
#   10369,
#   335,
#   842,
#   501,
#   7015,
#   295,
#   865,
#   10370,
#   1,
#   10371,
#   1,
#   10372],
#  [4032, 227, 497, 2469, 515, 1511, 1388, 2068, 2159, 83, 1297, 281, 1, 10373],
#  [10374, 7016, 640, 360, 5579, 1640, 308, 10375, 1, 10376, 1, 10377],
#  [2069,
#   2662,
#   7017,
#   1940,
#   1298,
#   2069,
#   638,
#   26,
#   605,
#   16,
#   39,
#   1717,
#   914,
#   39,
#   353,
#   1,
#   10378],
#  [2470, 37, 7018, 78, 323, 41, 2297],
#  [2160,
#   728,
#   7019,
#   4667,
#   142,
#   70,
#   2161,
#   72,
#   76,
#   1828,
#   45,
#   55,
#   20,
#   7020,
#   33,
#   7,
#   123,
#   1,
#   10379],
#  [810, 533, 114, 668, 5580, 5580, 1829, 1, 10380, 1, 10381],
#  [508, 7, 454, 1199, 1, 10382],
#  [32,
#   104,
#   1512,
#   427,
#   481,
#   697,
#   505,
#   146,
#   7021,
#   1389,
#   2646,
#   474,
#   237,
#   5581,
#   283,
#   552,
#   1,
#   10383],
#  [10384,
#   10385,
#   544,
#   714,
#   845,
#   3189,
#   2443,
#   249,
#   4668,
#   4669,
#   324,
#   2649,
#   811,
#   1,
#   10386],
#  [298, 3561, 395, 78, 1, 10387],
#  [1941, 1200, 1595, 99],
#  [46, 181, 457, 10, 310, 1659, 5, 7, 37, 130, 39, 1, 10388, 2895, 1, 10389],
#  [2, 214, 7022, 218, 14, 183, 1037, 302, 106, 225],
#  [3521, 7023, 236, 7, 50, 19, 1, 10390, 1, 10391],
#  [4670, 453, 846, 1, 10392],
#  [2070, 827, 103, 45, 17, 18, 7024, 4671, 2658, 137, 1, 10393],
#  [2896, 3562, 110, 414, 1, 10394],
#  [2897, 2897, 200, 10395, 10396, 10397, 5, 53, 10398, 1, 10399],
#  [4033, 1830, 1290],
#  [10400,
#   7025,
#   326,
#   349,
#   2,
#   506,
#   2162,
#   2898,
#   212,
#   10401,
#   4672,
#   510,
#   1660,
#   23,
#   385,
#   350,
#   81,
#   1,
#   10402],
#  [415, 512, 6978, 112, 13, 238, 1, 10403],
#  [684, 536, 251, 414, 1390, 2313, 444, 1, 10404, 4, 3, 9],
#  [779, 7026, 33, 52, 2663, 192, 401, 1, 10405, 1, 10406],
#  [493, 218, 3563, 3190, 1108, 1661, 2163, 69],
#  [10407, 2899],
#  [10408, 7027, 2306],
#  [7028,
#   65,
#   10409,
#   651,
#   7028,
#   1118,
#   257,
#   446,
#   169,
#   72,
#   4673,
#   1662,
#   90,
#   550,
#   1,
#   10410],
#  [3191, 4674, 5582, 10411, 5582, 3191, 317, 727, 847, 1, 10412],
#  [7029,
#   65,
#   10413,
#   516,
#   7029,
#   21,
#   409,
#   540,
#   10414,
#   129,
#   601,
#   4034,
#   7030,
#   550,
#   1,
#   10415],
#  [5583, 4675, 335, 1119, 555, 7031, 7032, 10416, 111, 1, 10417],
#  [1104, 930, 10418, 33, 3989, 1513, 1906, 1, 10419],
#  [1242,
#   1391,
#   10420,
#   10421,
#   10422,
#   10423,
#   2284,
#   2664,
#   1663,
#   126,
#   210,
#   2471,
#   82,
#   698,
#   358,
#   22,
#   1,
#   10424],
#  [549, 2665, 974, 5584, 387, 1662, 3564, 489, 4676, 497, 4035, 4036, 1, 10425],
#  [7033, 666, 30, 414, 121, 50, 1392, 4677, 1736, 197, 2472, 2, 609, 1, 10426],
#  [10427, 121, 37, 810, 3565, 7034, 905, 1243, 46, 1, 10428],
#  [3, 484, 1045, 1378, 1906, 182, 163, 1, 10429],
#  [10430, 2458, 905, 527, 1393, 7035, 4037, 1, 10431, 1, 10432],
#  [349, 92, 109, 484, 1596, 848, 146, 741, 5585, 780],
#  [2314,
#   22,
#   652,
#   562,
#   380,
#   129,
#   393,
#   252,
#   7036,
#   2315,
#   22,
#   896,
#   653,
#   4038,
#   4039,
#   349,
#   239,
#   3192,
#   2148,
#   1,
#   10433],
#  [3566,
#   3567,
#   28,
#   3568,
#   932,
#   480,
#   206,
#   1072,
#   304,
#   85,
#   21,
#   1013,
#   206,
#   459,
#   226,
#   984,
#   2900,
#   516,
#   58,
#   2666,
#   31,
#   1,
#   10434,
#   1,
#   10435],
#  [2042,
#   5586,
#   927,
#   2164,
#   748,
#   2901,
#   718,
#   73,
#   56,
#   305,
#   806,
#   13,
#   5587,
#   10436,
#   554,
#   2902,
#   1014,
#   1,
#   10437],
#  [3193,
#   154,
#   551,
#   541,
#   4678,
#   1120,
#   1335,
#   798,
#   5,
#   316,
#   915,
#   1,
#   10438,
#   24,
#   23,
#   9],
#  [4679, 4680, 71, 12, 2667, 439, 366, 1, 10439],
#  [10440,
#   675,
#   1446,
#   5588,
#   3569,
#   2316,
#   584,
#   1831,
#   11,
#   10441,
#   489,
#   90,
#   112,
#   119,
#   10442,
#   2316,
#   2473,
#   41,
#   7,
#   1,
#   10443,
#   1,
#   10444],
#  [493,
#   218,
#   73,
#   515,
#   45,
#   66,
#   116,
#   311,
#   494,
#   36,
#   94,
#   1433,
#   2474,
#   4681,
#   1,
#   10445],
#  [520, 293, 801, 413, 478, 1046, 10446, 1, 10447],
#  [29, 299, 1508, 246, 224, 1151, 495, 1597, 1, 10448],
#  [2,
#   391,
#   649,
#   1942,
#   1015,
#   2071,
#   1242,
#   2165,
#   423,
#   1197,
#   350,
#   15,
#   2317,
#   81,
#   1598,
#   4682,
#   3194,
#   4683,
#   1,
#   10449],
#  [2903,
#   65,
#   4684,
#   3195,
#   47,
#   12,
#   174,
#   1196,
#   48,
#   682,
#   11,
#   363,
#   167,
#   1737,
#   4685,
#   1,
#   10450],
#  [5,
#   316,
#   283,
#   3570,
#   2145,
#   2904,
#   1121,
#   76,
#   2668,
#   10451,
#   5589,
#   2669,
#   3196,
#   125,
#   326,
#   1437,
#   1,
#   10452],
#  [2136, 464, 364, 3, 67, 916, 6, 772, 119, 1738, 1, 10453, 23, 16, 9],
#  [203, 934, 1323, 1244, 103, 4686, 13, 1, 10454, 1, 10455],
#  [10456, 10457, 2166, 10458, 1, 10459, 23, 3, 16],
#  [4028,
#   3571,
#   28,
#   7037,
#   10460,
#   10461,
#   28,
#   1,
#   1394,
#   335,
#   10462,
#   3153,
#   4687,
#   2,
#   1,
#   10463,
#   1,
#   10464],
#  [710, 871, 4, 262, 1016, 25, 26, 103, 483, 1, 10465, 1, 10466],
#  [2318, 4040, 3, 765, 306, 61, 260, 639, 188, 81, 1, 10467],
#  [10468, 176, 261, 146, 97, 54, 1, 10469],
#  [345, 1016, 7038, 7039, 707, 1, 10470],
#  [32, 5590, 430, 7040, 110, 1510, 52, 524, 2319, 70, 1, 10471],
#  [26,
#   42,
#   100,
#   1297,
#   14,
#   2167,
#   897,
#   914,
#   39,
#   1237,
#   2670,
#   14,
#   557,
#   179,
#   7,
#   37,
#   4041,
#   10,
#   15,
#   1,
#   10472],
#  [773,
#   4688,
#   781,
#   2072,
#   4689,
#   1832,
#   42,
#   4042,
#   4014,
#   733,
#   917,
#   1076,
#   178,
#   368,
#   133,
#   849,
#   133,
#   76,
#   7041,
#   1739,
#   1514],
#  [385,
#   109,
#   666,
#   29,
#   408,
#   26,
#   42,
#   610,
#   212,
#   7,
#   142,
#   286,
#   1449,
#   2671,
#   1909,
#   3572,
#   5591,
#   3139,
#   1833,
#   74,
#   3197,
#   1,
#   10473,
#   57,
#   4690],
#  [1165, 949, 89, 812, 1664, 20, 234, 1, 10474],
#  [18, 176, 4691, 8, 67, 261, 314, 41, 7042, 641, 14, 1515, 121, 166, 1, 10475],
#  [10476,
#   441,
#   111,
#   4665,
#   4692,
#   10477,
#   556,
#   118,
#   137,
#   7,
#   7,
#   1200,
#   33,
#   195,
#   952,
#   37,
#   14,
#   51,
#   60,
#   101,
#   62,
#   15,
#   376,
#   2905,
#   74,
#   834,
#   1,
#   10478,
#   1,
#   10479],
#  [654,
#   5592,
#   3573,
#   2901,
#   211,
#   10480,
#   10481,
#   7043,
#   286,
#   10482,
#   5593,
#   1384,
#   3574,
#   7044,
#   827,
#   4,
#   1,
#   10483],
#  [10484, 3575, 130, 35, 37],
#  [3563,
#   10485,
#   932,
#   1816,
#   31,
#   459,
#   226,
#   347,
#   1069,
#   984,
#   10486,
#   127,
#   58,
#   7045,
#   31,
#   744,
#   31,
#   634,
#   85,
#   138,
#   1,
#   10487,
#   1,
#   10488],
#  [78, 3576, 50, 317, 122, 207, 10489, 252, 50, 669, 271, 14, 124, 1, 10490],
#  [7005, 7006, 804, 4693, 10491, 2320, 4694, 10492, 1, 10493],
#  [2,
#   5576,
#   4695,
#   68,
#   447,
#   4,
#   665,
#   3198,
#   3577,
#   2321,
#   417,
#   10,
#   414,
#   296,
#   113,
#   1,
#   10494],
#  [344,
#   898,
#   728,
#   4696,
#   1516,
#   4043,
#   115,
#   243,
#   585,
#   303,
#   809,
#   824,
#   1,
#   982,
#   9,
#   24],
#  [306, 53, 1656, 3199, 8, 10, 2906, 3578, 34, 9, 1, 10495],
#  [1493, 400, 68, 2475, 389, 250, 241, 2073, 729, 1005, 634, 3579, 10496],
#  [2672,
#   262,
#   76,
#   552,
#   915,
#   551,
#   4044,
#   1245,
#   379,
#   495,
#   918,
#   32,
#   104,
#   38,
#   42,
#   687,
#   1,
#   10497],
#  [2,
#   36,
#   435,
#   94,
#   2168,
#   117,
#   109,
#   7046,
#   7047,
#   168,
#   1450,
#   4045,
#   450,
#   5594,
#   730,
#   400,
#   1943,
#   579,
#   1108,
#   1808,
#   848,
#   1597,
#   1,
#   10498],
#  [10499, 2322, 4007, 81, 813, 31, 1, 10500],
#  [2074, 122, 14, 183, 434, 7, 388, 336, 182, 100, 123, 1, 10501, 1, 10502],
#  [2673, 3580, 551, 281, 152, 36, 94, 2864, 138, 1, 10503, 5595, 1, 10504],
#  [510, 465, 298, 171, 2, 257, 4, 728, 41, 114, 985, 5596, 1, 10505],
#  [5597, 1517, 188, 5598, 64, 97, 389, 287, 402, 30, 1, 10506, 1, 10507],
#  [2907, 10508, 2151, 611, 1122, 4697, 1651, 13, 1, 10509, 1, 10510],
#  [4698,
#   1071,
#   2476,
#   2908,
#   635,
#   325,
#   599,
#   4046,
#   2896,
#   589,
#   41,
#   117,
#   109,
#   1,
#   10511],
#  [5599,
#   714,
#   487,
#   1944,
#   153,
#   2323,
#   1066,
#   455,
#   2674,
#   2675,
#   28,
#   2676,
#   986,
#   2873,
#   300,
#   308,
#   5599,
#   714,
#   58,
#   5600,
#   1,
#   10512,
#   1,
#   10513],
#  [115, 303, 883, 135, 381, 1017, 4699, 5601, 2, 61, 1574, 1, 10514],
#  [1299, 318, 119, 3549, 177, 575, 605],
#  [1945, 2477, 7048, 1945, 255, 596, 122, 127, 499, 3200, 120, 826, 1, 10515],
#  [7049,
#   7050,
#   21,
#   238,
#   5602,
#   10516,
#   10517,
#   1077,
#   4047,
#   136,
#   571,
#   300,
#   1,
#   10518],
#  [2169,
#   270,
#   112,
#   5,
#   202,
#   4700,
#   3581,
#   10519,
#   10520,
#   882,
#   915,
#   2169,
#   123,
#   7,
#   1395,
#   96,
#   85,
#   1,
#   10521],
#  [7051, 5603, 58, 182, 31, 642, 618, 697, 1, 10522],
#  [10523,
#   5604,
#   1440,
#   8,
#   2324,
#   10524,
#   297,
#   39,
#   10525,
#   1078,
#   7052,
#   1079,
#   400,
#   1033,
#   57,
#   676,
#   1,
#   10526],
#  [866,
#   3201,
#   163,
#   323,
#   1396,
#   190,
#   150,
#   484,
#   473,
#   734,
#   1513,
#   477,
#   4,
#   2325,
#   749,
#   2326],
#  [2327,
#   1120,
#   3202,
#   120,
#   26,
#   142,
#   7053,
#   595,
#   1946,
#   387,
#   10527,
#   272,
#   1,
#   10528,
#   1,
#   10529],
#  [10530, 5605, 96, 158, 3582, 33, 1115, 7054, 361, 1034, 20, 1947, 1, 10531],
#  [7055, 4701, 7056, 453, 297, 4702, 1, 10532],
#  [2,
#   282,
#   3203,
#   251,
#   170,
#   254,
#   2328,
#   4003,
#   10533,
#   10534,
#   7057,
#   7,
#   723,
#   5606,
#   393,
#   569,
#   10535,
#   1,
#   10536],
#  [7058, 7058, 192, 474, 4703, 57, 30, 529, 1, 10537],
#  [1518, 1518, 118, 97, 54, 1, 10538],
#  [2, 3, 119, 1336, 4048, 221, 265, 7059, 98, 342, 1, 10539],
#  [436, 7060, 535, 1123, 10540, 92, 249, 1325, 1577, 759, 1, 10541],
#  [188,
#   766,
#   906,
#   15,
#   542,
#   7061,
#   39,
#   557,
#   46,
#   558,
#   652,
#   15,
#   100,
#   46,
#   116,
#   896,
#   188,
#   1834,
#   1,
#   10542,
#   1,
#   10543],
#  [256, 8, 72, 1237, 643, 117, 49, 1, 10544],
#  [187,
#   1565,
#   2329,
#   7062,
#   7063,
#   2,
#   247,
#   319,
#   4049,
#   1519,
#   675,
#   2677,
#   2909,
#   11,
#   767,
#   307,
#   1,
#   10545,
#   1,
#   10546],
#  [80,
#   1185,
#   1004,
#   818,
#   511,
#   1201,
#   2322,
#   81,
#   677,
#   1163,
#   10547,
#   60,
#   833,
#   177,
#   122,
#   1,
#   10548],
#  [206,
#   2678,
#   158,
#   5,
#   5607,
#   3583,
#   1451,
#   1948,
#   828,
#   4704,
#   1187,
#   476,
#   574,
#   7064,
#   1,
#   10549,
#   1,
#   10550],
#  [69, 750, 263, 139, 987, 131, 34, 4, 10551, 2478, 7065],
#  [2075, 97, 337, 417, 54, 1, 10552, 1, 10553],
#  [7066, 7067, 7068, 1337, 4050, 169, 725, 3204, 165, 93, 1035, 4051, 1, 10554],
#  [3518,
#   4592,
#   96,
#   4592,
#   2330,
#   28,
#   1325,
#   442,
#   7069,
#   10555,
#   2679,
#   3202,
#   1,
#   10556],
#  [1374, 2479, 930, 313, 3581, 10557, 10558, 390, 36, 1, 10559, 1, 10560],
#  [2,
#   956,
#   1047,
#   580,
#   518,
#   214,
#   95,
#   214,
#   214,
#   2,
#   1939,
#   580,
#   518,
#   214,
#   95,
#   214,
#   214],
#  [153, 631, 8, 422, 3584, 154, 20, 694, 7, 140, 719, 1, 10561],
#  [850, 59, 1599, 21, 10562, 10563, 36, 1, 10564, 1, 10565],
#  [10566,
#   34,
#   384,
#   28,
#   2480,
#   209,
#   7070,
#   622,
#   5,
#   110,
#   5608,
#   112,
#   1,
#   10567,
#   1,
#   10568],
#  [5609, 458, 329, 21, 337, 54, 467, 30, 1, 10569, 1, 10570],
#  [1600,
#   246,
#   72,
#   105,
#   1452,
#   580,
#   2,
#   2331,
#   838,
#   10571,
#   10572,
#   2076,
#   152,
#   919,
#   42,
#   131,
#   443,
#   1,
#   10573],
#  [155, 150, 71, 508, 437, 48, 314, 369],
#  [26, 329, 34, 64, 492, 32, 260, 269, 279, 165, 250, 1, 10574, 1, 10575],
#  [4705, 648, 17, 18, 19, 128, 27, 1, 10576, 1, 10577],
#  [139,
#   1598,
#   1246,
#   304,
#   2865,
#   759,
#   36,
#   3585,
#   4706,
#   113,
#   206,
#   136,
#   2680,
#   63,
#   1453,
#   3988,
#   1835,
#   935,
#   10578,
#   2910,
#   132,
#   135,
#   1,
#   7071,
#   1,
#   10579],
#  [2481,
#   2481,
#   2170,
#   2681,
#   2911,
#   949,
#   529,
#   865,
#   2912,
#   2170,
#   4052,
#   7072,
#   5610,
#   1,
#   10580],
#  [32,
#   1324,
#   353,
#   380,
#   187,
#   829,
#   162,
#   26,
#   236,
#   4707,
#   229,
#   323,
#   446,
#   82,
#   56,
#   286,
#   141,
#   224,
#   524,
#   1,
#   10581],
#  [10582,
#   56,
#   10583,
#   198,
#   800,
#   2913,
#   395,
#   200,
#   150,
#   133,
#   612,
#   346,
#   50,
#   137,
#   1601,
#   1,
#   10584],
#  [176, 7073, 70, 67, 162, 652, 15, 100, 239, 252, 5611, 22, 1, 10585],
#  [2332,
#   10586,
#   410,
#   195,
#   1324,
#   3586,
#   143,
#   17,
#   18,
#   2042,
#   204,
#   801,
#   10587,
#   9,
#   57,
#   338,
#   1,
#   10588],
#  [2639, 2141, 2142, 10589, 7074, 763, 3587, 3588, 7075, 1, 10590],
#  [28, 12, 6, 457, 10591, 571, 78, 1, 10592, 9, 4, 11],
#  [868,
#   91,
#   899,
#   848,
#   741,
#   126,
#   2914,
#   41,
#   35,
#   1331,
#   1810,
#   296,
#   107,
#   642,
#   851,
#   1520,
#   3205,
#   198,
#   83,
#   146,
#   14,
#   1,
#   10593],
#  [464,
#   134,
#   1236,
#   4708,
#   7076,
#   176,
#   1733,
#   2915,
#   2682,
#   1513,
#   1080,
#   440,
#   869,
#   917,
#   424,
#   247,
#   4708,
#   3587,
#   428,
#   495,
#   7077,
#   4708,
#   176,
#   93,
#   1,
#   3206,
#   1,
#   10594],
#  [1454, 104, 76, 408, 698, 13, 41, 35, 513, 735, 5, 1397, 137, 229, 1, 10595],
#  [2, 40, 3207, 279, 178, 185, 1166, 531, 3589, 302, 59, 106, 59, 225],
#  [7078, 1440, 120, 41, 689, 123, 123, 11, 4053, 196, 1, 10596, 1, 10597],
#  [1108, 203, 328, 5585, 41, 479, 848, 356],
#  [3193, 10598, 2683, 4678, 1120, 3, 1455, 17, 49, 16, 1, 10599],
#  [4709, 5612, 714, 67, 98, 67, 54, 1, 10600, 24, 16, 4],
#  [220, 30, 4710, 881, 37, 130],
#  [10601, 22, 17, 18, 38, 19, 138, 1, 10602, 1, 10603],
#  [592, 501, 153, 850, 28, 850, 136, 5613, 259, 1, 10604, 1, 10605],
#  [3208, 200, 10606, 10607, 7079, 285, 7080, 953, 1, 10608, 1, 10609],
#  [1521, 782, 436, 222, 360, 148, 79, 205, 44, 59, 47, 1, 10610],
#  [4711,
#   1300,
#   750,
#   623,
#   4054,
#   690,
#   1301,
#   1501,
#   486,
#   107,
#   55,
#   211,
#   36,
#   7081,
#   7082,
#   2684,
#   7083,
#   8,
#   1,
#   10611],
#  [298, 5614, 3, 4, 680, 166, 39, 1, 10612],
#  [2, 391, 1247, 2461, 100, 1302, 1, 10613],
#  [290, 2171, 69, 2482, 4055, 91, 107, 66, 55, 8, 294, 237, 33, 759, 1, 10614],
#  [7084, 588, 3209, 5615, 1, 10615, 1, 10616],
#  [2, 410, 868, 160, 46, 26, 42, 7, 1, 10617],
#  [157, 35, 37, 155, 35, 37, 5616, 4712, 3193, 131, 484, 190],
#  [203, 913, 546, 692, 604, 1596, 3210],
#  [255,
#   478,
#   117,
#   109,
#   520,
#   293,
#   8,
#   750,
#   5617,
#   2685,
#   1046,
#   1836,
#   495,
#   211,
#   2916,
#   4713,
#   113,
#   918,
#   1,
#   10618,
#   1,
#   10619],
#  [10620,
#   4034,
#   1740,
#   5618,
#   5619,
#   196,
#   10621,
#   420,
#   7085,
#   37,
#   206,
#   632,
#   451,
#   1,
#   10622,
#   1,
#   10623],
#  [10624, 38, 58, 210, 292, 18, 6, 648, 128, 27, 86, 1, 10625, 1, 10626],
#  [10627, 2633, 50, 43, 929, 541, 10628, 1, 10629],
#  [1602, 26, 3211, 1654, 1018, 2333, 1597, 547, 69, 1, 10630],
#  [7086, 7087, 47, 47, 233, 904, 12, 79, 439, 233, 439, 904, 363, 79, 1, 10631],
#  [71, 41, 35, 2686, 939, 1, 10632],
#  [3566,
#   3567,
#   28,
#   3568,
#   932,
#   480,
#   206,
#   1072,
#   304,
#   85,
#   21,
#   487,
#   1338,
#   28,
#   96,
#   52,
#   58,
#   3590,
#   984,
#   31,
#   1,
#   10633,
#   1,
#   10634],
#  [7088, 7089, 148, 79, 44, 1, 10635],
#  [10636, 10637, 751, 687, 12, 156, 19, 1, 10638],
#  [2917, 2917, 535, 583, 12, 156, 219, 135, 1, 10639],
#  [1949, 1837, 10640, 217, 2918, 10641, 849, 10642, 852, 10643, 1, 10644],
#  [2687, 205, 47, 233, 135, 219, 21, 30, 1339, 361],
#  [10645,
#   284,
#   4714,
#   549,
#   1340,
#   4056,
#   10646,
#   4057,
#   7090,
#   4715,
#   165,
#   531,
#   1905,
#   4052,
#   53,
#   7091,
#   10647,
#   453,
#   2,
#   4716,
#   1,
#   10648],
#  [872, 7092, 148, 79, 44, 1, 10649],
#  [341, 123, 61, 760, 3, 1913, 699, 353, 1, 10650],
#  [29,
#   63,
#   1838,
#   4058,
#   64,
#   7,
#   2483,
#   33,
#   3,
#   17,
#   18,
#   979,
#   2688,
#   299,
#   200,
#   510,
#   5620,
#   451,
#   1,
#   10651],
#  [93, 1227, 10652, 385, 13, 638, 935, 69, 1103, 1341, 603, 1, 10653],
#  [10654, 1121, 2919, 1398, 22, 5621, 697, 10655, 52, 1, 10656, 1, 10657],
#  [10658, 7093, 4059, 5622, 601, 19, 10659, 483, 5623, 10660, 15, 1, 10661],
#  [10662, 1124, 5624, 169, 716, 137, 127, 172, 1, 10663, 1, 10664],
#  [10665, 10666, 33, 761, 92, 405, 5625, 10667, 717, 1, 10668, 16, 25, 3],
#  [2, 3591, 51, 11, 167, 518, 95, 184],
#  [375,
#   675,
#   2,
#   55,
#   14,
#   700,
#   5626,
#   56,
#   141,
#   1665,
#   742,
#   116,
#   228,
#   2658,
#   2484,
#   353,
#   1,
#   10669],
#  [349,
#   40,
#   673,
#   4717,
#   251,
#   1037,
#   302,
#   106,
#   225,
#   95,
#   349,
#   40,
#   673,
#   4717,
#   251,
#   1399,
#   302,
#   106,
#   225,
#   95],
#  [153,
#   32,
#   1741,
#   783,
#   590,
#   385,
#   649,
#   758,
#   659,
#   99,
#   370,
#   790,
#   473,
#   565,
#   238,
#   988,
#   1189,
#   400,
#   1,
#   10670],
#  [1835,
#   187,
#   1731,
#   7094,
#   7095,
#   2485,
#   1069,
#   5,
#   347,
#   1342,
#   443,
#   497,
#   450,
#   1,
#   10671],
#  [10672,
#   10673,
#   7096,
#   7097,
#   655,
#   37,
#   81,
#   1456,
#   3574,
#   7098,
#   7096,
#   152,
#   309,
#   351,
#   7097],
#  [243,
#   115,
#   1603,
#   2920,
#   731,
#   713,
#   1666,
#   2921,
#   2061,
#   853,
#   288,
#   71,
#   3212,
#   781,
#   41,
#   390,
#   173,
#   1950,
#   7099,
#   1582,
#   2689,
#   3213,
#   972,
#   1107,
#   3214,
#   51,
#   1950,
#   472,
#   5627,
#   1604,
#   593,
#   371,
#   1605,
#   4718,
#   1303,
#   1,
#   10674],
#  [189,
#   55,
#   452,
#   559,
#   10675,
#   166,
#   198,
#   665,
#   1400,
#   244,
#   48,
#   107,
#   60,
#   160,
#   2922,
#   130,
#   18,
#   1009,
#   26,
#   18,
#   306,
#   490,
#   136,
#   548,
#   440,
#   10676,
#   73,
#   1,
#   10677],
#  [32, 10678, 2690, 15, 186, 184, 32, 1047, 580, 307, 186, 214, 1304, 214],
#  [2, 181, 1037, 186, 302, 106, 225, 95],
#  [170, 183, 1821, 193, 14, 3592, 7100, 60, 1343, 10, 554, 1, 10679],
#  [3593,
#   51,
#   36,
#   2878,
#   1667,
#   2923,
#   485,
#   114,
#   103,
#   80,
#   13,
#   180,
#   101,
#   62,
#   15,
#   496,
#   39,
#   419,
#   116,
#   396,
#   61,
#   46,
#   1,
#   10680],
#  [1190, 13, 228, 116, 337, 54, 30, 30, 1, 10681],
#  [5628, 7101, 662, 746, 1441, 1, 10682, 24, 25, 9],
#  [347, 3594, 221, 1522, 3215, 221, 246, 1, 10683, 1, 10684],
#  [78,
#   275,
#   174,
#   1067,
#   193,
#   13,
#   3,
#   5629,
#   388,
#   182,
#   221,
#   30,
#   412,
#   22,
#   917,
#   20,
#   76,
#   677,
#   519,
#   327,
#   48,
#   41,
#   7,
#   1,
#   10685,
#   593,
#   1,
#   10686],
#  [5630, 1016, 25, 1, 10687, 1, 10688],
#  [371, 256, 22, 117, 49, 141, 117, 49, 939, 752, 1, 10689],
#  [2486, 65, 3595, 38, 12, 6, 63, 439, 122, 327, 469, 491, 1, 10690],
#  [7102,
#   200,
#   382,
#   1167,
#   2888,
#   10691,
#   7103,
#   10692,
#   259,
#   308,
#   1,
#   10693,
#   1,
#   10694],
#  [975, 1839, 5, 20, 200, 1187, 1668, 764, 1, 10695],
#  [5631, 1669, 3216, 1951, 482, 647, 129, 7104, 1048, 2051, 1, 10696, 1, 10697],
#  [1081,
#   455,
#   873,
#   1081,
#   1325,
#   1394,
#   2,
#   2039,
#   597,
#   608,
#   261,
#   314,
#   710,
#   1,
#   10698],
#  [51,
#   152,
#   180,
#   1202,
#   778,
#   1742,
#   101,
#   62,
#   15,
#   231,
#   41,
#   7,
#   549,
#   10,
#   1457,
#   71,
#   2906,
#   3578,
#   2,
#   1,
#   10699],
#  [2691,
#   1458,
#   30,
#   3549,
#   177,
#   362,
#   22,
#   1,
#   2035,
#   377,
#   957,
#   70,
#   4719,
#   646,
#   43,
#   130],
#  [5632,
#   5632,
#   2334,
#   5632,
#   5633,
#   10700,
#   52,
#   118,
#   10701,
#   1459,
#   30,
#   190,
#   2894,
#   1,
#   10702,
#   11,
#   4,
#   25],
#  [1523,
#   493,
#   218,
#   935,
#   1281,
#   1168,
#   7105,
#   245,
#   2335,
#   365,
#   1072,
#   4060,
#   580,
#   7106,
#   10703,
#   264,
#   7107,
#   10704,
#   617,
#   4061,
#   2172,
#   82,
#   440,
#   869,
#   3596,
#   1,
#   10705],
#  [5634, 1392, 196, 197, 2687, 382, 549, 75, 768, 1, 10706, 1, 10707],
#  [1952,
#   697,
#   5635,
#   277,
#   352,
#   28,
#   84,
#   7108,
#   49,
#   1953,
#   183,
#   3212,
#   424,
#   35,
#   100,
#   46,
#   125,
#   287,
#   49,
#   28,
#   84,
#   352,
#   243,
#   115,
#   1,
#   10708],
#  [10709, 1082, 10710, 229, 774, 240, 97, 389, 287, 1, 10711],
#  [5636, 5637, 1394, 7109, 32, 597, 1099, 4720, 483, 4062, 172, 1, 10712],
#  [10713, 164, 1125, 2173, 255, 1239, 2924, 71, 469, 323, 1203, 2336],
#  [10, 187, 328, 2, 1499, 1111, 4063, 624, 7, 1083, 57, 1649, 1, 10714],
#  [4721, 4721, 360, 148, 79, 205, 44, 205, 101, 363, 4063, 219, 1, 10715],
#  [4722,
#   4723,
#   409,
#   792,
#   10716,
#   4724,
#   7110,
#   106,
#   882,
#   202,
#   7111,
#   4724,
#   3217,
#   4725,
#   1,
#   10717],
#  [3218, 45, 497, 7112, 67, 2, 506, 33, 1019, 85, 1, 10718],
#  [10719,
#   10720,
#   10721,
#   28,
#   1248,
#   932,
#   21,
#   206,
#   1072,
#   459,
#   226,
#   347,
#   1069,
#   2487,
#   933,
#   2925,
#   744,
#   31,
#   927,
#   177,
#   634,
#   85,
#   1,
#   10722,
#   1,
#   10723],
#  [45, 119, 820, 177, 2, 318, 160, 166, 1513, 14, 3597, 49, 69, 4017, 139],
#  [26, 1670, 7113, 3598, 158, 10724, 7052, 332, 1, 10725, 1, 10726],
#  [2077,
#   5638,
#   2337,
#   1049,
#   2077,
#   53,
#   4726,
#   10727,
#   12,
#   19,
#   6,
#   27,
#   254,
#   1,
#   10728,
#   3,
#   4,
#   23],
#  [10729, 10730, 5639, 793, 50, 189, 165, 777, 81, 1249, 940, 1, 10731],
#  [17,
#   10732,
#   651,
#   10733,
#   1524,
#   10734,
#   1394,
#   7114,
#   509,
#   844,
#   571,
#   1,
#   10735,
#   1,
#   10736],
#  [7115, 7115, 1401, 927, 1743, 2488, 1, 10737, 24, 3, 11],
#  [144, 89, 2174, 1020, 43, 157, 446, 2489, 753, 1840, 1671, 1, 10738],
#  [684, 65, 536, 2692, 5640, 251, 1344, 10739, 784, 1, 10740],
#  [7116, 1050, 920, 163, 553, 1038, 1, 10741],
#  [487,
#   1117,
#   1525,
#   304,
#   85,
#   744,
#   31,
#   2337,
#   1049,
#   177,
#   634,
#   85,
#   1,
#   10742,
#   1,
#   10743],
#  [7117, 120, 7117, 1195, 989, 462, 1, 10744, 1, 10745],
#  [144,
#   89,
#   1126,
#   67,
#   157,
#   2693,
#   4727,
#   575,
#   223,
#   399,
#   335,
#   5641,
#   5642,
#   10746,
#   356,
#   10747,
#   1,
#   10748,
#   1,
#   10749],
#  [2907, 5643, 2151, 256, 5644, 860, 1570, 812, 1084, 57, 1649, 1, 10750],
#  [5562, 134, 174, 47, 205, 233, 1460, 30, 1339, 12, 1, 10751],
#  [2694, 21, 2338, 4620, 278, 2339, 1, 10752, 1, 10753],
#  [28, 58, 12, 6, 1445, 79, 95, 44, 426, 95, 426],
#  [2,
#   747,
#   649,
#   4064,
#   2490,
#   513,
#   167,
#   4065,
#   281,
#   1018,
#   204,
#   597,
#   43,
#   3599,
#   4728,
#   577,
#   513,
#   1005,
#   105,
#   404,
#   4,
#   108,
#   171,
#   1,
#   10754,
#   1,
#   10755],
#  [3151,
#   4626,
#   2926,
#   4729,
#   190,
#   71,
#   14,
#   160,
#   2,
#   1297,
#   668,
#   130,
#   39,
#   82,
#   104,
#   75,
#   1288,
#   600,
#   1,
#   10756],
#  [7118, 87, 21, 1003, 529, 4730, 1, 10757, 1, 10758],
#  [493,
#   625,
#   3600,
#   2927,
#   4,
#   39,
#   10759,
#   1526,
#   765,
#   751,
#   14,
#   1444,
#   7119,
#   5645,
#   98,
#   754,
#   1,
#   10760],
#  [4731,
#   71,
#   246,
#   7120,
#   449,
#   3219,
#   4066,
#   742,
#   10,
#   319,
#   2928,
#   124,
#   6,
#   82,
#   5,
#   7015,
#   75,
#   1,
#   10761],
#  [2491, 3601, 411, 14, 5646, 3, 320, 1, 10762],
#  [2042,
#   2929,
#   534,
#   37,
#   125,
#   130,
#   142,
#   39,
#   295,
#   33,
#   195,
#   3602,
#   31,
#   2175,
#   1402,
#   1,
#   10763],
#  [1744, 822, 14, 226, 431, 65, 4],
#  [5647,
#   560,
#   88,
#   110,
#   242,
#   10,
#   1745,
#   7,
#   2176,
#   213,
#   617,
#   280,
#   406,
#   273,
#   1,
#   10764],
#  [7121, 5648, 317, 3179, 10765, 34, 20, 1, 10766, 1, 10767],
#  [5649, 1926, 199, 114, 180, 1201, 114, 1927, 149, 267, 99, 781, 1606],
#  [146, 874, 32, 495, 291, 378, 1202, 10768, 1, 10769],
#  [153,
#   1741,
#   783,
#   590,
#   110,
#   368,
#   589,
#   41,
#   117,
#   109,
#   423,
#   5650,
#   91,
#   229,
#   10,
#   549,
#   1,
#   10770],
#  [351,
#   921,
#   224,
#   524,
#   875,
#   3220,
#   2,
#   481,
#   772,
#   370,
#   814,
#   53,
#   7122,
#   7123,
#   1,
#   10771],
#  [2930,
#   480,
#   2695,
#   1021,
#   193,
#   275,
#   174,
#   797,
#   56,
#   7,
#   336,
#   257,
#   50,
#   7124,
#   1345,
#   10772,
#   1,
#   10773],
#  [1006, 890, 688, 20, 1527, 825, 217, 144, 89, 59, 626],
#  [1169, 141, 2696, 31, 746, 502, 179, 495, 1127, 1, 10774, 1, 10775],
#  [7125,
#   146,
#   5651,
#   2492,
#   92,
#   263,
#   3603,
#   3604,
#   979,
#   934,
#   1051,
#   607,
#   2493,
#   96,
#   1,
#   10776,
#   1,
#   10777],
#  [201, 201, 1, 10778],
#  [1128,
#   395,
#   105,
#   542,
# ...
#  [11257, 21, 17, 18, 1530, 19, 1, 11258, 1, 11259],
#  [11260, 2363, 63, 1834, 1565, 4804, 183, 17, 1355, 7, 1, 11261, 1, 11262],
#  [943,
#   631,
#   32,
#   85,
#   7219,
#   2718,
#   486,
#   693,
#   400,
#   41,
#   142,
#   7,
#   3658,
#   82,
#   5,
#   441,
#   1,
#   11263],
#  [11264, 52, 930, 11265, 4805, 386, 1, 11266, 1, 11267],
#  [11268, 723, 3632, 3260, 222, 97, 54, 1, 11269],
#  [78,
#   3659,
#   2364,
#   2293,
#   26,
#   42,
#   142,
#   7,
#   1386,
#   30,
#   1825,
#   85,
#   4806,
#   671,
#   1103,
#   2719,
#   660,
#   1413,
#   1214,
#   700,
#   102,
#   141,
#   11270,
#   1382,
#   1,
#   11271,
#   1,
#   11272],
#  [67,
#   246,
#   496,
#   497,
#   2091,
#   769,
#   2365,
#   43,
#   132,
#   639,
#   479,
#   246,
#   658,
#   2,
#   1,
#   11273],
#  [1204, 612, 37],
#  [45, 119, 820, 182, 1299, 318, 910],
#  [42, 67, 5730, 1, 11274],
#  [1193,
#   7220,
#   11275,
#   11276,
#   2357,
#   11277,
#   11278,
#   3660,
#   11279,
#   4807,
#   7221,
#   7222,
#   526,
#   4808,
#   11280,
#   685,
#   730,
#   5731,
#   4809,
#   3661,
#   7223,
#   4810,
#   11281,
#   4811,
#   1174,
#   4758,
#   1107,
#   5732,
#   7224,
#   5733,
#   11282,
#   11283,
#   5734,
#   2178,
#   71,
#   3543,
#   11284,
#   11285,
#   11286,
#   7225,
#   11287],
#  [2965, 37, 4812, 1396, 150, 7226, 5735, 623, 456],
#  [1682,
#   312,
#   102,
#   17,
#   141,
#   2876,
#   4121,
#   7227,
#   2454,
#   72,
#   7228,
#   1852,
#   86,
#   353,
#   72,
#   7,
#   388,
#   1,
#   11288],
#  [119, 135, 115, 243, 585, 1, 982, 9, 24],
#  [7229, 7229, 4122, 257, 4123, 2492, 1, 11289, 24, 16, 25],
#  [2891, 4813, 28, 4124, 106, 5736, 351, 54, 3, 1, 11290, 23, 4, 25],
#  [593, 1227, 91, 366, 221, 1130, 2183, 1853, 267, 1090, 67, 30, 1, 11291],
#  [78,
#   2,
#   3,
#   856,
#   1140,
#   182,
#   20,
#   2524,
#   103,
#   13,
#   1538,
#   6,
#   47,
#   289,
#   320,
#   4814,
#   31,
#   1894,
#   83,
#   10,
#   778,
#   51,
#   60,
#   5737,
#   733,
#   222,
#   1,
#   7230,
#   1,
#   11292],
#  [7231, 2720, 3271, 148, 79, 44, 1, 11293],
#  [4815, 5738, 97, 54, 1, 11294],
#  [1290,
#   174,
#   782,
#   436,
#   222,
#   19,
#   3641,
#   11295,
#   88,
#   559,
#   37,
#   4596,
#   124,
#   447,
#   143,
#   2366,
#   3272,
#   143,
#   3273,
#   150,
#   190,
#   265,
#   1,
#   11296],
#  [2169,
#   134,
#   808,
#   364,
#   73,
#   204,
#   2894,
#   552,
#   1757,
#   505,
#   1617,
#   842,
#   1580,
#   418,
#   7232,
#   364,
#   841,
#   901,
#   4125,
#   564,
#   1061,
#   1,
#   11297],
#  [7233,
#   541,
#   4816,
#   766,
#   71,
#   687,
#   289,
#   1012,
#   34,
#   4816,
#   354,
#   3274,
#   1504,
#   48,
#   4816,
#   188,
#   766,
#   1,
#   11298,
#   1,
#   11299],
#  [216,
#   22,
#   6,
#   1906,
#   648,
#   11300,
#   28,
#   11301,
#   3645,
#   11302,
#   11303,
#   11304,
#   11305,
#   11306,
#   11307,
#   11308,
#   11309,
#   110,
#   1910,
#   1,
#   4817],
#  [11310, 21, 4126, 136, 1091, 300, 7234, 11311, 1, 11312, 1, 11313],
#  [2931, 105, 455, 21, 2471, 53, 4127, 11314, 1, 11315],
#  [203, 101, 10, 289, 273, 1973, 4818, 91, 189, 55, 1, 11316],
#  [661, 807, 989, 1195, 401, 11317, 2721, 1637, 1, 11318],
#  [121,
#   255,
#   425,
#   296,
#   80,
#   2,
#   675,
#   2966,
#   851,
#   621,
#   35,
#   1041,
#   1414,
#   863,
#   143,
#   5,
#   3979,
#   1,
#   11319],
#  [2684, 257, 4819, 299, 2967, 205, 44, 47, 1, 11320],
#  [5739, 1192, 329, 21, 389, 417, 287, 1, 11321, 1, 11322],
#  [1141, 1142, 7075, 465, 2141, 2142, 7074, 763, 3587, 3588, 43, 1, 11323],
#  [5740, 71, 34, 384, 229, 2722, 1976, 1, 11324, 1, 11325],
#  [175, 521, 389, 818, 354, 40, 1, 11326],
#  [1124,
#   87,
#   3,
#   133,
#   83,
#   3662,
#   472,
#   1287,
#   526,
#   3222,
#   3145,
#   115,
#   243,
#   585,
#   303,
#   809,
#   824,
#   1,
#   982,
#   9,
#   24],
#  [732, 562, 1071, 1539, 5, 55, 1491, 1, 11327, 57, 732],
#  [2717, 2081, 270, 199, 922, 1163, 1, 11328, 24, 23, 16],
#  [495,
#   1127,
#   297,
#   40,
#   416,
#   241,
#   483,
#   173,
#   5,
#   791,
#   2450,
#   7235,
#   568,
#   175,
#   521,
#   1295,
#   88,
#   1,
#   11329],
#  [187, 2514, 32, 424, 42, 310, 493, 187, 398, 521, 1977, 425, 438, 1, 11330],
#  [255, 545, 91, 432, 253, 372, 35],
#  [13, 228, 453, 414, 5, 151, 3663, 141, 2, 13, 43, 4820, 70, 1, 11331],
#  [11332,
#   225,
#   5741,
#   446,
#   130,
#   7236,
#   2289,
#   253,
#   214,
#   2968,
#   2969,
#   2870,
#   424,
#   11333,
#   88,
#   11334,
#   2289,
#   253,
#   4821,
#   4128,
#   1467],
#  [387, 7237, 1761, 2462, 87, 1102, 235, 4748, 11335, 440, 3603, 1, 11336],
#  [11337, 176, 2057, 1762, 2276, 597, 2041, 2092, 458, 749, 1, 11338, 1, 11339],
#  [11340, 11341, 1192, 326, 64, 97, 1533, 54, 1, 11342],
#  [7,
#   272,
#   94,
#   925,
#   191,
#   76,
#   985,
#   1125,
#   3664,
#   1312,
#   1294,
#   399,
#   495,
#   5742,
#   3665,
#   60,
#   161,
#   295,
#   1,
#   11343],
#  [105, 556, 833, 1, 11344],
#  [78,
#   175,
#   4822,
#   7,
#   125,
#   1978,
#   1323,
#   718,
#   105,
#   330,
#   33,
#   211,
#   2723,
#   489,
#   98,
#   2,
#   463,
#   3666,
#   266,
#   51,
#   77,
#   15,
#   1850,
#   1,
#   11345,
#   1,
#   11346],
#  [32,
#   2525,
#   291,
#   1763,
#   427,
#   679,
#   333,
#   635,
#   325,
#   104,
#   2139,
#   739,
#   1261,
#   11347,
#   117,
#   109,
#   379,
#   238,
#   988,
#   1,
#   11348],
#  [2724, 65, 420, 257, 85, 5743, 1054, 356, 67, 2724, 784, 1, 11349],
#  [2725, 66, 430, 3275, 121, 10, 4006, 108, 443, 50, 46, 1, 11350],
#  [11351, 4823, 2205, 5744, 2526, 2726, 1, 11352, 25, 16, 11],
#  [525,
#   3667,
#   58,
#   228,
#   1618,
#   22,
#   331,
#   292,
#   18,
#   6,
#   97,
#   337,
#   54,
#   402,
#   30,
#   1,
#   11353,
#   1,
#   11354],
#  [7003, 11355, 313, 1394, 3668, 838, 1854, 1465, 76, 4824, 2970, 1, 11356],
#  [371,
#   135,
#   596,
#   323,
#   49,
#   2350,
#   1534,
#   118,
#   170,
#   149,
#   561,
#   386,
#   1950,
#   3,
#   764,
#   1,
#   11357],
#  [2206,
#   970,
#   56,
#   102,
#   63,
#   775,
#   1855,
#   376,
#   1619,
#   11,
#   745,
#   1215,
#   141,
#   574,
#   944,
#   1167,
#   1,
#   11358],
#  [153,
#   2,
#   649,
#   1325,
#   5745,
#   11359,
#   8,
#   1014,
#   1502,
#   743,
#   69,
#   1540,
#   139,
#   139,
#   1527,
#   7238,
#   385,
#   248,
#   354,
#   69,
#   788,
#   149,
#   170,
#   104,
#   1764,
#   1,
#   11360,
#   1,
#   11361],
#  [3, 328, 141, 159, 1327, 782, 436, 222, 157, 1216, 1, 11362],
#  [154,
#   4,
#   504,
#   4825,
#   1012,
#   140,
#   4826,
#   3669,
#   719,
#   4110,
#   1,
#   11363,
#   2727,
#   1,
#   11364],
#  [3670,
#   31,
#   1044,
#   591,
#   4827,
#   86,
#   167,
#   1188,
#   660,
#   166,
#   100,
#   2164,
#   7239,
#   748,
#   718,
#   108,
#   4129,
#   7240,
#   697,
#   163,
#   3276,
#   22,
#   1,
#   11365,
#   1,
#   11366],
#  [5746, 7241, 182, 1021, 5747, 4828, 75, 2728, 3277, 369, 202, 1, 11367],
#  [155,
#   643,
#   927,
#   5748,
#   555,
#   298,
#   112,
#   1415,
#   11368,
#   102,
#   336,
#   2080,
#   463,
#   1,
#   11369],
#  [13, 228, 1765, 72, 11370, 252, 1092, 795, 1, 11371],
#  [7242,
#   37,
#   397,
#   784,
#   4130,
#   1895,
#   7243,
#   142,
#   4829,
#   2729,
#   187,
#   267,
#   1164,
#   887,
#   483,
#   4130,
#   1575,
#   1,
#   11372],
#  [29, 840, 75, 215, 1140, 834, 12, 11373, 909, 46, 603],
#  [943,
#   2197,
#   223,
#   52,
#   5749,
#   1856,
#   282,
#   1175,
#   1014,
#   11374,
#   223,
#   1620,
#   1325,
#   1,
#   11375],
#  [280,
#   1102,
#   245,
#   523,
#   358,
#   70,
#   1136,
#   2971,
#   2327,
#   56,
#   90,
#   5750,
#   420,
#   257,
#   85,
#   781,
#   2950,
#   1166,
#   1,
#   11376],
#  [216, 1014, 5751],
#  [1454, 104, 76, 408, 698, 13, 41, 35, 513, 735, 5, 1397, 137, 229, 1, 11377],
#  [1387, 68, 93, 431, 1300, 553, 125, 1356, 623, 5752, 1296, 4120],
#  [115,
#   243,
#   164,
#   785,
#   705,
#   2527,
#   1603,
#   713,
#   731,
#   713,
#   1666,
#   2921,
#   71,
#   3212,
#   49,
#   449],
#  [5753, 65, 7244, 5753, 22, 2667, 12, 19, 583, 11, 135, 550, 1, 11378],
#  [7245, 7245, 11379, 194, 1, 11380, 9, 16, 11],
#  [11381, 11382, 588, 5754, 180, 667, 1353, 1338, 11, 38, 735, 2641, 1, 11383],
#  [11384, 34, 712, 21, 17, 18, 6, 158, 334, 1, 11385, 1, 11386],
#  [5755,
#   4,
#   21,
#   3671,
#   11387,
#   488,
#   53,
#   11388,
#   11389,
#   413,
#   5755,
#   52,
#   618,
#   2207,
#   690,
#   1,
#   11390,
#   1,
#   11391],
#  [11392, 282, 251, 155, 11393, 382, 4131, 911, 1, 11394],
#  [4830, 5756, 12, 150, 1528, 2716, 865, 1, 11395, 16, 4, 3],
#  [1977,
#   1979,
#   107,
#   131,
#   17,
#   129,
#   2730,
#   1217,
#   5,
#   1851,
#   449,
#   124,
#   296,
#   1416,
#   82,
#   1,
#   11396],
#  [3672, 464, 3278, 11397, 84, 28, 93, 622, 202, 1, 11398, 1, 11399],
#  [716, 370, 34, 9, 813, 500, 413, 1234, 11400, 7246, 1074, 1, 11401, 57, 338],
#  [132,
#   297,
#   117,
#   109,
#   520,
#   293,
#   937,
#   923,
#   408,
#   36,
#   450,
#   674,
#   126,
#   267,
#   1025,
#   1,
#   11402,
#   1,
#   11403],
#  [1621, 274, 11404, 1766, 20, 2694, 1054, 287, 442, 1, 11405, 1, 11406],
#  [11407, 118, 619, 2, 915, 375, 1, 11408, 24, 16, 11],
#  [220,
#   3547,
#   40,
#   902,
#   213,
#   72,
#   821,
#   17,
#   18,
#   997,
#   120,
#   1969,
#   779,
#   1857,
#   87,
#   60,
#   675,
#   68,
#   152,
#   627,
#   140,
#   526,
#   6,
#   22,
#   1,
#   11409],
#  [6, 572, 180, 663, 200, 190, 42, 239, 56],
#  [2367,
#   180,
#   11410,
#   11411,
#   4831,
#   63,
#   458,
#   1131,
#   7247,
#   1468,
#   416,
#   1160,
#   2301,
#   1,
#   11412],
#  [2, 33, 649, 5757, 8, 1767, 197, 5758, 1246, 33, 66, 430],
#  [11413,
#   63,
#   7248,
#   134,
#   621,
#   335,
#   11414,
#   376,
#   736,
#   2087,
#   4132,
#   851,
#   328,
#   1589,
#   3561,
#   4096,
#   1,
#   11415],
#  [563,
#   162,
#   50,
#   654,
#   46,
#   680,
#   142,
#   7,
#   330,
#   62,
#   15,
#   77,
#   2923,
#   502,
#   4133,
#   1,
#   11416],
#  [663,
#   2648,
#   431,
#   844,
#   2717,
#   575,
#   99,
#   691,
#   2705,
#   1017,
#   1161,
#   4134,
#   130,
#   35,
#   1,
#   11417],
#  [322,
#   468,
#   134,
#   808,
#   146,
#   1026,
#   2731,
#   40,
#   1617,
#   863,
#   4832,
#   5759,
#   42,
#   2138,
#   123,
#   41,
#   35,
#   1,
#   11418],
#  [117, 49, 894, 256, 445, 185, 617, 1823, 5, 2, 378, 357, 4833, 1, 11419],
#  [175,
#   7249,
#   7,
#   56,
#   370,
#   34,
#   1195,
#   105,
#   4834,
#   7250,
#   1514,
#   7,
#   112,
#   1415,
#   83,
#   2,
#   62,
#   15,
#   1,
#   11420,
#   1,
#   11421],
#  [304,
#   85,
#   7251,
#   2368,
#   1580,
#   2937,
#   20,
#   1357,
#   3673,
#   1378,
#   5,
#   272,
#   322,
#   1858,
#   283,
#   1,
#   11422],
#  [752, 651, 120, 270, 2732, 1637, 2320, 1541, 1, 11423, 1, 11424],
#  [1924, 136, 548, 8, 1334, 534, 432, 187, 4135, 2, 98, 2528, 1, 11425],
#  [5, 843, 10, 1503, 548, 126, 17, 18, 582, 7, 37, 1, 11426],
#  [11427, 11428, 90, 97, 1533, 54, 1, 11429],
#  [11430,
#   1123,
#   2164,
#   72,
#   416,
#   4835,
#   509,
#   11431,
#   771,
#   203,
#   5760,
#   11432,
#   359,
#   1,
#   11433,
#   1,
#   11434],
#  [11435, 13, 1843, 7252, 28, 2208, 21, 7253, 2705, 2209, 267, 1, 11436],
#  [51, 2972, 546, 51, 152, 180, 231, 734, 1027, 15, 403, 1409],
#  [11437, 1082, 22, 1542, 39, 123, 165, 192, 426, 46, 3279, 1, 11438],
#  [436, 7060, 12, 6, 457, 1, 11439],
#  [5761, 2529, 323, 1350, 431],
#  [139,
#   1004,
#   787,
#   354,
#   385,
#   248,
#   307,
#   185,
#   840,
#   2339,
#   69,
#   788,
#   4836,
#   9,
#   1,
#   11440],
#  [5762, 725, 1650, 2973, 747, 2153, 5763, 770, 228, 1, 11441, 1, 11442],
#  [7254, 701, 13, 172, 101, 337, 54, 1, 11443],
#  [349,
#   687,
#   133,
#   1406,
#   390,
#   1355,
#   39,
#   46,
#   83,
#   33,
#   14,
#   1313,
#   1487,
#   944,
#   11444,
#   286,
#   532,
#   281,
#   1,
#   11445],
#  [692, 604, 55, 503, 2093, 5764, 461, 3674, 603],
#  [435, 94, 324, 427, 579, 1108, 357, 848, 1597, 4136, 1, 11446],
#  [11447, 329, 21, 334, 17, 18, 38, 19, 740, 128, 27, 1, 11448, 1, 11449],
#  [5765, 1143, 207, 111, 1296, 194, 287, 2210, 1, 11450, 9, 11, 3],
#  [34,
#   2974,
#   5766,
#   73,
#   85,
#   204,
#   22,
#   121,
#   44,
#   1314,
#   7,
#   4137,
#   745,
#   7255,
#   2463,
#   3280,
#   87,
#   1,
#   11451],
#  [589, 877, 477, 557, 100, 82, 655, 1980, 1, 11452],
#  [31,
#   397,
#   304,
#   272,
#   4138,
#   471,
#   1768,
#   21,
#   487,
#   1,
#   4837,
#   58,
#   371,
#   984,
#   31,
#   1,
#   11453,
#   1,
#   11454],
#  [3675,
#   65,
#   4139,
#   21,
#   618,
#   11,
#   7256,
#   1279,
#   1312,
#   605,
#   417,
#   452,
#   7257,
#   315,
#   235,
#   92,
#   480,
#   4059,
#   1048,
#   202,
#   2530,
#   1,
#   11455],
#  [29, 104, 2351, 131, 429, 576, 1100, 644, 2733, 920, 1595, 1, 11456],
#  [36,
#   831,
#   1411,
#   576,
#   687,
#   278,
#   5501,
#   49,
#   100,
#   2637,
#   2975,
#   1285,
#   1141,
#   1142,
#   26,
#   1281,
#   5767,
#   29,
#   100,
#   252,
#   2900,
#   1,
#   11457],
#  [721, 384, 639, 629, 195, 5768, 43, 461, 1, 11458, 1, 11459],
#  [1081, 1839, 5, 261, 3676, 3281, 1528, 669, 1, 11460],
#  [2531, 111, 2352, 7258, 1461, 41, 1417, 2531, 2211, 766, 1, 11461, 1, 11462],
#  [5769,
#   4838,
#   360,
#   148,
#   79,
#   47,
#   44,
#   205,
#   59,
#   583,
#   363,
#   1445,
#   79,
#   219,
#   1,
#   11463],
#  [11464,
#   5770,
#   33,
#   168,
#   3282,
#   5771,
#   7259,
#   7260,
#   11465,
#   1505,
#   11466,
#   50,
#   1,
#   11467],
#  [1307, 2136, 22, 12, 6, 205, 1, 11468],
#  [2491, 3601, 411, 14, 320, 30, 467, 3, 402, 30, 1, 11469],
#  [298,
#   3614,
#   1683,
#   3227,
#   180,
#   3227,
#   2212,
#   1684,
#   11470,
#   11471,
#   1921,
#   11472,
#   11473,
#   11474,
#   513,
#   441,
#   4140,
#   298,
#   241,
#   49,
#   221,
#   1,
#   11475,
#   2194,
#   1,
#   11476,
#   1,
#   11477],
#  [1600,
#   65,
#   1600,
#   1841,
#   304,
#   11478,
#   1349,
#   4839,
#   7261,
#   104,
#   4141,
#   1839,
#   7262,
#   1,
#   11479],
#  [349, 1958, 791, 251, 186, 377, 184],
#  [11480, 111, 2976, 5772, 62, 7263, 1, 11481, 1, 11482],
#  [493, 218, 8, 36, 94, 2213, 605, 129],
#  [850, 28, 850, 1913, 167, 63, 6, 266, 1, 11483],
#  [2977, 466, 1028, 47, 47, 233, 1, 11484],
#  [7264, 7265, 182, 409, 792, 527, 217, 129, 411, 1, 11485],
#  [748, 111, 21, 337, 287, 17, 18, 6, 158, 334, 1, 11486, 1, 11487],
#  [3677, 2452, 11488, 11489, 68, 1144, 2734, 1, 11490, 1, 11491],
#  [11492, 458, 162, 839, 710, 1, 11493, 23, 4, 25],
#  [7266, 110, 1538, 334, 17, 18, 38, 19, 1, 11494, 1, 11495],
#  [37, 194, 1440, 551, 1769, 2735, 1170, 11496, 1, 11497, 9, 16, 3],
#  [94, 1654, 602, 1859, 667, 68, 351, 281, 849, 191, 880, 1, 11498],
#  [1923, 33, 1116, 14, 1, 11499],
#  [2077, 793, 2337, 12, 215, 179, 310, 554, 164, 105, 1, 11500],
#  [5769, 4838, 284, 12, 19, 6, 27, 321, 1, 11501, 3, 24, 16],
#  [268,
#   85,
#   2202,
#   5773,
#   438,
#   5,
#   316,
#   1357,
#   7267,
#   11502,
#   1622,
#   3678,
#   11503,
#   3562,
#   31,
#   1,
#   11504],
#  [4840, 654, 2094, 53, 74, 1145, 1, 11505],
#  [2169,
#   2532,
#   510,
#   7268,
#   195,
#   3274,
#   432,
#   919,
#   1469,
#   253,
#   807,
#   43,
#   283,
#   840,
#   421,
#   7,
#   1,
#   11506],
#  [255,
#   69,
#   1418,
#   239,
#   1386,
#   55,
#   107,
#   141,
#   503,
#   692,
#   604,
#   320,
#   1029,
#   3679,
#   230,
#   88,
#   1,
#   11507],
#  [144,
#   89,
#   1731,
#   157,
#   11508,
#   1527,
#   2937,
#   217,
#   4841,
#   581,
#   1126,
#   1020,
#   1314,
#   70,
#   67,
#   20,
#   1,
#   11509],
#  [1744, 323, 3283, 93],
#  [3284, 3284, 220, 2533, 11510, 2137, 11, 745, 1, 11511, 24, 4, 16],
#  [11512, 3680, 33, 97, 427, 2083, 4142, 503, 1, 11513],
#  [108,
#   466,
#   1981,
#   91,
#   343,
#   55,
#   1431,
#   41,
#   1717,
#   39,
#   76,
#   204,
#   4143,
#   888,
#   146,
#   695,
#   92,
#   1,
#   11514],
#  [7269, 120, 315, 87, 37, 431, 11515, 196, 408, 519, 617, 1, 11516, 1, 11517],
#  [11518,
#   3,
#   397,
#   4144,
#   4145,
#   932,
#   857,
#   581,
#   50,
#   7270,
#   358,
#   52,
#   58,
#   2214,
#   386,
#   1,
#   11519,
#   1,
#   11520],
#  [33, 14, 542, 39, 1, 11521, 2048, 1, 11522],
#  [108, 3, 820, 353, 2, 10, 75, 1, 7271, 1, 11523],
#  [1860,
#   1860,
#   7272,
#   11524,
#   231,
#   861,
#   28,
#   20,
#   12,
#   19,
#   6,
#   27,
#   321,
#   1,
#   11525,
#   9,
#   11,
#   25],
#  [2095,
#   1263,
#   491,
#   570,
#   1129,
#   639,
#   1176,
#   719,
#   1189,
#   2,
#   81,
#   1024,
#   615,
#   1543,
#   390,
#   49,
#   450,
#   1,
#   11526],
#  [4146, 4146, 2334, 1623, 410, 299, 194, 67, 1286, 2736, 1, 11527, 16, 24, 25],
#  [2534, 26, 1544, 13, 3, 568, 12, 6, 47, 1464, 454, 48, 1, 11528],
#  [306,
#   490,
#   76,
#   677,
#   519,
#   7273,
#   437,
#   709,
#   697,
#   275,
#   174,
#   13,
#   161,
#   3285,
#   2535,
#   1,
#   11529],
#  [7274, 7275, 3286, 613, 360, 148, 79, 47, 44, 47, 1, 11530],
#  [2215, 80, 13, 101, 170, 62, 15, 396, 61, 1343, 1751, 10, 1, 11531],
#  [4147, 11532, 1139, 2702, 154, 524, 694, 332, 1069, 2737, 719, 998, 1, 11533],
#  [7276, 11534, 411, 91, 1218, 1, 11535],
#  [175, 934, 1323, 105, 718, 132, 4, 135, 1, 11536, 1, 11537],
#  [7277,
#   111,
#   11538,
#   52,
#   5774,
#   123,
#   123,
#   196,
#   893,
#   575,
#   170,
#   1189,
#   280,
#   104,
#   382,
#   1,
#   11539],
#  [322,
#   2053,
#   1453,
#   857,
#   378,
#   153,
#   36,
#   5526,
#   11540,
#   104,
#   1126,
#   7278,
#   142,
#   770,
#   2053,
#   1,
#   11541],
#  [11542, 11543, 158, 5, 4148, 28, 5718, 207, 1, 11544],
#  [7279,
#   28,
#   3287,
#   2918,
#   123,
#   123,
#   196,
#   7277,
#   3681,
#   156,
#   957,
#   1634,
#   2978,
#   1,
#   11545,
#   1,
#   11546],
#  [1454, 147, 13, 1026, 1397, 229, 1, 11547],
#  [528, 1028, 4, 110, 133, 816, 605, 2, 253, 22, 1, 11548],
#  [2951,
#   2,
#   105,
#   7280,
#   718,
#   175,
#   26,
#   42,
#   247,
#   7281,
#   1074,
#   833,
#   1,
#   11549,
#   1,
#   11550],
#  [63, 4842, 1342, 112, 1861, 101, 482, 5, 3682, 1, 11551, 1, 11552],
#  [7282,
#   11553,
#   1465,
#   102,
#   26,
#   752,
#   3683,
#   258,
#   5775,
#   1087,
#   7282,
#   11554,
#   5776,
#   1,
#   11555,
#   1,
#   11556],
#  [78,
#   213,
#   524,
#   405,
#   154,
#   780,
#   56,
#   3600,
#   468,
#   35,
#   103,
#   1195,
#   1467,
#   463,
#   1,
#   11557],
#  [4,
#   159,
#   83,
#   2712,
#   115,
#   243,
#   585,
#   303,
#   809,
#   824,
#   526,
#   216,
#   2369,
#   3288,
#   2738,
#   1,
#   982,
#   9,
#   24],
#  [151, 194, 124, 69, 1460, 55, 452, 1, 11558],
#  [26, 479, 1608, 739, 238, 988, 131, 4792, 4793, 4794, 1, 11559],
#  ...]

# %%
vocab_size
# Out:
# 65658

# %% [markdown]
# Lakukan padding agar panjang sequences sama

# %%
from keras.preprocessing.sequence import pad_sequences

pad_rev= pad_sequences(encd_rev, maxlen=max_sen_len, padding='post')
pad_rev.shape
# Out:
# (13592, 57)

# %%
pad_rev
# Out:
# array([[  173,    15,   505, ...,     0,     0,     0],
#        [  157,   817,  1892, ...,     0,     0,     0],
#        [ 3515,    21,   740, ...,     0,     0,     0],
#        ...,
#        [  633,  1268,  2212, ...,     0,     0,     0],
#        [ 2422,  3963,   437, ...,     0,     0,     0],
#        [  173, 32829,   164, ...,     0,     0,     0]], dtype=int32)

# %% [markdown]
# **Classification**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.initializers import Constant
from tensorflow.keras.layers import Dense, Embedding, Activation, Flatten

# %%
model = keras.Sequential()
model._name = "lstm"
model.add(layers.Embedding(input_dim=vocab_size,output_dim=embed_dim,input_length=max_sen_len,embeddings_initializer=Constant(embed_matrix)))
model.add(layers.LSTM(max_sen_len))
model.add(layers.BatchNormalization())
model.add(layers.Dense(20)) #sesuai jumlah class
print(model.summary())
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 57, 100)           6565800
#
#  lstm (LSTM)                 (None, 57)                36024
#
#  batch_normalization (Batch  (None, 57)                228
#  Normalization)
#
#  dense (Dense)               (None, 20)                1160
#
# =================================================================
# Total params: 6603212 (25.19 MB)
# Trainable params: 6603098 (25.19 MB)
# Non-trainable params: 114 (456.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Optimizer SGD

# %%
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer='sgd',
    metrics=["accuracy"]
)

# %%
model.fit(pad_rev, y_train, batch_size=64, epochs=20)
# Out:
# Epoch 1/20
# 213/213 [==============================] - 24s 103ms/step - loss: 2.8872 - accuracy: 0.2058
# Epoch 2/20
# 213/213 [==============================] - 18s 86ms/step - loss: 2.7387 - accuracy: 0.2087
# Epoch 3/20
# 213/213 [==============================] - 18s 84ms/step - loss: 2.6717 - accuracy: 0.2095
# Epoch 4/20
# 213/213 [==============================] - 18s 86ms/step - loss: 2.6395 - accuracy: 0.2106
# Epoch 5/20
# 213/213 [==============================] - 23s 107ms/step - loss: 2.4051 - accuracy: 0.2568
# Epoch 6/20
# 213/213 [==============================] - 19s 90ms/step - loss: 2.1783 - accuracy: 0.3106
# Epoch 7/20
# 213/213 [==============================] - 24s 114ms/step - loss: 2.1112 - accuracy: 0.3209
# Epoch 8/20
# 213/213 [==============================] - 20s 93ms/step - loss: 2.0591 - accuracy: 0.3256
# Epoch 9/20
# 213/213 [==============================] - 19s 88ms/step - loss: 2.0167 - accuracy: 0.3381
# Epoch 10/20
# 213/213 [==============================] - 19s 92ms/step - loss: 1.9904 - accuracy: 0.3479
# Epoch 11/20
# 213/213 [==============================] - 22s 104ms/step - loss: 1.9689 - accuracy: 0.3497
# Epoch 12/20
# 213/213 [==============================] - 19s 89ms/step - loss: 1.9476 - accuracy: 0.3561
# Epoch 13/20
# 213/213 [==============================] - 18s 86ms/step - loss: 1.8911 - accuracy: 0.3785
# Epoch 14/20
# 213/213 [==============================] - 19s 90ms/step - loss: 1.8041 - accuracy: 0.4367
# Epoch 15/20
# 213/213 [==============================] - 19s 87ms/step - loss: 1.7488 - accuracy: 0.4707
# Epoch 16/20
# 213/213 [==============================] - 20s 95ms/step - loss: 1.6869 - accuracy: 0.4954
# Epoch 17/20
# 213/213 [==============================] - 20s 95ms/step - loss: 1.6400 - accuracy: 0.5110
# Epoch 18/20
# 213/213 [==============================] - 18s 86ms/step - loss: 1.6038 - accuracy: 0.5193
# Epoch 19/20
# 213/213 [==============================] - 19s 91ms/step - loss: 1.5354 - accuracy: 0.5361
# Epoch 20/20
# 213/213 [==============================] - 20s 94ms/step - loss: 1.4747 - accuracy: 0.5499

# %%
model2 = keras.Sequential()
model2._name = "lstm"
model2.add(layers.Embedding(input_dim=vocab_size,output_dim=embed_dim,input_length=max_sen_len,embeddings_initializer=Constant(embed_matrix)))
model2.add(layers.LSTM(max_sen_len))
model2.add(layers.BatchNormalization())
model2.add(layers.Dense(20)) #sesuai jumlah class
print(model2.summary())
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 57, 100)           6565800
#
#  lstm_1 (LSTM)               (None, 57)                36024
#
#  batch_normalization_1 (Bat  (None, 57)                228
#  chNormalization)
#
#  dense_1 (Dense)             (None, 20)                1160
#
# =================================================================
# Total params: 6603212 (25.19 MB)
# Trainable params: 6603098 (25.19 MB)
# Non-trainable params: 114 (456.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Optimizer Adam

# %%
model2.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer='adam',
    metrics=["accuracy"]
)

# %%
model2.fit(pad_rev, y_train, batch_size=64, epochs=15)
# Out:
# Epoch 1/15
# 213/213 [==============================] - 40s 170ms/step - loss: 2.2369 - accuracy: 0.3410
# Epoch 2/15
# 213/213 [==============================] - 30s 141ms/step - loss: 1.5906 - accuracy: 0.5175
# Epoch 3/15
# 213/213 [==============================] - 32s 150ms/step - loss: 1.0397 - accuracy: 0.6916
# Epoch 4/15
# 213/213 [==============================] - 37s 173ms/step - loss: 0.7033 - accuracy: 0.7869
# Epoch 5/15
# 213/213 [==============================] - 30s 140ms/step - loss: 0.4769 - accuracy: 0.8563
# Epoch 6/15
# 213/213 [==============================] - 30s 141ms/step - loss: 0.3073 - accuracy: 0.9106
# Epoch 7/15
# 213/213 [==============================] - 29s 138ms/step - loss: 0.2175 - accuracy: 0.9374
# Epoch 8/15
# 213/213 [==============================] - 29s 138ms/step - loss: 0.1354 - accuracy: 0.9655
# Epoch 9/15
# 213/213 [==============================] - 28s 132ms/step - loss: 0.1171 - accuracy: 0.9684
# Epoch 10/15
# 213/213 [==============================] - 29s 136ms/step - loss: 0.1069 - accuracy: 0.9736
# Epoch 11/15
# 213/213 [==============================] - 31s 146ms/step - loss: 0.1059 - accuracy: 0.9720
# Epoch 12/15
# 213/213 [==============================] - 30s 140ms/step - loss: 0.0635 - accuracy: 0.9843
# Epoch 13/15
# 213/213 [==============================] - 29s 138ms/step - loss: 0.0592 - accuracy: 0.9859
# Epoch 14/15
# 213/213 [==============================] - 30s 139ms/step - loss: 0.0616 - accuracy: 0.9851
# Epoch 15/15
# 213/213 [==============================] - 29s 137ms/step - loss: 0.1034 - accuracy: 0.9734

# %% [markdown]
# **Testing**

# %% [markdown]
# **Preparing  Test Data for Embedding Layer**

# %%
# Tokenize the words in the testing text data
word_token_test =[word_tokenize(i) for i in x_test]

# %%
word_token_test[0]
# Out:
# ['the',
#  'nonprofit',
#  'organization',
#  'pursuit',
#  'has',
#  'sold',
#  'a',
#  'million',
#  'bond',
#  'to',
#  'finance',
#  'its',
#  'job',
#  'training',
#  'program',
#  'now',
#  'it',
#  'needs',
#  'participants',
#  'to',
#  'pay',
#  'down',
#  'the',
#  'debt',
#  'with',
#  'their',
#  'future',
#  'earnings',
#  't',
#  'co',
#  'bakphufj']

# %%
# Remove stopwords from each sublist in word_token_test
filtered_tokens_test = [[word for word in sublist if word not in stop_words] for sublist in word_token_test]
# Display the first sublist of filtered tokens after removing stopwords
print(filtered_tokens_test[0])
# Out:
# ['nonprofit', 'organization', 'pursuit', 'sold', 'million', 'bond', 'finance', 'job', 'training', 'program', 'needs', 'participants', 'pay', 'debt', 'future', 'earnings', 'co', 'bakphufj']

# %%
lemmatized_tokens_test = [[lemmatizer.lemmatize(word) for word in sublist] for sublist in filtered_tokens_test]

# %%
# tok.fit_on_texts(lemmatized_tokens_test) #tidak perlu di fit lagi
encd_rev_test = tok.texts_to_sequences(lemmatized_tokens_test)

# %%
from keras.preprocessing.sequence import pad_sequences

pad_rev_test= pad_sequences(encd_rev_test, maxlen=max_sen_len, padding='post')
pad_rev_test.shape
# Out:
# (3398, 57)

# %%
pad_rev_test
# Out:
# array([[ 3672,  1886,  4236, ...,     0,     0,     0],
#        [  248,  1291,   405, ...,     0,     0,     0],
#        [  804,    16,   612, ...,     0,     0,     0],
#        ...,
#        [32436,  1796,   624, ...,     0,     0,     0],
#        [  228,    21,     5, ...,     0,     0,     0],
#        [  176,   364,   289, ...,     0,     0,     0]], dtype=int32)

# %%
test_predict=model2.predict(pad_rev_test)
classe_test=np.argmax(test_predict,axis=1)
# Out:
# 107/107 [==============================] - 2s 11ms/step

# %%
classe_test
# Out:
# array([ 3,  3, 18, ..., 18, 18,  7])

# %%
print('\nClassification Report\n')
print(classification_report(y_test, classe_test))
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.17      0.49      0.25        51
#            1       0.81      0.80      0.80       167
#            2       0.78      0.60      0.68       709
#            3       0.48      0.50      0.49        64
#            4       0.81      0.92      0.86        72
#            5       0.92      0.92      0.92       198
#            6       0.81      0.85      0.83       105
#            7       0.74      0.62      0.68       125
#            8       0.49      0.55      0.51        33
#            9       0.42      0.70      0.53       311
#           10       0.27      0.29      0.28        14
#           11       0.06      0.56      0.11         9
#           12       0.98      0.63      0.77        97
#           13       0.67      0.19      0.30        94
#           14       0.74      0.80      0.77       364
#           15       0.86      0.48      0.62       100
#           16       0.88      0.82      0.85       197
#           17       0.65      0.54      0.59        99
#           18       0.74      0.75      0.75       424
#           19       0.60      0.38      0.46       165
#
#     accuracy                           0.67      3398
#    macro avg       0.64      0.62      0.60      3398
# weighted avg       0.72      0.67      0.68      3398

# %% [markdown]
# Arsitektur untuk model yang dipakai yaitu:
# - 1 layer embedding
# - 1 layer LSTM
# - 1 layer batch normalization
# - 1 layer Dende
#
#
# Accuracy pada data train menggunakan optimizer sgd didapat sebesar 0.59.
#
# Accuracy pada data train menggunakan optimizer Adam didapat sebesar 0.98.
#
# Untuk model test saya menggunakan optimizer yang memiliki accuracy tertinggi, yaitu Adam. Dimana angka tersebut (98%) sangat baik dalam memprediksi kata pada data train
#
# Dan pada test data didapatkan accuracy keseluruhan sebesar 0.67
#
# Performa model cukup baik untuk beberapa class, misalnya pada kelas 5, 6, 16 yang memiliki precision & recall yang tinggi.
#
# Namun ada beberapa yang buruk, seperti pada kelas 0, 3, 9, 11, 13
#
#
#
#
# Untuk menambah performa model dapat dilakukan beberapa hal:
#
# Memperbanyak jumlah epoch, menambah design arsitektur, melakukan Regularization
